# %% [markdown]
# # **To use Tensorflow Version 1**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# # **Mount the Google Drive**

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#define your folder or create one in your google drive
root_path = '/content/drive/My Drive/ex_140/'
os.chdir(root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Record the time execution per code section**

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=e3f6aa3fc24822d03641c0046e22518fa464af877c7a88bf1185b64bd11e24ba
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %% [markdown]
# #**Ngrok : Running tensorboard inside Google Colab**

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# Out:
# --2020-04-11 08:25:35--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 34.192.123.246, 34.192.78.186, 54.174.156.76, ...
# Connecting to bin.equinox.io (bin.equinox.io)|34.192.123.246|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  5.16MB/s    in 2.5s
#
# 2020-04-11 08:25:39 (5.16 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok
# time: 10.8 s

# %%
import os
LOG_DIR = '/content/drive/My Drive/ex_20/log'
#LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))
# Out:
# time: 58 ms

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
get_ipython().system_raw('./ngrok http 6006 &')
# Out:
# time: 53.3 ms

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"
# Out:
# https://cba644dd.ngrok.io
# time: 4.53 s

# %% [markdown]
# # **Data Preparation**

# %%
# Downloading cifar-10-python files
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -xvzf cifar-10-python.tar.gz
# Out:
# --2020-04-17 10:31:13--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz.1’
#
# cifar-10-python.tar 100%[===================>] 162.60M  49.9MB/s    in 3.6s
#
# 2020-04-17 10:31:17 (45.0 MB/s) - ‘cifar-10-python.tar.gz.1’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# time: 13.6 s

# %%
# Provided on https://www.cs.toronto.edu/~kriz/cifar.html 
# Given a "pickled" file, returns a dictionary containing the image data
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
# time: 2.16 ms

# %% [markdown]
# The training data is stored in four files, which are read and merged.

# %%
import numpy as np

for file_no in range(4):
    # Obtain data dictionary from each file
    filename = "cifar-10-batches-py/data_batch_" + str(file_no + 1)
    image_batch = unpickle(filename)
    # First file, create numpy arrays containing data & labels
    if file_no == 0:
        # Reshape to 32x32 image with 3 channels (RGB), which is made to be the last axes
        image_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_labels = image_batch[b'labels']
    else: # Concatenate to one file
        new_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_data = np.concatenate([image_data, new_data])
        image_labels = np.concatenate([image_labels, image_batch[b'labels']])

print("Training data shape: ",image_data.shape)

# Create numpy array containing test data
test_batch = unpickle("cifar-10-batches-py/test_batch")
test_data = test_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
test_labels = test_batch[b'labels']

# Obtain label names from the meta data
label_names = unpickle("cifar-10-batches-py/batches.meta")[b'label_names']
label_names = [l.decode('UTF-8') for l in label_names]
# Out:
# Training data shape:  (40000, 32, 32, 3)
# time: 348 ms

# %% [markdown]
# ### **Image samples**

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10,9,figsize=(7,9))
plt.subplots_adjust(wspace=0.01, hspace=0.01)

for image_type in range(10):
    # Obtain indices of images in each group
    group = np.argwhere(image_labels == image_type)
    # Display 1st 5 images from each group
    for col in range(8):
        n = group[col][0]
        img_rgb = image_data[n]
        axes[image_type,col].imshow(img_rgb)
        axes[image_type,col].axis('off')
    # Display image labels    
    axes[image_type,8].axis('off')    
    axes[image_type,8].text(0.1,0.5,label_names[image_type], fontsize=12)

plt.show()
# Out:
# time: 2.32 s

# %% [markdown]
# ## Model Building
# ### Hyperparameters

# %%
import tensorflow as tf
# Fixed hyperparameters
height = 32
width = 32
channels = 3
outputs = 10

n_epochs = 500
# number of epochs to try to get a lower loss before stopping
early_stop_rounds = 4

# number of iterations, within epoch, to do an accuracy check
acc_check = 25

# Variable Hyperparameters
hyperparam_range = {'filter1':[16, 32, 64, 96],
                    'kernelsize_1':[3, 4, 5],
                    'filter2':[48, 64, 96, 128],
                    'kernelsize_2':[3, 4, 5],
                    'filter3':[64, 96, 128],
                    'kernelsize_3':[3, 4, 5],
                    'hidden_1':[60, 100, 125],
                    'hidden_2':[80, 100, 125],
                    'activation':['relu', 'lrelu', 'elu'],
                    'learning_rate':[0.001, 0.0015, 0.002, 0.003],
                    'batch_size':[32, 64, 128],
                    'momentum':[0.9, 0.95, 0.99],
                    'p_reduct':[0],
                    'optimizer':['adam', 'rmsprop', 'nesterov']
                   }

# Calculate the number of hyperparamter grid points
first_item = True
for key,values in hyperparam_range.items():
    count = len(values)
    if first_item:
        display = str(count)
        total = count
        first_item = False
    else:
        display = display + ' X ' + str(count)
        total *= count

print('The total number of possible hyperparameter combinations is ' + display + ' = ' + "{:,}".format(total))
# Out:
# The total number of possible hyperparameter combinations is 4 X 3 X 4 X 3 X 3 X 3 X 3 X 3 X 3 X 4 X 3 X 3 X 1 X 3 = 3,779,136
# time: 26.9 ms

# %% [markdown]
# ### Convolutional Layer

# %%
def conv_layer(tensor_input, layer_no, filters, ksize, kstride, activation_unit, momentum, phase_train):
    # convolutional layer with batch normalisation and max pooling
    with tf.name_scope("conv_layer" + str(layer_no)):
        conv = tf.layers.conv2d(
            tensor_input,
            filters=filters,
            kernel_size=ksize,
            strides=[kstride,kstride],
            padding="SAME",
            activation=None
        )

        conv_bn = tf.layers.batch_normalization(
            inputs=conv,
            axis=-1,
            momentum=0.9,
            epsilon=0.001,
            center=True,
            scale=True,
            trainable=True,
            training = phase_train
        )

        #apply activation unit
        conv_bn_relu =  activation_unit(conv_bn)

        max_pool = tf.nn.max_pool(
            conv_bn_relu,
            ksize=[1,2,2,1],
            strides=[1,2,2,1],
            padding="VALID"
        )
            
        dropout = tf.layers.dropout(
            max_pool,
            training = phase_train
        )
            
        return dropout
# Out:
# time: 14.1 ms

# %% [markdown]
# ### Graph defintion

# %%
def build_graph(hyperparam):
    # Retrieve hyperparamaters from dictionary   
    filter1 = hyperparam['filter1']
    kernelsize_1 = hyperparam['kernelsize_1']
    filter2 = hyperparam['filter2']
    kernelsize_2 = hyperparam['kernelsize_2']
    filter3 = hyperparam['filter3']
    kernelsize_3 = hyperparam['kernelsize_3']
    hidden_1 = hyperparam['hidden_1']
    hidden_2 = hyperparam['hidden_2']
    activation = hyperparam['activation']
    learning_rate = hyperparam['learning_rate']
    momentum = hyperparam['momentum']
    p_reduct =  hyperparam['p_reduct']
    optimizer_method = hyperparam['optimizer']
    
    patch_height = height - 2 * p_reduct
    patch_width = width - 2 * p_reduct
    
    if activation == 'elu':
        activation_unit = tf.nn.elu
    elif activation == 'lrelu':
        activation_unit = tf.nn.leaky_relu
    else:    
        activation_unit = tf.nn.relu
        
    graph = tf.Graph()
    with graph.as_default():
        X = tf.placeholder(shape=(None, patch_height, patch_width, channels), dtype=tf.float32)
        y = tf.placeholder(shape=(None), dtype=tf.int32)
        phase_train = tf.placeholder(tf.bool, name='phase_train')

        # 1st convolutional layer
        conv1 = conv_layer(X, 1, filter1, kernelsize_1, 2, activation_unit, momentum, phase_train)
        
        # 2nd convolutional layer
        conv2 = conv_layer(conv1, 2, filter2, kernelsize_2, 1, activation_unit, momentum, phase_train)
        
        # 3rd cnn
        conv3 = conv_layer(conv2, 3, filter3, kernelsize_3, 1, activation_unit, momentum, phase_train)
        
        # 1st fully connected (dense) layer
        fully_conn1 = tf.layers.dense(conv3, hidden_1, name="fully_conn1", activation=activation_unit)
        flat = tf.contrib.layers.flatten(fully_conn1)
        
        # 2nd fully connected layer
        fully_conn2 = tf.layers.dense(flat, hidden_2, name="fully_conn2", activation=activation_unit)
        
        # Output layer (no activation function, as this is built into cross-entropy)
        logits = tf.layers.dense(fully_conn2, outputs, name="logits")

        # Cross Entropy Loss
        with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
            loss = tf.reduce_mean(xentropy, name="loss")

        # Training    
        with tf.name_scope("train"):
            if optimizer_method == 'rmsprop':
                    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, momentum=0.9)
            elif optimizer_method == 'nesterov':
                    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov = True)
            else:    
                optimizer = tf.train.AdamOptimizer(learning_rate)
            training_op = optimizer.minimize(loss)
    
        # Initialization & Saver
        init = tf.global_variables_initializer()
        saver = tf.train.Saver() 
        
        return graph, X, y, phase_train, logits, loss, training_op, init, saver
# Out:
# time: 112 ms

# %% [markdown]
# ### Model Training

# %%
# Function to train model, returns minimised loss
def train_model(batch_size = 128):
    training_size = image_data.shape[0]
    no_batches = training_size // batch_size
    
    with graph.as_default():
        # Ensure batch normalisation gets updated
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)    
        # Add Evaluation metrics
        with tf.name_scope("evaluation"):
            correct = tf.nn.in_top_k(logits, y, 1)
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            acc_summary = tf.summary.scalar('Accuracy', accuracy)
            loss_summary = tf.summary.scalar('Loss', loss)
            
    # Initialise best loss for early stopping
    best_loss = 1e9
    best_acc = 1e9
    early_stopping = False
    
    # Run training
    with tf.Session(graph=graph) as sess:                     
        init.run()
        epoch = 0
        early_stop_count = 0
        # Initialise training accuracy sum
        sum_acc_train = 0.0
        sum_loss_train = 0.0
        count_train = 0
        while (epoch < n_epochs) and (not early_stopping):
            epoch += 1
            # Shuffle training data
            p = np.random.permutation(training_size)
            image_data_shuffle = image_data_patch[p]
            image_labels_shuffle = image_labels[p]
            for iteration in range(no_batches-1):
                # Train on mini-batch
                X_batch = image_data_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                y_batch = image_labels_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                sess.run([training_op, extra_update_ops], feed_dict={X: X_batch, y: y_batch, phase_train: True})
                # Evaluate model on current mini-batch
                if (iteration % acc_check == 0):
                    acc_train, loss_train = sess.run([accuracy, loss], feed_dict={X: X_batch,
                                                                                   y: y_batch,
                                                                                   phase_train: True})
                    # Update training average for current epoch
                    sum_acc_train += acc_train
                    sum_loss_train += loss_train
                    count_train += 1
                    mean_acc_train = sum_acc_train / count_train
                    mean_loss_train = sum_loss_train / count_train
                    print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train, end='\r')
                     
            # Print mean Train accuracy        
            print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train)
            train_summary = tf.Summary()
            train_summary.value.add(tag='eval/Accuracy', simple_value=mean_acc_train)
            train_summary.value.add(tag='eval/Loss', simple_value=mean_loss_train)
            file_writer_train.add_summary(train_summary, epoch)
            
            # Evaluate model on test data every epoch
            acc_test, loss_test, summary_str_acc_test, summary_str_loss_test = sess.run([accuracy, loss,
                                                                                         acc_summary,
                                                                                         loss_summary],
                                                                                        feed_dict={X: test_data_patch,
                                                                                                   y: test_labels,
                                                                                                   phase_train: False})
            # Check for mininimum loss
            if loss_test < best_loss:
                # Reset early stopping best loss and count
                best_loss = loss_test
                best_acc = acc_test
                best_train_acc = mean_acc_train
                best_train_loss = mean_loss_train
                early_stop_count = 0
                # Save model
                save_path = saver.save(sess, ckptfile)
            else:
                # Increment early stopping count
                early_stop_count += 1
            # Check if sufficient rounds (epochs) have passed without improvement
            if early_stop_count  > early_stop_rounds:
                # Flag early stopping, so training loop will stop
                early_stopping = True
                print("Early stopping, best loss: ", best_loss)
            else:    
                # Record and display test loss and accuracy
                file_writer_test.add_summary(summary_str_acc_test, epoch)
                file_writer_test.add_summary(summary_str_loss_test, epoch)
                print(epoch, "Test accuracy:", acc_test, " Test loss:", loss_test)
            
        # Return Best Loss obtaned and number of epochs
        return best_loss, best_acc, best_train_acc, best_train_loss, epoch
# Out:
# time: 101 ms

# %% [markdown]
# ### Random Hyperparameter Selection and Evaluation

# %%
import pandas as pd

import random
random.seed(261001)

import os.path
if not os.path.exists('./log'):
    os.makedirs('./log')
if not os.path.exists('./graphs'):
    os.makedirs('./graphs')
    
if(os.path.isfile('./log/model_hyperparam.csv')):
    hyperparam_df = pd.read_csv('./log/model_hyperparam.csv')
    new_results_file = False
else:
    new_results_file = True

# Random Model search
for n in range(140):
    # Create log directory using current timestamp
    from datetime import datetime
    now = datetime.now().strftime("%Y%m%dT%H%M%S")
    root_logdir = "./log"
    root_graphdir = "./graphs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    graphdir = "{}/run-{}/".format(root_graphdir, now)
    #root_modeldir = "./model"
    graphfile = graphdir
    ckptfile = graphdir + "checkpoint.ckpt"

    # Note that the graph is not written using same filewriter as the logging data.
    # This allows the logs to be viewed during training before the filewriter is closed
    file_writer_train = tf.summary.FileWriter(logdir + '/train')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    
    # tensorboard --logdir e:\Programming\TensorFlow\CIFAR-10\log
    # The command must be executed from same drive (E:) as the logdir

    tf.reset_default_graph()

    hyperparam_dict = {key:random.choice(values) for (key,values) in hyperparam_range.items()}
    print("Training Model with following hyperparameters:")
    print(hyperparam_dict)

    # Obtain graph and nodes required for training
    graph, X, y, phase_train, logits, loss, training_op, init, saver = build_graph(hyperparam = hyperparam_dict)
    
    # Write graph to file and close to avoid TensorBoard conflict
    file_writer_graph = tf.summary.FileWriter(graphfile, graph)
    file_writer_graph.close()

    # Extract image patches
    p_reduct =  hyperparam_dict['p_reduct']
    if p_reduct == 0:
        image_data_patch = image_data
        test_data_patch = test_data
    else:
        image_data_patch = image_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
        test_data_patch = test_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
    
    # Train the model
    best_loss, best_acc, best_train_acc, best_train_loss, no_epochs = train_model(batch_size = hyperparam_dict['batch_size'])
    
    # Add results to dictionary
    hyperparam_dict['best_loss'] = best_loss
    hyperparam_dict['best_acc'] = best_acc
    hyperparam_dict['best_train_acc'] = best_train_acc
    hyperparam_dict['best_train_loss'] = best_train_loss
    hyperparam_dict['no_epochs'] = no_epochs
    hyperparam_dict['logdir'] = logdir
    
    # Add results to dataframe
    if new_results_file:
        hyperparam_df = pd.DataFrame(hyperparam_dict, index=[0])
        new_results_file = False
    else:
        hyperparam_df = hyperparam_df.append(hyperparam_dict, ignore_index=True)
        
    # Write results file (don't wait until end, as next model may be interrupted)
    hyperparam_df.to_csv('./log/modelhyperparameter_140.csv', index=False)

    # Close filewriters
    file_writer_train.close()
    file_writer_test.close()
    
    # NOTE - From this point onwards there are only training logs.
    # Results and Conclusion are in a seperate notebook
# Out:
# Streaming output truncated to the last 5000 lines.
# 8 623 Train accuracy: 0.3737692384980619  Train loss: 1.6567064619064331
# 8 Test accuracy: 0.4285  Test loss: 1.5179105
# 9 623 Train accuracy: 0.3831794953842958  Train loss: 1.6336538961198594
# 9 Test accuracy: 0.4384  Test loss: 1.5668961
# 10 623 Train accuracy: 0.392123085424304  Train loss: 1.6096542253494264
# 10 Test accuracy: 0.5162  Test loss: 1.329573
# 11 623 Train accuracy: 0.399664344611493  Train loss: 1.5948645201596348
# 11 Test accuracy: 0.4277  Test loss: 1.5618838
# 12 623 Train accuracy: 0.4077948812022805  Train loss: 1.5783625678221385
# 12 Test accuracy: 0.5094  Test loss: 1.3585979
# 13 623 Train accuracy: 0.4160473473599324  Train loss: 1.5582571143370407
# 13 Test accuracy: 0.4687  Test loss: 1.4562069
# 14 623 Train accuracy: 0.42259341711444515  Train loss: 1.5441274537358964
# 14 Test accuracy: 0.4973  Test loss: 1.3665671
# 15 623 Train accuracy: 0.4288820624649525  Train loss: 1.5291322088241577
# Early stopping, best loss:  1.329573
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.2600000071525574  Train loss: 1.966409924030304
# 1 Test accuracy: 0.3032  Test loss: 1.853442
# 2 1248 Train accuracy: 0.30909091770648955  Train loss: 1.8452326190471648
# 2 Test accuracy: 0.3797  Test loss: 1.6997883
# 3 1248 Train accuracy: 0.33252526183923087  Train loss: 1.7747692124048868
# 3 Test accuracy: 0.3724  Test loss: 1.7238672
# 4 1248 Train accuracy: 0.3510606150329113  Train loss: 1.7267399746179581
# 4 Test accuracy: 0.4154  Test loss: 1.5901544
# 5 1248 Train accuracy: 0.368727281332016  Train loss: 1.688162187576294
# 5 Test accuracy: 0.3966  Test loss: 1.6559854
# 6 1248 Train accuracy: 0.3826262710491816  Train loss: 1.65182013630867
# 6 Test accuracy: 0.3902  Test loss: 1.6482584
# 7 1248 Train accuracy: 0.3951515236071178  Train loss: 1.6255237981251307
# 7 Test accuracy: 0.4536  Test loss: 1.4700495
# 8 1248 Train accuracy: 0.4037121294438839  Train loss: 1.6034374913573266
# 8 Test accuracy: 0.447  Test loss: 1.515182
# 9 1248 Train accuracy: 0.41306398113568626  Train loss: 1.5863038905461628
# 9 Test accuracy: 0.4851  Test loss: 1.4121495
# 10 1248 Train accuracy: 0.42181818950176236  Train loss: 1.56284170794487
# 10 Test accuracy: 0.4623  Test loss: 1.5030682
# 11 1248 Train accuracy: 0.42953168803995306  Train loss: 1.545269545208324
# 11 Test accuracy: 0.4916  Test loss: 1.4622467
# 12 1248 Train accuracy: 0.4374747551480929  Train loss: 1.5279768244425456
# 12 Test accuracy: 0.4319  Test loss: 1.5940819
# 13 1248 Train accuracy: 0.4436363712182412  Train loss: 1.5132659967129047
# 13 Test accuracy: 0.4933  Test loss: 1.4412271
# 14 1248 Train accuracy: 0.44978355718510493  Train loss: 1.499138982636588
# 14 Test accuracy: 0.5281  Test loss: 1.3246815
# 15 1248 Train accuracy: 0.45575758298238117  Train loss: 1.4871474170684815
# 15 Test accuracy: 0.5555  Test loss: 1.2423599
# 16 1248 Train accuracy: 0.4607954617217183  Train loss: 1.4720020962506533
# 16 Test accuracy: 0.5285  Test loss: 1.3069884
# 17 1248 Train accuracy: 0.4649197931500042  Train loss: 1.4623864436149596
# 17 Test accuracy: 0.533  Test loss: 1.3391087
# 18 1248 Train accuracy: 0.4704040473037296  Train loss: 1.4506601774692536
# 18 Test accuracy: 0.5278  Test loss: 1.3210196
# 19 1248 Train accuracy: 0.4745773593061849  Train loss: 1.4402723997517637
# 19 Test accuracy: 0.4801  Test loss: 1.4332035
# 20 1248 Train accuracy: 0.4789090975821018  Train loss: 1.4290519265532493
# 20 Test accuracy: 0.5563  Test loss: 1.2291905
# 21 1248 Train accuracy: 0.4834920700107302  Train loss: 1.4194604959942045
# 21 Test accuracy: 0.5627  Test loss: 1.201416
# 22 1248 Train accuracy: 0.48730028187686747  Train loss: 1.4095131948319348
# 22 Test accuracy: 0.4691  Test loss: 1.493957
# 23 1248 Train accuracy: 0.49011858336303543  Train loss: 1.4012247162798177
# 23 Test accuracy: 0.5815  Test loss: 1.1596131
# 24 1248 Train accuracy: 0.49318182453513143  Train loss: 1.3921787291268508
# 24 Test accuracy: 0.5696  Test loss: 1.1976829
# 25 1248 Train accuracy: 0.49597576401233673  Train loss: 1.3846951926708222
# 25 Test accuracy: 0.5659  Test loss: 1.1741971
# 26 1248 Train accuracy: 0.4997902162946187  Train loss: 1.3741945434533633
# 26 Test accuracy: 0.6268  Test loss: 1.0420254
# 27 1248 Train accuracy: 0.502558929125468  Train loss: 1.3670772663310722
# 27 Test accuracy: 0.5724  Test loss: 1.1949356
# 28 1248 Train accuracy: 0.505259746823992  Train loss: 1.3603191686528069
# 28 Test accuracy: 0.571  Test loss: 1.1934401
# 29 1248 Train accuracy: 0.5080668821417053  Train loss: 1.3533621624009362
# 29 Test accuracy: 0.6293  Test loss: 1.0459586
# 30 1248 Train accuracy: 0.5112525318264961  Train loss: 1.3456366119384766
# 30 Test accuracy: 0.6114  Test loss: 1.0806055
# 31 1248 Train accuracy: 0.5147018637580256  Train loss: 1.33728670885486
# 31 Test accuracy: 0.6387  Test loss: 1.0074008
# 32 1248 Train accuracy: 0.5167613699659706  Train loss: 1.331375036202371
# 32 Test accuracy: 0.6402  Test loss: 1.0015737
# 33 1248 Train accuracy: 0.5197061586921865  Train loss: 1.3234911343184383
# 33 Test accuracy: 0.6418  Test loss: 0.98758245
# 34 1248 Train accuracy: 0.5215686336860937  Train loss: 1.3182820542069043
# 34 Test accuracy: 0.6178  Test loss: 1.0622301
# 35 1248 Train accuracy: 0.5235844218220029  Train loss: 1.312493418931961
# 35 Test accuracy: 0.6466  Test loss: 0.9858175
# 36 1248 Train accuracy: 0.5259764371646776  Train loss: 1.305636810991499
# 36 Test accuracy: 0.635  Test loss: 1.0191694
# 37 1248 Train accuracy: 0.5282227743799622  Train loss: 1.2998595486138318
# 37 Test accuracy: 0.6567  Test loss: 0.9584398
# 38 1248 Train accuracy: 0.5303030363352675  Train loss: 1.2941842524001472
# 38 Test accuracy: 0.6593  Test loss: 0.96256834
# 39 1248 Train accuracy: 0.5323698582863197  Train loss: 1.2889249052145542
# 39 Test accuracy: 0.6501  Test loss: 0.9813622
# 40 1248 Train accuracy: 0.53430303619802  Train loss: 1.2840429182946682
# 40 Test accuracy: 0.603  Test loss: 1.1068237
# 41 1248 Train accuracy: 0.536023656958487  Train loss: 1.2789002687465854
# 41 Test accuracy: 0.6315  Test loss: 1.029191
# 42 1248 Train accuracy: 0.5383838441542217  Train loss: 1.2727231723353976
# 42 Test accuracy: 0.6628  Test loss: 0.9571654
# 43 1248 Train accuracy: 0.540140950042148  Train loss: 1.2680968709601912
# 43 Test accuracy: 0.6347  Test loss: 1.0238732
# 44 1248 Train accuracy: 0.5420385732704943  Train loss: 1.263171961659735
# 44 Test accuracy: 0.6682  Test loss: 0.9344709
# 45 1248 Train accuracy: 0.5438249216079712  Train loss: 1.2585731700261433
# 45 Test accuracy: 0.6752  Test loss: 0.9161543
# 46 1248 Train accuracy: 0.5456258291265239  Train loss: 1.2538721821100816
# 46 Test accuracy: 0.6782  Test loss: 0.90102756
# 47 1248 Train accuracy: 0.5475822107335354  Train loss: 1.2487239006478736
# 47 Test accuracy: 0.6636  Test loss: 0.93928516
# 48 1248 Train accuracy: 0.5494318238521616  Train loss: 1.2440173533807197
# 48 Test accuracy: 0.6813  Test loss: 0.8983858
# 49 1248 Train accuracy: 0.5517254231170732  Train loss: 1.2382285458457714
# 49 Test accuracy: 0.6569  Test loss: 0.9497709
# 50 1248 Train accuracy: 0.5532121268868446  Train loss: 1.2335039765357971
# 50 Test accuracy: 0.6599  Test loss: 0.94662774
# 51 1248 Train accuracy: 0.5547593640229281  Train loss: 1.2300097731515474
# 51 Test accuracy: 0.6835  Test loss: 0.8838746
# 52 1248 Train accuracy: 0.5565734323286093  Train loss: 1.2253257839496319
# 52 Test accuracy: 0.6287  Test loss: 1.0486629
# 53 1248 Train accuracy: 0.5581475186347962  Train loss: 1.221385896970641
# 53 Test accuracy: 0.6551  Test loss: 0.9661391
# 54 1248 Train accuracy: 0.5599663357491846  Train loss: 1.2168345971902212
# 54 Test accuracy: 0.677  Test loss: 0.9004672
# 55 1248 Train accuracy: 0.5614435319141908  Train loss: 1.2132335793538527
# 55 Test accuracy: 0.6604  Test loss: 0.9400058
# 56 1248 Train accuracy: 0.5630627762526274  Train loss: 1.2087901911352361
# 56 Test accuracy: 0.6921  Test loss: 0.8700332
# 57 1248 Train accuracy: 0.5645933071772258  Train loss: 1.204565196141862
# 57 Test accuracy: 0.6226  Test loss: 1.0451666
# 58 1248 Train accuracy: 0.5658934226632119  Train loss: 1.2012259078436884
# 58 Test accuracy: 0.6738  Test loss: 0.91772723
# 59 1248 Train accuracy: 0.567036472094261  Train loss: 1.1980213050923105
# 59 Test accuracy: 0.6652  Test loss: 0.9304166
# 60 1248 Train accuracy: 0.568484854221344  Train loss: 1.1943850045204163
# 60 Test accuracy: 0.6878  Test loss: 0.87020594
# 61 1248 Train accuracy: 0.569766523369023  Train loss: 1.1918633901877482
# 61 Test accuracy: 0.6984  Test loss: 0.8555685
# 62 1248 Train accuracy: 0.5713587545579479  Train loss: 1.1876116047559246
# 62 Test accuracy: 0.6715  Test loss: 0.92183566
# 63 1248 Train accuracy: 0.5730158787681943  Train loss: 1.1838028501896631
# 63 Test accuracy: 0.6992  Test loss: 0.83691984
# 64 1248 Train accuracy: 0.5741382632870227  Train loss: 1.180784472990781
# 64 Test accuracy: 0.6607  Test loss: 0.94911915
# 65 1248 Train accuracy: 0.5756550173484362  Train loss: 1.1773802043474637
# 65 Test accuracy: 0.6737  Test loss: 0.9049082
# 66 1248 Train accuracy: 0.5769054234840653  Train loss: 1.1741519541090184
# 66 Test accuracy: 0.706  Test loss: 0.83011824
# 67 1248 Train accuracy: 0.578118504063407  Train loss: 1.171118647322726
# 67 Test accuracy: 0.704  Test loss: 0.8394586
# 68 1248 Train accuracy: 0.5795187221905764  Train loss: 1.167470131639172
# 68 Test accuracy: 0.6972  Test loss: 0.8488785
# 69 1248 Train accuracy: 0.5806499836583069  Train loss: 1.1643095465673916
# 69 Test accuracy: 0.7053  Test loss: 0.83020467
# 70 1248 Train accuracy: 0.5823116939408438  Train loss: 1.160010247043201
# 70 Test accuracy: 0.6945  Test loss: 0.8529695
# 71 1248 Train accuracy: 0.5836022250249352  Train loss: 1.1566884627476544
# Early stopping, best loss:  0.83011824
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.2898032206755418  Train loss: 1.94104370704064
# 1 Test accuracy: 0.3626  Test loss: 1.7131027
# 2 310 Train accuracy: 0.3574836036333671  Train loss: 1.7429187572919405
# 2 Test accuracy: 0.4349  Test loss: 1.4984933
# 3 310 Train accuracy: 0.38978334344350374  Train loss: 1.6596972117057214
# 3 Test accuracy: 0.4049  Test loss: 1.6919496
# 4 310 Train accuracy: 0.41681574285030365  Train loss: 1.5899797907242408
# 4 Test accuracy: 0.5025  Test loss: 1.3841599
# 5 310 Train accuracy: 0.4343470490895785  Train loss: 1.5556065247609066
# 5 Test accuracy: 0.4926  Test loss: 1.3576967
# 6 310 Train accuracy: 0.446531505156786  Train loss: 1.520486214222052
# 6 Test accuracy: 0.4815  Test loss: 1.4747185
# 7 310 Train accuracy: 0.4556606195785187  Train loss: 1.5016217821246975
# 7 Test accuracy: 0.5026  Test loss: 1.3748965
# 8 310 Train accuracy: 0.46310375831448114  Train loss: 1.483300425685369
# 8 Test accuracy: 0.555  Test loss: 1.2394848
# 9 310 Train accuracy: 0.4698867041331071  Train loss: 1.4652399150734274
# 9 Test accuracy: 0.448  Test loss: 1.5313498
# 10 310 Train accuracy: 0.4768634477486977  Train loss: 1.443805678991171
# 10 Test accuracy: 0.5798  Test loss: 1.161927
# 11 310 Train accuracy: 0.48224643643919407  Train loss: 1.4281682101162998
# 11 Test accuracy: 0.569  Test loss: 1.1796619
# 12 310 Train accuracy: 0.48588749842766005  Train loss: 1.4194915562103956
# 12 Test accuracy: 0.4712  Test loss: 1.4908013
# 13 310 Train accuracy: 0.4912618701979959  Train loss: 1.4061505914439816
# 13 Test accuracy: 0.4957  Test loss: 1.4447278
# 14 310 Train accuracy: 0.4957406951503439  Train loss: 1.3936481547879649
# 14 Test accuracy: 0.5877  Test loss: 1.1443274
# 15 310 Train accuracy: 0.49966209683662804  Train loss: 1.3840292374293008
# 15 Test accuracy: 0.5654  Test loss: 1.2119123
# 16 310 Train accuracy: 0.5031678614994655  Train loss: 1.3740124014707713
# 16 Test accuracy: 0.6112  Test loss: 1.1079158
# 17 310 Train accuracy: 0.5065067196054156  Train loss: 1.3635699498167944
# 17 Test accuracy: 0.5945  Test loss: 1.1088531
# 18 310 Train accuracy: 0.5091433140457186  Train loss: 1.3574274612797632
# 18 Test accuracy: 0.5958  Test loss: 1.1391357
# 19 310 Train accuracy: 0.5120986748320854  Train loss: 1.350894074449655
# 19 Test accuracy: 0.5931  Test loss: 1.1327825
# 20 310 Train accuracy: 0.5144305327763924  Train loss: 1.3437063485383987
# 20 Test accuracy: 0.5878  Test loss: 1.1250958
# 21 310 Train accuracy: 0.5172217982810933  Train loss: 1.3369061874819326
# Early stopping, best loss:  1.1079158
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.22338462114334107  Train loss: 2.0434959936141968
# 1 Test accuracy: 0.2964  Test loss: 1.8418669
# 2 623 Train accuracy: 0.2750769302248955  Train loss: 1.9038718295097352
# 2 Test accuracy: 0.3188  Test loss: 1.8773656
# 3 623 Train accuracy: 0.3095384685198466  Train loss: 1.8184830013910929
# 3 Test accuracy: 0.3731  Test loss: 1.6889814
# 4 623 Train accuracy: 0.3324615454673767  Train loss: 1.7651890194416047
# 4 Test accuracy: 0.4051  Test loss: 1.6011072
# 5 623 Train accuracy: 0.3428923149108887  Train loss: 1.7383797302246093
# 5 Test accuracy: 0.4293  Test loss: 1.5474608
# 6 623 Train accuracy: 0.3560000071922938  Train loss: 1.7082863632837932
# 6 Test accuracy: 0.4565  Test loss: 1.4646711
# 7 623 Train accuracy: 0.36545055644852775  Train loss: 1.6857779455184936
# 7 Test accuracy: 0.4584  Test loss: 1.4692602
# 8 623 Train accuracy: 0.3768461611866951  Train loss: 1.660905739068985
# 8 Test accuracy: 0.4598  Test loss: 1.4609832
# 9 623 Train accuracy: 0.3863931696944767  Train loss: 1.639459515147739
# 9 Test accuracy: 0.4548  Test loss: 1.5076593
# 10 623 Train accuracy: 0.3932307767868042  Train loss: 1.6254759650230408
# 10 Test accuracy: 0.4663  Test loss: 1.4494427
# 11 623 Train accuracy: 0.40072728059508583  Train loss: 1.608025884628296
# 11 Test accuracy: 0.4575  Test loss: 1.5161214
# 12 623 Train accuracy: 0.40846154689788816  Train loss: 1.591951732635498
# 12 Test accuracy: 0.4599  Test loss: 1.4808791
# 13 623 Train accuracy: 0.4132544464331407  Train loss: 1.5783171697763296
# 13 Test accuracy: 0.4763  Test loss: 1.4542147
# 14 623 Train accuracy: 0.4180219867399761  Train loss: 1.5666880120549884
# 14 Test accuracy: 0.4331  Test loss: 1.5753367
# 15 623 Train accuracy: 0.4220307780901591  Train loss: 1.556651517868042
# 15 Test accuracy: 0.4968  Test loss: 1.3754151
# 16 623 Train accuracy: 0.4268846245855093  Train loss: 1.5479177820682526
# 16 Test accuracy: 0.4869  Test loss: 1.4350297
# 17 623 Train accuracy: 0.4310588331783519  Train loss: 1.5375661389967974
# 17 Test accuracy: 0.5129  Test loss: 1.3762494
# 18 623 Train accuracy: 0.4352478733327654  Train loss: 1.5263482928276062
# 18 Test accuracy: 0.4873  Test loss: 1.4084927
# 19 623 Train accuracy: 0.43711741899189194  Train loss: 1.5198433876037598
# 19 Test accuracy: 0.5141  Test loss: 1.3452513
# 20 623 Train accuracy: 0.4410769335031509  Train loss: 1.5090848567485808
# 20 Test accuracy: 0.5197  Test loss: 1.3388588
# 21 623 Train accuracy: 0.44410257492746624  Train loss: 1.5019433761778331
# 21 Test accuracy: 0.5043  Test loss: 1.3644334
# 22 623 Train accuracy: 0.44763637483119967  Train loss: 1.493194601319053
# 22 Test accuracy: 0.479  Test loss: 1.4451203
# 23 623 Train accuracy: 0.4511036904480146  Train loss: 1.4837684079875118
# 23 Test accuracy: 0.5619  Test loss: 1.2214463
# 24 623 Train accuracy: 0.45371796026825906  Train loss: 1.4765487345059713
# 24 Test accuracy: 0.5102  Test loss: 1.3505577
# 25 623 Train accuracy: 0.4567630886554718  Train loss: 1.4699102073669434
# 25 Test accuracy: 0.5271  Test loss: 1.3063303
# 26 623 Train accuracy: 0.4598106628656387  Train loss: 1.4613964996888087
# 26 Test accuracy: 0.4874  Test loss: 1.4541448
# 27 623 Train accuracy: 0.4630427473562735  Train loss: 1.453814067222454
# 27 Test accuracy: 0.5298  Test loss: 1.3039126
# 28 623 Train accuracy: 0.46632968293769017  Train loss: 1.4466969566685812
# 28 Test accuracy: 0.592  Test loss: 1.1426237
# 29 623 Train accuracy: 0.46883820920154967  Train loss: 1.4403610703040814
# 29 Test accuracy: 0.5278  Test loss: 1.3057945
# 30 623 Train accuracy: 0.47185642349720003  Train loss: 1.432656035423279
# 30 Test accuracy: 0.5697  Test loss: 1.1862576
# 31 623 Train accuracy: 0.4735682516713296  Train loss: 1.4284963572409846
# 31 Test accuracy: 0.5743  Test loss: 1.1591778
# 32 623 Train accuracy: 0.47657693684101105  Train loss: 1.4204488468170167
# 32 Test accuracy: 0.5205  Test loss: 1.3499832
# 33 623 Train accuracy: 0.47917950128064013  Train loss: 1.4141422740618388
# Early stopping, best loss:  1.1426237
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.34892308443784714  Train loss: 1.8324096202850342
# 1 Test accuracy: 0.3618  Test loss: 1.8295296
# 2 623 Train accuracy: 0.39323077604174617  Train loss: 1.6928121948242187
# 2 Test accuracy: 0.4845  Test loss: 1.4145625
# 3 623 Train accuracy: 0.41743590583403906  Train loss: 1.6191719722747804
# 3 Test accuracy: 0.3893  Test loss: 1.9767048
# 4 623 Train accuracy: 0.436461548730731  Train loss: 1.5719342052936554
# 4 Test accuracy: 0.5387  Test loss: 1.2854452
# 5 623 Train accuracy: 0.44824616450071336  Train loss: 1.538985492706299
# 5 Test accuracy: 0.5277  Test loss: 1.31838
# 6 623 Train accuracy: 0.45702565267682077  Train loss: 1.5149090011914572
# 6 Test accuracy: 0.5347  Test loss: 1.2694801
# 7 623 Train accuracy: 0.4616263857483864  Train loss: 1.4975395747593472
# 7 Test accuracy: 0.5308  Test loss: 1.3155588
# 8 623 Train accuracy: 0.46723078202456236  Train loss: 1.4844920045137406
# 8 Test accuracy: 0.5358  Test loss: 1.2610058
# 9 623 Train accuracy: 0.4722051416171922  Train loss: 1.4735066350301107
# 9 Test accuracy: 0.5779  Test loss: 1.1821445
# 10 623 Train accuracy: 0.47692309054732324  Train loss: 1.4611788613796235
# 10 Test accuracy: 0.5385  Test loss: 1.2713675
# 11 623 Train accuracy: 0.48005595768039877  Train loss: 1.4503092334487222
# 11 Test accuracy: 0.4869  Test loss: 1.4118313
# 12 623 Train accuracy: 0.4830769369751215  Train loss: 1.4412671490510305
# 12 Test accuracy: 0.566  Test loss: 1.2018242
# 13 623 Train accuracy: 0.48648522154642987  Train loss: 1.4292514731333805
# 13 Test accuracy: 0.5304  Test loss: 1.3302431
# 14 623 Train accuracy: 0.48967034414410593  Train loss: 1.4210698311669485
# Early stopping, best loss:  1.1821445
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.2903995244548871  Train loss: 1.9470445467875555
# 1 Test accuracy: 0.4232  Test loss: 1.561103
# 2 310 Train accuracy: 0.3595706628492245  Train loss: 1.7583734163871179
# 2 Test accuracy: 0.4428  Test loss: 1.5503408
# 3 310 Train accuracy: 0.38719936460256577  Train loss: 1.6747120649386675
# 3 Test accuracy: 0.4531  Test loss: 1.4978852
# 4 310 Train accuracy: 0.4115980928047345  Train loss: 1.6187776304208314
# 4 Test accuracy: 0.439  Test loss: 1.5339698
# 5 310 Train accuracy: 0.42313655488766155  Train loss: 1.5830776544717642
# 5 Test accuracy: 0.4975  Test loss: 1.3879502
# 6 310 Train accuracy: 0.4322202351803963  Train loss: 1.562795836191911
# 6 Test accuracy: 0.4898  Test loss: 1.4062642
# 7 310 Train accuracy: 0.4367492982483172  Train loss: 1.5498452736781194
# 7 Test accuracy: 0.4466  Test loss: 1.5742925
# 8 310 Train accuracy: 0.4434257617506843  Train loss: 1.5311358238642032
# 8 Test accuracy: 0.4806  Test loss: 1.4108349
# 9 310 Train accuracy: 0.44795600757894355  Train loss: 1.5194051072128818
# 9 Test accuracy: 0.4615  Test loss: 1.5058824
# 10 310 Train accuracy: 0.45187835584466274  Train loss: 1.5085140310800993
# 10 Test accuracy: 0.5145  Test loss: 1.3349056
# 11 310 Train accuracy: 0.4569306676308592  Train loss: 1.4962572676318509
# 11 Test accuracy: 0.5449  Test loss: 1.2904325
# 12 310 Train accuracy: 0.46004770586314875  Train loss: 1.4903662617389972
# 12 Test accuracy: 0.537  Test loss: 1.3000777
# 13 310 Train accuracy: 0.46429063128472786  Train loss: 1.4801228596613958
# 13 Test accuracy: 0.5012  Test loss: 1.3517177
# 14 310 Train accuracy: 0.466947783521571  Train loss: 1.4726579975295853
# 14 Test accuracy: 0.5479  Test loss: 1.2336632
# 15 310 Train accuracy: 0.4694096626761632  Train loss: 1.4648586040888076
# 15 Test accuracy: 0.5547  Test loss: 1.2301602
# 16 310 Train accuracy: 0.47268187516154003  Train loss: 1.4567457649570246
# 16 Test accuracy: 0.5316  Test loss: 1.280356
# 17 310 Train accuracy: 0.4753235851275435  Train loss: 1.45057343142065
# 17 Test accuracy: 0.5514  Test loss: 1.2398514
# 18 310 Train accuracy: 0.4765785494739683  Train loss: 1.4462534606966198
# 18 Test accuracy: 0.5302  Test loss: 1.2936578
# 19 310 Train accuracy: 0.47964724261871716  Train loss: 1.4389773153583048
# 19 Test accuracy: 0.4647  Test loss: 1.5152273
# 20 310 Train accuracy: 0.4826475879607292  Train loss: 1.4335709851521712
# 20 Test accuracy: 0.5704  Test loss: 1.186545
# 21 310 Train accuracy: 0.4853053950182684  Train loss: 1.425668940002665
# 21 Test accuracy: 0.5435  Test loss: 1.2558125
# 22 310 Train accuracy: 0.48777579305159463  Train loss: 1.4191381668711043
# 22 Test accuracy: 0.5119  Test loss: 1.4102958
# 23 310 Train accuracy: 0.48912395594211727  Train loss: 1.4159818831893514
# 23 Test accuracy: 0.6011  Test loss: 1.1251003
# 24 310 Train accuracy: 0.4911796884515729  Train loss: 1.4118298349472194
# 24 Test accuracy: 0.5802  Test loss: 1.1792794
# 25 310 Train accuracy: 0.4932140754048641  Train loss: 1.4073604429685151
# 25 Test accuracy: 0.5269  Test loss: 1.3185176
# 26 310 Train accuracy: 0.4951607750938136  Train loss: 1.4020770227415322
# 26 Test accuracy: 0.573  Test loss: 1.213013
# 27 310 Train accuracy: 0.49658782489364306  Train loss: 1.3981245599920593
# 27 Test accuracy: 0.5878  Test loss: 1.137385
# 28 310 Train accuracy: 0.49833887318087805  Train loss: 1.3930444622432792
# Early stopping, best loss:  1.1251003
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.21454546093940735  Train loss: 2.2897152400016783
# 1 Test accuracy: 0.1282  Test loss: 2.724749
# 2 1248 Train accuracy: 0.23939394652843476  Train loss: 2.1981845724582674
# 2 Test accuracy: 0.2208  Test loss: 2.2272608
# 3 1248 Train accuracy: 0.2450505123535792  Train loss: 2.17051860888799
# 3 Test accuracy: 0.2459  Test loss: 2.3651392
# 4 1248 Train accuracy: 0.2540909166634083  Train loss: 2.1469191086292265
# 4 Test accuracy: 0.2026  Test loss: 2.244999
# 5 1248 Train accuracy: 0.25878788650035855  Train loss: 2.1380520243644714
# 5 Test accuracy: 0.2704  Test loss: 2.557339
# 6 1248 Train accuracy: 0.2593939471244812  Train loss: 2.1307944277922313
# 6 Test accuracy: 0.2457  Test loss: 1.9988601
# 7 1248 Train accuracy: 0.2613852891751698  Train loss: 2.124854782649449
# 7 Test accuracy: 0.1534  Test loss: 2.6536398
# 8 1248 Train accuracy: 0.2612878865748644  Train loss: 2.11868340075016
# 8 Test accuracy: 0.2515  Test loss: 2.1278815
# 9 1248 Train accuracy: 0.26168350948227775  Train loss: 2.109099192884233
# 9 Test accuracy: 0.2466  Test loss: 2.086767
# 10 1248 Train accuracy: 0.26296970480680465  Train loss: 2.106566127538681
# 10 Test accuracy: 0.2718  Test loss: 2.2175074
# 11 1248 Train accuracy: 0.26451791421933607  Train loss: 2.105423416441137
# Early stopping, best loss:  1.9988601
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.31782946105186755  Train loss: 1.8915246358284583
# 1 Test accuracy: 0.381  Test loss: 1.7688313
# 2 310 Train accuracy: 0.37060226786595124  Train loss: 1.7269816857117872
# 2 Test accuracy: 0.453  Test loss: 1.5352331
# 3 310 Train accuracy: 0.39455376718288815  Train loss: 1.6545077531765668
# 3 Test accuracy: 0.4668  Test loss: 1.4643337
# 4 310 Train accuracy: 0.4193500323364368  Train loss: 1.5847743520369897
# 4 Test accuracy: 0.3962  Test loss: 1.766523
# 5 310 Train accuracy: 0.4302921902674895  Train loss: 1.5541548857322105
# 5 Test accuracy: 0.4897  Test loss: 1.4515047
# 6 310 Train accuracy: 0.4399721746643384  Train loss: 1.5285464143141723
# 6 Test accuracy: 0.526  Test loss: 1.3463908
# 7 310 Train accuracy: 0.4511457562119096  Train loss: 1.4964065656557188
# 7 Test accuracy: 0.554  Test loss: 1.2537168
# 8 310 Train accuracy: 0.463700061950546  Train loss: 1.4664366600605159
# 8 Test accuracy: 0.4627  Test loss: 1.5393478
# 9 310 Train accuracy: 0.4718743816145465  Train loss: 1.446197192893069
# 9 Test accuracy: 0.5397  Test loss: 1.2979059
# 10 310 Train accuracy: 0.4789505093143536  Train loss: 1.428901587999784
# 10 Test accuracy: 0.5741  Test loss: 1.196364
# 11 310 Train accuracy: 0.4845232308119327  Train loss: 1.4113969869546956
# 11 Test accuracy: 0.568  Test loss: 1.2138628
# 12 310 Train accuracy: 0.49006162001154363  Train loss: 1.396883956132791
# 12 Test accuracy: 0.5304  Test loss: 1.3325732
# 13 310 Train accuracy: 0.4963075105078827  Train loss: 1.38225533341515
# 13 Test accuracy: 0.5922  Test loss: 1.1384076
# 14 310 Train accuracy: 0.5014055724163632  Train loss: 1.3700689941972166
# 14 Test accuracy: 0.5059  Test loss: 1.485182
# 15 310 Train accuracy: 0.5051878365950707  Train loss: 1.3612910539675982
# 15 Test accuracy: 0.5315  Test loss: 1.3657959
# 16 310 Train accuracy: 0.5086091243160459  Train loss: 1.3512657966751318
# 16 Test accuracy: 0.5565  Test loss: 1.2554005
# 17 310 Train accuracy: 0.5130309736971402  Train loss: 1.341102992247672
# 17 Test accuracy: 0.5754  Test loss: 1.2154232
# 18 310 Train accuracy: 0.5178228323148866  Train loss: 1.3293469487092433
# Early stopping, best loss:  1.1384076
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3415384691953659  Train loss: 1.759109501838684
# 1 Test accuracy: 0.395  Test loss: 1.6240557
# 2 623 Train accuracy: 0.39507693201303484  Train loss: 1.6187254858016968
# 2 Test accuracy: 0.4856  Test loss: 1.4242558
# 3 623 Train accuracy: 0.4252307786544164  Train loss: 1.5330121994018555
# 3 Test accuracy: 0.5098  Test loss: 1.3636769
# 4 623 Train accuracy: 0.4483077023923397  Train loss: 1.4782016348838807
# 4 Test accuracy: 0.548  Test loss: 1.2390971
# 5 623 Train accuracy: 0.46658462727069855  Train loss: 1.4380802969932556
# 5 Test accuracy: 0.5655  Test loss: 1.245892
# 6 623 Train accuracy: 0.4847179624438286  Train loss: 1.404065062602361
# 6 Test accuracy: 0.6275  Test loss: 1.0589747
# 7 623 Train accuracy: 0.49863737779004236  Train loss: 1.369858457701547
# 7 Test accuracy: 0.614  Test loss: 1.0806773
# 8 623 Train accuracy: 0.5073846314102411  Train loss: 1.3470737060904503
# 8 Test accuracy: 0.6081  Test loss: 1.0938311
# 9 623 Train accuracy: 0.5156239482429292  Train loss: 1.32251925362481
# 9 Test accuracy: 0.6422  Test loss: 0.9935297
# 10 623 Train accuracy: 0.5241230942606926  Train loss: 1.3006223967075348
# 10 Test accuracy: 0.5645  Test loss: 1.2116885
# 11 623 Train accuracy: 0.5313566611571745  Train loss: 1.2832718888196077
# 11 Test accuracy: 0.5798  Test loss: 1.1812577
# 12 623 Train accuracy: 0.538974377065897  Train loss: 1.264145290652911
# 12 Test accuracy: 0.6329  Test loss: 1.0198576
# 13 623 Train accuracy: 0.544994101203405  Train loss: 1.246950662136078
# 13 Test accuracy: 0.663  Test loss: 0.95740646
# 14 623 Train accuracy: 0.5512088098270552  Train loss: 1.2325773543970926
# 14 Test accuracy: 0.662  Test loss: 0.9626924
# 15 623 Train accuracy: 0.5567179675499598  Train loss: 1.22018128379186
# 15 Test accuracy: 0.6638  Test loss: 0.9695857
# 16 623 Train accuracy: 0.5611923266574741  Train loss: 1.2094256533682346
# 16 Test accuracy: 0.6736  Test loss: 0.9217541
# 17 623 Train accuracy: 0.5662624625248067  Train loss: 1.19807960692574
# 17 Test accuracy: 0.656  Test loss: 0.97127664
# 18 623 Train accuracy: 0.5714530106054412  Train loss: 1.1856887639893425
# 18 Test accuracy: 0.6612  Test loss: 0.9693308
# 19 623 Train accuracy: 0.574898804708531  Train loss: 1.1762214622999492
# 19 Test accuracy: 0.668  Test loss: 0.94919133
# 20 623 Train accuracy: 0.5777846347987652  Train loss: 1.169087746977806
# 20 Test accuracy: 0.6869  Test loss: 0.8867721
# 21 623 Train accuracy: 0.5810696165618442  Train loss: 1.1588965261550177
# 21 Test accuracy: 0.6835  Test loss: 0.89797384
# 22 623 Train accuracy: 0.5841958236965266  Train loss: 1.1498606790195811
# 22 Test accuracy: 0.7002  Test loss: 0.85368264
# 23 623 Train accuracy: 0.5875585479580838  Train loss: 1.140934623013372
# 23 Test accuracy: 0.6558  Test loss: 1.0001867
# 24 623 Train accuracy: 0.590769250318408  Train loss: 1.1332926708459854
# 24 Test accuracy: 0.682  Test loss: 0.8897756
# 25 623 Train accuracy: 0.5937230964899063  Train loss: 1.1265371013641357
# 25 Test accuracy: 0.6992  Test loss: 0.8629756
# 26 623 Train accuracy: 0.596662741463918  Train loss: 1.1179646085775816
# 26 Test accuracy: 0.6547  Test loss: 1.0000175
# 27 623 Train accuracy: 0.5998176833656099  Train loss: 1.110940062381603
# Early stopping, best loss:  0.85368264
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3772307789325714  Train loss: 1.7354606342315675
# 1 Test accuracy: 0.3672  Test loss: 1.8928969
# 2 623 Train accuracy: 0.42430770516395566  Train loss: 1.5951747798919678
# 2 Test accuracy: 0.4813  Test loss: 1.426462
# 3 623 Train accuracy: 0.4498461671670278  Train loss: 1.5264789565404255
# 3 Test accuracy: 0.5421  Test loss: 1.2975988
# 4 623 Train accuracy: 0.4707692462205887  Train loss: 1.4697723090648651
# 4 Test accuracy: 0.5625  Test loss: 1.2014751
# 5 623 Train accuracy: 0.48566155433654784  Train loss: 1.4255105242729187
# 5 Test accuracy: 0.5706  Test loss: 1.1951758
# 6 623 Train accuracy: 0.4953846321503321  Train loss: 1.4010075120131176
# 6 Test accuracy: 0.5932  Test loss: 1.1263193
# 7 623 Train accuracy: 0.5044395778860364  Train loss: 1.3778285752023969
# 7 Test accuracy: 0.5522  Test loss: 1.2451352
# 8 623 Train accuracy: 0.5140769408643245  Train loss: 1.3571895888447763
# 8 Test accuracy: 0.5964  Test loss: 1.1214299
# 9 623 Train accuracy: 0.5202735225359599  Train loss: 1.3421673822402953
# 9 Test accuracy: 0.5869  Test loss: 1.1271673
# 10 623 Train accuracy: 0.5251692492961884  Train loss: 1.327537220954895
# 10 Test accuracy: 0.6037  Test loss: 1.0889198
# 11 623 Train accuracy: 0.5302937250787562  Train loss: 1.3140511709993536
# 11 Test accuracy: 0.5892  Test loss: 1.1978949
# 12 623 Train accuracy: 0.5373846344153086  Train loss: 1.2970655431350073
# 12 Test accuracy: 0.6276  Test loss: 1.0466557
# 13 623 Train accuracy: 0.5421065281904661  Train loss: 1.2842178058624267
# 13 Test accuracy: 0.6305  Test loss: 1.0476365
# 14 623 Train accuracy: 0.5461978218385152  Train loss: 1.2740800298963275
# 14 Test accuracy: 0.6394  Test loss: 1.0281578
# 15 623 Train accuracy: 0.5507692506313324  Train loss: 1.2619752847353618
# 15 Test accuracy: 0.5872  Test loss: 1.1421299
# 16 623 Train accuracy: 0.5540384816378355  Train loss: 1.2534693305194378
# 16 Test accuracy: 0.6438  Test loss: 1.0107322
# 17 623 Train accuracy: 0.5568144999532139  Train loss: 1.2424718166800106
# 17 Test accuracy: 0.6339  Test loss: 1.0078014
# 18 623 Train accuracy: 0.5600342084964116  Train loss: 1.2328690412309435
# 18 Test accuracy: 0.6263  Test loss: 1.0549599
# 19 623 Train accuracy: 0.5626235023297762  Train loss: 1.2259172059360304
# 19 Test accuracy: 0.6585  Test loss: 0.9653095
# 20 623 Train accuracy: 0.5666769436597824  Train loss: 1.2153819060325624
# 20 Test accuracy: 0.64  Test loss: 1.0087477
# 21 623 Train accuracy: 0.5688205335253761  Train loss: 1.2087093117123557
# 21 Test accuracy: 0.6623  Test loss: 0.9534054
# 22 623 Train accuracy: 0.571440580216321  Train loss: 1.2014020172032442
# 22 Test accuracy: 0.6672  Test loss: 0.93549865
# 23 623 Train accuracy: 0.5734582148427548  Train loss: 1.1954615710092626
# 23 Test accuracy: 0.642  Test loss: 0.9762918
# 24 623 Train accuracy: 0.5752051491041978  Train loss: 1.1903882830341657
# 24 Test accuracy: 0.6432  Test loss: 1.0086877
# 25 623 Train accuracy: 0.5782154055118561  Train loss: 1.1842119037628174
# 25 Test accuracy: 0.6549  Test loss: 0.9809866
# 26 623 Train accuracy: 0.580189370054465  Train loss: 1.179388309258681
# 26 Test accuracy: 0.6297  Test loss: 1.015016
# 27 623 Train accuracy: 0.5821766591513599  Train loss: 1.1742651787510625
# 27 Test accuracy: 0.6638  Test loss: 0.9336789
# 28 623 Train accuracy: 0.5844615594404085  Train loss: 1.1685296115704946
# 28 Test accuracy: 0.6737  Test loss: 0.9312509
# 29 623 Train accuracy: 0.5865252199255186  Train loss: 1.1634141823341106
# 29 Test accuracy: 0.6516  Test loss: 0.9841873
# 30 623 Train accuracy: 0.5883692517280579  Train loss: 1.1575044490496318
# 30 Test accuracy: 0.6736  Test loss: 0.93029815
# 31 623 Train accuracy: 0.5896377380817167  Train loss: 1.154547742336027
# 31 Test accuracy: 0.6868  Test loss: 0.88106346
# 32 623 Train accuracy: 0.5915577132627368  Train loss: 1.1494346421957016
# 32 Test accuracy: 0.6875  Test loss: 0.88212717
# 33 623 Train accuracy: 0.5926899976802594  Train loss: 1.1462319984580531
# 33 Test accuracy: 0.6612  Test loss: 0.96771604
# 34 623 Train accuracy: 0.5944796589893453  Train loss: 1.1414134359359742
# 34 Test accuracy: 0.6859  Test loss: 0.89168495
# 35 623 Train accuracy: 0.5964659550189972  Train loss: 1.1367494641712734
# 35 Test accuracy: 0.6784  Test loss: 0.92186624
# 36 623 Train accuracy: 0.5981880551245478  Train loss: 1.1325687728325526
# Early stopping, best loss:  0.88106346
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.28861061598245913  Train loss: 2.0087021589279175
# 1 Test accuracy: 0.3073  Test loss: 1.9295578
# 2 310 Train accuracy: 0.32766845564429575  Train loss: 1.8448890860264118
# 2 Test accuracy: 0.378  Test loss: 1.6498375
# 3 310 Train accuracy: 0.35380640148352355  Train loss: 1.7569250877086933
# 3 Test accuracy: 0.3644  Test loss: 1.7399012
# 4 310 Train accuracy: 0.37209302401886535  Train loss: 1.7065664048378284
# 4 Test accuracy: 0.4683  Test loss: 1.4598744
# 5 310 Train accuracy: 0.38234943460959653  Train loss: 1.6818650007247924
# 5 Test accuracy: 0.4333  Test loss: 1.5284436
# 6 310 Train accuracy: 0.3881932029930445  Train loss: 1.6607028001394026
# 6 Test accuracy: 0.4443  Test loss: 1.4978434
# 7 310 Train accuracy: 0.393900674368654  Train loss: 1.6485209622225918
# 7 Test accuracy: 0.4323  Test loss: 1.5476795
# 8 310 Train accuracy: 0.4000447237004454  Train loss: 1.6358855263544962
# 8 Test accuracy: 0.472  Test loss: 1.4641119
# 9 310 Train accuracy: 0.4038295905686851  Train loss: 1.6269146020595844
# 9 Test accuracy: 0.4717  Test loss: 1.4058738
# 10 310 Train accuracy: 0.4090638052385587  Train loss: 1.6159156203269958
# 10 Test accuracy: 0.4611  Test loss: 1.4607768
# 11 310 Train accuracy: 0.4138884379209338  Train loss: 1.60378353579061
# 11 Test accuracy: 0.4592  Test loss: 1.4842926
# 12 310 Train accuracy: 0.41651759158151275  Train loss: 1.596020595385478
# 12 Test accuracy: 0.4816  Test loss: 1.4074796
# 13 310 Train accuracy: 0.4196596494352324  Train loss: 1.5871222442423805
# 13 Test accuracy: 0.4548  Test loss: 1.4863061
# 14 310 Train accuracy: 0.4216287595803266  Train loss: 1.5821081563666626
# Early stopping, best loss:  1.4058738
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.3490909171104431  Train loss: 1.7584611988067627
# 1 Test accuracy: 0.401  Test loss: 1.658097
# 2 1248 Train accuracy: 0.372424251139164  Train loss: 1.6810042333602906
# 2 Test accuracy: 0.4215  Test loss: 1.697826
# 3 1248 Train accuracy: 0.39858586649099986  Train loss: 1.6149658274650573
# 3 Test accuracy: 0.4152  Test loss: 1.7370602
# 4 1248 Train accuracy: 0.4192424322664738  Train loss: 1.5662508401274682
# 4 Test accuracy: 0.4303  Test loss: 1.6989367
# 5 1248 Train accuracy: 0.43975758337974546  Train loss: 1.5246980912685395
# 5 Test accuracy: 0.5149  Test loss: 1.3647902
# 6 1248 Train accuracy: 0.4518181891242663  Train loss: 1.4928733811775843
# 6 Test accuracy: 0.5823  Test loss: 1.1798977
# 7 1248 Train accuracy: 0.46545455191816604  Train loss: 1.4634567982809885
# 7 Test accuracy: 0.5376  Test loss: 1.2910639
# 8 1248 Train accuracy: 0.4768939457088709  Train loss: 1.436115069836378
# 8 Test accuracy: 0.5958  Test loss: 1.1321911
# 9 1248 Train accuracy: 0.4873400735192829  Train loss: 1.4110246364275614
# 9 Test accuracy: 0.577  Test loss: 1.1725129
# 10 1248 Train accuracy: 0.49545455145835876  Train loss: 1.3902575778961181
# 10 Test accuracy: 0.6198  Test loss: 1.0534402
# 11 1248 Train accuracy: 0.5046832014755769  Train loss: 1.3654121009870008
# 11 Test accuracy: 0.5913  Test loss: 1.1482745
# 12 1248 Train accuracy: 0.5133838444451491  Train loss: 1.3435503241419793
# 12 Test accuracy: 0.5897  Test loss: 1.1721853
# 13 1248 Train accuracy: 0.5179021039834389  Train loss: 1.3276309666266808
# 13 Test accuracy: 0.6235  Test loss: 1.0422567
# 14 1248 Train accuracy: 0.5244588804670742  Train loss: 1.310701294881957
# 14 Test accuracy: 0.5981  Test loss: 1.1518344
# 15 1248 Train accuracy: 0.529212127049764  Train loss: 1.297898776292801
# 15 Test accuracy: 0.5751  Test loss: 1.2428778
# 16 1248 Train accuracy: 0.5350000057369471  Train loss: 1.2819556953758002
# 16 Test accuracy: 0.6423  Test loss: 1.0096014
# 17 1248 Train accuracy: 0.5398574032503016  Train loss: 1.269942094999201
# 17 Test accuracy: 0.6493  Test loss: 0.98569727
# 18 1248 Train accuracy: 0.5455555612511105  Train loss: 1.2579277651177512
# 18 Test accuracy: 0.6404  Test loss: 1.0106397
# 19 1248 Train accuracy: 0.5510366881834833  Train loss: 1.2445425827879655
# 19 Test accuracy: 0.646  Test loss: 1.004459
# 20 1248 Train accuracy: 0.555484854131937  Train loss: 1.2326640556454658
# 20 Test accuracy: 0.659  Test loss: 0.97847325
# 21 1248 Train accuracy: 0.5595959652037847  Train loss: 1.2215605111633028
# 21 Test accuracy: 0.668  Test loss: 0.9275311
# 22 1248 Train accuracy: 0.5634710799293084  Train loss: 1.2103277970715003
# 22 Test accuracy: 0.6178  Test loss: 1.0855738
# 23 1248 Train accuracy: 0.5679314942981886  Train loss: 1.1994171352749285
# 23 Test accuracy: 0.6606  Test loss: 0.96216184
# 24 1248 Train accuracy: 0.5716414195795854  Train loss: 1.188061829432845
# 24 Test accuracy: 0.6135  Test loss: 1.1270381
# 25 1248 Train accuracy: 0.5749818236589431  Train loss: 1.17902441675663
# 25 Test accuracy: 0.6711  Test loss: 0.93183243
# 26 1248 Train accuracy: 0.5772261127141806  Train loss: 1.171278402369756
# 26 Test accuracy: 0.6771  Test loss: 0.91791916
# 27 1248 Train accuracy: 0.5804040459350304  Train loss: 1.1637573821235585
# 27 Test accuracy: 0.6737  Test loss: 0.90925604
# 28 1248 Train accuracy: 0.5828787934141499  Train loss: 1.156923327169248
# 28 Test accuracy: 0.6861  Test loss: 0.8839754
# 29 1248 Train accuracy: 0.5856635373214195  Train loss: 1.1488792558168544
# 29 Test accuracy: 0.6201  Test loss: 1.1087692
# 30 1248 Train accuracy: 0.5873333388169607  Train loss: 1.1432095995942753
# 30 Test accuracy: 0.6885  Test loss: 0.87087226
# 31 1248 Train accuracy: 0.5902834854971978  Train loss: 1.1361855918938113
# 31 Test accuracy: 0.6584  Test loss: 0.98394924
# 32 1248 Train accuracy: 0.5924053085781634  Train loss: 1.1312864632345736
# 32 Test accuracy: 0.6476  Test loss: 1.0092882
# 33 1248 Train accuracy: 0.5947291147889513  Train loss: 1.1246420999909892
# 33 Test accuracy: 0.6893  Test loss: 0.8773654
# 34 1248 Train accuracy: 0.5970231783915968  Train loss: 1.1185864639457535
# 34 Test accuracy: 0.6936  Test loss: 0.8767797
# 35 1248 Train accuracy: 0.5996190530572619  Train loss: 1.1119366277115685
# 35 Test accuracy: 0.7203  Test loss: 0.81351596
# 36 1248 Train accuracy: 0.6021043825480673  Train loss: 1.106012255532874
# 36 Test accuracy: 0.6985  Test loss: 0.86368984
# 37 1248 Train accuracy: 0.6042588096534883  Train loss: 1.099451736453417
# 37 Test accuracy: 0.7139  Test loss: 0.8120928
# 38 1248 Train accuracy: 0.6067145189329197  Train loss: 1.0943333866251141
# 38 Test accuracy: 0.6498  Test loss: 1.0407335
# 39 1248 Train accuracy: 0.6088578142569615  Train loss: 1.0888628869026136
# 39 Test accuracy: 0.705  Test loss: 0.84157187
# 40 1248 Train accuracy: 0.6108181872069836  Train loss: 1.0841432631909846
# 40 Test accuracy: 0.7058  Test loss: 0.84009475
# 41 1248 Train accuracy: 0.6121655634990553  Train loss: 1.0801862923401158
# 41 Test accuracy: 0.6979  Test loss: 0.8630707
# 42 1248 Train accuracy: 0.613838389303003  Train loss: 1.0757529915798278
# Early stopping, best loss:  0.8120928
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3212307770550251  Train loss: 1.8176048278808594
# 1 Test accuracy: 0.4245  Test loss: 1.5643029
# 2 623 Train accuracy: 0.37784616149961947  Train loss: 1.6589369559288025
# 2 Test accuracy: 0.4804  Test loss: 1.3957705
# 3 623 Train accuracy: 0.4045128288368384  Train loss: 1.5894911273320516
# 3 Test accuracy: 0.4665  Test loss: 1.4537894
# 4 623 Train accuracy: 0.42800000954419376  Train loss: 1.5373355674743652
# 4 Test accuracy: 0.507  Test loss: 1.3889664
# 5 623 Train accuracy: 0.4452923187315464  Train loss: 1.4935173778533934
# 5 Test accuracy: 0.4912  Test loss: 1.4019074
# 6 623 Train accuracy: 0.4608205250153939  Train loss: 1.4589847405751546
# 6 Test accuracy: 0.5612  Test loss: 1.2075477
# 7 623 Train accuracy: 0.4756923209982259  Train loss: 1.4272128564970834
# 7 Test accuracy: 0.5851  Test loss: 1.1544783
# 8 623 Train accuracy: 0.4886153987981379  Train loss: 1.3930370011925697
# 8 Test accuracy: 0.6244  Test loss: 1.0528178
# 9 623 Train accuracy: 0.500444459600581  Train loss: 1.366281042628818
# 9 Test accuracy: 0.6376  Test loss: 1.0224662
# 10 623 Train accuracy: 0.5107077083140612  Train loss: 1.3420070893764495
# 10 Test accuracy: 0.5996  Test loss: 1.1008126
# 11 623 Train accuracy: 0.518657359060916  Train loss: 1.3236898790706288
# 11 Test accuracy: 0.6038  Test loss: 1.1001328
# 12 623 Train accuracy: 0.5269230937585234  Train loss: 1.3021649839480718
# 12 Test accuracy: 0.6453  Test loss: 0.9852639
# 13 623 Train accuracy: 0.5323550467880872  Train loss: 1.2885739115568309
# 13 Test accuracy: 0.6461  Test loss: 0.9781176
# 14 623 Train accuracy: 0.5380219956487418  Train loss: 1.2750014535018377
# 14 Test accuracy: 0.6713  Test loss: 0.9345506
# 15 623 Train accuracy: 0.543220530718565  Train loss: 1.2603487447102864
# 15 Test accuracy: 0.6525  Test loss: 0.9638712
# 16 623 Train accuracy: 0.5492692488897591  Train loss: 1.2454311600327492
# 16 Test accuracy: 0.655  Test loss: 0.9766685
# 17 623 Train accuracy: 0.5534117830237921  Train loss: 1.2341657027076272
# 17 Test accuracy: 0.6245  Test loss: 1.0405928
# 18 623 Train accuracy: 0.5597265141291751  Train loss: 1.2196984170542824
# 18 Test accuracy: 0.6544  Test loss: 0.9856251
# 19 623 Train accuracy: 0.5634979941735142  Train loss: 1.2086346345198782
# 19 Test accuracy: 0.6666  Test loss: 0.9299107
# 20 623 Train accuracy: 0.5672615570798516  Train loss: 1.1988724539279938
# 20 Test accuracy: 0.6751  Test loss: 0.9081323
# 21 623 Train accuracy: 0.5709890297268119  Train loss: 1.1890355862889972
# 21 Test accuracy: 0.6795  Test loss: 0.9044342
# 22 623 Train accuracy: 0.574181837039915  Train loss: 1.1799225536259739
# 22 Test accuracy: 0.6838  Test loss: 0.8925881
# 23 623 Train accuracy: 0.5773645674469678  Train loss: 1.1698490515999171
# 23 Test accuracy: 0.6941  Test loss: 0.8719498
# 24 623 Train accuracy: 0.5801795062236488  Train loss: 1.1625305952628453
# 24 Test accuracy: 0.5881  Test loss: 1.1758636
# 25 623 Train accuracy: 0.5837784806072712  Train loss: 1.153764644241333
# 25 Test accuracy: 0.6549  Test loss: 0.97013927
# 26 623 Train accuracy: 0.5872899599086779  Train loss: 1.1458137632333316
# 26 Test accuracy: 0.6553  Test loss: 0.96648127
# 27 623 Train accuracy: 0.5890826402163064  Train loss: 1.1406640911102295
# 27 Test accuracy: 0.7116  Test loss: 0.82255733
# 28 623 Train accuracy: 0.5914066125505737  Train loss: 1.1343453179086957
# 28 Test accuracy: 0.6687  Test loss: 0.9260378
# 29 623 Train accuracy: 0.5943766769715424  Train loss: 1.1266114718338538
# 29 Test accuracy: 0.7194  Test loss: 0.80846053
# 30 623 Train accuracy: 0.5965743781576553  Train loss: 1.120678209702174
# 30 Test accuracy: 0.695  Test loss: 0.86944705
# 31 623 Train accuracy: 0.5991464211719651  Train loss: 1.1132681829698625
# 31 Test accuracy: 0.6789  Test loss: 0.91717947
# 32 623 Train accuracy: 0.6016923268744722  Train loss: 1.106832182854414
# 32 Test accuracy: 0.6652  Test loss: 0.9424833
# 33 623 Train accuracy: 0.6042144713844314  Train loss: 1.0999437385616881
# 33 Test accuracy: 0.6742  Test loss: 0.9259258
# 34 623 Train accuracy: 0.6062081639424843  Train loss: 1.0951922004363117
# Early stopping, best loss:  0.80846053
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.0015, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.260307699739933  Train loss: 2.0395430612564085
# 1 Test accuracy: 0.3321  Test loss: 1.7724891
# 2 623 Train accuracy: 0.3190769301354885  Train loss: 1.8527082324028015
# 2 Test accuracy: 0.3858  Test loss: 1.6911159
# 3 623 Train accuracy: 0.3474871868888537  Train loss: 1.7804650052388509
# 3 Test accuracy: 0.3919  Test loss: 1.6805408
# 4 623 Train accuracy: 0.37107693038880823  Train loss: 1.7206810653209685
# 4 Test accuracy: 0.4349  Test loss: 1.5545629
# 5 623 Train accuracy: 0.39163077729940415  Train loss: 1.6660023736953735
# 5 Test accuracy: 0.4849  Test loss: 1.3987294
# 6 623 Train accuracy: 0.40246154740452766  Train loss: 1.626694900194804
# 6 Test accuracy: 0.4839  Test loss: 1.442164
# 7 623 Train accuracy: 0.4144175919038909  Train loss: 1.5969421461650304
# 7 Test accuracy: 0.4855  Test loss: 1.4173723
# 8 623 Train accuracy: 0.42292308669537304  Train loss: 1.5716033947467805
# 8 Test accuracy: 0.5028  Test loss: 1.373167
# 9 623 Train accuracy: 0.4322051389680968  Train loss: 1.5495635864469741
# 9 Test accuracy: 0.4468  Test loss: 1.5896035
# ...
# 23 623 Train accuracy: 0.4422742583829424  Train loss: 1.513231285136679
# 23 Test accuracy: 0.5165  Test loss: 1.3184448
# 24 623 Train accuracy: 0.44589744715640944  Train loss: 1.5056971192359925
# 24 Test accuracy: 0.5566  Test loss: 1.2375613
# 25 623 Train accuracy: 0.4484923192381859  Train loss: 1.498122631263733
# 25 Test accuracy: 0.5244  Test loss: 1.2915665
# 26 623 Train accuracy: 0.451360958390511  Train loss: 1.4904713537142826
# 26 Test accuracy: 0.5339  Test loss: 1.2976793
# 27 623 Train accuracy: 0.4540854819946819  Train loss: 1.4835414849387274
# 27 Test accuracy: 0.5273  Test loss: 1.2890785
# 28 623 Train accuracy: 0.45648352856082575  Train loss: 1.4774090123176575
# 28 Test accuracy: 0.5469  Test loss: 1.2500714
# 29 623 Train accuracy: 0.45977720070501854  Train loss: 1.4701402803947186
# Early stopping, best loss:  1.2375613
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.353011334171662  Train loss: 1.8030753502478967
# 1 Test accuracy: 0.3758  Test loss: 1.6629394
# 2 310 Train accuracy: 0.4004174155684618  Train loss: 1.6276048467709467
# 2 Test accuracy: 0.5106  Test loss: 1.3419791
# 3 310 Train accuracy: 0.4337109950108406  Train loss: 1.5288767936902168
# 3 Test accuracy: 0.4273  Test loss: 1.5368221
# 4 310 Train accuracy: 0.4627310699568345  Train loss: 1.4616532073571131
# 4 Test accuracy: 0.5528  Test loss: 1.243314
# 5 310 Train accuracy: 0.47978533300069665  Train loss: 1.4180243675525372
# 5 Test accuracy: 0.4941  Test loss: 1.4078455
# 6 310 Train accuracy: 0.4988073956889984  Train loss: 1.3744300496883881
# 6 Test accuracy: 0.6024  Test loss: 1.1076621
# 7 310 Train accuracy: 0.5120538392892251  Train loss: 1.3391490107054238
# 7 Test accuracy: 0.5633  Test loss: 1.26128
# 8 310 Train accuracy: 0.5227340498509315  Train loss: 1.3116089506791189
# 8 Test accuracy: 0.6415  Test loss: 1.0055102
# 9 310 Train accuracy: 0.5317034383869579  Train loss: 1.2883506142176115
# 9 Test accuracy: 0.6181  Test loss: 1.0724549
# 10 310 Train accuracy: 0.5413237919027989  Train loss: 1.2637925592752604
# 10 Test accuracy: 0.6108  Test loss: 1.0791444
# 11 310 Train accuracy: 0.5492492004499568  Train loss: 1.2422316682922256
# 11 Test accuracy: 0.6659  Test loss: 0.94575644
# 12 310 Train accuracy: 0.5541641822037024  Train loss: 1.2285301001408162
# 12 Test accuracy: 0.6328  Test loss: 1.0625709
# 13 310 Train accuracy: 0.5597449656597961  Train loss: 1.2103186722337846
# 13 Test accuracy: 0.6741  Test loss: 0.93477464
# 14 310 Train accuracy: 0.5653803557321265  Train loss: 1.1964101221535233
# 14 Test accuracy: 0.6486  Test loss: 0.97870517
# 15 310 Train accuracy: 0.5719340088275763  Train loss: 1.1820140581864578
# 15 Test accuracy: 0.6797  Test loss: 0.90499026
# 16 310 Train accuracy: 0.5759913530917122  Train loss: 1.1714906552090094
# 16 Test accuracy: 0.6876  Test loss: 0.892239
# 17 310 Train accuracy: 0.5813953476658774  Train loss: 1.1586324111368862
# 17 Test accuracy: 0.6658  Test loss: 0.95055956
# 18 310 Train accuracy: 0.5854038287304405  Train loss: 1.1486223036916847
# 18 Test accuracy: 0.6582  Test loss: 0.9580014
# 19 310 Train accuracy: 0.5879546803863425  Train loss: 1.1419143445096036
# 19 Test accuracy: 0.6784  Test loss: 0.90258175
# 20 310 Train accuracy: 0.5920095406472683  Train loss: 1.131986099252334
# 20 Test accuracy: 0.6964  Test loss: 0.8660219
# 21 310 Train accuracy: 0.5959337818207758  Train loss: 1.1230055541345925
# 21 Test accuracy: 0.704  Test loss: 0.8354469
# 22 310 Train accuracy: 0.5989320761152914  Train loss: 1.1151254029123934
# 22 Test accuracy: 0.7003  Test loss: 0.8536346
# 23 310 Train accuracy: 0.6013066815991067  Train loss: 1.108679879867911
# 23 Test accuracy: 0.6964  Test loss: 0.84968925
# 24 310 Train accuracy: 0.6037070173770189  Train loss: 1.1020655471545
# 24 Test accuracy: 0.6764  Test loss: 0.9528656
# 25 310 Train accuracy: 0.6054382833609214  Train loss: 1.0960722495959356
# 25 Test accuracy: 0.7185  Test loss: 0.811765
# 26 310 Train accuracy: 0.6074950698123881  Train loss: 1.0914278319601476
# 26 Test accuracy: 0.6623  Test loss: 0.98127306
# 27 310 Train accuracy: 0.6103491691018101  Train loss: 1.0841140798014453
# 27 Test accuracy: 0.7053  Test loss: 0.84318125
# 28 310 Train accuracy: 0.6128077354323078  Train loss: 1.076920128949396
# 28 Test accuracy: 0.7096  Test loss: 0.82432646
# 29 310 Train accuracy: 0.6157341725551165  Train loss: 1.0705082903490142
# 29 Test accuracy: 0.7193  Test loss: 0.79131913
# 30 310 Train accuracy: 0.6182468695136217  Train loss: 1.0636708164826418
# 30 Test accuracy: 0.7046  Test loss: 0.8427372
# 31 310 Train accuracy: 0.6200203899636162  Train loss: 1.0582909276408534
# 31 Test accuracy: 0.6539  Test loss: 1.0311141
# 32 310 Train accuracy: 0.6218694098508701  Train loss: 1.052929100365593
# 32 Test accuracy: 0.7255  Test loss: 0.78373176
# 33 310 Train accuracy: 0.6237689959349888  Train loss: 1.0477122060068838
# 33 Test accuracy: 0.7114  Test loss: 0.8169453
# 34 310 Train accuracy: 0.6261180680734  Train loss: 1.0422776278057788
# 34 Test accuracy: 0.7132  Test loss: 0.83565515
# 35 310 Train accuracy: 0.6278047535118166  Train loss: 1.0372128033376002
# 35 Test accuracy: 0.6914  Test loss: 0.90053767
# 36 310 Train accuracy: 0.6295302455178183  Train loss: 1.0325159881359491
# 36 Test accuracy: 0.7224  Test loss: 0.78721416
# 37 310 Train accuracy: 0.6311624681813306  Train loss: 1.0278168211607823
# 37 Test accuracy: 0.7251  Test loss: 0.7691807
# 38 310 Train accuracy: 0.6322223267514213  Train loss: 1.025114853975744
# 38 Test accuracy: 0.6916  Test loss: 0.88100636
# 39 310 Train accuracy: 0.633610078892294  Train loss: 1.0211052660641116
# 39 Test accuracy: 0.7087  Test loss: 0.82912636
# 40 310 Train accuracy: 0.6355098389375669  Train loss: 1.0159364877985073
# 40 Test accuracy: 0.7289  Test loss: 0.77088505
# 41 310 Train accuracy: 0.6366188168022467  Train loss: 1.0127846235182227
# 41 Test accuracy: 0.7221  Test loss: 0.803433
# 42 310 Train accuracy: 0.6378737540417538  Train loss: 1.0098051155879821
# Early stopping, best loss:  0.7691807
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.39384616374969483  Train loss: 1.6769089603424072
# 1 Test accuracy: 0.4531  Test loss: 1.5052617
# 2 623 Train accuracy: 0.4326153951883316  Train loss: 1.5588755083084107
# 2 Test accuracy: 0.4935  Test loss: 1.4487982
# 3 623 Train accuracy: 0.46584616700808207  Train loss: 1.4685809739430746
# 3 Test accuracy: 0.5418  Test loss: 1.2649598
# 4 623 Train accuracy: 0.48723078370094297  Train loss: 1.4039398497343063
# 4 Test accuracy: 0.5753  Test loss: 1.2498964
# 5 623 Train accuracy: 0.5070769393444061  Train loss: 1.3503931279182435
# 5 Test accuracy: 0.6271  Test loss: 1.0632702
# 6 623 Train accuracy: 0.5261538632710775  Train loss: 1.3039372499783835
# 6 Test accuracy: 0.5976  Test loss: 1.1765639
# 7 623 Train accuracy: 0.5410989189147949  Train loss: 1.2691561603546142
# 7 Test accuracy: 0.6628  Test loss: 0.9650865
# 8 623 Train accuracy: 0.5533077105879783  Train loss: 1.2364913815259932
# 8 Test accuracy: 0.6256  Test loss: 1.0803382
# 9 623 Train accuracy: 0.5654017278883192  Train loss: 1.2070998676617941
# 9 Test accuracy: 0.6775  Test loss: 0.90896016
# 10 623 Train accuracy: 0.5742769417762756  Train loss: 1.18398610663414
# 10 Test accuracy: 0.671  Test loss: 0.93867403
# 11 623 Train accuracy: 0.5811468720436096  Train loss: 1.1661713524298234
# 11 Test accuracy: 0.6405  Test loss: 1.0399879
# 12 623 Train accuracy: 0.5861538652578989  Train loss: 1.1506417586406072
# 12 Test accuracy: 0.6672  Test loss: 0.956293
# 13 623 Train accuracy: 0.5914319718801059  Train loss: 1.1345551248697134
# 13 Test accuracy: 0.5951  Test loss: 1.2112131
# 14 623 Train accuracy: 0.5978901290893555  Train loss: 1.1172143185138703
# Early stopping, best loss:  0.90896016
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.35878788769245146  Train loss: 1.7062507677078247
# 1 Test accuracy: 0.4596  Test loss: 1.4950467
# 2 1248 Train accuracy: 0.42121212869882585  Train loss: 1.574584243297577
# 2 Test accuracy: 0.4126  Test loss: 1.6481293
# 3 1248 Train accuracy: 0.4389899073044459  Train loss: 1.5177900473276773
# 3 Test accuracy: 0.5477  Test loss: 1.2606257
# 4 1248 Train accuracy: 0.46075758248567583  Train loss: 1.4663725546002389
# 4 Test accuracy: 0.5684  Test loss: 1.1832055
# 5 1248 Train accuracy: 0.482545459985733  Train loss: 1.416553701877594
# 5 Test accuracy: 0.486  Test loss: 1.4903345
# 6 1248 Train accuracy: 0.49464647005001705  Train loss: 1.3896993414560954
# 6 Test accuracy: 0.5686  Test loss: 1.2086426
# 7 1248 Train accuracy: 0.5054545507260731  Train loss: 1.3610949097360883
# 7 Test accuracy: 0.5887  Test loss: 1.147391
# 8 1248 Train accuracy: 0.5152272776514292  Train loss: 1.333037682324648
# 8 Test accuracy: 0.6384  Test loss: 1.0258498
# 9 1248 Train accuracy: 0.5230303080214395  Train loss: 1.3137053557236988
# 9 Test accuracy: 0.5963  Test loss: 1.1063997
# 10 1248 Train accuracy: 0.5320606105923653  Train loss: 1.2925347777605056
# 10 Test accuracy: 0.6554  Test loss: 0.9734344
# 11 1248 Train accuracy: 0.5397245223413815  Train loss: 1.2727229897542434
# 11 Test accuracy: 0.6299  Test loss: 1.0317233
# 12 1248 Train accuracy: 0.5439899036288262  Train loss: 1.2583629608154296
# 12 Test accuracy: 0.6589  Test loss: 0.9660011
# 13 1248 Train accuracy: 0.5496503544312257  Train loss: 1.2450989856169774
# 13 Test accuracy: 0.6351  Test loss: 1.0398744
# 14 1248 Train accuracy: 0.5549350697653634  Train loss: 1.2321186074188777
# 14 Test accuracy: 0.6307  Test loss: 1.0358449
# 15 1248 Train accuracy: 0.5609697018067042  Train loss: 1.2177712269624075
# 15 Test accuracy: 0.6713  Test loss: 0.9340797
# 16 1248 Train accuracy: 0.5649621260538698  Train loss: 1.2057970327883958
# 16 Test accuracy: 0.6146  Test loss: 1.1189948
# 17 1248 Train accuracy: 0.5700891314183965  Train loss: 1.1941885793910307
# 17 Test accuracy: 0.6354  Test loss: 1.0141228
# 18 1248 Train accuracy: 0.5736700385808945  Train loss: 1.1838150664832856
# 18 Test accuracy: 0.6841  Test loss: 0.892265
# 19 1248 Train accuracy: 0.5774481707183938  Train loss: 1.1742808781799516
# 19 Test accuracy: 0.6776  Test loss: 0.90556717
# 20 1248 Train accuracy: 0.5805454595685006  Train loss: 1.1672061623930932
# 20 Test accuracy: 0.6726  Test loss: 0.9174113
# 21 1248 Train accuracy: 0.583001447944414  Train loss: 1.1605883723781223
# 21 Test accuracy: 0.6765  Test loss: 0.90216583
# 22 1248 Train accuracy: 0.5861708036065102  Train loss: 1.1515436202829534
# 22 Test accuracy: 0.6915  Test loss: 0.8679094
# 23 1248 Train accuracy: 0.5893017175664073  Train loss: 1.1443444767723914
# 23 Test accuracy: 0.6632  Test loss: 0.97148496
# 24 1248 Train accuracy: 0.5924494996666908  Train loss: 1.135881168047587
# 24 Test accuracy: 0.6884  Test loss: 0.89478874
# 25 1248 Train accuracy: 0.5949818228960038  Train loss: 1.1305132723331452
# 25 Test accuracy: 0.6945  Test loss: 0.87975705
# 26 1248 Train accuracy: 0.5967599113858663  Train loss: 1.12607289653558
# 26 Test accuracy: 0.7038  Test loss: 0.83672774
# 27 1248 Train accuracy: 0.598989903639864  Train loss: 1.1201393650196216
# 27 Test accuracy: 0.6896  Test loss: 0.87782127
# 28 1248 Train accuracy: 0.6014718660925116  Train loss: 1.1129143305548599
# 28 Test accuracy: 0.7141  Test loss: 0.81925774
# 29 1248 Train accuracy: 0.6039916452046098  Train loss: 1.1073333707554587
# 29 Test accuracy: 0.6804  Test loss: 0.9076248
# 30 1248 Train accuracy: 0.6065252573092779  Train loss: 1.101929916679859
# 30 Test accuracy: 0.7032  Test loss: 0.85055
# 31 1248 Train accuracy: 0.607917893317438  Train loss: 1.096483455108058
# 31 Test accuracy: 0.6926  Test loss: 0.8731377
# 32 1248 Train accuracy: 0.6096401561796665  Train loss: 1.092405737955123
# 32 Test accuracy: 0.7108  Test loss: 0.8336541
# 33 1248 Train accuracy: 0.6108539991306536  Train loss: 1.0902657864129905
# Early stopping, best loss:  0.81925774
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.341212130188942  Train loss: 1.8039121079444884
# 1 Test accuracy: 0.449  Test loss: 1.5063953
# 2 1248 Train accuracy: 0.3966666749119759  Train loss: 1.673025918006897
# 2 Test accuracy: 0.3752  Test loss: 1.8288724
# 3 1248 Train accuracy: 0.41474748333295186  Train loss: 1.611175742149353
# 3 Test accuracy: 0.4881  Test loss: 1.4813789
# 4 1248 Train accuracy: 0.4313636438548565  Train loss: 1.5607130390405655
# 4 Test accuracy: 0.4154  Test loss: 1.7373805
# 5 1248 Train accuracy: 0.44896970403194425  Train loss: 1.5207887444496155
# 5 Test accuracy: 0.5514  Test loss: 1.2478489
# 6 1248 Train accuracy: 0.464747482140859  Train loss: 1.4792126631736755
# 6 Test accuracy: 0.5139  Test loss: 1.3725141
# 7 1248 Train accuracy: 0.47480520171778545  Train loss: 1.451501135485513
# 7 Test accuracy: 0.5654  Test loss: 1.2050431
# 8 1248 Train accuracy: 0.48674243070185186  Train loss: 1.4225475664436817
# 8 Test accuracy: 0.5555  Test loss: 1.2749544
# 9 1248 Train accuracy: 0.49528620150354175  Train loss: 1.3968388158745235
# 9 Test accuracy: 0.562  Test loss: 1.2459077
# 10 1248 Train accuracy: 0.5049090967774391  Train loss: 1.3736114972829818
# 10 Test accuracy: 0.5786  Test loss: 1.2053236
# 11 1248 Train accuracy: 0.5122865072705529  Train loss: 1.3537728973952208
# 11 Test accuracy: 0.6333  Test loss: 1.031341
# 12 1248 Train accuracy: 0.5184343490004539  Train loss: 1.334163003563881
# 12 Test accuracy: 0.6157  Test loss: 1.0860294
# 13 1248 Train accuracy: 0.5251282105537561  Train loss: 1.3169443152501032
# 13 Test accuracy: 0.6121  Test loss: 1.0983459
# 14 1248 Train accuracy: 0.5299134254881314  Train loss: 1.3004374205214637
# 14 Test accuracy: 0.5923  Test loss: 1.1749133
# 15 1248 Train accuracy: 0.5353939449389775  Train loss: 1.2852213128407797
# 15 Test accuracy: 0.5539  Test loss: 1.3120254
# 16 1248 Train accuracy: 0.5400378840044141  Train loss: 1.2743133737891912
# Early stopping, best loss:  1.031341
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.2957575845718384  Train loss: 1.9452994132041932
# 1 Test accuracy: 0.3732  Test loss: 1.6770222
# 2 1248 Train accuracy: 0.3400000092387199  Train loss: 1.816221742630005
# 2 Test accuracy: 0.356  Test loss: 1.8337032
# 3 1248 Train accuracy: 0.3583838478724162  Train loss: 1.7554986810684203
# 3 Test accuracy: 0.4602  Test loss: 1.4678811
# 4 1248 Train accuracy: 0.37060606956481934  Train loss: 1.713381667137146
# 4 Test accuracy: 0.4358  Test loss: 1.5611444
# 5 1248 Train accuracy: 0.3900606144666672  Train loss: 1.6702019853591918
# 5 Test accuracy: 0.3631  Test loss: 1.8417243
# 6 1248 Train accuracy: 0.3987878871957461  Train loss: 1.6417458573977153
# 6 Test accuracy: 0.4441  Test loss: 1.5420789
# 7 1248 Train accuracy: 0.4084848568269185  Train loss: 1.617438806125096
# 7 Test accuracy: 0.4635  Test loss: 1.5423008
# 8 1248 Train accuracy: 0.41568182677030563  Train loss: 1.5991729345917702
# Early stopping, best loss:  1.4678811
# time: 3h 40min 37s
