# %% [markdown]
# # **To use Tensorflow Version 1**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# # **Mount the Google Drive**

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#define your folder or create one in your google drive
root_path = '/content/drive/My Drive/ex_60/'
os.chdir(root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Record the time execution per code section**

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=b825ccfafe1efbeb1696307fbce4538e422d33ae08ca8d53bea341217a876454
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %% [markdown]
# #**Ngrok : Running tensorboard inside Google Colab**

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
LOG_DIR = '/content/drive/My Drive/ex_40/log'
#LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # **Data Preparation**

# %%
# Downloading cifar-10-python files
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -xvzf cifar-10-python.tar.gz
# Out:
# --2020-04-13 15:39:09--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  29.9MB/s    in 6.1s
#
# 2020-04-13 15:39:15 (26.6 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# time: 13.9 s

# %%
# Provided on https://www.cs.toronto.edu/~kriz/cifar.html 
# Given a "pickled" file, returns a dictionary containing the image data
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
# time: 2.35 ms

# %% [markdown]
# The training data is stored in four files, which are read and merged.

# %%
import numpy as np

for file_no in range(4):
    # Obtain data dictionary from each file
    filename = "cifar-10-batches-py/data_batch_" + str(file_no + 1)
    image_batch = unpickle(filename)
    # First file, create numpy arrays containing data & labels
    if file_no == 0:
        # Reshape to 32x32 image with 3 channels (RGB), which is made to be the last axes
        image_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_labels = image_batch[b'labels']
    else: # Concatenate to one file
        new_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_data = np.concatenate([image_data, new_data])
        image_labels = np.concatenate([image_labels, image_batch[b'labels']])

print("Training data shape: ",image_data.shape)

# Create numpy array containing test data
test_batch = unpickle("cifar-10-batches-py/test_batch")
test_data = test_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
test_labels = test_batch[b'labels']

# Obtain label names from the meta data
label_names = unpickle("cifar-10-batches-py/batches.meta")[b'label_names']
label_names = [l.decode('UTF-8') for l in label_names]
# Out:
# Training data shape:  (40000, 32, 32, 3)
# time: 371 ms

# %% [markdown]
# ### **Image samples**

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10,9,figsize=(7,9))
plt.subplots_adjust(wspace=0.01, hspace=0.01)

for image_type in range(10):
    # Obtain indices of images in each group
    group = np.argwhere(image_labels == image_type)
    # Display 1st 5 images from each group
    for col in range(8):
        n = group[col][0]
        img_rgb = image_data[n]
        axes[image_type,col].imshow(img_rgb)
        axes[image_type,col].axis('off')
    # Display image labels    
    axes[image_type,8].axis('off')    
    axes[image_type,8].text(0.1,0.5,label_names[image_type], fontsize=12)

plt.show()
# Out:
# time: 2.28 s

# %% [markdown]
# ## Model Building
# ### Hyperparameters

# %%
import tensorflow as tf
# Fixed hyperparameters
height = 32
width = 32
channels = 3
outputs = 10

n_epochs = 500
# number of epochs to try to get a lower loss before stopping
early_stop_rounds = 4

# number of iterations, within epoch, to do an accuracy check
acc_check = 25

# Variable Hyperparameters
hyperparam_range = {'filter1':[16, 32, 64, 96],
                    'kernelsize_1':[3, 4, 5],
                    'filter2':[48, 64, 96, 128],
                    'kernelsize_2':[3, 4, 5],
                    'filter3':[64, 96, 128],
                    'kernelsize_3':[3, 4, 5],
                    'hidden_1':[60, 100, 125],
                    'hidden_2':[80, 100, 125],
                    'activation':['relu', 'lrelu', 'elu'],
                    'learning_rate':[0.001, 0.0015, 0.002, 0.003],
                    'batch_size':[32, 64, 128],
                    'momentum':[0.9, 0.95, 0.99],
                    'p_reduct':[0],
                    'optimizer':['adam', 'rmsprop', 'nesterov']
                   }

# Calculate the number of hyperparamter grid points
first_item = True
for key,values in hyperparam_range.items():
    count = len(values)
    if first_item:
        display = str(count)
        total = count
        first_item = False
    else:
        display = display + ' X ' + str(count)
        total *= count

print('The total number of possible hyperparameter combinations is ' + display + ' = ' + "{:,}".format(total))
# Out:
# The total number of possible hyperparameter combinations is 4 X 3 X 4 X 3 X 3 X 3 X 3 X 3 X 3 X 4 X 3 X 3 X 1 X 3 = 3,779,136
# time: 30.5 ms

# %% [markdown]
# ### Convolutional Layer

# %%
def conv_layer(tensor_input, layer_no, filters, ksize, kstride, activation_unit, momentum, phase_train):
    # convolutional layer with batch normalisation and max pooling
    with tf.name_scope("conv_layer" + str(layer_no)):
        conv = tf.layers.conv2d(
            tensor_input,
            filters=filters,
            kernel_size=ksize,
            strides=[kstride,kstride],
            padding="SAME",
            activation=None
        )

        conv_bn = tf.layers.batch_normalization(
            inputs=conv,
            axis=-1,
            momentum=0.9,
            epsilon=0.001,
            center=True,
            scale=True,
            trainable=True,
            training = phase_train
        )

        #apply activation unit
        conv_bn_relu =  activation_unit(conv_bn)

        max_pool = tf.nn.max_pool(
            conv_bn_relu,
            ksize=[1,2,2,1],
            strides=[1,2,2,1],
            padding="VALID"
        )
            
        dropout = tf.layers.dropout(
            max_pool,
            training = phase_train
        )
            
        return dropout
# Out:
# time: 23.7 ms

# %% [markdown]
# ### Graph defintion

# %%
def build_graph(hyperparam):
    # Retrieve hyperparamaters from dictionary   
    filter1 = hyperparam['filter1']
    kernelsize_1 = hyperparam['kernelsize_1']
    filter2 = hyperparam['filter2']
    kernelsize_2 = hyperparam['kernelsize_2']
    filter3 = hyperparam['filter3']
    kernelsize_3 = hyperparam['kernelsize_3']
    hidden_1 = hyperparam['hidden_1']
    hidden_2 = hyperparam['hidden_2']
    activation = hyperparam['activation']
    learning_rate = hyperparam['learning_rate']
    momentum = hyperparam['momentum']
    p_reduct =  hyperparam['p_reduct']
    optimizer_method = hyperparam['optimizer']
    
    patch_height = height - 2 * p_reduct
    patch_width = width - 2 * p_reduct
    
    if activation == 'elu':
        activation_unit = tf.nn.elu
    elif activation == 'lrelu':
        activation_unit = tf.nn.leaky_relu
    else:    
        activation_unit = tf.nn.relu
        
    graph = tf.Graph()
    with graph.as_default():
        X = tf.placeholder(shape=(None, patch_height, patch_width, channels), dtype=tf.float32)
        y = tf.placeholder(shape=(None), dtype=tf.int32)
        phase_train = tf.placeholder(tf.bool, name='phase_train')

        # 1st convolutional layer
        conv1 = conv_layer(X, 1, filter1, kernelsize_1, 2, activation_unit, momentum, phase_train)
        
        # 2nd convolutional layer
        conv2 = conv_layer(conv1, 2, filter2, kernelsize_2, 1, activation_unit, momentum, phase_train)
        
        # 3rd cnn
        conv3 = conv_layer(conv2, 3, filter3, kernelsize_3, 1, activation_unit, momentum, phase_train)
        
        # 1st fully connected (dense) layer
        fully_conn1 = tf.layers.dense(conv3, hidden_1, name="fully_conn1", activation=activation_unit)
        flat = tf.contrib.layers.flatten(fully_conn1)
        
        # 2nd fully connected layer
        fully_conn2 = tf.layers.dense(flat, hidden_2, name="fully_conn2", activation=activation_unit)
        
        # Output layer (no activation function, as this is built into cross-entropy)
        logits = tf.layers.dense(fully_conn2, outputs, name="logits")

        # Cross Entropy Loss
        with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
            loss = tf.reduce_mean(xentropy, name="loss")

        # Training    
        with tf.name_scope("train"):
            if optimizer_method == 'rmsprop':
                    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, momentum=0.9)
            elif optimizer_method == 'nesterov':
                    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov = True)
            else:    
                optimizer = tf.train.AdamOptimizer(learning_rate)
            training_op = optimizer.minimize(loss)
    
        # Initialization & Saver
        init = tf.global_variables_initializer()
        saver = tf.train.Saver() 
        
        return graph, X, y, phase_train, logits, loss, training_op, init, saver
# Out:
# time: 78 ms

# %% [markdown]
# ### Model Training

# %%
# Function to train model, returns minimised loss
def train_model(batch_size = 128):
    training_size = image_data.shape[0]
    no_batches = training_size // batch_size
    
    with graph.as_default():
        # Ensure batch normalisation gets updated
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)    
        # Add Evaluation metrics
        with tf.name_scope("evaluation"):
            correct = tf.nn.in_top_k(logits, y, 1)
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            acc_summary = tf.summary.scalar('Accuracy', accuracy)
            loss_summary = tf.summary.scalar('Loss', loss)
            
    # Initialise best loss for early stopping
    best_loss = 1e9
    best_acc = 1e9
    early_stopping = False
    
    # Run training
    with tf.Session(graph=graph) as sess:                     
        init.run()
        epoch = 0
        early_stop_count = 0
        # Initialise training accuracy sum
        sum_acc_train = 0.0
        sum_loss_train = 0.0
        count_train = 0
        while (epoch < n_epochs) and (not early_stopping):
            epoch += 1
            # Shuffle training data
            p = np.random.permutation(training_size)
            image_data_shuffle = image_data_patch[p]
            image_labels_shuffle = image_labels[p]
            for iteration in range(no_batches-1):
                # Train on mini-batch
                X_batch = image_data_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                y_batch = image_labels_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                sess.run([training_op, extra_update_ops], feed_dict={X: X_batch, y: y_batch, phase_train: True})
                # Evaluate model on current mini-batch
                if (iteration % acc_check == 0):
                    acc_train, loss_train = sess.run([accuracy, loss], feed_dict={X: X_batch,
                                                                                   y: y_batch,
                                                                                   phase_train: True})
                    # Update training average for current epoch
                    sum_acc_train += acc_train
                    sum_loss_train += loss_train
                    count_train += 1
                    mean_acc_train = sum_acc_train / count_train
                    mean_loss_train = sum_loss_train / count_train
                    print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train, end='\r')
                     
            # Print mean Train accuracy        
            print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train)
            train_summary = tf.Summary()
            train_summary.value.add(tag='eval/Accuracy', simple_value=mean_acc_train)
            train_summary.value.add(tag='eval/Loss', simple_value=mean_loss_train)
            file_writer_train.add_summary(train_summary, epoch)
            
            # Evaluate model on test data every epoch
            acc_test, loss_test, summary_str_acc_test, summary_str_loss_test = sess.run([accuracy, loss,
                                                                                         acc_summary,
                                                                                         loss_summary],
                                                                                        feed_dict={X: test_data_patch,
                                                                                                   y: test_labels,
                                                                                                   phase_train: False})
            # Check for mininimum loss
            if loss_test < best_loss:
                # Reset early stopping best loss and count
                best_loss = loss_test
                best_acc = acc_test
                best_train_acc = mean_acc_train
                best_train_loss = mean_loss_train
                early_stop_count = 0
                # Save model
                save_path = saver.save(sess, ckptfile)
            else:
                # Increment early stopping count
                early_stop_count += 1
            # Check if sufficient rounds (epochs) have passed without improvement
            if early_stop_count  > early_stop_rounds:
                # Flag early stopping, so training loop will stop
                early_stopping = True
                print("Early stopping, best loss: ", best_loss)
            else:    
                # Record and display test loss and accuracy
                file_writer_test.add_summary(summary_str_acc_test, epoch)
                file_writer_test.add_summary(summary_str_loss_test, epoch)
                print(epoch, "Test accuracy:", acc_test, " Test loss:", loss_test)
            
        # Return Best Loss obtaned and number of epochs
        return best_loss, best_acc, best_train_acc, best_train_loss, epoch
# Out:
# time: 90.6 ms

# %% [markdown]
# ### Random Hyperparameter Selection and Evaluation

# %%
import pandas as pd

import random
random.seed(261001)

import os.path
if not os.path.exists('./log'):
    os.makedirs('./log')
if not os.path.exists('./graphs'):
    os.makedirs('./graphs')
    
if(os.path.isfile('./log/model_hyperparam.csv')):
    hyperparam_df = pd.read_csv('./log/model_hyperparam.csv')
    new_results_file = False
else:
    new_results_file = True

# Random Model search
for n in range(60):
    # Create log directory using current timestamp
    from datetime import datetime
    now = datetime.now().strftime("%Y%m%dT%H%M%S")
    root_logdir = "./log"
    root_graphdir = "./graphs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    graphdir = "{}/run-{}/".format(root_graphdir, now)
    #root_modeldir = "./model"
    graphfile = graphdir
    ckptfile = graphdir + "checkpoint.ckpt"

    # Note that the graph is not written using same filewriter as the logging data.
    # This allows the logs to be viewed during training before the filewriter is closed
    file_writer_train = tf.summary.FileWriter(logdir + '/train')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    
    # tensorboard --logdir e:\Programming\TensorFlow\CIFAR-10\log
    # The command must be executed from same drive (E:) as the logdir

    tf.reset_default_graph()

    hyperparam_dict = {key:random.choice(values) for (key,values) in hyperparam_range.items()}
    print("Training Model with following hyperparameters:")
    print(hyperparam_dict)

    # Obtain graph and nodes required for training
    graph, X, y, phase_train, logits, loss, training_op, init, saver = build_graph(hyperparam = hyperparam_dict)
    
    # Write graph to file and close to avoid TensorBoard conflict
    file_writer_graph = tf.summary.FileWriter(graphfile, graph)
    file_writer_graph.close()

    # Extract image patches
    p_reduct =  hyperparam_dict['p_reduct']
    if p_reduct == 0:
        image_data_patch = image_data
        test_data_patch = test_data
    else:
        image_data_patch = image_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
        test_data_patch = test_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
    
    # Train the model
    best_loss, best_acc, best_train_acc, best_train_loss, no_epochs = train_model(batch_size = hyperparam_dict['batch_size'])
    
    # Add results to dictionary
    hyperparam_dict['best_loss'] = best_loss
    hyperparam_dict['best_acc'] = best_acc
    hyperparam_dict['best_train_acc'] = best_train_acc
    hyperparam_dict['best_train_loss'] = best_train_loss
    hyperparam_dict['no_epochs'] = no_epochs
    hyperparam_dict['logdir'] = logdir
    
    # Add results to dataframe
    if new_results_file:
        hyperparam_df = pd.DataFrame(hyperparam_dict, index=[0])
        new_results_file = False
    else:
        hyperparam_df = hyperparam_df.append(hyperparam_dict, ignore_index=True)
        
    # Write results file (don't wait until end, as next model may be interrupted)
    hyperparam_df.to_csv('./log/modelhyperparameter_60.csv', index=False)

    # Close filewriters
    file_writer_train.close()
    file_writer_test.close()
    
    # NOTE - From this point onwards there are only training logs.
    # Results and Conclusion are in a seperate notebook
# Out:
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# WARNING:tensorflow:From <ipython-input-10-d64d55e2381b>:10: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-10-d64d55e2381b>:21: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From <ipython-input-10-d64d55e2381b>:36: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From <ipython-input-11-b18cb819f30a>:43: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# 1 1248 Train accuracy: 0.3800000077486038  Train loss: 1.6786427545547484
# 1 Test accuracy: 0.4347  Test loss: 1.491398
# 2 1248 Train accuracy: 0.42787879556417463  Train loss: 1.5512138354778289
# 2 Test accuracy: 0.4341  Test loss: 1.5624467
# 3 1248 Train accuracy: 0.45212122003237404  Train loss: 1.492956596215566
# 3 Test accuracy: 0.5645  Test loss: 1.2076911
# 4 1248 Train accuracy: 0.47393940106034277  Train loss: 1.4392212206125259
# 4 Test accuracy: 0.5752  Test loss: 1.1895815
# 5 1248 Train accuracy: 0.49006061267852785  Train loss: 1.3982549171447753
# 5 Test accuracy: 0.5549  Test loss: 1.245006
# 6 1248 Train accuracy: 0.502020207842191  Train loss: 1.361592072447141
# 6 Test accuracy: 0.5579  Test loss: 1.2711741
# 7 1248 Train accuracy: 0.513073598231588  Train loss: 1.3306069602285113
# 7 Test accuracy: 0.6207  Test loss: 1.0572311
# 8 1248 Train accuracy: 0.5256818234920502  Train loss: 1.3003914703428745
# 8 Test accuracy: 0.6571  Test loss: 0.97717166
# 9 1248 Train accuracy: 0.5352188603745567  Train loss: 1.2807507848739623
# 9 Test accuracy: 0.6557  Test loss: 0.981916
# 10 1248 Train accuracy: 0.5404848535060882  Train loss: 1.2683283112049102
# 10 Test accuracy: 0.6457  Test loss: 0.99584043
# 11 1248 Train accuracy: 0.5477686002579603  Train loss: 1.2486002143946562
# 11 Test accuracy: 0.5876  Test loss: 1.1121147
# 12 1248 Train accuracy: 0.5550505099693934  Train loss: 1.2305828513701758
# 12 Test accuracy: 0.6522  Test loss: 0.9811326
# 13 1248 Train accuracy: 0.5620512870641855  Train loss: 1.2125681712077214
# 13 Test accuracy: 0.6941  Test loss: 0.88607424
# 14 1248 Train accuracy: 0.5672727323855673  Train loss: 1.198870136822973
# 14 Test accuracy: 0.6912  Test loss: 0.88962024
# 15 1248 Train accuracy: 0.5722424293359121  Train loss: 1.185902854045232
# 15 Test accuracy: 0.6809  Test loss: 0.89931494
# 16 1248 Train accuracy: 0.5769697021320462  Train loss: 1.175362250804901
# 16 Test accuracy: 0.6878  Test loss: 0.88383067
# 17 1248 Train accuracy: 0.5809269212624606  Train loss: 1.1652295325784123
# 17 Test accuracy: 0.6989  Test loss: 0.8535699
# 18 1248 Train accuracy: 0.5857239108946588  Train loss: 1.154268266359965
# 18 Test accuracy: 0.684  Test loss: 0.90284026
# 19 1248 Train accuracy: 0.5904944229753394  Train loss: 1.1423092459377489
# 19 Test accuracy: 0.6867  Test loss: 0.89735353
# 20 1248 Train accuracy: 0.5954545508027077  Train loss: 1.1291344898343085
# 20 Test accuracy: 0.6981  Test loss: 0.8719922
# 21 1248 Train accuracy: 0.5981241035177595  Train loss: 1.1216311398574283
# 21 Test accuracy: 0.7079  Test loss: 0.82453924
# 22 1248 Train accuracy: 0.6015151569518176  Train loss: 1.1126254805651579
# 22 Test accuracy: 0.7022  Test loss: 0.8567871
# 23 1248 Train accuracy: 0.6035573175419932  Train loss: 1.1066138018214184
# 23 Test accuracy: 0.662  Test loss: 0.9270928
# 24 1248 Train accuracy: 0.6061111164589723  Train loss: 1.1003469655911127
# 24 Test accuracy: 0.7241  Test loss: 0.79772747
# 25 1248 Train accuracy: 0.6090181873083115  Train loss: 1.0935798729896546
# 25 Test accuracy: 0.7254  Test loss: 0.7790218
# 26 1248 Train accuracy: 0.6112820568451515  Train loss: 1.0870834328119572
# 26 Test accuracy: 0.722  Test loss: 0.7959353
# 27 1248 Train accuracy: 0.6140965263931839  Train loss: 1.0803869267304738
# 27 Test accuracy: 0.7138  Test loss: 0.8237279
# 28 1248 Train accuracy: 0.6157575813787324  Train loss: 1.0762589145345347
# 28 Test accuracy: 0.7256  Test loss: 0.79599714
# 29 1248 Train accuracy: 0.6177011550911542  Train loss: 1.0709042581402022
# 29 Test accuracy: 0.7199  Test loss: 0.796063
# 30 1248 Train accuracy: 0.619777783413728  Train loss: 1.0652234929203988
# 30 Test accuracy: 0.7391  Test loss: 0.7539073
# 31 1248 Train accuracy: 0.6217399861158863  Train loss: 1.06085731104497
# 31 Test accuracy: 0.7186  Test loss: 0.80861026
# 32 1248 Train accuracy: 0.6230303087644279  Train loss: 1.05794618351385
# 32 Test accuracy: 0.7162  Test loss: 0.8051443
# 33 1248 Train accuracy: 0.6250872416387905  Train loss: 1.0517642556356661
# 33 Test accuracy: 0.7343  Test loss: 0.76459813
# 34 1248 Train accuracy: 0.6275757632010124  Train loss: 1.0460828303414234
# 34 Test accuracy: 0.745  Test loss: 0.74022967
# 35 1248 Train accuracy: 0.629489183136395  Train loss: 1.0412243408645903
# 35 Test accuracy: 0.73  Test loss: 0.7673781
# 36 1248 Train accuracy: 0.6309932716853088  Train loss: 1.0375537148614724
# 36 Test accuracy: 0.7364  Test loss: 0.7605077
# 37 1248 Train accuracy: 0.6319410376452111  Train loss: 1.0347780338010273
# 37 Test accuracy: 0.7359  Test loss: 0.75680584
# 38 1248 Train accuracy: 0.633540675561679  Train loss: 1.0306528036374796
# 38 Test accuracy: 0.7195  Test loss: 0.8040168
# 39 1248 Train accuracy: 0.6348562605717243  Train loss: 1.0272133122193507
# 39 Test accuracy: 0.7454  Test loss: 0.73878527
# 40 1248 Train accuracy: 0.6359848541766405  Train loss: 1.0246749952286482
# 40 Test accuracy: 0.7295  Test loss: 0.78442264
# 41 1248 Train accuracy: 0.6376053272078677  Train loss: 1.0207283569981411
# 41 Test accuracy: 0.7312  Test loss: 0.7628136
# 42 1248 Train accuracy: 0.638831174501351  Train loss: 1.0175847354389371
# 42 Test accuracy: 0.7365  Test loss: 0.7612253
# 43 1248 Train accuracy: 0.640000005669372  Train loss: 1.0143508326452833
# 43 Test accuracy: 0.7423  Test loss: 0.75164706
# 44 1248 Train accuracy: 0.6413774161582644  Train loss: 1.0104321457174692
# Early stopping, best loss:  0.73878527
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3593939483165741  Train loss: 1.7363763737678528
# 1 Test accuracy: 0.426  Test loss: 1.5558865
# 2 1248 Train accuracy: 0.40000000953674314  Train loss: 1.619058586359024
# 2 Test accuracy: 0.4813  Test loss: 1.4047332
# 3 1248 Train accuracy: 0.41777778724829356  Train loss: 1.562511962254842
# 3 Test accuracy: 0.5352  Test loss: 1.290277
# 4 1248 Train accuracy: 0.4340909184515476  Train loss: 1.5161935806274414
# 4 Test accuracy: 0.5644  Test loss: 1.2174246
# 5 1248 Train accuracy: 0.45406061470508574  Train loss: 1.4762793333530426
# 5 Test accuracy: 0.5627  Test loss: 1.2077723
# 6 1248 Train accuracy: 0.468585866689682  Train loss: 1.44461134771506
# 6 Test accuracy: 0.5466  Test loss: 1.2498531
# 7 1248 Train accuracy: 0.47896104659352984  Train loss: 1.4163981914520263
# 7 Test accuracy: 0.5974  Test loss: 1.1214151
# 8 1248 Train accuracy: 0.48848485566675665  Train loss: 1.3905709105730057
# 8 Test accuracy: 0.5888  Test loss: 1.1481857
# 9 1248 Train accuracy: 0.49973064667648737  Train loss: 1.3658563897344802
# 9 Test accuracy: 0.6222  Test loss: 1.0563378
# 10 1248 Train accuracy: 0.5081212186813354  Train loss: 1.347063380241394
# 10 Test accuracy: 0.5213  Test loss: 1.3119346
# 11 1248 Train accuracy: 0.5137190144712275  Train loss: 1.3309880758415569
# 11 Test accuracy: 0.6295  Test loss: 1.0506599
# 12 1248 Train accuracy: 0.518535359253486  Train loss: 1.315383986234665
# 12 Test accuracy: 0.6125  Test loss: 1.0989138
# 13 1248 Train accuracy: 0.5236829894322615  Train loss: 1.30135702756735
# 13 Test accuracy: 0.5826  Test loss: 1.186891
# 14 1248 Train accuracy: 0.5287013041973114  Train loss: 1.2914592554739543
# 14 Test accuracy: 0.6458  Test loss: 1.0059961
# 15 1248 Train accuracy: 0.534424247821172  Train loss: 1.278172235806783
# 15 Test accuracy: 0.6366  Test loss: 1.0027866
# 16 1248 Train accuracy: 0.5390909143164754  Train loss: 1.2670461735874414
# 16 Test accuracy: 0.6336  Test loss: 1.0345907
# 17 1248 Train accuracy: 0.5436007182037129  Train loss: 1.255352705927456
# 17 Test accuracy: 0.6234  Test loss: 1.0585071
# 18 1248 Train accuracy: 0.5470370422138108  Train loss: 1.2475184037950304
# 18 Test accuracy: 0.6556  Test loss: 0.9714637
# 19 1248 Train accuracy: 0.5503030355666814  Train loss: 1.2392513048648834
# 19 Test accuracy: 0.6643  Test loss: 0.9515242
# 20 1248 Train accuracy: 0.5541212172210217  Train loss: 1.2294426828026772
# 20 Test accuracy: 0.684  Test loss: 0.91008186
# 21 1248 Train accuracy: 0.5575757625840959  Train loss: 1.2211703525270734
# 21 Test accuracy: 0.69  Test loss: 0.8881668
# 22 1248 Train accuracy: 0.5607438066872683  Train loss: 1.2123973294279793
# 22 Test accuracy: 0.6901  Test loss: 0.88303673
# 23 1248 Train accuracy: 0.5636627192082613  Train loss: 1.2066407586180645
# 23 Test accuracy: 0.6613  Test loss: 0.9576801
# 24 1248 Train accuracy: 0.5665656616042057  Train loss: 1.2001060781876247
# 24 Test accuracy: 0.6804  Test loss: 0.9158334
# 25 1248 Train accuracy: 0.5685575807332992  Train loss: 1.1952313043117524
# 25 Test accuracy: 0.6569  Test loss: 0.95487005
# 26 1248 Train accuracy: 0.5703263452190619  Train loss: 1.1907288388564037
# 26 Test accuracy: 0.6529  Test loss: 0.9811791
# 27 1248 Train accuracy: 0.5726599376289933  Train loss: 1.184981355490508
# Early stopping, best loss:  0.88303673
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 1 623 Train accuracy: 0.3064615467190743  Train loss: 1.8838428258895874
# 1 Test accuracy: 0.2999  Test loss: 1.8135117
# 2 623 Train accuracy: 0.33907693073153494  Train loss: 1.7727645254135131
# 2 Test accuracy: 0.3074  Test loss: 1.7312039
# 3 623 Train accuracy: 0.35384616126616797  Train loss: 1.726971287727356
# 3 Test accuracy: 0.3964  Test loss: 1.6138833
# 4 623 Train accuracy: 0.37015385381877425  Train loss: 1.6936489236354828
# 4 Test accuracy: 0.4133  Test loss: 1.5168699
# 5 623 Train accuracy: 0.37772308439016344  Train loss: 1.6683648738861083
# 5 Test accuracy: 0.4399  Test loss: 1.5187124
# 6 623 Train accuracy: 0.38266667420665423  Train loss: 1.6516992457707722
# 6 Test accuracy: 0.4063  Test loss: 1.6227919
# 7 623 Train accuracy: 0.38839561202696393  Train loss: 1.6367606108529227
# 7 Test accuracy: 0.3645  Test loss: 1.7595277
# 8 623 Train accuracy: 0.3945384692773223  Train loss: 1.6224502754211425
# 8 Test accuracy: 0.3959  Test loss: 1.6572571
# 9 623 Train accuracy: 0.3975384693344434  Train loss: 1.6123331530888876
# 9 Test accuracy: 0.4721  Test loss: 1.4302074
# 10 623 Train accuracy: 0.400738469094038  Train loss: 1.606821632385254
# 10 Test accuracy: 0.4281  Test loss: 1.5176046
# 11 623 Train accuracy: 0.40156644092364746  Train loss: 1.6029045677185059
# 11 Test accuracy: 0.4639  Test loss: 1.4200393
# 12 623 Train accuracy: 0.40256410993635655  Train loss: 1.6036901724338533
# 12 Test accuracy: 0.4272  Test loss: 1.5339335
# 13 623 Train accuracy: 0.4042603624554781  Train loss: 1.6005140572327834
# 13 Test accuracy: 0.4096  Test loss: 1.5647824
# 14 623 Train accuracy: 0.4049230842292309  Train loss: 1.5944641539028712
# 14 Test accuracy: 0.3546  Test loss: 1.733275
# 15 623 Train accuracy: 0.40578462260961534  Train loss: 1.5914323040644327
# 15 Test accuracy: 0.4747  Test loss: 1.4268703
# 16 623 Train accuracy: 0.40815385358408096  Train loss: 1.5869185423851013
# Early stopping, best loss:  1.4200393
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.2572307759523392  Train loss: 2.025468053817749
# 1 Test accuracy: 0.2676  Test loss: 2.008777
# 2 623 Train accuracy: 0.29876923859119414  Train loss: 1.8843226528167725
# 2 Test accuracy: 0.3683  Test loss: 1.7328064
# 3 623 Train accuracy: 0.3294359052181244  Train loss: 1.802644271850586
# 3 Test accuracy: 0.3795  Test loss: 1.6839511
# 4 623 Train accuracy: 0.35000000774860385  Train loss: 1.746816223859787
# 4 Test accuracy: 0.4334  Test loss: 1.5643506
# 5 623 Train accuracy: 0.3629538538455963  Train loss: 1.7118644790649413
# 5 Test accuracy: 0.3739  Test loss: 1.7652347
# 6 623 Train accuracy: 0.3760000075896581  Train loss: 1.679703807036082
# 6 Test accuracy: 0.4028  Test loss: 1.6375307
# 7 623 Train accuracy: 0.3855824255943298  Train loss: 1.6577185576302664
# 7 Test accuracy: 0.4328  Test loss: 1.6100283
# 8 623 Train accuracy: 0.39530770033597945  Train loss: 1.632869200706482
# 8 Test accuracy: 0.3897  Test loss: 1.7404681
# 9 623 Train accuracy: 0.4038974440097809  Train loss: 1.6150556484858194
# 9 Test accuracy: 0.4563  Test loss: 1.5264199
# 10 623 Train accuracy: 0.4117538551092148  Train loss: 1.5953811960220337
# 10 Test accuracy: 0.4708  Test loss: 1.4351909
# 11 623 Train accuracy: 0.41594406496394765  Train loss: 1.5845961631428112
# 11 Test accuracy: 0.3935  Test loss: 1.763518
# 12 623 Train accuracy: 0.4222051375110944  Train loss: 1.5691169981161754
# 12 Test accuracy: 0.5164  Test loss: 1.3580757
# 13 623 Train accuracy: 0.42660355989749615  Train loss: 1.557995826281034
# 13 Test accuracy: 0.4464  Test loss: 1.5106801
# 14 623 Train accuracy: 0.4330549550056457  Train loss: 1.5420504474639893
# 14 Test accuracy: 0.4549  Test loss: 1.4927875
# 15 623 Train accuracy: 0.43733334374427796  Train loss: 1.528924607594808
# 15 Test accuracy: 0.4617  Test loss: 1.5174288
# 16 623 Train accuracy: 0.44192308753728865  Train loss: 1.5163961696624755
# 16 Test accuracy: 0.4177  Test loss: 1.6974633
# 17 623 Train accuracy: 0.4453212778708514  Train loss: 1.508005895614624
# 17 Test accuracy: 0.5267  Test loss: 1.294207
# 18 623 Train accuracy: 0.4489230881134669  Train loss: 1.4984998133447436
# 18 Test accuracy: 0.4551  Test loss: 1.5155352
# 19 623 Train accuracy: 0.45253442444299397  Train loss: 1.4889116184335005
# 19 Test accuracy: 0.4927  Test loss: 1.4167868
# 20 623 Train accuracy: 0.455015396296978  Train loss: 1.482256662607193
# 20 Test accuracy: 0.5524  Test loss: 1.260441
# 21 623 Train accuracy: 0.4584029423055195  Train loss: 1.4733097446532477
# 21 Test accuracy: 0.4447  Test loss: 1.6519918
# 22 623 Train accuracy: 0.46128672534769233  Train loss: 1.4653377405079928
# 22 Test accuracy: 0.5561  Test loss: 1.2403746
# 23 623 Train accuracy: 0.46405352390330773  Train loss: 1.458292384562285
# 23 Test accuracy: 0.4687  Test loss: 1.5645236
# 24 623 Train accuracy: 0.4667179611325264  Train loss: 1.4519154796997706
# 24 Test accuracy: 0.5625  Test loss: 1.2118009
# 25 623 Train accuracy: 0.46934155111312864  Train loss: 1.4458561429977417
# 25 Test accuracy: 0.5155  Test loss: 1.3911766
# 26 623 Train accuracy: 0.47190533839739285  Train loss: 1.438353386750588
# 26 Test accuracy: 0.5699  Test loss: 1.179707
# 27 623 Train accuracy: 0.47512252039379543  Train loss: 1.431684924055029
# 27 Test accuracy: 0.5886  Test loss: 1.1497871
# 28 623 Train accuracy: 0.4774505630135536  Train loss: 1.4272788059711456
# 28 Test accuracy: 0.517  Test loss: 1.3718617
# 29 623 Train accuracy: 0.48072149926218494  Train loss: 1.4202330203714042
# 29 Test accuracy: 0.5488  Test loss: 1.2372453
# 30 623 Train accuracy: 0.48322052697340645  Train loss: 1.4140522418816885
# 30 Test accuracy: 0.5302  Test loss: 1.3401421
# 31 623 Train accuracy: 0.48587594493742914  Train loss: 1.4075531461161952
# 31 Test accuracy: 0.5813  Test loss: 1.1755217
# 32 623 Train accuracy: 0.48792309157550334  Train loss: 1.401118789166212
# Early stopping, best loss:  1.1497871
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3563076987862587  Train loss: 1.7441002368927
# 1 Test accuracy: 0.4394  Test loss: 1.5375267
# 2 623 Train accuracy: 0.3935384692251682  Train loss: 1.6387278938293457
# 2 Test accuracy: 0.4864  Test loss: 1.4477326
# 3 623 Train accuracy: 0.42338462521632514  Train loss: 1.5625581725438435
# 3 Test accuracy: 0.4718  Test loss: 1.4644971
# 4 623 Train accuracy: 0.4400000111013651  Train loss: 1.5193624603748321
# 4 Test accuracy: 0.5433  Test loss: 1.2705725
# 5 623 Train accuracy: 0.4509538581967354  Train loss: 1.4865606546401977
# 5 Test accuracy: 0.5185  Test loss: 1.3309507
# 6 623 Train accuracy: 0.469128218938907  Train loss: 1.4476276111602784
# 6 Test accuracy: 0.5653  Test loss: 1.2053889
# 7 623 Train accuracy: 0.4810549593397549  Train loss: 1.422648083141872
# 7 Test accuracy: 0.5871  Test loss: 1.1596208
# 8 623 Train accuracy: 0.48807693798094987  Train loss: 1.398647932112217
# 8 Test accuracy: 0.5902  Test loss: 1.1405108
# 9 623 Train accuracy: 0.4949059987399313  Train loss: 1.3801670461230808
# 9 Test accuracy: 0.496  Test loss: 1.4915404
# 10 623 Train accuracy: 0.5033846317827702  Train loss: 1.363096742630005
# 10 Test accuracy: 0.5608  Test loss: 1.2568854
# 11 623 Train accuracy: 0.5091468699682843  Train loss: 1.350100172216242
# 11 Test accuracy: 0.5251  Test loss: 1.3250529
# 12 623 Train accuracy: 0.513538478637735  Train loss: 1.3401555907726288
# 12 Test accuracy: 0.5847  Test loss: 1.1633236
# 13 623 Train accuracy: 0.5185798990038725  Train loss: 1.3281595235604506
# Early stopping, best loss:  1.1405108
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.2800000083446503  Train loss: 1.894711790084839
# 1 Test accuracy: 0.3473  Test loss: 1.732137
# 2 1248 Train accuracy: 0.33363637238740923  Train loss: 1.7662766671180725
# 2 Test accuracy: 0.4343  Test loss: 1.5414041
# 3 1248 Train accuracy: 0.34989899933338164  Train loss: 1.7336619679133098
# 3 Test accuracy: 0.4158  Test loss: 1.5815583
# 4 1248 Train accuracy: 0.37757576644420626  Train loss: 1.6753683829307555
# 4 Test accuracy: 0.3803  Test loss: 1.7272836
# 5 1248 Train accuracy: 0.3964848567247391  Train loss: 1.6318466367721558
# 5 Test accuracy: 0.4386  Test loss: 1.5271693
# 6 1248 Train accuracy: 0.40797980586687727  Train loss: 1.6027403767903645
# 6 Test accuracy: 0.4633  Test loss: 1.4304639
# 7 1248 Train accuracy: 0.4200865878377642  Train loss: 1.5759712839126587
# 7 Test accuracy: 0.4438  Test loss: 1.4952031
# 8 1248 Train accuracy: 0.4300000074505806  Train loss: 1.5508692681789398
# 8 Test accuracy: 0.5272  Test loss: 1.2951328
# 9 1248 Train accuracy: 0.43602694325976904  Train loss: 1.5309885406494141
# 9 Test accuracy: 0.5579  Test loss: 1.239516
# 10 1248 Train accuracy: 0.44224243134260177  Train loss: 1.5152384834289552
# 10 Test accuracy: 0.5484  Test loss: 1.2468046
# 11 1248 Train accuracy: 0.4494765905358575  Train loss: 1.4975692346963017
# 11 Test accuracy: 0.5302  Test loss: 1.2895819
# 12 1248 Train accuracy: 0.456767683327198  Train loss: 1.479557447731495
# 12 Test accuracy: 0.5685  Test loss: 1.1780465
# 13 1248 Train accuracy: 0.4633566497380917  Train loss: 1.4619648002661192
# 13 Test accuracy: 0.5754  Test loss: 1.1777092
# 14 1248 Train accuracy: 0.46727273374795913  Train loss: 1.4503678750991822
# 14 Test accuracy: 0.5808  Test loss: 1.1993002
# 15 1248 Train accuracy: 0.4716363702217738  Train loss: 1.4393829181989033
# 15 Test accuracy: 0.5959  Test loss: 1.1216211
# 16 1248 Train accuracy: 0.4767803096398711  Train loss: 1.4262810081988573
# 16 Test accuracy: 0.6186  Test loss: 1.0895642
# 17 1248 Train accuracy: 0.4814973329445895  Train loss: 1.4143920383733861
# 17 Test accuracy: 0.6101  Test loss: 1.0997293
# 18 1248 Train accuracy: 0.486329973174466  Train loss: 1.401644319958157
# 18 Test accuracy: 0.6038  Test loss: 1.0988019
# 19 1248 Train accuracy: 0.4921212187566255  Train loss: 1.3892493468209317
# 19 Test accuracy: 0.5952  Test loss: 1.1234454
# 20 1248 Train accuracy: 0.49584849140048026  Train loss: 1.380244165480137
# 20 Test accuracy: 0.6233  Test loss: 1.0488026
# 21 1248 Train accuracy: 0.498816745366369  Train loss: 1.3732875401633127
# 21 Test accuracy: 0.5918  Test loss: 1.1484504
# 22 1248 Train accuracy: 0.5027272791754116  Train loss: 1.3646162497997283
# 22 Test accuracy: 0.5318  Test loss: 1.3417406
# 23 1248 Train accuracy: 0.5071673317059227  Train loss: 1.3549825059849283
# 23 Test accuracy: 0.6277  Test loss: 1.0482062
# 24 1248 Train accuracy: 0.5103787939250469  Train loss: 1.3460862443347772
# 24 Test accuracy: 0.6231  Test loss: 1.0567282
# 25 1248 Train accuracy: 0.5138424300909042  Train loss: 1.3376133268833161
# 25 Test accuracy: 0.6511  Test loss: 0.9678554
# 26 1248 Train accuracy: 0.5171328729391098  Train loss: 1.3294354134339552
# 26 Test accuracy: 0.6435  Test loss: 1.0004778
# 27 1248 Train accuracy: 0.5202469193714636  Train loss: 1.321658253537284
# 27 Test accuracy: 0.6437  Test loss: 0.9910971
# 28 1248 Train accuracy: 0.5237662395196302  Train loss: 1.31403574436903
# 28 Test accuracy: 0.6529  Test loss: 0.9920656
# 29 1248 Train accuracy: 0.5267502667986114  Train loss: 1.3057461672815782
# 29 Test accuracy: 0.6552  Test loss: 0.97841716
# 30 1248 Train accuracy: 0.529454550921917  Train loss: 1.2989739290475846
# Early stopping, best loss:  0.9678554
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3790769320726395  Train loss: 1.7151189851760864
# 1 Test accuracy: 0.4122  Test loss: 1.6387477
# 2 623 Train accuracy: 0.4280000105500221  Train loss: 1.5946575617790222
# 2 Test accuracy: 0.48  Test loss: 1.3993592
# 3 623 Train accuracy: 0.46112821797529857  Train loss: 1.5025593105951944
# 3 Test accuracy: 0.5587  Test loss: 1.212238
# 4 623 Train accuracy: 0.4760000137984753  Train loss: 1.4466352796554565
# 4 Test accuracy: 0.5856  Test loss: 1.1409512
# 5 623 Train accuracy: 0.4980923234224319  Train loss: 1.3933160591125489
# 5 Test accuracy: 0.473  Test loss: 1.5566442
# 6 623 Train accuracy: 0.5132307860255242  Train loss: 1.3532781207561493
# 6 Test accuracy: 0.5856  Test loss: 1.1448478
# 7 623 Train accuracy: 0.5240439737694604  Train loss: 1.3249905746323722
# 7 Test accuracy: 0.6017  Test loss: 1.1120975
# 8 623 Train accuracy: 0.5330769415944815  Train loss: 1.2976785480976105
# 8 Test accuracy: 0.6044  Test loss: 1.0991821
# 9 623 Train accuracy: 0.5419487368398243  Train loss: 1.2733187397321066
# 9 Test accuracy: 0.6074  Test loss: 1.109528
# 10 623 Train accuracy: 0.5498461731076241  Train loss: 1.255428352832794
# 10 Test accuracy: 0.6525  Test loss: 0.9765217
# 11 623 Train accuracy: 0.5554685510830446  Train loss: 1.238434161272916
# 11 Test accuracy: 0.6541  Test loss: 0.9694704
# 12 623 Train accuracy: 0.5607179684937  Train loss: 1.2263123945395151
# 12 Test accuracy: 0.6675  Test loss: 0.93367165
# 13 623 Train accuracy: 0.5661065288231923  Train loss: 1.2101528917826139
# 13 Test accuracy: 0.671  Test loss: 0.93191034
# 14 623 Train accuracy: 0.569978042117187  Train loss: 1.1969900558676039
# 14 Test accuracy: 0.6394  Test loss: 1.017461
# 15 623 Train accuracy: 0.5733743792772293  Train loss: 1.1872473514874777
# 15 Test accuracy: 0.5776  Test loss: 1.2256666
# 16 623 Train accuracy: 0.5785000203177333  Train loss: 1.1749385534226895
# 16 Test accuracy: 0.6617  Test loss: 0.95608515
# 17 623 Train accuracy: 0.582407260186532  Train loss: 1.1659807683439816
# 17 Test accuracy: 0.6732  Test loss: 0.9189612
# 18 623 Train accuracy: 0.5865983109672864  Train loss: 1.1548294297854105
# 18 Test accuracy: 0.6959  Test loss: 0.8619816
# 19 623 Train accuracy: 0.590866417100555  Train loss: 1.1453825271757025
# 19 Test accuracy: 0.675  Test loss: 0.91865456
# 20 623 Train accuracy: 0.594523097127676  Train loss: 1.1350325362682343
# 20 Test accuracy: 0.6491  Test loss: 1.0080099
# 21 623 Train accuracy: 0.5975970898071925  Train loss: 1.1260196655137198
# 21 Test accuracy: 0.6902  Test loss: 0.881346
# 22 623 Train accuracy: 0.6001678523963148  Train loss: 1.118427972793579
# 22 Test accuracy: 0.7036  Test loss: 0.8594951
# 23 623 Train accuracy: 0.6029164081811905  Train loss: 1.1104585151050401
# 23 Test accuracy: 0.7107  Test loss: 0.82586104
# 24 623 Train accuracy: 0.605333353554209  Train loss: 1.1029446902871132
# 24 Test accuracy: 0.6968  Test loss: 0.87108827
# 25 623 Train accuracy: 0.606769251036644  Train loss: 1.0988810984611512
# 25 Test accuracy: 0.7099  Test loss: 0.82189727
# 26 623 Train accuracy: 0.6089230971840712  Train loss: 1.0924307284905361
# 26 Test accuracy: 0.6924  Test loss: 0.86998516
# 27 623 Train accuracy: 0.6119658321583713  Train loss: 1.0854929531062092
# 27 Test accuracy: 0.7056  Test loss: 0.8473294
# 28 623 Train accuracy: 0.6151648552715778  Train loss: 1.0783724507263728
# 28 Test accuracy: 0.6033  Test loss: 1.1850399
# 29 623 Train accuracy: 0.6168700466279325  Train loss: 1.0737709072540547
# 29 Test accuracy: 0.6972  Test loss: 0.86124104
# 30 623 Train accuracy: 0.6180102765361468  Train loss: 1.0687118846575419
# 30 Test accuracy: 0.7158  Test loss: 0.80006194
# 31 623 Train accuracy: 0.6196327744568548  Train loss: 1.064133879676942
# 31 Test accuracy: 0.6915  Test loss: 0.8932402
# 32 623 Train accuracy: 0.6212692508660257  Train loss: 1.059426242262125
# 32 Test accuracy: 0.6584  Test loss: 0.99709904
# 33 623 Train accuracy: 0.6234592275005398  Train loss: 1.0541466428294326
# 33 Test accuracy: 0.7112  Test loss: 0.8151481
# 34 623 Train accuracy: 0.6249773955871077  Train loss: 1.0494050690707037
# 34 Test accuracy: 0.7242  Test loss: 0.7931321
# 35 623 Train accuracy: 0.6269011188745499  Train loss: 1.0445528569221496
# 35 Test accuracy: 0.7199  Test loss: 0.7965896
# 36 623 Train accuracy: 0.6284444643888208  Train loss: 1.0403367052475612
# 36 Test accuracy: 0.7172  Test loss: 0.8046188
# 37 623 Train accuracy: 0.6300374419463647  Train loss: 1.0361878855163986
# 37 Test accuracy: 0.7119  Test loss: 0.8396114
# 38 623 Train accuracy: 0.631773299214087  Train loss: 1.0310341043221323
# 38 Test accuracy: 0.7268  Test loss: 0.7806488
# 39 623 Train accuracy: 0.6336726036285742  Train loss: 1.0263259973281469
# 39 Test accuracy: 0.7218  Test loss: 0.7958468
# 40 623 Train accuracy: 0.6351230966895819  Train loss: 1.0226352215409278
# 40 Test accuracy: 0.7045  Test loss: 0.85875654
# 41 623 Train accuracy: 0.6364277870916739  Train loss: 1.018998198625518
# 41 Test accuracy: 0.7161  Test loss: 0.81920177
# 42 623 Train accuracy: 0.637934085627397  Train loss: 1.0162445769991193
# 42 Test accuracy: 0.7273  Test loss: 0.778098
# 43 623 Train accuracy: 0.6390268533035767  Train loss: 1.0127838756317316
# 43 Test accuracy: 0.724  Test loss: 0.806337
# 44 623 Train accuracy: 0.639804215471853  Train loss: 1.0102014165032993
# 44 Test accuracy: 0.7256  Test loss: 0.7865735
# 45 623 Train accuracy: 0.6413401905563143  Train loss: 1.0061911867459614
# 45 Test accuracy: 0.7226  Test loss: 0.78596914
# 46 623 Train accuracy: 0.6420200865035471  Train loss: 1.004024831160255
# 46 Test accuracy: 0.721  Test loss: 0.7898963
# 47 623 Train accuracy: 0.6433257151537753  Train loss: 1.0004893147184493
# 47 Test accuracy: 0.7271  Test loss: 0.77579534
# 48 623 Train accuracy: 0.6442820708329479  Train loss: 0.9982290683190028
# 48 Test accuracy: 0.7084  Test loss: 0.8269393
# 49 623 Train accuracy: 0.6449858908142362  Train loss: 0.996578844080166
# 49 Test accuracy: 0.7224  Test loss: 0.79581755
# 50 623 Train accuracy: 0.645907711827755  Train loss: 0.993419606590271
# 50 Test accuracy: 0.7296  Test loss: 0.7738088
# 51 623 Train accuracy: 0.6468778475476247  Train loss: 0.9907053536994784
# 51 Test accuracy: 0.7334  Test loss: 0.76711
# 52 623 Train accuracy: 0.648023688093974  Train loss: 0.9876452873761837
# 52 Test accuracy: 0.7389  Test loss: 0.7563146
# 53 623 Train accuracy: 0.6487199033318826  Train loss: 0.9855433361935165
# 53 Test accuracy: 0.7316  Test loss: 0.7547347
# 54 623 Train accuracy: 0.6496410450560075  Train loss: 0.9824694484693033
# 54 Test accuracy: 0.7039  Test loss: 0.84651214
# 55 623 Train accuracy: 0.6504951242858713  Train loss: 0.9803862629370256
# 55 Test accuracy: 0.7064  Test loss: 0.86797374
# 56 623 Train accuracy: 0.6513406787067652  Train loss: 0.9778817529337747
# 56 Test accuracy: 0.6872  Test loss: 0.8966256
# 57 623 Train accuracy: 0.6521133796687711  Train loss: 0.9762598545927751
# 57 Test accuracy: 0.7058  Test loss: 0.84368587
# 58 623 Train accuracy: 0.6529655365594502  Train loss: 0.9738729757687141
# Early stopping, best loss:  0.7547347
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3442424339056015  Train loss: 1.7531740427017213
# 1 Test accuracy: 0.3559  Test loss: 1.7587512
# 2 1248 Train accuracy: 0.3906060707569122  Train loss: 1.6548981833457947
# 2 Test accuracy: 0.4664  Test loss: 1.4416935
# 3 1248 Train accuracy: 0.4175757670402527  Train loss: 1.5887894177436828
# 3 Test accuracy: 0.5202  Test loss: 1.3224074
# 4 1248 Train accuracy: 0.43393940299749373  Train loss: 1.5418334099650384
# 4 Test accuracy: 0.5223  Test loss: 1.2967124
# 5 1248 Train accuracy: 0.4455757658481598  Train loss: 1.5085241255760193
# 5 Test accuracy: 0.4893  Test loss: 1.4557291
# 6 1248 Train accuracy: 0.4570707149306933  Train loss: 1.4795165075858434
# 6 Test accuracy: 0.5105  Test loss: 1.3615142
# 7 1248 Train accuracy: 0.4644155924660819  Train loss: 1.4575978260380882
# 7 Test accuracy: 0.409  Test loss: 1.785405
# 8 1248 Train accuracy: 0.46863637171685696  Train loss: 1.4450433705747128
# 8 Test accuracy: 0.5594  Test loss: 1.1977015
# 9 1248 Train accuracy: 0.47367004136244456  Train loss: 1.4315451481607224
# 9 Test accuracy: 0.5596  Test loss: 1.2193912
# 10 1248 Train accuracy: 0.47927273458242414  Train loss: 1.4197187983989716
# 10 Test accuracy: 0.4689  Test loss: 1.5633569
# 11 1248 Train accuracy: 0.48523416660048746  Train loss: 1.4100047692385587
# 11 Test accuracy: 0.5858  Test loss: 1.1857482
# 12 1248 Train accuracy: 0.48954546118776004  Train loss: 1.4024871559937795
# 12 Test accuracy: 0.5812  Test loss: 1.1733787
# 13 1248 Train accuracy: 0.49403264054885276  Train loss: 1.3896801218619714
# 13 Test accuracy: 0.579  Test loss: 1.1899283
# 14 1248 Train accuracy: 0.4985281446150371  Train loss: 1.3780027346100125
# 14 Test accuracy: 0.5199  Test loss: 1.3535655
# 15 1248 Train accuracy: 0.5015353595415751  Train loss: 1.3711030566692353
# 15 Test accuracy: 0.5738  Test loss: 1.18639
# 16 1248 Train accuracy: 0.5048484908044338  Train loss: 1.3624618302285672
# 16 Test accuracy: 0.5877  Test loss: 1.1368291
# 17 1248 Train accuracy: 0.5082352999028038  Train loss: 1.3540951198690079
# 17 Test accuracy: 0.5868  Test loss: 1.1998484
# 18 1248 Train accuracy: 0.5102693659729428  Train loss: 1.3494302204582427
# 18 Test accuracy: 0.5669  Test loss: 1.1984034
# 19 1248 Train accuracy: 0.5127910741379387  Train loss: 1.346813168211987
# 19 Test accuracy: 0.5757  Test loss: 1.1957878
# 20 1248 Train accuracy: 0.5150909145474434  Train loss: 1.3414001586437225
# 20 Test accuracy: 0.5874  Test loss: 1.15656
# 21 1248 Train accuracy: 0.5165368018831525  Train loss: 1.3381554769334338
# 21 Test accuracy: 0.5966  Test loss: 1.1290833
# 22 1248 Train accuracy: 0.5189531732960181  Train loss: 1.333357990763404
# 22 Test accuracy: 0.5625  Test loss: 1.2376028
# 23 1248 Train accuracy: 0.5201317575444346  Train loss: 1.3307714121756347
# 23 Test accuracy: 0.5488  Test loss: 1.271017
# 24 1248 Train accuracy: 0.5218939446657896  Train loss: 1.3265757398307323
# 24 Test accuracy: 0.5946  Test loss: 1.1242213
# 25 1248 Train accuracy: 0.5241212173700333  Train loss: 1.3213624357700349
# 25 Test accuracy: 0.6153  Test loss: 1.0864698
# 26 1248 Train accuracy: 0.5260139911220624  Train loss: 1.3169229944394185
# 26 Test accuracy: 0.5992  Test loss: 1.1241516
# 27 1248 Train accuracy: 0.52772166620802  Train loss: 1.3134637374789626
# 27 Test accuracy: 0.6028  Test loss: 1.1289123
# 28 1248 Train accuracy: 0.5287445938587189  Train loss: 1.3100687296049935
# 28 Test accuracy: 0.5784  Test loss: 1.1946498
# 29 1248 Train accuracy: 0.5298641639125758  Train loss: 1.3059566760474237
# 29 Test accuracy: 0.6278  Test loss: 1.0625985
# 30 1248 Train accuracy: 0.5317979847987493  Train loss: 1.3020784673690795
# 30 Test accuracy: 0.5969  Test loss: 1.1299335
# 31 1248 Train accuracy: 0.5329423314717509  Train loss: 1.298479158032325
# 31 Test accuracy: 0.5872  Test loss: 1.1437088
# 32 1248 Train accuracy: 0.5345454594492912  Train loss: 1.2949345084652304
# 32 Test accuracy: 0.6298  Test loss: 1.0450486
# 33 1248 Train accuracy: 0.5363085448019432  Train loss: 1.2905982747222438
# 33 Test accuracy: 0.6185  Test loss: 1.0886996
# 34 1248 Train accuracy: 0.5378431420641787  Train loss: 1.2874843290272882
# 34 Test accuracy: 0.5775  Test loss: 1.234607
# 35 1248 Train accuracy: 0.5392034679140364  Train loss: 1.2837956545352935
# 35 Test accuracy: 0.6379  Test loss: 1.0269824
# 36 1248 Train accuracy: 0.5397979844444328  Train loss: 1.2824590150846376
# 36 Test accuracy: 0.6032  Test loss: 1.1063647
# 37 1248 Train accuracy: 0.5413431659421405  Train loss: 1.2793760870920645
# 37 Test accuracy: 0.6231  Test loss: 1.0611027
# 38 1248 Train accuracy: 0.5425996855999294  Train loss: 1.2759199540866049
# 38 Test accuracy: 0.6103  Test loss: 1.0952748
# 39 1248 Train accuracy: 0.5435742081892796  Train loss: 1.2727766009171804
# 39 Test accuracy: 0.6417  Test loss: 1.0181073
# 40 1248 Train accuracy: 0.5443333379328251  Train loss: 1.2710680820643903
# 40 Test accuracy: 0.5537  Test loss: 1.3080313
# 41 1248 Train accuracy: 0.544951963148466  Train loss: 1.2695993188241632
# 41 Test accuracy: 0.5904  Test loss: 1.1672018
# 42 1248 Train accuracy: 0.5460173205250786  Train loss: 1.2674889330636887
# 42 Test accuracy: 0.6116  Test loss: 1.0891627
# 43 1248 Train accuracy: 0.5472868262196696  Train loss: 1.264572778330293
# 43 Test accuracy: 0.5786  Test loss: 1.1732432
# 44 1248 Train accuracy: 0.5478512441976504  Train loss: 1.262942015691237
# Early stopping, best loss:  1.0181073
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.35138462215662003  Train loss: 1.8017261123657227
# 1 Test accuracy: 0.4435  Test loss: 1.640933
# 2 623 Train accuracy: 0.3947692383825779  Train loss: 1.6579936122894288
# 2 Test accuracy: 0.507  Test loss: 1.3483825
# 3 623 Train accuracy: 0.43548719098170596  Train loss: 1.5598030471801758
# 3 Test accuracy: 0.4875  Test loss: 1.583493
# 4 623 Train accuracy: 0.4635384751111269  Train loss: 1.4926362121105194
# 4 Test accuracy: 0.5336  Test loss: 1.4082869
# 5 623 Train accuracy: 0.4802461686730385  Train loss: 1.4515904865264893
# 5 Test accuracy: 0.5005  Test loss: 1.6457642
# 6 623 Train accuracy: 0.49405129755536714  Train loss: 1.4161129768689473
# 6 Test accuracy: 0.5587  Test loss: 1.2807367
# 7 623 Train accuracy: 0.5073406758052962  Train loss: 1.382018311704908
# 7 Test accuracy: 0.485  Test loss: 1.8256414
# 8 623 Train accuracy: 0.5204615557566286  Train loss: 1.3526800954341889
# 8 Test accuracy: 0.5665  Test loss: 1.3896924
# 9 623 Train accuracy: 0.5277265135778321  Train loss: 1.3378099791208904
# 9 Test accuracy: 0.6281  Test loss: 1.1207557
# 10 623 Train accuracy: 0.5366154028475285  Train loss: 1.318787223815918
# 10 Test accuracy: 0.5699  Test loss: 1.3080002
# 11 623 Train accuracy: 0.5421538645841859  Train loss: 1.307740410891446
# 11 Test accuracy: 0.6018  Test loss: 1.192543
# 12 623 Train accuracy: 0.5495384802669286  Train loss: 1.2912562096118927
# 12 Test accuracy: 0.5436  Test loss: 1.6607898
# 13 623 Train accuracy: 0.5559763503303895  Train loss: 1.2764120221138
# 13 Test accuracy: 0.6761  Test loss: 0.9551586
# 14 623 Train accuracy: 0.5611428762546607  Train loss: 1.264057786975588
# 14 Test accuracy: 0.5511  Test loss: 1.4799827
# 15 623 Train accuracy: 0.5655384807785352  Train loss: 1.2536354031562804
# 15 Test accuracy: 0.686  Test loss: 0.9438047
# 16 623 Train accuracy: 0.5693077117390931  Train loss: 1.2443127991259098
# 16 Test accuracy: 0.6809  Test loss: 0.9369095
# 17 623 Train accuracy: 0.5744434584063642  Train loss: 1.2313543438911438
# 17 Test accuracy: 0.6524  Test loss: 1.1981795
# 18 623 Train accuracy: 0.5784615580406454  Train loss: 1.222454094754325
# 18 Test accuracy: 0.6681  Test loss: 0.96316594
# 19 623 Train accuracy: 0.5823481977142786  Train loss: 1.2135515972187645
# 19 Test accuracy: 0.6331  Test loss: 1.0956489
# 20 623 Train accuracy: 0.5867077118903399  Train loss: 1.2029855459928513
# 20 Test accuracy: 0.6139  Test loss: 1.2956511
# 21 623 Train accuracy: 0.5891868328622409  Train loss: 1.196562361036028
# 21 Test accuracy: 0.6922  Test loss: 0.91720027
# 22 623 Train accuracy: 0.5922797399894758  Train loss: 1.1885078726031564
# 22 Test accuracy: 0.6041  Test loss: 1.2471082
# 23 623 Train accuracy: 0.5948628960096318  Train loss: 1.1819832246199897
# 23 Test accuracy: 0.6432  Test loss: 1.1522465
# 24 623 Train accuracy: 0.598615404330194  Train loss: 1.1731077003479005
# 24 Test accuracy: 0.6914  Test loss: 0.93953806
# 25 623 Train accuracy: 0.6011815581917763  Train loss: 1.1669941999435425
# 25 Test accuracy: 0.66  Test loss: 1.0942094
# 26 623 Train accuracy: 0.6037870019788926  Train loss: 1.1601564574241638
# Early stopping, best loss:  0.91720027
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3309091007709503  Train loss: 1.7846259951591492
# 1 Test accuracy: 0.4467  Test loss: 1.5159408
# 2 1248 Train accuracy: 0.38878788888454435  Train loss: 1.6688982474803924
# 2 Test accuracy: 0.4947  Test loss: 1.3812326
# 3 1248 Train accuracy: 0.41111112117767334  Train loss: 1.5964506109555563
# 3 Test accuracy: 0.458  Test loss: 1.4803935
# 4 1248 Train accuracy: 0.4351515243947506  Train loss: 1.5451448249816895
# 4 Test accuracy: 0.4945  Test loss: 1.4175844
# 5 1248 Train accuracy: 0.4523636447191238  Train loss: 1.502078643798828
# 5 Test accuracy: 0.5681  Test loss: 1.1915734
# 6 1248 Train accuracy: 0.4664646542072296  Train loss: 1.462077819108963
# 6 Test accuracy: 0.5937  Test loss: 1.1422447
# 7 1248 Train accuracy: 0.47575758269854956  Train loss: 1.4362386475290572
# 7 Test accuracy: 0.5973  Test loss: 1.1127851
# 8 1248 Train accuracy: 0.48325758241117  Train loss: 1.4187924054265022
# 8 Test accuracy: 0.6059  Test loss: 1.0882596
# 9 1248 Train accuracy: 0.49373738037215337  Train loss: 1.3956698554091984
# 9 Test accuracy: 0.6375  Test loss: 1.0391996
# 10 1248 Train accuracy: 0.5024242491126061  Train loss: 1.3731368691921235
# 10 Test accuracy: 0.5988  Test loss: 1.1187992
# 11 1248 Train accuracy: 0.5073278300328689  Train loss: 1.357641106302088
# 11 Test accuracy: 0.6079  Test loss: 1.1346459
# 12 1248 Train accuracy: 0.5144444508850574  Train loss: 1.342158955236276
# 12 Test accuracy: 0.6082  Test loss: 1.0938082
# 13 1248 Train accuracy: 0.519533805847168  Train loss: 1.3301537455962253
# 13 Test accuracy: 0.5996  Test loss: 1.1492305
# 14 1248 Train accuracy: 0.5244155907205172  Train loss: 1.3161605372599192
# Early stopping, best loss:  1.0391996
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.2611806799586003  Train loss: 2.041472086539635
# 1 Test accuracy: 0.3534  Test loss: 1.7200536
# 2 310 Train accuracy: 0.3142516403817214  Train loss: 1.8523467916708727
# 2 Test accuracy: 0.3506  Test loss: 1.791027
# 3 310 Train accuracy: 0.33631484917341137  Train loss: 1.7842064973635552
# 3 Test accuracy: 0.4247  Test loss: 1.5641958
# 4 310 Train accuracy: 0.35450208745896816  Train loss: 1.736291309961906
# 4 Test accuracy: 0.416  Test loss: 1.6232281
# 5 310 Train accuracy: 0.36803816499618386  Train loss: 1.6940808277863724
# 5 Test accuracy: 0.3994  Test loss: 1.6866852
# 6 310 Train accuracy: 0.3818326392808022  Train loss: 1.6585208177566528
# 6 Test accuracy: 0.4695  Test loss: 1.4452482
# 7 310 Train accuracy: 0.3915154625262533  Train loss: 1.6364427700147524
# 7 Test accuracy: 0.4086  Test loss: 1.7072583
# 8 310 Train accuracy: 0.4032498525742155  Train loss: 1.6112007258030085
# 8 Test accuracy: 0.3662  Test loss: 1.9362115
# 9 310 Train accuracy: 0.4139667412536776  Train loss: 1.5852716284939365
# 9 Test accuracy: 0.4875  Test loss: 1.4084324
# 10 310 Train accuracy: 0.42098986454881154  Train loss: 1.5679922021352328
# 10 Test accuracy: 0.4084  Test loss: 1.7785387
# 11 310 Train accuracy: 0.42836233697362713  Train loss: 1.5503310356940423
# 11 Test accuracy: 0.5323  Test loss: 1.2874343
# 12 310 Train accuracy: 0.4330649986767616  Train loss: 1.535144601876919
# 12 Test accuracy: 0.5474  Test loss: 1.2438855
# 13 310 Train accuracy: 0.4402091666703393  Train loss: 1.5150260967615794
# 13 Test accuracy: 0.4466  Test loss: 1.6376355
# 14 310 Train accuracy: 0.4465882975894671  Train loss: 1.4990554248893655
# 14 Test accuracy: 0.5466  Test loss: 1.2633681
# 15 310 Train accuracy: 0.4527131804671043  Train loss: 1.4864614015970474
# 15 Test accuracy: 0.5262  Test loss: 1.3250518
# 16 310 Train accuracy: 0.45781157047559434  Train loss: 1.4744803103116841
# 16 Test accuracy: 0.5041  Test loss: 1.439018
# 17 310 Train accuracy: 0.46150338659863666  Train loss: 1.4632265044553248
# 17 Test accuracy: 0.5738  Test loss: 1.1840947
# 18 310 Train accuracy: 0.46740210855491143  Train loss: 1.4501205703132174
# 18 Test accuracy: 0.5083  Test loss: 1.3650062
# 19 310 Train accuracy: 0.47167561275635655  Train loss: 1.4391226831235384
# 19 Test accuracy: 0.5546  Test loss: 1.2624042
# 20 310 Train accuracy: 0.4757901027512092  Train loss: 1.4285621363383072
# 20 Test accuracy: 0.5268  Test loss: 1.363932
# 21 310 Train accuracy: 0.48084731926739  Train loss: 1.4159449290879917
# 21 Test accuracy: 0.6109  Test loss: 1.0954285
# 22 310 Train accuracy: 0.4852550559892104  Train loss: 1.4054817640698039
# 22 Test accuracy: 0.5971  Test loss: 1.1240635
# 23 310 Train accuracy: 0.4896943306793337  Train loss: 1.394608456155528
# 23 Test accuracy: 0.6005  Test loss: 1.1105983
# 24 310 Train accuracy: 0.49383820352168417  Train loss: 1.38486903714828
# 24 Test accuracy: 0.592  Test loss: 1.1578168
# 25 310 Train accuracy: 0.49729278507140967  Train loss: 1.3746705731978783
# 25 Test accuracy: 0.5852  Test loss: 1.1622834
# 26 310 Train accuracy: 0.5006192375701912  Train loss: 1.3661605488266466
# Early stopping, best loss:  1.0954285
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.27090909898281096  Train loss: 1.9153497099876404
# 1 Test accuracy: 0.3096  Test loss: 1.7914791
# 2 1248 Train accuracy: 0.31090910017490386  Train loss: 1.8335448217391968
# 2 Test accuracy: 0.4137  Test loss: 1.5472889
# 3 1248 Train accuracy: 0.33494950433572135  Train loss: 1.7643590410550436
# 3 Test accuracy: 0.4289  Test loss: 1.5087126
# 4 1248 Train accuracy: 0.3495454639196396  Train loss: 1.7276596480607986
# 4 Test accuracy: 0.3942  Test loss: 1.5880182
# 5 1248 Train accuracy: 0.35600000953674316  Train loss: 1.7118585543632507
# 5 Test accuracy: 0.4142  Test loss: 1.4958404
# 6 1248 Train accuracy: 0.36161617130041124  Train loss: 1.6913876163959503
# 6 Test accuracy: 0.3354  Test loss: 1.6761426
# 7 1248 Train accuracy: 0.36813853791781836  Train loss: 1.6788298412731715
# 7 Test accuracy: 0.4279  Test loss: 1.48424
# 8 1248 Train accuracy: 0.37325758568942546  Train loss: 1.667559644281864
# 8 Test accuracy: 0.4376  Test loss: 1.5020353
# 9 1248 Train accuracy: 0.3740740840302573  Train loss: 1.6633979807959662
# 9 Test accuracy: 0.393  Test loss: 1.5471296
# 10 1248 Train accuracy: 0.3760000100135803  Train loss: 1.6601321134567262
# 10 Test accuracy: 0.4437  Test loss: 1.4603175
# 11 1248 Train accuracy: 0.3795592386614193  Train loss: 1.6500801225142046
# 11 Test accuracy: 0.4508  Test loss: 1.5009518
# 12 1248 Train accuracy: 0.38181819175680476  Train loss: 1.6462620884180068
# 12 Test accuracy: 0.4328  Test loss: 1.4645118
# 13 1248 Train accuracy: 0.3839160937529344  Train loss: 1.6387732377419104
# 13 Test accuracy: 0.4048  Test loss: 1.4950387
# 14 1248 Train accuracy: 0.38484849461487364  Train loss: 1.6353341138362885
# 14 Test accuracy: 0.4339  Test loss: 1.4312018
# 15 1248 Train accuracy: 0.38698990873495737  Train loss: 1.6337932362556458
# 15 Test accuracy: 0.4542  Test loss: 1.4330081
# 16 1248 Train accuracy: 0.3890909189730883  Train loss: 1.6292383927106857
# 16 Test accuracy: 0.4911  Test loss: 1.366159
# 17 1248 Train accuracy: 0.3911943056653528  Train loss: 1.6252752263405743
# 17 Test accuracy: 0.4516  Test loss: 1.4098022
# 18 1248 Train accuracy: 0.3919528717464871  Train loss: 1.6208101801077526
# 18 Test accuracy: 0.3882  Test loss: 1.5803297
# ...
# 9 1248 Train accuracy: 0.48801347461011674  Train loss: 1.4091113531589508
# 9 Test accuracy: 0.5965  Test loss: 1.1236048
# 10 1248 Train accuracy: 0.49739394581317903  Train loss: 1.3851002525091172
# 10 Test accuracy: 0.6168  Test loss: 1.0688798
# 11 1248 Train accuracy: 0.5046281053261323  Train loss: 1.366375645940954
# 11 Test accuracy: 0.6202  Test loss: 1.0604688
# 12 1248 Train accuracy: 0.513181823939085  Train loss: 1.3446617252628008
# 12 Test accuracy: 0.508  Test loss: 1.4826035
# 13 1248 Train accuracy: 0.5193473249215346  Train loss: 1.3280473577059233
# 13 Test accuracy: 0.6041  Test loss: 1.1212543
# 14 1248 Train accuracy: 0.5267532522337778  Train loss: 1.3078003099986486
# 14 Test accuracy: 0.6179  Test loss: 1.0698783
# 15 1248 Train accuracy: 0.5333333386977513  Train loss: 1.2901969327131908
# 15 Test accuracy: 0.571  Test loss: 1.239357
# 16 1248 Train accuracy: 0.5384848537296056  Train loss: 1.2765076207369566
# Early stopping, best loss:  1.0604688
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.334153853058815  Train loss: 1.7982241773605347
# 1 Test accuracy: 0.3835  Test loss: 1.6281779
# 2 623 Train accuracy: 0.3763076987862587  Train loss: 1.6701639413833618
# 2 Test accuracy: 0.4932  Test loss: 1.3851439
# 3 623 Train accuracy: 0.40574359834194185  Train loss: 1.5984181944529217
# 3 Test accuracy: 0.5078  Test loss: 1.3695515
# 4 623 Train accuracy: 0.43276924178004267  Train loss: 1.5336330318450928
# 4 Test accuracy: 0.5514  Test loss: 1.2456136
# 5 623 Train accuracy: 0.4531692432165146  Train loss: 1.4890770635604857
# 5 Test accuracy: 0.581  Test loss: 1.1855953
# 6 623 Train accuracy: 0.46779488533735275  Train loss: 1.4474788467089335
# 6 Test accuracy: 0.556  Test loss: 1.2487601
# 7 623 Train accuracy: 0.48079122347491127  Train loss: 1.4117839622497559
# 7 Test accuracy: 0.5779  Test loss: 1.1587824
# 8 623 Train accuracy: 0.49300001583993436  Train loss: 1.382708222270012
# 8 Test accuracy: 0.6034  Test loss: 1.111851
# 9 623 Train accuracy: 0.5028376236889097  Train loss: 1.3578816390037536
# 9 Test accuracy: 0.6427  Test loss: 1.0073946
# 10 623 Train accuracy: 0.5116923250555993  Train loss: 1.3344686250686646
# 10 Test accuracy: 0.6257  Test loss: 1.0412138
# 11 623 Train accuracy: 0.5184335844625126  Train loss: 1.3166756465218283
# 11 Test accuracy: 0.6205  Test loss: 1.0717927
# 12 623 Train accuracy: 0.5270769414802392  Train loss: 1.2936137231190998
# 12 Test accuracy: 0.6503  Test loss: 0.9929908
# 13 623 Train accuracy: 0.5323550482438161  Train loss: 1.277152458337637
# 13 Test accuracy: 0.6483  Test loss: 0.9903123
# 14 623 Train accuracy: 0.5403077110648156  Train loss: 1.2597715154715947
# 14 Test accuracy: 0.5936  Test loss: 1.1644073
# 15 623 Train accuracy: 0.5457641214927037  Train loss: 1.2460117877324421
# 15 Test accuracy: 0.6478  Test loss: 0.988846
# 16 623 Train accuracy: 0.5503846345469355  Train loss: 1.2325184239447118
# 16 Test accuracy: 0.6527  Test loss: 0.9874783
# 17 623 Train accuracy: 0.555040743245798  Train loss: 1.2204257287698634
# 17 Test accuracy: 0.6622  Test loss: 0.9330177
# 18 623 Train accuracy: 0.5590427544050747  Train loss: 1.2105404551823933
# 18 Test accuracy: 0.6339  Test loss: 1.058566
# 19 623 Train accuracy: 0.5642429343336507  Train loss: 1.1982175786871658
# 19 Test accuracy: 0.696  Test loss: 0.87325996
# 20 623 Train accuracy: 0.567938481003046  Train loss: 1.1879194226264953
# 20 Test accuracy: 0.6857  Test loss: 0.89010274
# 21 623 Train accuracy: 0.5716337191774732  Train loss: 1.1782128389676412
# 21 Test accuracy: 0.6857  Test loss: 0.8965199
# 22 623 Train accuracy: 0.5749650545824658  Train loss: 1.1704274221983824
# 22 Test accuracy: 0.69  Test loss: 0.87835246
# 23 623 Train accuracy: 0.5782207554578781  Train loss: 1.1621319626725237
# 23 Test accuracy: 0.6911  Test loss: 0.87520486
# 24 623 Train accuracy: 0.5815897632886966  Train loss: 1.153622155090173
# 24 Test accuracy: 0.7035  Test loss: 0.85784924
# 25 623 Train accuracy: 0.584738481259346  Train loss: 1.1460365856170653
# 25 Test accuracy: 0.6898  Test loss: 0.8817576
# 26 623 Train accuracy: 0.5879526824446825  Train loss: 1.1372506160919482
# 26 Test accuracy: 0.6959  Test loss: 0.8618201
# 27 623 Train accuracy: 0.5904501622032237  Train loss: 1.1304982979209335
# 27 Test accuracy: 0.6902  Test loss: 0.8911123
# 28 623 Train accuracy: 0.5930549648191248  Train loss: 1.1238963175671441
# 28 Test accuracy: 0.7041  Test loss: 0.8523372
# 29 623 Train accuracy: 0.5957135476120587  Train loss: 1.1171950188998518
# 29 Test accuracy: 0.6863  Test loss: 0.88399607
# 30 623 Train accuracy: 0.5980923274556795  Train loss: 1.1110343010425567
# 30 Test accuracy: 0.686  Test loss: 0.8847538
# 31 623 Train accuracy: 0.6001786798238754  Train loss: 1.1053569199962001
# 31 Test accuracy: 0.6848  Test loss: 0.9080745
# 32 623 Train accuracy: 0.6019230967201292  Train loss: 1.0995954830944539
# 32 Test accuracy: 0.7006  Test loss: 0.86329085
# 33 623 Train accuracy: 0.6043077120817069  Train loss: 1.0941817732290788
# Early stopping, best loss:  0.8523372
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.0015, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.29600000828504563  Train loss: 1.94794029712677
# 1 Test accuracy: 0.3577  Test loss: 1.7632191
# 2 623 Train accuracy: 0.32707693114876746  Train loss: 1.8246995282173157
# 2 Test accuracy: 0.4275  Test loss: 1.537283
# 3 623 Train accuracy: 0.34851282844940823  Train loss: 1.7547331905364991
# 3 Test accuracy: 0.3648  Test loss: 1.808826
# 4 623 Train accuracy: 0.36507693119347095  Train loss: 1.7140150475502014
# 4 Test accuracy: 0.4347  Test loss: 1.5827376
# 5 623 Train accuracy: 0.3785846231579781  Train loss: 1.6777384757995606
# 5 Test accuracy: 0.4153  Test loss: 1.7591715
# 6 623 Train accuracy: 0.3920000084737937  Train loss: 1.6408738446235658
# 6 Test accuracy: 0.3866  Test loss: 1.8596836
# 7 623 Train accuracy: 0.40659341577972685  Train loss: 1.606393848827907
# 7 Test accuracy: 0.51  Test loss: 1.3467723
# 8 623 Train accuracy: 0.41500000972300766  Train loss: 1.5826931393146515
# 8 Test accuracy: 0.4973  Test loss: 1.4262547
# 9 623 Train accuracy: 0.424683770901627  Train loss: 1.5577404165267945
# 9 Test accuracy: 0.5204  Test loss: 1.3761069
# 10 623 Train accuracy: 0.4326153955757618  Train loss: 1.5367305178642272
# 10 Test accuracy: 0.5157  Test loss: 1.3535773
# 11 623 Train accuracy: 0.44201399784196505  Train loss: 1.5141401412270286
# 11 Test accuracy: 0.4918  Test loss: 1.4560935
# 12 623 Train accuracy: 0.45066667857269443  Train loss: 1.4963527238368988
# 12 Test accuracy: 0.5496  Test loss: 1.2858429
# 13 623 Train accuracy: 0.4583195392214335  Train loss: 1.477627846277677
# 13 Test accuracy: 0.5146  Test loss: 1.3551176
# 14 623 Train accuracy: 0.4640439690223762  Train loss: 1.4640685272216798
# 14 Test accuracy: 0.5695  Test loss: 1.1819496
# 15 623 Train accuracy: 0.46953847497701645  Train loss: 1.451072408994039
# 15 Test accuracy: 0.3968  Test loss: 1.9295832
# 16 623 Train accuracy: 0.47396155217662456  Train loss: 1.4392317762970925
# 16 Test accuracy: 0.5657  Test loss: 1.1980313
# 17 623 Train accuracy: 0.4780090638644555  Train loss: 1.426871044776019
# 17 Test accuracy: 0.582  Test loss: 1.1512344
# 18 623 Train accuracy: 0.4837948863539431  Train loss: 1.4134813058376312
# 18 Test accuracy: 0.6071  Test loss: 1.0932347
# 19 623 Train accuracy: 0.48887450891105755  Train loss: 1.4002206456033808
# 19 Test accuracy: 0.5698  Test loss: 1.2107996
# 20 623 Train accuracy: 0.49406155385077  Train loss: 1.3874998034238815
# 20 Test accuracy: 0.5548  Test loss: 1.2868677
# 21 623 Train accuracy: 0.4981978178733871  Train loss: 1.3769445570309957
# 21 Test accuracy: 0.6148  Test loss: 1.0528401
# 22 623 Train accuracy: 0.5017902258444916  Train loss: 1.3669942718202417
# 22 Test accuracy: 0.618  Test loss: 1.0647037
# 23 623 Train accuracy: 0.5054180764763252  Train loss: 1.3587051655935205
# 23 Test accuracy: 0.5647  Test loss: 1.2776463
# 24 623 Train accuracy: 0.508230785690248  Train loss: 1.3505598189433417
# 24 Test accuracy: 0.5596  Test loss: 1.2386688
# 25 623 Train accuracy: 0.5127384781956673  Train loss: 1.3396111168861389
# 25 Test accuracy: 0.582  Test loss: 1.1887
# 26 623 Train accuracy: 0.5172781233718762  Train loss: 1.3299968591103186
# Early stopping, best loss:  1.0528401
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.25104353118401307  Train loss: 2.105432024368873
# 1 Test accuracy: 0.2938  Test loss: 1.9312848
# 2 310 Train accuracy: 0.3005366717966703  Train loss: 1.9359326454309316
# 2 Test accuracy: 0.3278  Test loss: 1.8824074
# 3 310 Train accuracy: 0.33313456426064175  Train loss: 1.8351167012483647
# 3 Test accuracy: 0.411  Test loss: 1.5816758
# 4 310 Train accuracy: 0.3528622533552922  Train loss: 1.7733277105368102
# 4 Test accuracy: 0.3913  Test loss: 1.6689796
# 5 310 Train accuracy: 0.364102564064356  Train loss: 1.733628905736483
# 5 Test accuracy: 0.3705  Test loss: 1.8271521
# 6 310 Train accuracy: 0.3783542044842855  Train loss: 1.701368246323023
# 6 Test accuracy: 0.3712  Test loss: 1.7988443
# 7 310 Train accuracy: 0.3867450380227068  Train loss: 1.6810285717576414
# 7 Test accuracy: 0.4549  Test loss: 1.4989641
# 8 310 Train accuracy: 0.39333631477963465  Train loss: 1.6620697184250905
# 8 Test accuracy: 0.3854  Test loss: 1.7573276
# 9 310 Train accuracy: 0.40005300448745745  Train loss: 1.6391862019514427
# 9 Test accuracy: 0.4252  Test loss: 1.6302147
# 10 310 Train accuracy: 0.4066785927575368  Train loss: 1.6203302200023944
# 10 Test accuracy: 0.4319  Test loss: 1.609577
# 11 310 Train accuracy: 0.41426790265978636  Train loss: 1.6017872570277927
# 11 Test accuracy: 0.4865  Test loss: 1.4115893
# 12 310 Train accuracy: 0.4209401711152914  Train loss: 1.5888457986024709
# 12 Test accuracy: 0.4849  Test loss: 1.4340079
# 13 310 Train accuracy: 0.42530159189327227  Train loss: 1.5740865419602252
# 13 Test accuracy: 0.398  Test loss: 1.7629914
# 14 310 Train accuracy: 0.42976403486106424  Train loss: 1.5606547587520474
# 14 Test accuracy: 0.5047  Test loss: 1.3515475
# 15 310 Train accuracy: 0.4337507459215629  Train loss: 1.5496237131265493
# 15 Test accuracy: 0.5359  Test loss: 1.2772096
# 16 310 Train accuracy: 0.43906529580887693  Train loss: 1.534867576108529
# 16 Test accuracy: 0.4847  Test loss: 1.4610615
# 17 310 Train accuracy: 0.44301799509455175  Train loss: 1.5237564269234152
# 17 Test accuracy: 0.4858  Test loss: 1.4709811
# 18 310 Train accuracy: 0.447989134866203  Train loss: 1.5118688283822475
# 18 Test accuracy: 0.5264  Test loss: 1.3067275
# 19 310 Train accuracy: 0.4520917688364442  Train loss: 1.5026424968773537
# 19 Test accuracy: 0.5335  Test loss: 1.2833369
# 20 310 Train accuracy: 0.4559332150965929  Train loss: 1.4906394930986258
# Early stopping, best loss:  1.2772096
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.17889087704511789  Train loss: 2.255844913996183
# 1 Test accuracy: 0.1888  Test loss: 2.1130905
# 2 310 Train accuracy: 0.22271914264330497  Train loss: 2.0604875729634213
# 2 Test accuracy: 0.2784  Test loss: 1.9445566
# 3 310 Train accuracy: 0.2597893075301097  Train loss: 1.9579219970947657
# 3 Test accuracy: 0.2899  Test loss: 1.8610063
# 4 310 Train accuracy: 0.2819022063452464  Train loss: 1.9011127581963172
# 4 Test accuracy: 0.2524  Test loss: 2.1169298
# 5 310 Train accuracy: 0.30459153216618756  Train loss: 1.850178735072796
# 5 Test accuracy: 0.3064  Test loss: 1.8991516
# 6 310 Train accuracy: 0.3167362348773541  Train loss: 1.8152924241163793
# 6 Test accuracy: 0.3559  Test loss: 1.7562922
# 7 310 Train accuracy: 0.3273703031815015  Train loss: 1.7846794010518672
# 7 Test accuracy: 0.3752  Test loss: 1.7249743
# 8 310 Train accuracy: 0.33862552147072095  Train loss: 1.7603468218675027
# 8 Test accuracy: 0.3436  Test loss: 1.8586123
# 9 310 Train accuracy: 0.34333797104847735  Train loss: 1.7458757294548883
# 9 Test accuracy: 0.3942  Test loss: 1.6522988
# 10 310 Train accuracy: 0.35295169892219397  Train loss: 1.7246526809839102
# 10 Test accuracy: 0.3814  Test loss: 1.6887027
# 11 310 Train accuracy: 0.3585948930545287  Train loss: 1.709274029398298
# 11 Test accuracy: 0.3677  Test loss: 1.7621354
# 12 310 Train accuracy: 0.3655336908996105  Train loss: 1.693379120184825
# 12 Test accuracy: 0.4399  Test loss: 1.5282924
# 13 310 Train accuracy: 0.37044172306385265  Train loss: 1.6815230345584937
# 13 Test accuracy: 0.4347  Test loss: 1.5683719
# 14 310 Train accuracy: 0.37596899246449  Train loss: 1.6706292720941396
# 14 Test accuracy: 0.4507  Test loss: 1.5106479
# 15 310 Train accuracy: 0.3817133774360021  Train loss: 1.6589467372649755
# 15 Test accuracy: 0.4683  Test loss: 1.4852136
# 16 310 Train accuracy: 0.3856216463475273  Train loss: 1.6484326210159521
# 16 Test accuracy: 0.403  Test loss: 1.6842588
# 17 310 Train accuracy: 0.389876881403621  Train loss: 1.6376507719178006
# 17 Test accuracy: 0.4231  Test loss: 1.6194217
# 18 310 Train accuracy: 0.39418935960429347  Train loss: 1.627050329477359
# 18 Test accuracy: 0.4636  Test loss: 1.4592719
# 19 310 Train accuracy: 0.39886388635104486  Train loss: 1.6167665671723093
# 19 Test accuracy: 0.4623  Test loss: 1.5243695
# 20 310 Train accuracy: 0.4031902208351172  Train loss: 1.6076079657444586
# 20 Test accuracy: 0.3639  Test loss: 1.8347199
# 21 310 Train accuracy: 0.4060254992692025  Train loss: 1.6002541618906099
# 21 Test accuracy: 0.444  Test loss: 1.5693637
# 22 310 Train accuracy: 0.40963300286264687  Train loss: 1.5902536319685983
# 22 Test accuracy: 0.4642  Test loss: 1.4889435
# 23 310 Train accuracy: 0.41328977776012293  Train loss: 1.5814031418350627
# 23 Test accuracy: 0.4703  Test loss: 1.4439915
# 24 310 Train accuracy: 0.41703935660039765  Train loss: 1.5727594208258848
# 24 Test accuracy: 0.4865  Test loss: 1.4655617
# 25 310 Train accuracy: 0.42027429988751047  Train loss: 1.565660002048199
# 25 Test accuracy: 0.485  Test loss: 1.4259503
# 26 310 Train accuracy: 0.4230998585650907  Train loss: 1.5591573545918662
# 26 Test accuracy: 0.4966  Test loss: 1.3752445
# 27 310 Train accuracy: 0.42551734877957237  Train loss: 1.5533638214453673
# 27 Test accuracy: 0.4643  Test loss: 1.5161126
# 28 310 Train accuracy: 0.42848624334066776  Train loss: 1.547200050327804
# 28 Test accuracy: 0.5072  Test loss: 1.3601454
# 29 310 Train accuracy: 0.4307363321436495  Train loss: 1.5419492655154565
# 29 Test accuracy: 0.5327  Test loss: 1.2971383
# 30 310 Train accuracy: 0.43271715469085253  Train loss: 1.5359734437404535
# 30 Test accuracy: 0.5058  Test loss: 1.3701996
# 31 310 Train accuracy: 0.4357820236431458  Train loss: 1.5290581579539675
# 31 Test accuracy: 0.551  Test loss: 1.2389524
# 32 310 Train accuracy: 0.43841309010839236  Train loss: 1.5235230664794261
# 32 Test accuracy: 0.5522  Test loss: 1.2467687
# 33 310 Train accuracy: 0.4400896275446409  Train loss: 1.5192749469708173
# 33 Test accuracy: 0.4813  Test loss: 1.4295012
# 34 310 Train accuracy: 0.4420183114538905  Train loss: 1.5140590352170609
# 34 Test accuracy: 0.5424  Test loss: 1.2668469
# 35 310 Train accuracy: 0.444092343043495  Train loss: 1.5088897524299203
# 35 Test accuracy: 0.4992  Test loss: 1.3798618
# 36 310 Train accuracy: 0.4462167906264464  Train loss: 1.5039422672528486
# Early stopping, best loss:  1.2389524
# time: 1h 47min 28s

# %%
# %load_ext tensorboard  # only needed once (e.g., at top of notebook)

# %tensorboard --logdir logs

# %% [markdown]
# Preventing it to get disconnected.You need to paste this script into the JavaScript console of the Colab browser window (Ctrl+Shift+i):

# %%
function ClickConnect() {
  console.log('Working')
  document
    .querySelector('#top-toolbar > colab-connect-button')
    .shadowRoot.querySelector('#connect')
    .click()
}

setInterval(ClickConnect, 60000)
