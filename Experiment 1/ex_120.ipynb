# %% [markdown]
# # **To use Tensorflow Version 1**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# # **Mount the Google Drive**

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#define your folder or create one in your google drive
root_path = '/content/drive/My Drive/ex_120/'
os.chdir(root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Record the time execution per code section**

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=d531544fe6a6784597e2096b24240b225eb3c1fa3742cf93f23f1b8e8a59116f
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %% [markdown]
# #**Ngrok : Running tensorboard inside Google Colab**

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
import os
LOG_DIR = '/content/drive/My Drive/ex_20/log'
#LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # **Data Preparation**

# %%
# Downloading cifar-10-python files
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -xvzf cifar-10-python.tar.gz
# Out:
# --2020-04-15 15:41:26--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz.3’
#
# cifar-10-python.tar 100%[===================>] 162.60M  48.5MB/s    in 3.7s
#
# 2020-04-15 15:41:30 (43.6 MB/s) - ‘cifar-10-python.tar.gz.3’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# time: 13.6 s

# %%
# Provided on https://www.cs.toronto.edu/~kriz/cifar.html 
# Given a "pickled" file, returns a dictionary containing the image data
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
# time: 10.1 ms

# %% [markdown]
# The training data is stored in four files, which are read and merged.

# %%
import numpy as np

for file_no in range(4):
    # Obtain data dictionary from each file
    filename = "cifar-10-batches-py/data_batch_" + str(file_no + 1)
    image_batch = unpickle(filename)
    # First file, create numpy arrays containing data & labels
    if file_no == 0:
        # Reshape to 32x32 image with 3 channels (RGB), which is made to be the last axes
        image_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_labels = image_batch[b'labels']
    else: # Concatenate to one file
        new_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_data = np.concatenate([image_data, new_data])
        image_labels = np.concatenate([image_labels, image_batch[b'labels']])

print("Training data shape: ",image_data.shape)

# Create numpy array containing test data
test_batch = unpickle("cifar-10-batches-py/test_batch")
test_data = test_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
test_labels = test_batch[b'labels']

# Obtain label names from the meta data
label_names = unpickle("cifar-10-batches-py/batches.meta")[b'label_names']
label_names = [l.decode('UTF-8') for l in label_names]
# Out:
# Training data shape:  (40000, 32, 32, 3)
# time: 384 ms

# %% [markdown]
# ### **Image samples**

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10,9,figsize=(7,9))
plt.subplots_adjust(wspace=0.01, hspace=0.01)

for image_type in range(10):
    # Obtain indices of images in each group
    group = np.argwhere(image_labels == image_type)
    # Display 1st 5 images from each group
    for col in range(8):
        n = group[col][0]
        img_rgb = image_data[n]
        axes[image_type,col].imshow(img_rgb)
        axes[image_type,col].axis('off')
    # Display image labels    
    axes[image_type,8].axis('off')    
    axes[image_type,8].text(0.1,0.5,label_names[image_type], fontsize=12)

plt.show()
# Out:
# time: 2.35 s

# %% [markdown]
# ## Model Building
# ### Hyperparameters

# %%
import tensorflow as tf
# Fixed hyperparameters
height = 32
width = 32
channels = 3
outputs = 10

n_epochs = 500
# number of epochs to try to get a lower loss before stopping
early_stop_rounds = 4

# number of iterations, within epoch, to do an accuracy check
acc_check = 25

# Variable Hyperparameters
hyperparam_range = {'filter1':[16, 32, 64, 96],
                    'kernelsize_1':[3, 4, 5],
                    'filter2':[48, 64, 96, 128],
                    'kernelsize_2':[3, 4, 5],
                    'filter3':[64, 96, 128],
                    'kernelsize_3':[3, 4, 5],
                    'hidden_1':[60, 100, 125],
                    'hidden_2':[80, 100, 125],
                    'activation':['relu', 'lrelu', 'elu'],
                    'learning_rate':[0.001, 0.0015, 0.002, 0.003],
                    'batch_size':[32, 64, 128],
                    'momentum':[0.9, 0.95, 0.99],
                    'p_reduct':[0],
                    'optimizer':['adam', 'rmsprop', 'nesterov']
                   }

# Calculate the number of hyperparamter grid points
first_item = True
for key,values in hyperparam_range.items():
    count = len(values)
    if first_item:
        display = str(count)
        total = count
        first_item = False
    else:
        display = display + ' X ' + str(count)
        total *= count

print('The total number of possible hyperparameter combinations is ' + display + ' = ' + "{:,}".format(total))
# Out:
# The total number of possible hyperparameter combinations is 4 X 3 X 4 X 3 X 3 X 3 X 3 X 3 X 3 X 4 X 3 X 3 X 1 X 3 = 3,779,136
# time: 23.7 ms

# %% [markdown]
# ### Convolutional Layer

# %%
def conv_layer(tensor_input, layer_no, filters, ksize, kstride, activation_unit, momentum, phase_train):
    # convolutional layer with batch normalisation and max pooling
    with tf.name_scope("conv_layer" + str(layer_no)):
        conv = tf.layers.conv2d(
            tensor_input,
            filters=filters,
            kernel_size=ksize,
            strides=[kstride,kstride],
            padding="SAME",
            activation=None
        )

        conv_bn = tf.layers.batch_normalization(
            inputs=conv,
            axis=-1,
            momentum=0.9,
            epsilon=0.001,
            center=True,
            scale=True,
            trainable=True,
            training = phase_train
        )

        #apply activation unit
        conv_bn_relu =  activation_unit(conv_bn)

        max_pool = tf.nn.max_pool(
            conv_bn_relu,
            ksize=[1,2,2,1],
            strides=[1,2,2,1],
            padding="VALID"
        )
            
        dropout = tf.layers.dropout(
            max_pool,
            training = phase_train
        )
            
        return dropout
# Out:
# time: 9.42 ms

# %% [markdown]
# ### Graph defintion

# %%
def build_graph(hyperparam):
    # Retrieve hyperparamaters from dictionary   
    filter1 = hyperparam['filter1']
    kernelsize_1 = hyperparam['kernelsize_1']
    filter2 = hyperparam['filter2']
    kernelsize_2 = hyperparam['kernelsize_2']
    filter3 = hyperparam['filter3']
    kernelsize_3 = hyperparam['kernelsize_3']
    hidden_1 = hyperparam['hidden_1']
    hidden_2 = hyperparam['hidden_2']
    activation = hyperparam['activation']
    learning_rate = hyperparam['learning_rate']
    momentum = hyperparam['momentum']
    p_reduct =  hyperparam['p_reduct']
    optimizer_method = hyperparam['optimizer']
    
    patch_height = height - 2 * p_reduct
    patch_width = width - 2 * p_reduct
    
    if activation == 'elu':
        activation_unit = tf.nn.elu
    elif activation == 'lrelu':
        activation_unit = tf.nn.leaky_relu
    else:    
        activation_unit = tf.nn.relu
        
    graph = tf.Graph()
    with graph.as_default():
        X = tf.placeholder(shape=(None, patch_height, patch_width, channels), dtype=tf.float32)
        y = tf.placeholder(shape=(None), dtype=tf.int32)
        phase_train = tf.placeholder(tf.bool, name='phase_train')

        # 1st convolutional layer
        conv1 = conv_layer(X, 1, filter1, kernelsize_1, 2, activation_unit, momentum, phase_train)
        
        # 2nd convolutional layer
        conv2 = conv_layer(conv1, 2, filter2, kernelsize_2, 1, activation_unit, momentum, phase_train)
        
        # 3rd cnn
        conv3 = conv_layer(conv2, 3, filter3, kernelsize_3, 1, activation_unit, momentum, phase_train)
        
        # 1st fully connected (dense) layer
        fully_conn1 = tf.layers.dense(conv3, hidden_1, name="fully_conn1", activation=activation_unit)
        flat = tf.contrib.layers.flatten(fully_conn1)
        
        # 2nd fully connected layer
        fully_conn2 = tf.layers.dense(flat, hidden_2, name="fully_conn2", activation=activation_unit)
        
        # Output layer (no activation function, as this is built into cross-entropy)
        logits = tf.layers.dense(fully_conn2, outputs, name="logits")

        # Cross Entropy Loss
        with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
            loss = tf.reduce_mean(xentropy, name="loss")

        # Training    
        with tf.name_scope("train"):
            if optimizer_method == 'rmsprop':
                    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, momentum=0.9)
            elif optimizer_method == 'nesterov':
                    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov = True)
            else:    
                optimizer = tf.train.AdamOptimizer(learning_rate)
            training_op = optimizer.minimize(loss)
    
        # Initialization & Saver
        init = tf.global_variables_initializer()
        saver = tf.train.Saver() 
        
        return graph, X, y, phase_train, logits, loss, training_op, init, saver
# Out:
# time: 60 ms

# %% [markdown]
# ### Model Training

# %%
# Function to train model, returns minimised loss
def train_model(batch_size = 128):
    training_size = image_data.shape[0]
    no_batches = training_size // batch_size
    
    with graph.as_default():
        # Ensure batch normalisation gets updated
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)    
        # Add Evaluation metrics
        with tf.name_scope("evaluation"):
            correct = tf.nn.in_top_k(logits, y, 1)
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            acc_summary = tf.summary.scalar('Accuracy', accuracy)
            loss_summary = tf.summary.scalar('Loss', loss)
            
    # Initialise best loss for early stopping
    best_loss = 1e9
    best_acc = 1e9
    early_stopping = False
    
    # Run training
    with tf.Session(graph=graph) as sess:                     
        init.run()
        epoch = 0
        early_stop_count = 0
        # Initialise training accuracy sum
        sum_acc_train = 0.0
        sum_loss_train = 0.0
        count_train = 0
        while (epoch < n_epochs) and (not early_stopping):
            epoch += 1
            # Shuffle training data
            p = np.random.permutation(training_size)
            image_data_shuffle = image_data_patch[p]
            image_labels_shuffle = image_labels[p]
            for iteration in range(no_batches-1):
                # Train on mini-batch
                X_batch = image_data_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                y_batch = image_labels_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                sess.run([training_op, extra_update_ops], feed_dict={X: X_batch, y: y_batch, phase_train: True})
                # Evaluate model on current mini-batch
                if (iteration % acc_check == 0):
                    acc_train, loss_train = sess.run([accuracy, loss], feed_dict={X: X_batch,
                                                                                   y: y_batch,
                                                                                   phase_train: True})
                    # Update training average for current epoch
                    sum_acc_train += acc_train
                    sum_loss_train += loss_train
                    count_train += 1
                    mean_acc_train = sum_acc_train / count_train
                    mean_loss_train = sum_loss_train / count_train
                    print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train, end='\r')
                     
            # Print mean Train accuracy        
            print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train)
            train_summary = tf.Summary()
            train_summary.value.add(tag='eval/Accuracy', simple_value=mean_acc_train)
            train_summary.value.add(tag='eval/Loss', simple_value=mean_loss_train)
            file_writer_train.add_summary(train_summary, epoch)
            
            # Evaluate model on test data every epoch
            acc_test, loss_test, summary_str_acc_test, summary_str_loss_test = sess.run([accuracy, loss,
                                                                                         acc_summary,
                                                                                         loss_summary],
                                                                                        feed_dict={X: test_data_patch,
                                                                                                   y: test_labels,
                                                                                                   phase_train: False})
            # Check for mininimum loss
            if loss_test < best_loss:
                # Reset early stopping best loss and count
                best_loss = loss_test
                best_acc = acc_test
                best_train_acc = mean_acc_train
                best_train_loss = mean_loss_train
                early_stop_count = 0
                # Save model
                save_path = saver.save(sess, ckptfile)
            else:
                # Increment early stopping count
                early_stop_count += 1
            # Check if sufficient rounds (epochs) have passed without improvement
            if early_stop_count  > early_stop_rounds:
                # Flag early stopping, so training loop will stop
                early_stopping = True
                print("Early stopping, best loss: ", best_loss)
            else:    
                # Record and display test loss and accuracy
                file_writer_test.add_summary(summary_str_acc_test, epoch)
                file_writer_test.add_summary(summary_str_loss_test, epoch)
                print(epoch, "Test accuracy:", acc_test, " Test loss:", loss_test)
            
        # Return Best Loss obtaned and number of epochs
        return best_loss, best_acc, best_train_acc, best_train_loss, epoch
# Out:
# time: 74.6 ms

# %% [markdown]
# ### Random Hyperparameter Selection and Evaluation

# %%
import pandas as pd

import random
random.seed(261001)

import os.path
if not os.path.exists('./log'):
    os.makedirs('./log')
if not os.path.exists('./graphs'):
    os.makedirs('./graphs')
    
if(os.path.isfile('./log/model_hyperparam.csv')):
    hyperparam_df = pd.read_csv('./log/model_hyperparam.csv')
    new_results_file = False
else:
    new_results_file = True

# Random Model search
for n in range(120):
    # Create log directory using current timestamp
    from datetime import datetime
    now = datetime.now().strftime("%Y%m%dT%H%M%S")
    root_logdir = "./log"
    root_graphdir = "./graphs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    graphdir = "{}/run-{}/".format(root_graphdir, now)
    #root_modeldir = "./model"
    graphfile = graphdir
    ckptfile = graphdir + "checkpoint.ckpt"

    # Note that the graph is not written using same filewriter as the logging data.
    # This allows the logs to be viewed during training before the filewriter is closed
    file_writer_train = tf.summary.FileWriter(logdir + '/train')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    
    # tensorboard --logdir e:\Programming\TensorFlow\CIFAR-10\log
    # The command must be executed from same drive (E:) as the logdir

    tf.reset_default_graph()

    hyperparam_dict = {key:random.choice(values) for (key,values) in hyperparam_range.items()}
    print("Training Model with following hyperparameters:")
    print(hyperparam_dict)

    # Obtain graph and nodes required for training
    graph, X, y, phase_train, logits, loss, training_op, init, saver = build_graph(hyperparam = hyperparam_dict)
    
    # Write graph to file and close to avoid TensorBoard conflict
    file_writer_graph = tf.summary.FileWriter(graphfile, graph)
    file_writer_graph.close()

    # Extract image patches
    p_reduct =  hyperparam_dict['p_reduct']
    if p_reduct == 0:
        image_data_patch = image_data
        test_data_patch = test_data
    else:
        image_data_patch = image_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
        test_data_patch = test_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
    
    # Train the model
    best_loss, best_acc, best_train_acc, best_train_loss, no_epochs = train_model(batch_size = hyperparam_dict['batch_size'])
    
    # Add results to dictionary
    hyperparam_dict['best_loss'] = best_loss
    hyperparam_dict['best_acc'] = best_acc
    hyperparam_dict['best_train_acc'] = best_train_acc
    hyperparam_dict['best_train_loss'] = best_train_loss
    hyperparam_dict['no_epochs'] = no_epochs
    hyperparam_dict['logdir'] = logdir
    
    # Add results to dataframe
    if new_results_file:
        hyperparam_df = pd.DataFrame(hyperparam_dict, index=[0])
        new_results_file = False
    else:
        hyperparam_df = hyperparam_df.append(hyperparam_dict, ignore_index=True)
        
    # Write results file (don't wait until end, as next model may be interrupted)
    hyperparam_df.to_csv('./log/modelhyperparameter_120.csv', index=False)

    # Close filewriters
    file_writer_train.close()
    file_writer_test.close()
    
    # NOTE - From this point onwards there are only training logs.
    # Results and Conclusion are in a seperate notebook
# Out:
# Streaming output truncated to the last 5000 lines.
# 9 310 Train accuracy: 0.5230239189715467  Train loss: 1.35512379805247
# 9 Test accuracy: 0.6076  Test loss: 1.1574887
# 10 310 Train accuracy: 0.5295169943227218  Train loss: 1.3382455486517686
# 10 Test accuracy: 0.6293  Test loss: 1.0647272
# 11 310 Train accuracy: 0.5366184197209932  Train loss: 1.3193609176815806
# 11 Test accuracy: 0.6149  Test loss: 1.156354
# 12 310 Train accuracy: 0.5427847338888125  Train loss: 1.3029799274145029
# 12 Test accuracy: 0.6098  Test loss: 1.1718047
# 13 310 Train accuracy: 0.5488739040564503  Train loss: 1.2862027492043535
# 13 Test accuracy: 0.6149  Test loss: 1.1771792
# 14 310 Train accuracy: 0.5551154265118824  Train loss: 1.270916155406407
# 14 Test accuracy: 0.6658  Test loss: 1.0125434
# 15 310 Train accuracy: 0.5612403095150605  Train loss: 1.2564538616400498
# 15 Test accuracy: 0.6569  Test loss: 1.0053567
# 16 310 Train accuracy: 0.5659287407492789  Train loss: 1.2445135448987668
# 16 Test accuracy: 0.6394  Test loss: 1.11729
# 17 310 Train accuracy: 0.5704865125576835  Train loss: 1.2330677021143124
# 17 Test accuracy: 0.6371  Test loss: 1.1182555
# 18 310 Train accuracy: 0.5752335513313102  Train loss: 1.2197270775452638
# 18 Test accuracy: 0.6484  Test loss: 1.0959496
# 19 310 Train accuracy: 0.5797319773298043  Train loss: 1.2072035969510253
# 19 Test accuracy: 0.6734  Test loss: 0.9651133
# 20 310 Train accuracy: 0.5838700057508853  Train loss: 1.198334960295604
# 20 Test accuracy: 0.6539  Test loss: 1.0593648
# 21 310 Train accuracy: 0.5880398666520259  Train loss: 1.1891103913059164
# 21 Test accuracy: 0.6176  Test loss: 1.2266076
# 22 310 Train accuracy: 0.5912343467084261  Train loss: 1.181089316006307
# 22 Test accuracy: 0.643  Test loss: 1.1260245
# 23 310 Train accuracy: 0.5949547587080942  Train loss: 1.1708529507834775
# 23 Test accuracy: 0.704  Test loss: 0.8946918
# 24 310 Train accuracy: 0.5977191414254216  Train loss: 1.1635404890164351
# 24 Test accuracy: 0.6582  Test loss: 1.0498296
# 25 310 Train accuracy: 0.6004054861114575  Train loss: 1.1556542330521804
# 25 Test accuracy: 0.561  Test loss: 1.5716804
# 26 310 Train accuracy: 0.6026099723868469  Train loss: 1.1512425159208872
# 26 Test accuracy: 0.6744  Test loss: 1.0098311
# 27 310 Train accuracy: 0.605534574860691  Train loss: 1.1446330299404612
# 27 Test accuracy: 0.7083  Test loss: 0.878017
# 28 310 Train accuracy: 0.6089104693382978  Train loss: 1.1357908763073303
# 28 Test accuracy: 0.6176  Test loss: 1.2887884
# 29 310 Train accuracy: 0.6110871218599438  Train loss: 1.1308317616068084
# 29 Test accuracy: 0.6404  Test loss: 1.203395
# 30 310 Train accuracy: 0.6131981714604757  Train loss: 1.125911604746794
# 30 Test accuracy: 0.6734  Test loss: 1.0153682
# 31 310 Train accuracy: 0.6148460193285279  Train loss: 1.1212568389570743
# 31 Test accuracy: 0.66  Test loss: 1.0292422
# 32 310 Train accuracy: 0.6171921584217881  Train loss: 1.1158615175921183
# Early stopping, best loss:  0.878017
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.22778771817684174  Train loss: 2.181777468094459
# 1 Test accuracy: 0.3026  Test loss: 1.857701
# 2 310 Train accuracy: 0.2680381633914434  Train loss: 2.0137086235559902
# 2 Test accuracy: 0.3336  Test loss: 1.8079336
# 3 310 Train accuracy: 0.28582786864195114  Train loss: 1.9335152552678034
# 3 Test accuracy: 0.3637  Test loss: 1.7279016
# 4 310 Train accuracy: 0.314102565153287  Train loss: 1.860748176391308
# 4 Test accuracy: 0.4049  Test loss: 1.6031017
# 5 310 Train accuracy: 0.33321407460249386  Train loss: 1.808734134527353
# 5 Test accuracy: 0.4274  Test loss: 1.5585935
# 6 310 Train accuracy: 0.34784337209585386  Train loss: 1.7691129812827477
# 6 Test accuracy: 0.3379  Test loss: 1.9668483
# 7 310 Train accuracy: 0.35940029054552647  Train loss: 1.733516773024758
# 7 Test accuracy: 0.4147  Test loss: 1.6277813
# 8 310 Train accuracy: 0.36642814613878727  Train loss: 1.7116598337888718
# 8 Test accuracy: 0.4039  Test loss: 1.7000362
# 9 310 Train accuracy: 0.3758033530579673  Train loss: 1.690246126590631
# 9 Test accuracy: 0.4579  Test loss: 1.4757847
# 10 310 Train accuracy: 0.3843172340438916  Train loss: 1.668171619451963
# 10 Test accuracy: 0.4838  Test loss: 1.4307183
# 11 310 Train accuracy: 0.3912289274947627  Train loss: 1.6508680457001799
# 11 Test accuracy: 0.3915  Test loss: 1.7781683
# 12 310 Train accuracy: 0.3975352825453648  Train loss: 1.6351915468008091
# 12 Test accuracy: 0.4623  Test loss: 1.4931011
# 13 310 Train accuracy: 0.40245860418271734  Train loss: 1.6210683668858907
# 13 Test accuracy: 0.5135  Test loss: 1.3299104
# 14 310 Train accuracy: 0.4084675026300189  Train loss: 1.6056277476824248
# 14 Test accuracy: 0.4888  Test loss: 1.3894852
# 15 310 Train accuracy: 0.41554363056635246  Train loss: 1.5889241022941394
# 15 Test accuracy: 0.4765  Test loss: 1.4675041
# 16 310 Train accuracy: 0.4202072165476588  Train loss: 1.5766286145036037
# 16 Test accuracy: 0.4737  Test loss: 1.4957514
# 17 310 Train accuracy: 0.4235153824630366  Train loss: 1.5664121133709386
# 17 Test accuracy: 0.3833  Test loss: 1.9590006
# 18 310 Train accuracy: 0.42801298742365634  Train loss: 1.5552776226630578
# 18 Test accuracy: 0.5376  Test loss: 1.2817762
# 19 310 Train accuracy: 0.4317860853696159  Train loss: 1.5436830805380817
# 19 Test accuracy: 0.5114  Test loss: 1.3801826
# 20 310 Train accuracy: 0.43613595853631315  Train loss: 1.5324431520241957
# 20 Test accuracy: 0.4291  Test loss: 1.6966125
# 21 310 Train accuracy: 0.44015674391290643  Train loss: 1.5220168405400092
# 21 Test accuracy: 0.5189  Test loss: 1.3243363
# 22 310 Train accuracy: 0.443622270716237  Train loss: 1.5115064774359857
# 22 Test accuracy: 0.4188  Test loss: 1.8465034
# 23 310 Train accuracy: 0.4486790608901244  Train loss: 1.5005087649144457
# 23 Test accuracy: 0.5512  Test loss: 1.2457606
# 24 310 Train accuracy: 0.4518236947269776  Train loss: 1.4914004153166063
# 24 Test accuracy: 0.5355  Test loss: 1.3067019
# 25 310 Train accuracy: 0.45490757469947524  Train loss: 1.4830407593800472
# 25 Test accuracy: 0.5422  Test loss: 1.2781074
# 26 310 Train accuracy: 0.4576854290076967  Train loss: 1.4746755174631199
# 26 Test accuracy: 0.5642  Test loss: 1.2024175
# 27 310 Train accuracy: 0.4613396958832727  Train loss: 1.4659895723701541
# 27 Test accuracy: 0.5391  Test loss: 1.30373
# 28 310 Train accuracy: 0.4643496059208781  Train loss: 1.4586408665547004
# 28 Test accuracy: 0.5861  Test loss: 1.1455604
# 29 310 Train accuracy: 0.467049125295419  Train loss: 1.4515868472800015
# 29 Test accuracy: 0.5333  Test loss: 1.3355451
# 30 310 Train accuracy: 0.47068177496011443  Train loss: 1.442902597402915
# 30 Test accuracy: 0.5019  Test loss: 1.4547548
# 31 310 Train accuracy: 0.4740223534423719  Train loss: 1.4355472982965096
# 31 Test accuracy: 0.5463  Test loss: 1.2856691
# 32 310 Train accuracy: 0.4763155951021382  Train loss: 1.429968985513999
# 32 Test accuracy: 0.5447  Test loss: 1.2966969
# 33 310 Train accuracy: 0.47890352720008306  Train loss: 1.4231066839956181
# Early stopping, best loss:  1.1455604
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.2646153923869133  Train loss: 1.920851969718933
# 1 Test accuracy: 0.3382  Test loss: 1.7155367
# 2 623 Train accuracy: 0.3080000080168247  Train loss: 1.8173182392120362
# 2 Test accuracy: 0.224  Test loss: 2.4798827
# 3 623 Train accuracy: 0.32758975178003313  Train loss: 1.7680701049168905
# 3 Test accuracy: 0.3668  Test loss: 1.7763146
# 4 623 Train accuracy: 0.34184616170823573  Train loss: 1.737250258922577
# 4 Test accuracy: 0.3891  Test loss: 1.6256106
# 5 623 Train accuracy: 0.3518769308924675  Train loss: 1.7039198513031006
# 5 Test accuracy: 0.3868  Test loss: 1.5724152
# 6 623 Train accuracy: 0.3591794947286447  Train loss: 1.6821555829048156
# 6 Test accuracy: 0.3975  Test loss: 1.5763619
# 7 623 Train accuracy: 0.36764835898365295  Train loss: 1.6677293402808053
# 7 Test accuracy: 0.4476  Test loss: 1.4412678
# 8 623 Train accuracy: 0.37769231509417295  Train loss: 1.649489659667015
# 8 Test accuracy: 0.4231  Test loss: 1.4903572
# 9 623 Train accuracy: 0.3808547081881099  Train loss: 1.6391508388519287
# 9 Test accuracy: 0.4069  Test loss: 1.6302804
# 10 623 Train accuracy: 0.38412308439612386  Train loss: 1.6309829993247986
# 10 Test accuracy: 0.4236  Test loss: 1.494538
# 11 623 Train accuracy: 0.387244762588631  Train loss: 1.6197394080595537
# 11 Test accuracy: 0.4528  Test loss: 1.5144643
# 12 623 Train accuracy: 0.3913333407789469  Train loss: 1.6085342411200205
# 12 Test accuracy: 0.4459  Test loss: 1.4294801
# 13 623 Train accuracy: 0.392899415745185  Train loss: 1.6055009049635667
# 13 Test accuracy: 0.3963  Test loss: 1.6034977
# 14 623 Train accuracy: 0.3950329745454448  Train loss: 1.5993895861080714
# 14 Test accuracy: 0.4473  Test loss: 1.4282845
# 15 623 Train accuracy: 0.39737436634302137  Train loss: 1.5937978843053182
# 15 Test accuracy: 0.4504  Test loss: 1.4815396
# 16 623 Train accuracy: 0.40119231505319475  Train loss: 1.5849378129839897
# 16 Test accuracy: 0.4829  Test loss: 1.3412025
# 17 623 Train accuracy: 0.4043076996066991  Train loss: 1.5778913321214563
# 17 Test accuracy: 0.4528  Test loss: 1.5014064
# 18 623 Train accuracy: 0.40741881084111004  Train loss: 1.5717481327056886
# 18 Test accuracy: 0.5163  Test loss: 1.3062527
# 19 623 Train accuracy: 0.4096194407657573  Train loss: 1.566846342337759
# 19 Test accuracy: 0.4746  Test loss: 1.3424344
# 20 623 Train accuracy: 0.41215385381877423  Train loss: 1.5617421431541443
# 20 Test accuracy: 0.4276  Test loss: 1.5299935
# 21 623 Train accuracy: 0.41450550225519  Train loss: 1.5558311957404727
# 21 Test accuracy: 0.5082  Test loss: 1.3124818
# 22 623 Train accuracy: 0.4167832246558233  Train loss: 1.5509418652274392
# 22 Test accuracy: 0.5041  Test loss: 1.2915001
# 23 623 Train accuracy: 0.4171772654030634  Train loss: 1.5477438406322312
# 23 Test accuracy: 0.498  Test loss: 1.3670549
# 24 623 Train accuracy: 0.4199487259363135  Train loss: 1.5411466430624325
# 24 Test accuracy: 0.4561  Test loss: 1.4381864
# 25 623 Train accuracy: 0.42151385415792464  Train loss: 1.5368567492485046
# 25 Test accuracy: 0.5006  Test loss: 1.3135773
# 26 623 Train accuracy: 0.42241420923517303  Train loss: 1.5333825513949761
# 26 Test accuracy: 0.4456  Test loss: 1.4718784
# 27 623 Train accuracy: 0.42427351235239597  Train loss: 1.5301109800515351
# Early stopping, best loss:  1.2915001
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3372307765483856  Train loss: 1.8529828786849976
# 1 Test accuracy: 0.2985  Test loss: 2.053846
# 2 623 Train accuracy: 0.38646154701709745  Train loss: 1.6852456307411194
# 2 Test accuracy: 0.4283  Test loss: 1.5779946
# 3 623 Train accuracy: 0.408000009059906  Train loss: 1.6124626938501994
# 3 Test accuracy: 0.3772  Test loss: 1.8164016
# 4 623 Train accuracy: 0.42061539441347123  Train loss: 1.573013845682144
# 4 Test accuracy: 0.5058  Test loss: 1.3409125
# 5 623 Train accuracy: 0.43483078050613405  Train loss: 1.537329529762268
# 5 Test accuracy: 0.4443  Test loss: 1.5592006
# 6 623 Train accuracy: 0.4458461664120356  Train loss: 1.5128537702560425
# 6 Test accuracy: 0.5234  Test loss: 1.3404133
# 7 623 Train accuracy: 0.4583736397538866  Train loss: 1.484926825932094
# 7 Test accuracy: 0.4294  Test loss: 1.8196166
# 8 623 Train accuracy: 0.4676923216879368  Train loss: 1.4656433221697807
# 8 Test accuracy: 0.5504  Test loss: 1.256951
# 9 623 Train accuracy: 0.4767863396803538  Train loss: 1.4451522901323106
# 9 Test accuracy: 0.5335  Test loss: 1.2475119
# 10 623 Train accuracy: 0.483323092341423  Train loss: 1.4331411805152894
# 10 Test accuracy: 0.5489  Test loss: 1.3257397
# 11 623 Train accuracy: 0.4902937223694541  Train loss: 1.4148245560039174
# 11 Test accuracy: 0.6179  Test loss: 1.0844184
# 12 623 Train accuracy: 0.4956923241416613  Train loss: 1.4017878373463948
# 12 Test accuracy: 0.587  Test loss: 1.1390047
# 13 623 Train accuracy: 0.5020591886226947  Train loss: 1.3859292626380921
# 13 Test accuracy: 0.6104  Test loss: 1.0764115
# 14 623 Train accuracy: 0.5075604569060462  Train loss: 1.3741324998651232
# 14 Test accuracy: 0.5646  Test loss: 1.2111229
# 15 623 Train accuracy: 0.5121641203562418  Train loss: 1.363084521929423
# 15 Test accuracy: 0.619  Test loss: 1.0664957
# 16 623 Train accuracy: 0.5173846334218979  Train loss: 1.3515730264782906
# 16 Test accuracy: 0.6185  Test loss: 1.0698891
# 17 623 Train accuracy: 0.5202172128593221  Train loss: 1.341872484964483
# 17 Test accuracy: 0.5731  Test loss: 1.1856498
# 18 623 Train accuracy: 0.525709420243899  Train loss: 1.3277614086204106
# 18 Test accuracy: 0.6224  Test loss: 1.0510383
# 19 623 Train accuracy: 0.5287125694124322  Train loss: 1.3182479338896902
# 19 Test accuracy: 0.5853  Test loss: 1.1580988
# 20 623 Train accuracy: 0.5315077113509178  Train loss: 1.3124181962013244
# 20 Test accuracy: 0.6043  Test loss: 1.1665926
# 21 623 Train accuracy: 0.5350915942873273  Train loss: 1.3042129451887947
# 21 Test accuracy: 0.5374  Test loss: 1.3276751
# 22 623 Train accuracy: 0.5389091102101586  Train loss: 1.295825348442251
# 22 Test accuracy: 0.5863  Test loss: 1.1371624
# 23 623 Train accuracy: 0.5416455043398816  Train loss: 1.2888175690692405
# Early stopping, best loss:  1.0510383
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.26833631556767684  Train loss: 2.0003654223222
# 1 Test accuracy: 0.3141  Test loss: 1.7824343
# 2 310 Train accuracy: 0.3169350033769241  Train loss: 1.8663060527581434
# 2 Test accuracy: 0.2487  Test loss: 2.5567956
# 3 310 Train accuracy: 0.3542039359991367  Train loss: 1.7947635008738592
# 3 Test accuracy: 0.4004  Test loss: 1.8462082
# 4 310 Train accuracy: 0.37760882624066794  Train loss: 1.7339372818286602
# 4 Test accuracy: 0.4039  Test loss: 1.6848613
# 5 310 Train accuracy: 0.395945141177911  Train loss: 1.6749731192222008
# 5 Test accuracy: 0.3995  Test loss: 1.8061832
# 6 310 Train accuracy: 0.41284039062567246  Train loss: 1.640928947008573
# 6 Test accuracy: 0.4773  Test loss: 1.4902518
# 7 310 Train accuracy: 0.4259306603408122  Train loss: 1.6173012924718333
# 7 Test accuracy: 0.4563  Test loss: 1.5983195
# 8 310 Train accuracy: 0.4357483614809238  Train loss: 1.59525243135599
# 8 Test accuracy: 0.4899  Test loss: 1.4620744
# 9 310 Train accuracy: 0.4441131665411159  Train loss: 1.577417471469977
# 9 Test accuracy: 0.5177  Test loss: 1.388686
# 10 310 Train accuracy: 0.4533691134590369  Train loss: 1.554508048754472
# 10 Test accuracy: 0.4997  Test loss: 1.4944172
# 11 310 Train accuracy: 0.4601832291671446  Train loss: 1.5363387302918867
# 11 Test accuracy: 0.5394  Test loss: 1.4401759
# 12 310 Train accuracy: 0.4665076540639767  Train loss: 1.5243796797899098
# 12 Test accuracy: 0.5424  Test loss: 1.3710543
# 13 310 Train accuracy: 0.4717214819065918  Train loss: 1.5153329457051656
# 13 Test accuracy: 0.454  Test loss: 1.7993761
# 14 310 Train accuracy: 0.4762330699589226  Train loss: 1.5053923300334386
# 14 Test accuracy: 0.5311  Test loss: 1.4750029
# 15 310 Train accuracy: 0.48193202225061565  Train loss: 1.4932063200534917
# 15 Test accuracy: 0.4564  Test loss: 1.7805145
# 16 310 Train accuracy: 0.4875894460397271  Train loss: 1.4812176978358855
# 16 Test accuracy: 0.5691  Test loss: 1.3315638
# 17 310 Train accuracy: 0.491108071952384  Train loss: 1.4721266829589912
# 17 Test accuracy: 0.5265  Test loss: 1.4198114
# 18 310 Train accuracy: 0.4954614729071275  Train loss: 1.4643661940199697
# 18 Test accuracy: 0.5319  Test loss: 1.4086684
# 19 310 Train accuracy: 0.5008944548696641  Train loss: 1.4522100590501237
# 19 Test accuracy: 0.4675  Test loss: 2.1212933
# 20 310 Train accuracy: 0.5041144910340126  Train loss: 1.4453619911120488
# 20 Test accuracy: 0.6493  Test loss: 1.0744724
# 21 310 Train accuracy: 0.5072550202136511  Train loss: 1.4374369599006989
# 21 Test accuracy: 0.5208  Test loss: 1.4907923
# 22 310 Train accuracy: 0.5099474183850355  Train loss: 1.4306889916216576
# 22 Test accuracy: 0.5204  Test loss: 1.4313536
# 23 310 Train accuracy: 0.5125612521350982  Train loss: 1.426243976007736
# 23 Test accuracy: 0.5538  Test loss: 1.389922
# 24 310 Train accuracy: 0.5161995640836465  Train loss: 1.4165246028166552
# 24 Test accuracy: 0.5661  Test loss: 1.4064785
# 25 310 Train accuracy: 0.5194991067281136  Train loss: 1.4092860948122465
# Early stopping, best loss:  1.0744724
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.356363645195961  Train loss: 1.735082323551178
# 1 Test accuracy: 0.4425  Test loss: 1.5362021
# 2 1248 Train accuracy: 0.4075757658481598  Train loss: 1.6133995378017425
# 2 Test accuracy: 0.3721  Test loss: 1.8400543
# 3 1248 Train accuracy: 0.44707071503003437  Train loss: 1.5127398951848348
# 3 Test accuracy: 0.5529  Test loss: 1.2500623
# 4 1248 Train accuracy: 0.4733333393931389  Train loss: 1.449723806977272
# 4 Test accuracy: 0.5643  Test loss: 1.2146189
# 5 1248 Train accuracy: 0.4976969752311707  Train loss: 1.3891609785556793
# 5 Test accuracy: 0.5757  Test loss: 1.2051764
# 6 1248 Train accuracy: 0.5076767728726069  Train loss: 1.3561684546868007
# 6 Test accuracy: 0.4726  Test loss: 1.5420504
# 7 1248 Train accuracy: 0.5236363683428084  Train loss: 1.3187627274649485
# 7 Test accuracy: 0.5815  Test loss: 1.1873721
# 8 1248 Train accuracy: 0.534393944516778  Train loss: 1.2889544972777367
# 8 Test accuracy: 0.6227  Test loss: 1.0966693
# 9 1248 Train accuracy: 0.5436363686455621  Train loss: 1.2646116689840952
# 9 Test accuracy: 0.6485  Test loss: 0.9889641
# 10 1248 Train accuracy: 0.551272732257843  Train loss: 1.2419187380075454
# 10 Test accuracy: 0.6597  Test loss: 0.9738459
# 11 1248 Train accuracy: 0.5595592334595594  Train loss: 1.2210100384192033
# 11 Test accuracy: 0.6884  Test loss: 0.88390136
# 12 1248 Train accuracy: 0.5679292978346347  Train loss: 1.2022572840253511
# 12 Test accuracy: 0.6747  Test loss: 0.91886365
# 13 1248 Train accuracy: 0.5753380002425267  Train loss: 1.1836511578009679
# 13 Test accuracy: 0.5964  Test loss: 1.1873394
# 14 1248 Train accuracy: 0.5793939440165248  Train loss: 1.171646900687899
# 14 Test accuracy: 0.6457  Test loss: 1.017167
# 15 1248 Train accuracy: 0.5849697015682856  Train loss: 1.160773893435796
# 15 Test accuracy: 0.6508  Test loss: 0.9988463
# 16 1248 Train accuracy: 0.5887121256813407  Train loss: 1.1497384458780289
# Early stopping, best loss:  0.88390136
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.3357185469223903  Train loss: 1.8461739650139442
# 1 Test accuracy: 0.3224  Test loss: 2.048654
# 2 310 Train accuracy: 0.39534884003492504  Train loss: 1.6798650576518133
# 2 Test accuracy: 0.4662  Test loss: 1.4769342
# 3 310 Train accuracy: 0.4245676826208066  Train loss: 1.5938524191196148
# 3 Test accuracy: 0.5593  Test loss: 1.2198728
# 4 310 Train accuracy: 0.4522957687194531  Train loss: 1.5154527953037848
# 4 Test accuracy: 0.5603  Test loss: 1.23966
# 5 310 Train accuracy: 0.4704830073393308  Train loss: 1.4616636808101948
# 5 Test accuracy: 0.5735  Test loss: 1.1758134
# 6 310 Train accuracy: 0.48608626692723006  Train loss: 1.4201227564078112
# 6 Test accuracy: 0.5145  Test loss: 1.4541833
# 7 310 Train accuracy: 0.503109295289595  Train loss: 1.3732669451734523
# 7 Test accuracy: 0.5837  Test loss: 1.2094958
# 8 310 Train accuracy: 0.5153548006828015  Train loss: 1.3408677262755542
# 8 Test accuracy: 0.5711  Test loss: 1.171361
# 9 310 Train accuracy: 0.5281918777359856  Train loss: 1.308585254045633
# 9 Test accuracy: 0.6421  Test loss: 1.0049564
# 10 310 Train accuracy: 0.5389982127226316  Train loss: 1.2780788481235503
# 10 Test accuracy: 0.6005  Test loss: 1.1185127
# 11 310 Train accuracy: 0.5483276431377118  Train loss: 1.255185886696502
# 11 Test accuracy: 0.6767  Test loss: 0.9263739
# 12 310 Train accuracy: 0.5566487793739026  Train loss: 1.2330148884883294
# 12 Test accuracy: 0.6301  Test loss: 1.026784
# 13 310 Train accuracy: 0.5648364780922613  Train loss: 1.2105642620628403
# 13 Test accuracy: 0.6765  Test loss: 0.9142822
# 14 310 Train accuracy: 0.5733452619432093  Train loss: 1.18905033154802
# 14 Test accuracy: 0.6651  Test loss: 0.9926995
# 15 310 Train accuracy: 0.5789703858204377  Train loss: 1.1719248059468392
# 15 Test accuracy: 0.6629  Test loss: 0.9686351
# 16 310 Train accuracy: 0.5857930848231683  Train loss: 1.1545877204491541
# 16 Test accuracy: 0.7171  Test loss: 0.81948507
# 17 310 Train accuracy: 0.5905503541635712  Train loss: 1.142612048673414
# 17 Test accuracy: 0.6552  Test loss: 1.0092221
# 18 310 Train accuracy: 0.5955078530515361  Train loss: 1.12918243296126
# 18 Test accuracy: 0.6885  Test loss: 0.8785131
# 19 310 Train accuracy: 0.6010733468812487  Train loss: 1.1122193811876089
# 19 Test accuracy: 0.6958  Test loss: 0.8608599
# 20 310 Train accuracy: 0.6059928458470565  Train loss: 1.0988363669468806
# 20 Test accuracy: 0.68  Test loss: 0.92805856
# 21 310 Train accuracy: 0.611267286560911  Train loss: 1.0848444955689567
# 21 Test accuracy: 0.7259  Test loss: 0.79562443
# 22 310 Train accuracy: 0.6155743490565907  Train loss: 1.072082450548252
# 22 Test accuracy: 0.6648  Test loss: 0.9828233
# 23 310 Train accuracy: 0.6192994739698328  Train loss: 1.0600375602875267
# 23 Test accuracy: 0.7118  Test loss: 0.84197205
# 24 310 Train accuracy: 0.6227390179649378  Train loss: 1.0502271715265055
# 24 Test accuracy: 0.7014  Test loss: 0.87268233
# 25 310 Train accuracy: 0.6264758495184092  Train loss: 1.0400950242922857
# 25 Test accuracy: 0.7376  Test loss: 0.7487423
# 26 310 Train accuracy: 0.6298564282747415  Train loss: 1.031095511285511
# 26 Test accuracy: 0.7206  Test loss: 0.8039238
# 27 310 Train accuracy: 0.6325228025770595  Train loss: 1.024296414308738
# 27 Test accuracy: 0.7396  Test loss: 0.74800175
# 28 310 Train accuracy: 0.6359357691400653  Train loss: 1.0150830033388767
# 28 Test accuracy: 0.7266  Test loss: 0.79683447
# 29 310 Train accuracy: 0.6390105476429987  Train loss: 1.0070500500322337
# 29 Test accuracy: 0.7161  Test loss: 0.8308997
# 30 310 Train accuracy: 0.6414231755794623  Train loss: 1.0010546250221057
# 30 Test accuracy: 0.7094  Test loss: 0.8279248
# 31 310 Train accuracy: 0.644757342397723  Train loss: 0.992902996818126
# 31 Test accuracy: 0.7157  Test loss: 0.8413166
# 32 310 Train accuracy: 0.6465973457178245  Train loss: 0.9872779588286693
# Early stopping, best loss:  0.74800175
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.3000000089406967  Train loss: 1.9294166851043701
# 1 Test accuracy: 0.3639  Test loss: 1.6932749
# 2 1248 Train accuracy: 0.3215151607990265  Train loss: 1.8426404893398285
# 2 Test accuracy: 0.3411  Test loss: 1.7175086
# 3 1248 Train accuracy: 0.32727273682753244  Train loss: 1.8042516295115154
# 3 Test accuracy: 0.378  Test loss: 1.6684793
# 4 1248 Train accuracy: 0.3316666762530804  Train loss: 1.7833375930786133
# 4 Test accuracy: 0.3756  Test loss: 1.6056387
# 5 1248 Train accuracy: 0.33466667640209197  Train loss: 1.7689661598205566
# 5 Test accuracy: 0.3955  Test loss: 1.5670455
# 6 1248 Train accuracy: 0.33686869670947395  Train loss: 1.755870952606201
# 6 Test accuracy: 0.3642  Test loss: 1.7886853
# 7 1248 Train accuracy: 0.3377489276443209  Train loss: 1.7453693308149065
# 7 Test accuracy: 0.4142  Test loss: 1.5507727
# 8 1248 Train accuracy: 0.34356061592698095  Train loss: 1.7335469773411751
# 8 Test accuracy: 0.3461  Test loss: 1.6643705
# 9 1248 Train accuracy: 0.34585859570238325  Train loss: 1.7273469159338208
# 9 Test accuracy: 0.3954  Test loss: 1.5155504
# 10 1248 Train accuracy: 0.3469091007113457  Train loss: 1.7233422362804414
# 10 Test accuracy: 0.4335  Test loss: 1.4900374
# 11 1248 Train accuracy: 0.35118458260189406  Train loss: 1.7136877664652739
# 11 Test accuracy: 0.4449  Test loss: 1.4641207
# 12 1248 Train accuracy: 0.3540909187495708  Train loss: 1.7067507990201314
# 12 Test accuracy: 0.4262  Test loss: 1.4749501
# 13 1248 Train accuracy: 0.35776224732398987  Train loss: 1.6986238554807809
# 13 Test accuracy: 0.4443  Test loss: 1.5084167
# 14 1248 Train accuracy: 0.3603896198953901  Train loss: 1.6925285158838546
# 14 Test accuracy: 0.4272  Test loss: 1.4687833
# 15 1248 Train accuracy: 0.3624646559158961  Train loss: 1.6900630547205606
# 15 Test accuracy: 0.4368  Test loss: 1.4883571
# 16 1248 Train accuracy: 0.36469697922468186  Train loss: 1.6854991747438908
# 16 Test accuracy: 0.4406  Test loss: 1.4576824
# 17 1248 Train accuracy: 0.3662388687624651  Train loss: 1.6804296273343704
# 17 Test accuracy: 0.4474  Test loss: 1.4902282
# 18 1248 Train accuracy: 0.3675420971049203  Train loss: 1.6768209342161815
# 18 Test accuracy: 0.4241  Test loss: 1.4897647
# 19 1248 Train accuracy: 0.36889953105073225  Train loss: 1.6727976846694945
# 19 Test accuracy: 0.4586  Test loss: 1.3979449
# 20 1248 Train accuracy: 0.3697272822856903  Train loss: 1.6704405128955842
# 20 Test accuracy: 0.4264  Test loss: 1.5276417
# 21 1248 Train accuracy: 0.37186148141111647  Train loss: 1.6664528627622694
# 21 Test accuracy: 0.4518  Test loss: 1.4193784
# 22 1248 Train accuracy: 0.3736914696205746  Train loss: 1.6622856906327335
# 22 Test accuracy: 0.4552  Test loss: 1.4115443
# 23 1248 Train accuracy: 0.3749143704901571  Train loss: 1.6579875233898993
# 23 Test accuracy: 0.4574  Test loss: 1.4822652
# 24 1248 Train accuracy: 0.3766414236774047  Train loss: 1.6568365839123727
# Early stopping, best loss:  1.3979449
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.2240000057220459  Train loss: 2.0578518533706665
# 1 Test accuracy: 0.2399  Test loss: 2.017239
# 2 623 Train accuracy: 0.2815384688973427  Train loss: 1.917082395553589
# 2 Test accuracy: 0.2961  Test loss: 1.8705766
# 3 623 Train accuracy: 0.3107692382733027  Train loss: 1.8346111408869425
# 3 Test accuracy: 0.3132  Test loss: 1.9418597
# 4 623 Train accuracy: 0.32153846964240074  Train loss: 1.8044732511043549
# 4 Test accuracy: 0.3605  Test loss: 1.7316574
# 5 623 Train accuracy: 0.33772308456897737  Train loss: 1.7628113584518432
# 5 Test accuracy: 0.3663  Test loss: 1.7527819
# 6 623 Train accuracy: 0.3501538539926211  Train loss: 1.7301557072003682
# 6 Test accuracy: 0.4007  Test loss: 1.5978745
# 7 623 Train accuracy: 0.3622857222386769  Train loss: 1.7049560982840402
# 7 Test accuracy: 0.4173  Test loss: 1.6270436
# 8 623 Train accuracy: 0.3740000080317259  Train loss: 1.6787791931629181
# 8 Test accuracy: 0.426  Test loss: 1.5617533
# 9 623 Train accuracy: 0.38092308474911585  Train loss: 1.6638559924231635
# 9 Test accuracy: 0.4157  Test loss: 1.6629771
# 10 623 Train accuracy: 0.3875692386031151  Train loss: 1.6472016286849975
# 10 Test accuracy: 0.4384  Test loss: 1.5230201
# 11 623 Train accuracy: 0.3951328754966909  Train loss: 1.6304512518102472
# 11 Test accuracy: 0.4307  Test loss: 1.5795282
# 12 623 Train accuracy: 0.3984615466495355  Train loss: 1.6226674350102743
# 12 Test accuracy: 0.4152  Test loss: 1.6945957
# 13 623 Train accuracy: 0.4029822569168531  Train loss: 1.6115513001955473
# 13 Test accuracy: 0.489  Test loss: 1.4003403
# 14 623 Train accuracy: 0.4071208875094141  Train loss: 1.6006019060952323
# 14 Test accuracy: 0.4611  Test loss: 1.4689595
# 15 623 Train accuracy: 0.41042052125930784  Train loss: 1.5898275413513183
# 15 Test accuracy: 0.4183  Test loss: 1.5836092
# 16 623 Train accuracy: 0.41357693158090114  Train loss: 1.580499611198902
# 16 Test accuracy: 0.4021  Test loss: 1.7176508
# 17 623 Train accuracy: 0.41752037062364467  Train loss: 1.5709766929289875
# 17 Test accuracy: 0.4598  Test loss: 1.4553653
# 18 623 Train accuracy: 0.42126496613025666  Train loss: 1.5628544746504889
# 18 Test accuracy: 0.5106  Test loss: 1.3758973
# 19 623 Train accuracy: 0.4238704542737258  Train loss: 1.555268006575735
# 19 Test accuracy: 0.4855  Test loss: 1.4252247
# 20 623 Train accuracy: 0.42812308633327484  Train loss: 1.5442480871677398
# 20 Test accuracy: 0.5238  Test loss: 1.3251069
# 21 623 Train accuracy: 0.43082784840038846  Train loss: 1.5365362778164091
# 21 Test accuracy: 0.5007  Test loss: 1.3740054
# 22 623 Train accuracy: 0.4329510585828261  Train loss: 1.5311745771494778
# 22 Test accuracy: 0.5297  Test loss: 1.3087388
# 23 623 Train accuracy: 0.4361204112094382  Train loss: 1.524245198291281
# 23 Test accuracy: 0.4783  Test loss: 1.4317181
# 24 623 Train accuracy: 0.4390256511171659  Train loss: 1.5176769626140594
# 24 Test accuracy: 0.5032  Test loss: 1.377729
# 25 623 Train accuracy: 0.4419446258068085  Train loss: 1.5106803007125855
# 25 Test accuracy: 0.5463  Test loss: 1.2720311
# 26 623 Train accuracy: 0.44456805797723625  Train loss: 1.5037972993117112
# 26 Test accuracy: 0.5207  Test loss: 1.3312954
# 27 623 Train accuracy: 0.44793163484997217  Train loss: 1.495339628148962
# 27 Test accuracy: 0.4995  Test loss: 1.3769988
# 28 623 Train accuracy: 0.4508571541735104  Train loss: 1.4879709441321236
# 28 Test accuracy: 0.5519  Test loss: 1.2483699
# 29 623 Train accuracy: 0.45366579417524666  Train loss: 1.4818601854916276
# 29 Test accuracy: 0.5588  Test loss: 1.2247924
# 30 623 Train accuracy: 0.45577437086900074  Train loss: 1.4767512555122375
# 30 Test accuracy: 0.4766  Test loss: 1.4472892
# 31 623 Train accuracy: 0.45838214612776235  Train loss: 1.4700205178414623
# 31 Test accuracy: 0.5029  Test loss: 1.3727068
# 32 623 Train accuracy: 0.4612692431733012  Train loss: 1.4640272541344166
# 32 Test accuracy: 0.5595  Test loss: 1.2108885
# 33 623 Train accuracy: 0.46310490770773455  Train loss: 1.4586376350576227
# 33 Test accuracy: 0.5606  Test loss: 1.2243837
# 34 623 Train accuracy: 0.4653393793456695  Train loss: 1.4529522533977732
# 34 Test accuracy: 0.5487  Test loss: 1.2642375
# 35 623 Train accuracy: 0.4669186943258558  Train loss: 1.4494405453545707
# 35 Test accuracy: 0.545  Test loss: 1.2550137
# 36 623 Train accuracy: 0.46885471403598783  Train loss: 1.4444990432262421
# 36 Test accuracy: 0.4489  Test loss: 1.561016
# 37 623 Train accuracy: 0.47050313182779263  Train loss: 1.4399284049626944
# Early stopping, best loss:  1.2108885
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.34424243211746214  Train loss: 1.764537925720215
# 1 Test accuracy: 0.403  Test loss: 1.6524603
# 2 1248 Train accuracy: 0.3787878867983818  Train loss: 1.6661289739608764
# 2 Test accuracy: 0.4701  Test loss: 1.4627535
# 3 1248 Train accuracy: 0.409292937318484  Train loss: 1.5967642625172933
# 3 Test accuracy: 0.5341  Test loss: 1.2938343
# 4 1248 Train accuracy: 0.42651515915989874  Train loss: 1.5565289071202277
# 4 Test accuracy: 0.5217  Test loss: 1.3378783
# 5 1248 Train accuracy: 0.44121212875843047  Train loss: 1.515686667203903
# 5 Test accuracy: 0.5502  Test loss: 1.225396
# 6 1248 Train accuracy: 0.4545454615354538  Train loss: 1.4852141167720159
# 6 Test accuracy: 0.5631  Test loss: 1.2168566
# 7 1248 Train accuracy: 0.46796537467411586  Train loss: 1.4578271164212908
# 7 Test accuracy: 0.5732  Test loss: 1.1796054
# 8 1248 Train accuracy: 0.4790909156948328  Train loss: 1.4258767935633658
# 8 Test accuracy: 0.5705  Test loss: 1.2017745
# 9 1248 Train accuracy: 0.4874747537242042  Train loss: 1.4054544242223104
# 9 Test accuracy: 0.5494  Test loss: 1.2630777
# 10 1248 Train accuracy: 0.49600000607967376  Train loss: 1.384340561747551
# 10 Test accuracy: 0.5787  Test loss: 1.1673297
# 11 1248 Train accuracy: 0.5015978022597053  Train loss: 1.367614254734733
# 11 Test accuracy: 0.5955  Test loss: 1.1254194
# 12 1248 Train accuracy: 0.5063636422157287  Train loss: 1.3558263430992763
# 12 Test accuracy: 0.6197  Test loss: 1.0599264
# 13 1248 Train accuracy: 0.510396275978822  Train loss: 1.3452067035895128
# 13 Test accuracy: 0.6154  Test loss: 1.0915201
# 14 1248 Train accuracy: 0.5148917802316801  Train loss: 1.333430420245443
# 14 Test accuracy: 0.6432  Test loss: 1.0129578
# 15 1248 Train accuracy: 0.5185858638683954  Train loss: 1.3236271327336628
# 15 Test accuracy: 0.6203  Test loss: 1.0627445
# 16 1248 Train accuracy: 0.5209848536550998  Train loss: 1.315030987933278
# 16 Test accuracy: 0.6506  Test loss: 0.9918803
# 17 1248 Train accuracy: 0.5245632849721348  Train loss: 1.304662879565183
# 17 Test accuracy: 0.5911  Test loss: 1.1447265
# 18 1248 Train accuracy: 0.5293939446078406  Train loss: 1.2921119513776567
# 18 Test accuracy: 0.6286  Test loss: 1.0207541
# 19 1248 Train accuracy: 0.5327272777494632  Train loss: 1.284473088728754
# 19 Test accuracy: 0.6321  Test loss: 1.0323603
# 20 1248 Train accuracy: 0.5350606111288071  Train loss: 1.277448265373707
# 20 Test accuracy: 0.6354  Test loss: 1.0080976
# 21 1248 Train accuracy: 0.537748922819183  Train loss: 1.2688948514915648
# 21 Test accuracy: 0.6514  Test loss: 0.9729337
# 22 1248 Train accuracy: 0.540578517507423  Train loss: 1.2617961252819407
# 22 Test accuracy: 0.6561  Test loss: 0.96618664
# 23 1248 Train accuracy: 0.544374181524567  Train loss: 1.2525449596280638
# 23 Test accuracy: 0.6454  Test loss: 1.0007272
# 24 1248 Train accuracy: 0.5462121261656284  Train loss: 1.2480394963423411
# 24 Test accuracy: 0.6616  Test loss: 0.9350072
# 25 1248 Train accuracy: 0.5493818231105805  Train loss: 1.2400359327793122
# 25 Test accuracy: 0.6609  Test loss: 0.9588571
# 26 1248 Train accuracy: 0.5511421960133772  Train loss: 1.2352719237712713
# 26 Test accuracy: 0.6609  Test loss: 0.94227815
# 27 1248 Train accuracy: 0.5531088711155785  Train loss: 1.2305783331835711
# 27 Test accuracy: 0.6627  Test loss: 0.94180214
# 28 1248 Train accuracy: 0.5554978401533195  Train loss: 1.2246635929175786
# 28 Test accuracy: 0.6722  Test loss: 0.91928977
# 29 1248 Train accuracy: 0.5576593566351924  Train loss: 1.219124558013061
# 29 Test accuracy: 0.6723  Test loss: 0.92531025
# 30 1248 Train accuracy: 0.5592929337422053  Train loss: 1.2151064118544261
# 30 Test accuracy: 0.6593  Test loss: 0.95071614
# 31 1248 Train accuracy: 0.5609970718814481  Train loss: 1.2095964374849872
# 31 Test accuracy: 0.6748  Test loss: 0.91464627
# 32 1248 Train accuracy: 0.5631250044517219  Train loss: 1.2050280991569162
# 32 Test accuracy: 0.6553  Test loss: 0.96065056
# 33 1248 Train accuracy: 0.564554641770594  Train loss: 1.2011405064481677
# 33 Test accuracy: 0.6473  Test loss: 0.97985077
# 34 1248 Train accuracy: 0.5661675623585196  Train loss: 1.197147522463518
# 34 Test accuracy: 0.6877  Test loss: 0.89033633
# 35 1248 Train accuracy: 0.5678268442153931  Train loss: 1.1926796032360623
# 35 Test accuracy: 0.6804  Test loss: 0.9068201
# 36 1248 Train accuracy: 0.569747479127513  Train loss: 1.187429611550437
# 36 Test accuracy: 0.6871  Test loss: 0.8885865
# 37 1248 Train accuracy: 0.5708927151963518  Train loss: 1.183953883970106
# 37 Test accuracy: 0.6884  Test loss: 0.87321466
# 38 1248 Train accuracy: 0.5723285529017449  Train loss: 1.1794400577482425
# 38 Test accuracy: 0.6807  Test loss: 0.90223867
# 39 1248 Train accuracy: 0.5740637182883728  Train loss: 1.1755470879566976
# 39 Test accuracy: 0.6885  Test loss: 0.88267237
# 40 1248 Train accuracy: 0.5755454587936402  Train loss: 1.171987081170082
# 40 Test accuracy: 0.6846  Test loss: 0.8841935
# 41 1248 Train accuracy: 0.5767775357060316  Train loss: 1.1690972685813903
# 41 Test accuracy: 0.6743  Test loss: 0.9055625
# 42 1248 Train accuracy: 0.577806642069703  Train loss: 1.1664400412638982
# Early stopping, best loss:  0.87321466
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3150769293308258  Train loss: 1.8325422477722169
# 1 Test accuracy: 0.3356  Test loss: 1.8103639
# 2 623 Train accuracy: 0.35384616017341614  Train loss: 1.7146811199188232
# 2 Test accuracy: 0.4136  Test loss: 1.7111317
# 3 623 Train accuracy: 0.3680000066757202  Train loss: 1.6715463081995645
# 3 Test accuracy: 0.4417  Test loss: 1.5273948
# 4 623 Train accuracy: 0.37953846842050554  Train loss: 1.6473610246181487
# 4 Test accuracy: 0.4141  Test loss: 1.5936879
# 5 623 Train accuracy: 0.38830769872665405  Train loss: 1.6291960344314576
# 5 Test accuracy: 0.4852  Test loss: 1.4096774
# 6 623 Train accuracy: 0.39558975060780843  Train loss: 1.6099599329630534
# 6 Test accuracy: 0.4884  Test loss: 1.3986496
# 7 623 Train accuracy: 0.4045714363030025  Train loss: 1.5915541580745152
# 7 Test accuracy: 0.3942  Test loss: 1.7473925
# 8 623 Train accuracy: 0.4090769308805466  Train loss: 1.5824498808383942
# 8 Test accuracy: 0.4936  Test loss: 1.3974106
# 9 623 Train accuracy: 0.41490599115689597  Train loss: 1.5683612765206232
# 9 Test accuracy: 0.5028  Test loss: 1.3444291
# 10 623 Train accuracy: 0.4196307774782181  Train loss: 1.5591458940505982
# 10 Test accuracy: 0.4756  Test loss: 1.3786132
# 11 623 Train accuracy: 0.42444756106896836  Train loss: 1.5511970806121826
# 11 Test accuracy: 0.4602  Test loss: 1.4315339
# 12 623 Train accuracy: 0.42738462418317796  Train loss: 1.5429395588239034
# 12 Test accuracy: 0.5062  Test loss: 1.3480535
# 13 623 Train accuracy: 0.4310059262239016  Train loss: 1.5336538391846877
# 13 Test accuracy: 0.4117  Test loss: 1.608894
# 14 623 Train accuracy: 0.43428572348185945  Train loss: 1.5288253385680062
# Early stopping, best loss:  1.3444291
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.3369697058200836  Train loss: 1.8361537742614746
# 1 Test accuracy: 0.2964  Test loss: 2.0144806
# 2 1248 Train accuracy: 0.36060607016086577  Train loss: 1.7261816704273223
# 2 Test accuracy: 0.4397  Test loss: 1.5354941
# 3 1248 Train accuracy: 0.38161617120107016  Train loss: 1.6616195559501648
# 3 Test accuracy: 0.445  Test loss: 1.4927927
# 4 1248 Train accuracy: 0.3989394035935402  Train loss: 1.6217914128303528
# 4 Test accuracy: 0.4172  Test loss: 1.6221119
# 5 1248 Train accuracy: 0.4144242514371872  Train loss: 1.5858876016139984
# 5 Test accuracy: 0.4769  Test loss: 1.4130898
# 6 1248 Train accuracy: 0.42575758437315625  Train loss: 1.5558600731690724
# 6 Test accuracy: 0.4654  Test loss: 1.4295502
# 7 1248 Train accuracy: 0.43653680503368375  Train loss: 1.5307880106994083
# 7 Test accuracy: 0.4775  Test loss: 1.4929603
# 8 1248 Train accuracy: 0.4445454624295235  Train loss: 1.51212961897254
# 8 Test accuracy: 0.5312  Test loss: 1.3194182
# 9 1248 Train accuracy: 0.45212121970123714  Train loss: 1.4953251633379194
# 9 Test accuracy: 0.5753  Test loss: 1.1954898
# 10 1248 Train accuracy: 0.46339394634962083  Train loss: 1.4686366846561432
# 10 Test accuracy: 0.5338  Test loss: 1.3165272
# 11 1248 Train accuracy: 0.46815427682616495  Train loss: 1.453553063652732
# 11 Test accuracy: 0.5661  Test loss: 1.1976125
# 12 1248 Train accuracy: 0.4757575818399588  Train loss: 1.4364499098062515
# 12 Test accuracy: 0.543  Test loss: 1.2586544
# 13 1248 Train accuracy: 0.48219114798765916  Train loss: 1.4177002787590027
# 13 Test accuracy: 0.5665  Test loss: 1.216929
# 14 1248 Train accuracy: 0.48974026543753485  Train loss: 1.3986029996190752
# 14 Test accuracy: 0.5944  Test loss: 1.098318
# 15 1248 Train accuracy: 0.4957575815121333  Train loss: 1.382272695382436
# 15 Test accuracy: 0.6133  Test loss: 1.0741845
# 16 1248 Train accuracy: 0.5010606117919087  Train loss: 1.367114487811923
# 16 Test accuracy: 0.5849  Test loss: 1.1691667
# 17 1248 Train accuracy: 0.5060962622656542  Train loss: 1.354341356754303
# 17 Test accuracy: 0.6442  Test loss: 0.9957872
# 18 1248 Train accuracy: 0.5108417562974824  Train loss: 1.3422708504729801
# 18 Test accuracy: 0.5895  Test loss: 1.1475118
# 19 1248 Train accuracy: 0.5156937852345015  Train loss: 1.3311311140813327
# 19 Test accuracy: 0.637  Test loss: 1.0193228
# 20 1248 Train accuracy: 0.5197575810253621  Train loss: 1.3205159537792206
# 20 Test accuracy: 0.6473  Test loss: 0.9968011
# 21 1248 Train accuracy: 0.5239538292090098  Train loss: 1.309799184061232
# 21 Test accuracy: 0.5804  Test loss: 1.1831471
# 22 1248 Train accuracy: 0.5276584072275595  Train loss: 1.3006844265352595
# Early stopping, best loss:  0.9957872
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.2172307750582695  Train loss: 2.1475458574295043
# 1 Test accuracy: 0.2403  Test loss: 1.9583691
# 2 623 Train accuracy: 0.25784616097807883  Train loss: 2.0056212329864502
# 2 Test accuracy: 0.3055  Test loss: 1.8104203
# 3 623 Train accuracy: 0.27856411029895145  Train loss: 1.9277563937505087
# 3 Test accuracy: 0.3404  Test loss: 1.7256316
# 4 623 Train accuracy: 0.29769231550395486  Train loss: 1.8761985540390014
# 4 Test accuracy: 0.3711  Test loss: 1.6767609
# 5 623 Train accuracy: 0.31249231547117234  Train loss: 1.8356207036972045
# 5 Test accuracy: 0.3952  Test loss: 1.6429068
# 6 623 Train accuracy: 0.3209230846663316  Train loss: 1.8056397541364033
# 6 Test accuracy: 0.3439  Test loss: 1.8173234
# 7 623 Train accuracy: 0.3304615460549082  Train loss: 1.7786057002203806
# 7 Test accuracy: 0.4274  Test loss: 1.5510634
# 8 623 Train accuracy: 0.3402307767048478  Train loss: 1.7547331589460373
# 8 Test accuracy: 0.4186  Test loss: 1.5418538
# 9 623 Train accuracy: 0.34919658889373145  Train loss: 1.733897999127706
# 9 Test accuracy: 0.4478  Test loss: 1.5001938
# 10 623 Train accuracy: 0.35741539230942726  Train loss: 1.712014148235321
# 10 Test accuracy: 0.4322  Test loss: 1.525333
# 11 623 Train accuracy: 0.3625734340331771  Train loss: 1.6954212747920643
# 11 Test accuracy: 0.4733  Test loss: 1.4462281
# 12 623 Train accuracy: 0.3688718025137981  Train loss: 1.6773624606927235
# 12 Test accuracy: 0.4868  Test loss: 1.3941711
# 13 623 Train accuracy: 0.3755739722114343  Train loss: 1.661311514560993
# 13 Test accuracy: 0.4597  Test loss: 1.4356959
# 14 623 Train accuracy: 0.3812747330537864  Train loss: 1.649215145111084
# 14 Test accuracy: 0.471  Test loss: 1.4153343
# 15 623 Train accuracy: 0.3870769310196241  Train loss: 1.6356216093699136
# 15 Test accuracy: 0.4664  Test loss: 1.4684126
# 16 623 Train accuracy: 0.3916153925843537  Train loss: 1.622456532716751
# 16 Test accuracy: 0.4771  Test loss: 1.421388
# 17 623 Train accuracy: 0.395981908352936  Train loss: 1.6110915986229393
# Early stopping, best loss:  1.3941711
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3476923134922981  Train loss: 1.7873015737533569
# 1 Test accuracy: 0.2816  Test loss: 2.710832
# 2 623 Train accuracy: 0.4058461613953114  Train loss: 1.6413234972953796
# 2 Test accuracy: 0.408  Test loss: 1.679731
# 3 623 Train accuracy: 0.4361025743683179  Train loss: 1.575307051340739
# 3 Test accuracy: 0.4524  Test loss: 1.5066417
# 4 623 Train accuracy: 0.4570769361406565  Train loss: 1.5248729336261748
# 4 Test accuracy: 0.4338  Test loss: 1.6215718
# 5 623 Train accuracy: 0.46892309027910234  Train loss: 1.4964477243423462
# 5 Test accuracy: 0.4718  Test loss: 1.5360805
# 6 623 Train accuracy: 0.48061539873480796  Train loss: 1.4631659138202666
# 6 Test accuracy: 0.5222  Test loss: 1.3778281
# 7 623 Train accuracy: 0.4896703446337155  Train loss: 1.436265161037445
# 7 Test accuracy: 0.5169  Test loss: 1.3827566
# 8 623 Train accuracy: 0.49415386144071816  Train loss: 1.423543171584606
# 8 Test accuracy: 0.5693  Test loss: 1.2180334
# 9 623 Train accuracy: 0.5029743749896686  Train loss: 1.4027039413981968
# 9 Test accuracy: 0.5818  Test loss: 1.1355541
# 10 623 Train accuracy: 0.5091692471802235  Train loss: 1.3897191183567048
# 10 Test accuracy: 0.6017  Test loss: 1.1180729
# 11 623 Train accuracy: 0.5141258907589046  Train loss: 1.3787866347486322
# 11 Test accuracy: 0.6254  Test loss: 1.0641993
# 12 623 Train accuracy: 0.5209230940788985  Train loss: 1.3623796039819718
# 12 Test accuracy: 0.5703  Test loss: 1.1988266
# 13 623 Train accuracy: 0.5257751654890868  Train loss: 1.3487405692614043
# 13 Test accuracy: 0.6478  Test loss: 1.0013872
# 14 623 Train accuracy: 0.5290989188849926  Train loss: 1.3394768404960633
# 14 Test accuracy: 0.6101  Test loss: 1.0973471
# 15 623 Train accuracy: 0.5348923258185386  Train loss: 1.3255183568000795
# 15 Test accuracy: 0.5953  Test loss: 1.1696563
# 16 623 Train accuracy: 0.5373077107407153  Train loss: 1.3197822608053684
# 16 Test accuracy: 0.607  Test loss: 1.1194482
# 17 623 Train accuracy: 0.5409230956084587  Train loss: 1.3096758371240953
# 17 Test accuracy: 0.6297  Test loss: 1.0469918
# 18 623 Train accuracy: 0.5451966001093388  Train loss: 1.2995528349611494
# Early stopping, best loss:  1.0013872
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.33929636214788145  Train loss: 1.8993800970224233
# 1 Test accuracy: 0.3738  Test loss: 1.8175743
# 2 310 Train accuracy: 0.3917710187916572  Train loss: 1.7039835498883174
# 2 Test accuracy: 0.4901  Test loss: 1.4083228
# 3 310 Train accuracy: 0.434108524177319  Train loss: 1.5827458791243725
# 3 Test accuracy: 0.4109  Test loss: 1.8512774
# 4 310 Train accuracy: 0.45751341389348876  Train loss: 1.517412726695721
# 4 Test accuracy: 0.55  Test loss: 1.2520038
# 5 310 Train accuracy: 0.47346451798310646  Train loss: 1.4799100490716788
# 5 Test accuracy: 0.5363  Test loss: 1.3410397
# 6 310 Train accuracy: 0.4902603829709383  Train loss: 1.4369841386110356
# 6 Test accuracy: 0.5749  Test loss: 1.2048703
# 7 310 Train accuracy: 0.49867961342845646  Train loss: 1.411877243073432
# 7 Test accuracy: 0.5735  Test loss: 1.25579
# 8 310 Train accuracy: 0.5102116864604446  Train loss: 1.3823338185365384
# 8 Test accuracy: 0.6169  Test loss: 1.0686015
# 9 310 Train accuracy: 0.5205061927947223  Train loss: 1.359136694516891
# 9 Test accuracy: 0.5317  Test loss: 1.4228045
# 10 310 Train accuracy: 0.5263565868712389  Train loss: 1.3385108828544616
# ...
# 9 Test accuracy: 0.3743  Test loss: 1.6878335
# 10 310 Train accuracy: 0.3319022067464315  Train loss: 1.7945670247077943
# 10 Test accuracy: 0.3921  Test loss: 1.63517
# 11 310 Train accuracy: 0.3376158729091391  Train loss: 1.778398728037214
# 11 Test accuracy: 0.4  Test loss: 1.5956391
# 12 310 Train accuracy: 0.3426257208562814  Train loss: 1.7632208611720648
# 12 Test accuracy: 0.415  Test loss: 1.6051747
# 13 310 Train accuracy: 0.34746112581893535  Train loss: 1.751798990915513
# 13 Test accuracy: 0.4149  Test loss: 1.581681
# 14 310 Train accuracy: 0.3515205726354987  Train loss: 1.7390268058567258
# 14 Test accuracy: 0.4278  Test loss: 1.5413718
# 15 310 Train accuracy: 0.3568674222781108  Train loss: 1.7258086608006404
# 15 Test accuracy: 0.4643  Test loss: 1.473699
# 16 310 Train accuracy: 0.3605023853910657  Train loss: 1.7146885440899775
# 16 Test accuracy: 0.4264  Test loss: 1.5201623
# 17 310 Train accuracy: 0.36553369111874523  Train loss: 1.7035684369807869
# 17 Test accuracy: 0.4152  Test loss: 1.6352971
# 18 310 Train accuracy: 0.3698734514351584  Train loss: 1.6943016836785862
# 18 Test accuracy: 0.4552  Test loss: 1.4818592
# 19 310 Train accuracy: 0.3732542448077607  Train loss: 1.684937382033962
# 19 Test accuracy: 0.4788  Test loss: 1.4334493
# 20 310 Train accuracy: 0.3770125223466983  Train loss: 1.6765402037363786
# 20 Test accuracy: 0.4648  Test loss: 1.4559472
# 21 310 Train accuracy: 0.3798165658127257  Train loss: 1.6695837760582948
# 21 Test accuracy: 0.438  Test loss: 1.528496
# 22 310 Train accuracy: 0.38277226639585893  Train loss: 1.6623080193579614
# 22 Test accuracy: 0.4511  Test loss: 1.5124385
# 23 310 Train accuracy: 0.38611910499657276  Train loss: 1.6545802219256909
# 23 Test accuracy: 0.4197  Test loss: 1.5976012
# 24 310 Train accuracy: 0.3887398133579737  Train loss: 1.6489573082862756
# Early stopping, best loss:  1.4334493
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.24000000715255737  Train loss: 2.011723024845123
# 1 Test accuracy: 0.2641  Test loss: 1.878967
# 2 1248 Train accuracy: 0.2751515233516693  Train loss: 1.9168129754066467
# 2 Test accuracy: 0.3358  Test loss: 1.7586572
# 3 1248 Train accuracy: 0.2941414229075114  Train loss: 1.8510715325673421
# 3 Test accuracy: 0.2847  Test loss: 1.9792168
# 4 1248 Train accuracy: 0.301363645195961  Train loss: 1.8305252313613891
# 4 Test accuracy: 0.3199  Test loss: 1.8480215
# 5 1248 Train accuracy: 0.3073939484357834  Train loss: 1.8135589017868041
# 5 Test accuracy: 0.3469  Test loss: 1.6280042
# 6 1248 Train accuracy: 0.31161617070436476  Train loss: 1.7964845796426137
# 6 Test accuracy: 0.3681  Test loss: 1.5977241
# 7 1248 Train accuracy: 0.3185281476804188  Train loss: 1.7782030487060547
# 7 Test accuracy: 0.3736  Test loss: 1.58058
# 8 1248 Train accuracy: 0.32257576689124107  Train loss: 1.768960826098919
# 8 Test accuracy: 0.4077  Test loss: 1.5393881
# 9 1248 Train accuracy: 0.3289562382962969  Train loss: 1.7527775059805977
# 9 Test accuracy: 0.4027  Test loss: 1.593383
# 10 1248 Train accuracy: 0.33272728210687635  Train loss: 1.7475319385528565
# 10 Test accuracy: 0.3539  Test loss: 1.6041727
# 11 1248 Train accuracy: 0.3325068964199586  Train loss: 1.745116967938163
# 11 Test accuracy: 0.3418  Test loss: 1.6453824
# 12 1248 Train accuracy: 0.3348484942317009  Train loss: 1.7371838750441868
# 12 Test accuracy: 0.345  Test loss: 1.6423926
# 13 1248 Train accuracy: 0.3366433659883646  Train loss: 1.729089974990258
# 13 Test accuracy: 0.424  Test loss: 1.5254539
# 14 1248 Train accuracy: 0.3374458968213626  Train loss: 1.7259455924374716
# 14 Test accuracy: 0.3664  Test loss: 1.6038632
# 15 1248 Train accuracy: 0.33797980737686156  Train loss: 1.7233570609092712
# 15 Test accuracy: 0.4119  Test loss: 1.4923227
# 16 1248 Train accuracy: 0.33981061551719904  Train loss: 1.7200784865021705
# 16 Test accuracy: 0.3585  Test loss: 1.6065688
# 17 1248 Train accuracy: 0.3418181912688648  Train loss: 1.7140281967555775
# 17 Test accuracy: 0.3324  Test loss: 1.6242385
# 18 1248 Train accuracy: 0.3433333428700765  Train loss: 1.7099590973059335
# 18 Test accuracy: 0.3728  Test loss: 1.6033785
# 19 1248 Train accuracy: 0.3465071866386815  Train loss: 1.7054043729681718
# 19 Test accuracy: 0.3925  Test loss: 1.4777107
# 20 1248 Train accuracy: 0.3479697066247463  Train loss: 1.701813990354538
# 20 Test accuracy: 0.3873  Test loss: 1.5308589
# 21 1248 Train accuracy: 0.34828283789611997  Train loss: 1.700249856880733
# 21 Test accuracy: 0.4154  Test loss: 1.494156
# 22 1248 Train accuracy: 0.3490633704987439  Train loss: 1.698596184578809
# 22 Test accuracy: 0.3978  Test loss: 1.5728455
# 23 1248 Train accuracy: 0.3493280728744424  Train loss: 1.6968851297834646
# 23 Test accuracy: 0.3539  Test loss: 1.7126535
# 24 1248 Train accuracy: 0.3501262723157803  Train loss: 1.6934308855732283
# Early stopping, best loss:  1.4777107
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.2915921314404561  Train loss: 1.9571742461277888
# 1 Test accuracy: 0.3959  Test loss: 1.6615746
# 2 310 Train accuracy: 0.35837805557709473  Train loss: 1.7794838914504418
# 2 Test accuracy: 0.4489  Test loss: 1.5376264
# 3 310 Train accuracy: 0.3854104559390973  Train loss: 1.6913388722982161
# 3 Test accuracy: 0.4217  Test loss: 1.7782246
# 4 310 Train accuracy: 0.4053369121482739  Train loss: 1.6300870524002955
# 4 Test accuracy: 0.4622  Test loss: 1.6670488
# 5 310 Train accuracy: 0.42230173097206997  Train loss: 1.5954492825728197
# 5 Test accuracy: 0.4797  Test loss: 1.525466
# 6 310 Train accuracy: 0.4384814174129413  Train loss: 1.5571000835834405
# 6 Test accuracy: 0.5097  Test loss: 1.3342607
# 7 310 Train accuracy: 0.4447567955805705  Train loss: 1.5381978042833098
# 7 Test accuracy: 0.4816  Test loss: 1.5710155
# 8 310 Train accuracy: 0.4531156846250479  Train loss: 1.5162077912917504
# 8 Test accuracy: 0.5276  Test loss: 1.3146749
# 9 310 Train accuracy: 0.4600145784962891  Train loss: 1.5039340196511684
# 9 Test accuracy: 0.5244  Test loss: 1.3807518
# 10 310 Train accuracy: 0.4643410874100832  Train loss: 1.4908180777843183
# 10 Test accuracy: 0.5069  Test loss: 1.3169588
# 11 310 Train accuracy: 0.4697240756733434  Train loss: 1.4793980121612549
# 11 Test accuracy: 0.4764  Test loss: 1.558363
# 12 310 Train accuracy: 0.47321606226838553  Train loss: 1.467959197667929
# 12 Test accuracy: 0.5509  Test loss: 1.2465845
# 13 310 Train accuracy: 0.4752993002622085  Train loss: 1.461373132361463
# 13 Test accuracy: 0.5818  Test loss: 1.17185
# 14 310 Train accuracy: 0.4780645726637526  Train loss: 1.4543605473015335
# 14 Test accuracy: 0.5084  Test loss: 1.4240968
# 15 310 Train accuracy: 0.4795468117182071  Train loss: 1.4482194301409599
# 15 Test accuracy: 0.5171  Test loss: 1.4234723
# 16 310 Train accuracy: 0.4833407891341127  Train loss: 1.4391975769629846
# 16 Test accuracy: 0.5491  Test loss: 1.311375
# 17 310 Train accuracy: 0.4857764239359765  Train loss: 1.4312977731497578
# 17 Test accuracy: 0.5574  Test loss: 1.2869587
# 18 310 Train accuracy: 0.4881070721735302  Train loss: 1.4252433787044296
# Early stopping, best loss:  1.17185
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.369090918302536  Train loss: 1.6933350324630738
# 1 Test accuracy: 0.3799  Test loss: 1.802693
# 2 1248 Train accuracy: 0.4275757652521133  Train loss: 1.56425399184227
# 2 Test accuracy: 0.5128  Test loss: 1.3482097
# 3 1248 Train accuracy: 0.4539394017060598  Train loss: 1.505580752690633
# 3 Test accuracy: 0.5198  Test loss: 1.339723
# 4 1248 Train accuracy: 0.47818182453513147  Train loss: 1.4341797208786011
# 4 Test accuracy: 0.5127  Test loss: 1.4474044
# 5 1248 Train accuracy: 0.49539394545555115  Train loss: 1.387126430273056
# 5 Test accuracy: 0.6107  Test loss: 1.085313
# 6 1248 Train accuracy: 0.512020207842191  Train loss: 1.3461499236027399
# 6 Test accuracy: 0.6312  Test loss: 1.0278776
# 7 1248 Train accuracy: 0.5264069319622857  Train loss: 1.307656022650855
# 7 Test accuracy: 0.5737  Test loss: 1.2457333
# 8 1248 Train accuracy: 0.5337878835946321  Train loss: 1.2855768378078938
# 8 Test accuracy: 0.6435  Test loss: 1.0113758
# 9 1248 Train accuracy: 0.5432323279645708  Train loss: 1.2626457113689846
# 9 Test accuracy: 0.6339  Test loss: 1.0255803
# 10 1248 Train accuracy: 0.5516363682150841  Train loss: 1.242945160984993
# 10 Test accuracy: 0.6086  Test loss: 1.0895439
# 11 1248 Train accuracy: 0.5584573047811334  Train loss: 1.225840051390908
# 11 Test accuracy: 0.6603  Test loss: 0.9598793
# 12 1248 Train accuracy: 0.5631313176949819  Train loss: 1.213888629178206
# 12 Test accuracy: 0.6715  Test loss: 0.9119232
# 13 1248 Train accuracy: 0.5685314731872999  Train loss: 1.200496555704337
# 13 Test accuracy: 0.6823  Test loss: 0.894346
# 14 1248 Train accuracy: 0.5755411301766123  Train loss: 1.1839382911154201
# 14 Test accuracy: 0.6799  Test loss: 0.9008592
# 15 1248 Train accuracy: 0.5799191964467366  Train loss: 1.1720251121918361
# 15 Test accuracy: 0.6727  Test loss: 0.9455672
# 16 1248 Train accuracy: 0.5839015197008848  Train loss: 1.1621504077687859
# 16 Test accuracy: 0.689  Test loss: 0.895816
# 17 1248 Train accuracy: 0.5866666711779202  Train loss: 1.153048725022989
# 17 Test accuracy: 0.7011  Test loss: 0.85408115
# 18 1248 Train accuracy: 0.5905387250582377  Train loss: 1.142320129374663
# 18 Test accuracy: 0.6658  Test loss: 0.95734495
# 19 1248 Train accuracy: 0.5948325404681657  Train loss: 1.1310871694276208
# 19 Test accuracy: 0.7152  Test loss: 0.822666
# 20 1248 Train accuracy: 0.5981818225979805  Train loss: 1.1227497093379497
# 20 Test accuracy: 0.6581  Test loss: 1.0123062
# 21 1248 Train accuracy: 0.6016450260934375  Train loss: 1.1156578679879507
# 21 Test accuracy: 0.6898  Test loss: 0.8938149
# 22 1248 Train accuracy: 0.6050688750635493  Train loss: 1.1055590080673043
# 22 Test accuracy: 0.7134  Test loss: 0.8189229
# 23 1248 Train accuracy: 0.6082740492406099  Train loss: 1.0974117748115373
# 23 Test accuracy: 0.6689  Test loss: 0.96931785
# 24 1248 Train accuracy: 0.611237378269434  Train loss: 1.0908342057466507
# 24 Test accuracy: 0.7245  Test loss: 0.7867595
# 25 1248 Train accuracy: 0.6133090954303742  Train loss: 1.08496391954422
# 25 Test accuracy: 0.7201  Test loss: 0.8001879
# 26 1248 Train accuracy: 0.6162237807420584  Train loss: 1.0776051987592992
# 26 Test accuracy: 0.7184  Test loss: 0.8189528
# 27 1248 Train accuracy: 0.6188327767672362  Train loss: 1.0700451206940191
# 27 Test accuracy: 0.7053  Test loss: 0.84936893
# 28 1248 Train accuracy: 0.6215368011168071  Train loss: 1.0624118325752872
# 28 Test accuracy: 0.7102  Test loss: 0.8512209
# 29 1248 Train accuracy: 0.6240334424890321  Train loss: 1.0551656622516699
# 29 Test accuracy: 0.7276  Test loss: 0.7723734
# 30 1248 Train accuracy: 0.6261414188146591  Train loss: 1.0505460360248884
# 30 Test accuracy: 0.7178  Test loss: 0.8057935
# 31 1248 Train accuracy: 0.6280742959437832  Train loss: 1.04571442967461
# 31 Test accuracy: 0.7181  Test loss: 0.8084711
# 32 1248 Train accuracy: 0.6295643987134099  Train loss: 1.0402230964414776
# 32 Test accuracy: 0.7101  Test loss: 0.8375096
# 33 1248 Train accuracy: 0.6319375621911251  Train loss: 1.0339841108069274
# 33 Test accuracy: 0.7239  Test loss: 0.79573894
# 34 1248 Train accuracy: 0.6339928746924681  Train loss: 1.0284995098850307
# Early stopping, best loss:  0.7723734
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.22957662321054018  Train loss: 2.074394336113563
# 1 Test accuracy: 0.3047  Test loss: 1.8662235
# 2 310 Train accuracy: 0.2903995221624008  Train loss: 1.9009090065956116
# 2 Test accuracy: 0.3785  Test loss: 1.6693856
# 3 310 Train accuracy: 0.3198171330568118  Train loss: 1.8154078691433637
# 3 Test accuracy: 0.386  Test loss: 1.6611341
# 4 310 Train accuracy: 0.33989266564066595  Train loss: 1.7594976425170898
# 4 Test accuracy: 0.3865  Test loss: 1.7175863
# 5 310 Train accuracy: 0.35599284515931057  Train loss: 1.7236548735545232
# 5 Test accuracy: 0.3724  Test loss: 1.7344203
# 6 310 Train accuracy: 0.3727887110450329  Train loss: 1.6852637773905046
# 6 Test accuracy: 0.3921  Test loss: 1.6886799
# 7 310 Train accuracy: 0.3871709686386716  Train loss: 1.6564106548225486
# 7 Test accuracy: 0.3976  Test loss: 1.7221028
# 8 310 Train accuracy: 0.3953488373125975  Train loss: 1.6321162214645972
# 8 Test accuracy: 0.4273  Test loss: 1.603086
# 9 310 Train accuracy: 0.40435963754470533  Train loss: 1.6037034387262459
# 9 Test accuracy: 0.4354  Test loss: 1.5628718
# 10 310 Train accuracy: 0.41144901708914683  Train loss: 1.5854011233036334
# 10 Test accuracy: 0.467  Test loss: 1.4651155
# 11 310 Train accuracy: 0.4194177927879187  Train loss: 1.5664989264694962
# 11 Test accuracy: 0.403  Test loss: 1.755447
# 12 310 Train accuracy: 0.42576028779149055  Train loss: 1.5513144700955122
# 12 Test accuracy: 0.5246  Test loss: 1.308304
# 13 310 Train accuracy: 0.4330994011558725  Train loss: 1.5335981916393755
# 13 Test accuracy: 0.4953  Test loss: 1.3899118
# 14 310 Train accuracy: 0.4392196969180317  Train loss: 1.5208474685857585
# 14 Test accuracy: 0.384  Test loss: 1.8211789
# 15 310 Train accuracy: 0.44523951755120206  Train loss: 1.5087644265248226
# 15 Test accuracy: 0.4949  Test loss: 1.4295244
# 16 310 Train accuracy: 0.4505441294123347  Train loss: 1.4967936638456125
# 16 Test accuracy: 0.5132  Test loss: 1.408513
# 17 310 Train accuracy: 0.45603143164205334  Train loss: 1.483803110964158
# Early stopping, best loss:  1.308304
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.21107692748308182  Train loss: 2.0865513992309572
# 1 Test accuracy: 0.1917  Test loss: 2.170243
# 2 623 Train accuracy: 0.2606153915822506  Train loss: 1.9565007543563844
# 2 Test accuracy: 0.2861  Test loss: 1.9305227
# 3 623 Train accuracy: 0.28984616150458653  Train loss: 1.880878144900004
# 3 Test accuracy: 0.3477  Test loss: 1.7827363
# 4 623 Train accuracy: 0.3130769305676222  Train loss: 1.822986695766449
# 4 Test accuracy: 0.3171  Test loss: 1.8491516
# 5 623 Train accuracy: 0.3319384691119194  Train loss: 1.7783854856491088
# 5 Test accuracy: 0.3762  Test loss: 1.6762191
# 6 623 Train accuracy: 0.3470769311487675  Train loss: 1.7430343087514242
# 6 Test accuracy: 0.3972  Test loss: 1.6631832
# 7 623 Train accuracy: 0.3560439639006342  Train loss: 1.7172002840042113
# 7 Test accuracy: 0.4394  Test loss: 1.5172918
# 8 623 Train accuracy: 0.3627692386135459  Train loss: 1.696583366394043
# 8 Test accuracy: 0.3655  Test loss: 1.7329239
# 9 623 Train accuracy: 0.3718974438971943  Train loss: 1.6774540328979493
# 9 Test accuracy: 0.3628  Test loss: 1.8615634
# 10 623 Train accuracy: 0.37821539244055746  Train loss: 1.664360945701599
# 10 Test accuracy: 0.4218  Test loss: 1.5750445
# 11 623 Train accuracy: 0.3848391684347933  Train loss: 1.651702044660395
# 11 Test accuracy: 0.4195  Test loss: 1.6354926
# 12 623 Train accuracy: 0.39015385396778585  Train loss: 1.6357480772336324
# Early stopping, best loss:  1.5172918
# time: 4h 3min 39s

# %%
# %load_ext tensorboard  # only needed once (e.g., at top of notebook)

# %tensorboard --logdir logs
