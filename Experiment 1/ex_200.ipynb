# %% [markdown]
# # **To use Tensorflow Version 1**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# # **Mount the Google Drive**

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#define your folder or create one in your google drive
root_path = '/content/drive/My Drive/ex_200/'
os.chdir(root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Record the time execution per code section**

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=6d748b44cc24910904c77c60066db0b6429e4654683aacee574d1547b90adde6
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %% [markdown]
# #**Ngrok : Running tensorboard inside Google Colab**

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
import os
LOG_DIR = '/content/drive/My Drive/ex_20/log'
#LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # **Data Preparation**

# %%
# Downloading cifar-10-python files
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -xvzf cifar-10-python.tar.gz
# Out:
# --2020-04-25 23:38:51--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  51.1MB/s    in 3.5s
#
# 2020-04-25 23:38:55 (46.0 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# time: 8.33 s

# %%
# Provided on https://www.cs.toronto.edu/~kriz/cifar.html 
# Given a "pickled" file, returns a dictionary containing the image data
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
# time: 3.01 ms

# %% [markdown]
# The training data is stored in four files, which are read and merged.

# %%
import numpy as np

for file_no in range(4):
    # Obtain data dictionary from each file
    filename = "cifar-10-batches-py/data_batch_" + str(file_no + 1)
    image_batch = unpickle(filename)
    # First file, create numpy arrays containing data & labels
    if file_no == 0:
        # Reshape to 32x32 image with 3 channels (RGB), which is made to be the last axes
        image_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_labels = image_batch[b'labels']
    else: # Concatenate to one file
        new_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_data = np.concatenate([image_data, new_data])
        image_labels = np.concatenate([image_labels, image_batch[b'labels']])

print("Training data shape: ",image_data.shape)

# Create numpy array containing test data
test_batch = unpickle("cifar-10-batches-py/test_batch")
test_data = test_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
test_labels = test_batch[b'labels']

# Obtain label names from the meta data
label_names = unpickle("cifar-10-batches-py/batches.meta")[b'label_names']
label_names = [l.decode('UTF-8') for l in label_names]
# Out:
# Training data shape:  (40000, 32, 32, 3)
# time: 340 ms

# %% [markdown]
# ### **Image samples**

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10,9,figsize=(7,9))
plt.subplots_adjust(wspace=0.01, hspace=0.01)

for image_type in range(10):
    # Obtain indices of images in each group
    group = np.argwhere(image_labels == image_type)
    # Display 1st 5 images from each group
    for col in range(8):
        n = group[col][0]
        img_rgb = image_data[n]
        axes[image_type,col].imshow(img_rgb)
        axes[image_type,col].axis('off')
    # Display image labels    
    axes[image_type,8].axis('off')    
    axes[image_type,8].text(0.1,0.5,label_names[image_type], fontsize=12)

plt.show()
# Out:
# time: 2.07 s

# %% [markdown]
# ## Model Building
# ### Hyperparameters

# %%
import tensorflow as tf
# Fixed hyperparameters
height = 32
width = 32
channels = 3
outputs = 10

n_epochs = 500
# number of epochs to try to get a lower loss before stopping
early_stop_rounds = 4

# number of iterations, within epoch, to do an accuracy check
acc_check = 25

# Variable Hyperparameters
hyperparam_range = {'filter1':[16, 32, 64, 96],
                    'kernelsize_1':[3, 4, 5],
                    'filter2':[48, 64, 96, 128],
                    'kernelsize_2':[3, 4, 5],
                    'filter3':[64, 96, 128],
                    'kernelsize_3':[3, 4, 5],
                    'hidden_1':[60, 100, 125],
                    'hidden_2':[80, 100, 125],
                    'activation':['relu', 'lrelu', 'elu'],
                    'learning_rate':[0.001, 0.0015, 0.002, 0.003],
                    'batch_size':[32, 64, 128],
                    'momentum':[0.9, 0.95, 0.99],
                    'p_reduct':[0],
                    'optimizer':['adam', 'rmsprop', 'nesterov']
                   }

# Calculate the number of hyperparamter grid points
first_item = True
for key,values in hyperparam_range.items():
    count = len(values)
    if first_item:
        display = str(count)
        total = count
        first_item = False
    else:
        display = display + ' X ' + str(count)
        total *= count

print('The total number of possible hyperparameter combinations is ' + display + ' = ' + "{:,}".format(total))
# Out:
# The total number of possible hyperparameter combinations is 4 X 3 X 4 X 3 X 3 X 3 X 3 X 3 X 3 X 4 X 3 X 3 X 1 X 3 = 3,779,136
# time: 23.6 ms

# %% [markdown]
# ### Convolutional Layer

# %%
def conv_layer(tensor_input, layer_no, filters, ksize, kstride, activation_unit, momentum, phase_train):
    # convolutional layer with batch normalisation and max pooling
    with tf.name_scope("conv_layer" + str(layer_no)):
        conv = tf.layers.conv2d(
            tensor_input,
            filters=filters,
            kernel_size=ksize,
            strides=[kstride,kstride],
            padding="SAME",
            activation=None
        )

        conv_bn = tf.layers.batch_normalization(
            inputs=conv,
            axis=-1,
            momentum=0.9,
            epsilon=0.001,
            center=True,
            scale=True,
            trainable=True,
            training = phase_train
        )

        #apply activation unit
        conv_bn_relu =  activation_unit(conv_bn)

        max_pool = tf.nn.max_pool(
            conv_bn_relu,
            ksize=[1,2,2,1],
            strides=[1,2,2,1],
            padding="VALID"
        )
            
        dropout = tf.layers.dropout(
            max_pool,
            training = phase_train
        )
            
        return dropout
# Out:
# time: 12.9 ms

# %% [markdown]
# ### Graph defintion

# %%
def build_graph(hyperparam):
    # Retrieve hyperparamaters from dictionary   
    filter1 = hyperparam['filter1']
    kernelsize_1 = hyperparam['kernelsize_1']
    filter2 = hyperparam['filter2']
    kernelsize_2 = hyperparam['kernelsize_2']
    filter3 = hyperparam['filter3']
    kernelsize_3 = hyperparam['kernelsize_3']
    hidden_1 = hyperparam['hidden_1']
    hidden_2 = hyperparam['hidden_2']
    activation = hyperparam['activation']
    learning_rate = hyperparam['learning_rate']
    momentum = hyperparam['momentum']
    p_reduct =  hyperparam['p_reduct']
    optimizer_method = hyperparam['optimizer']
    
    patch_height = height - 2 * p_reduct
    patch_width = width - 2 * p_reduct
    
    if activation == 'elu':
        activation_unit = tf.nn.elu
    elif activation == 'lrelu':
        activation_unit = tf.nn.leaky_relu
    else:    
        activation_unit = tf.nn.relu
        
    graph = tf.Graph()
    with graph.as_default():
        X = tf.placeholder(shape=(None, patch_height, patch_width, channels), dtype=tf.float32)
        y = tf.placeholder(shape=(None), dtype=tf.int32)
        phase_train = tf.placeholder(tf.bool, name='phase_train')

        # 1st convolutional layer
        conv1 = conv_layer(X, 1, filter1, kernelsize_1, 2, activation_unit, momentum, phase_train)
        
        # 2nd convolutional layer
        conv2 = conv_layer(conv1, 2, filter2, kernelsize_2, 1, activation_unit, momentum, phase_train)
        
        # 3rd cnn
        conv3 = conv_layer(conv2, 3, filter3, kernelsize_3, 1, activation_unit, momentum, phase_train)
        
        # 1st fully connected (dense) layer
        fully_conn1 = tf.layers.dense(conv3, hidden_1, name="fully_conn1", activation=activation_unit)
        flat = tf.contrib.layers.flatten(fully_conn1)
        
        # 2nd fully connected layer
        fully_conn2 = tf.layers.dense(flat, hidden_2, name="fully_conn2", activation=activation_unit)
        
        # Output layer (no activation function, as this is built into cross-entropy)
        logits = tf.layers.dense(fully_conn2, outputs, name="logits")

        # Cross Entropy Loss
        with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
            loss = tf.reduce_mean(xentropy, name="loss")

        # Training    
        with tf.name_scope("train"):
            if optimizer_method == 'rmsprop':
                    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, momentum=0.9)
            elif optimizer_method == 'nesterov':
                    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov = True)
            else:    
                optimizer = tf.train.AdamOptimizer(learning_rate)
            training_op = optimizer.minimize(loss)
    
        # Initialization & Saver
        init = tf.global_variables_initializer()
        saver = tf.train.Saver() 
        
        return graph, X, y, phase_train, logits, loss, training_op, init, saver
# Out:
# time: 56.7 ms

# %% [markdown]
# ### Model Training

# %%
# Function to train model, returns minimised loss
def train_model(batch_size = 128):
    training_size = image_data.shape[0]
    no_batches = training_size // batch_size
    
    with graph.as_default():
        # Ensure batch normalisation gets updated
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)    
        # Add Evaluation metrics
        with tf.name_scope("evaluation"):
            correct = tf.nn.in_top_k(logits, y, 1)
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            acc_summary = tf.summary.scalar('Accuracy', accuracy)
            loss_summary = tf.summary.scalar('Loss', loss)
            
    # Initialise best loss for early stopping
    best_loss = 1e9
    best_acc = 1e9
    early_stopping = False
    
    # Run training
    with tf.Session(graph=graph) as sess:                     
        init.run()
        epoch = 0
        early_stop_count = 0
        # Initialise training accuracy sum
        sum_acc_train = 0.0
        sum_loss_train = 0.0
        count_train = 0
        while (epoch < n_epochs) and (not early_stopping):
            epoch += 1
            # Shuffle training data
            p = np.random.permutation(training_size)
            image_data_shuffle = image_data_patch[p]
            image_labels_shuffle = image_labels[p]
            for iteration in range(no_batches-1):
                # Train on mini-batch
                X_batch = image_data_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                y_batch = image_labels_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                sess.run([training_op, extra_update_ops], feed_dict={X: X_batch, y: y_batch, phase_train: True})
                # Evaluate model on current mini-batch
                if (iteration % acc_check == 0):
                    acc_train, loss_train = sess.run([accuracy, loss], feed_dict={X: X_batch,
                                                                                   y: y_batch,
                                                                                   phase_train: True})
                    # Update training average for current epoch
                    sum_acc_train += acc_train
                    sum_loss_train += loss_train
                    count_train += 1
                    mean_acc_train = sum_acc_train / count_train
                    mean_loss_train = sum_loss_train / count_train
                    print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train, end='\r')
                     
            # Print mean Train accuracy        
            print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train)
            train_summary = tf.Summary()
            train_summary.value.add(tag='eval/Accuracy', simple_value=mean_acc_train)
            train_summary.value.add(tag='eval/Loss', simple_value=mean_loss_train)
            file_writer_train.add_summary(train_summary, epoch)
            
            # Evaluate model on test data every epoch
            acc_test, loss_test, summary_str_acc_test, summary_str_loss_test = sess.run([accuracy, loss,
                                                                                         acc_summary,
                                                                                         loss_summary],
                                                                                        feed_dict={X: test_data_patch,
                                                                                                   y: test_labels,
                                                                                                   phase_train: False})
            # Check for mininimum loss
            if loss_test < best_loss:
                # Reset early stopping best loss and count
                best_loss = loss_test
                best_acc = acc_test
                best_train_acc = mean_acc_train
                best_train_loss = mean_loss_train
                early_stop_count = 0
                # Save model
                save_path = saver.save(sess, ckptfile)
            else:
                # Increment early stopping count
                early_stop_count += 1
            # Check if sufficient rounds (epochs) have passed without improvement
            if early_stop_count  > early_stop_rounds:
                # Flag early stopping, so training loop will stop
                early_stopping = True
                print("Early stopping, best loss: ", best_loss)
            else:    
                # Record and display test loss and accuracy
                file_writer_test.add_summary(summary_str_acc_test, epoch)
                file_writer_test.add_summary(summary_str_loss_test, epoch)
                print(epoch, "Test accuracy:", acc_test, " Test loss:", loss_test)
            
        # Return Best Loss obtaned and number of epochs
        return best_loss, best_acc, best_train_acc, best_train_loss, epoch
# Out:
# time: 76.5 ms

# %% [markdown]
# ### Random Hyperparameter Selection and Evaluation

# %%
import pandas as pd

import random
random.seed(261001)

import os.path
if not os.path.exists('./log'):
    os.makedirs('./log')
if not os.path.exists('./graphs'):
    os.makedirs('./graphs')
    
if(os.path.isfile('./log/model_hyperparam.csv')):
    hyperparam_df = pd.read_csv('./log/model_hyperparam.csv')
    new_results_file = False
else:
    new_results_file = True

# Random Model search
for n in range(200):
    # Create log directory using current timestamp
    from datetime import datetime
    now = datetime.now().strftime("%Y%m%dT%H%M%S")
    root_logdir = "./log"
    root_graphdir = "./graphs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    graphdir = "{}/run-{}/".format(root_graphdir, now)
    #root_modeldir = "./model"
    graphfile = graphdir
    ckptfile = graphdir + "checkpoint.ckpt"

    # Note that the graph is not written using same filewriter as the logging data.
    # This allows the logs to be viewed during training before the filewriter is closed
    file_writer_train = tf.summary.FileWriter(logdir + '/train')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    
    # tensorboard --logdir e:\Programming\TensorFlow\CIFAR-10\log
    # The command must be executed from same drive (E:) as the logdir

    tf.reset_default_graph()

    hyperparam_dict = {key:random.choice(values) for (key,values) in hyperparam_range.items()}
    print("Training Model with following hyperparameters:")
    print(hyperparam_dict)

    # Obtain graph and nodes required for training
    graph, X, y, phase_train, logits, loss, training_op, init, saver = build_graph(hyperparam = hyperparam_dict)
    
    # Write graph to file and close to avoid TensorBoard conflict
    file_writer_graph = tf.summary.FileWriter(graphfile, graph)
    file_writer_graph.close()

    # Extract image patches
    p_reduct =  hyperparam_dict['p_reduct']
    if p_reduct == 0:
        image_data_patch = image_data
        test_data_patch = test_data
    else:
        image_data_patch = image_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
        test_data_patch = test_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
    
    # Train the model
    best_loss, best_acc, best_train_acc, best_train_loss, no_epochs = train_model(batch_size = hyperparam_dict['batch_size'])
    
    # Add results to dictionary
    hyperparam_dict['best_loss'] = best_loss
    hyperparam_dict['best_acc'] = best_acc
    hyperparam_dict['best_train_acc'] = best_train_acc
    hyperparam_dict['best_train_loss'] = best_train_loss
    hyperparam_dict['no_epochs'] = no_epochs
    hyperparam_dict['logdir'] = logdir
    
    # Add results to dataframe
    if new_results_file:
        hyperparam_df = pd.DataFrame(hyperparam_dict, index=[0])
        new_results_file = False
    else:
        hyperparam_df = hyperparam_df.append(hyperparam_dict, ignore_index=True)
        
    # Write results file (don't wait until end, as next model may be interrupted)
    hyperparam_df.to_csv('./log/modelhyperparameter_200.csv', index=False)

    # Close filewriters
    file_writer_train.close()
    file_writer_test.close()
    
    # NOTE - From this point onwards there are only training logs.
    # Results and Conclusion are in a seperate notebook
# Out:
# Streaming output truncated to the last 5000 lines.
# 22 1248 Train accuracy: 0.4944903649796139  Train loss: 1.3720694999803196
# 22 Test accuracy: 0.6143  Test loss: 1.076978
# 23 1248 Train accuracy: 0.49828722660956176  Train loss: 1.3636771965545156
# 23 Test accuracy: 0.6299  Test loss: 1.0290799
# 24 1248 Train accuracy: 0.5024495013058186  Train loss: 1.3532317300140857
# 24 Test accuracy: 0.6089  Test loss: 1.0785979
# 25 1248 Train accuracy: 0.5057212184906006  Train loss: 1.3449753463745118
# 25 Test accuracy: 0.6169  Test loss: 1.0723871
# 26 1248 Train accuracy: 0.5099300760947741  Train loss: 1.335190477692164
# 26 Test accuracy: 0.6376  Test loss: 1.0098523
# 27 1248 Train accuracy: 0.5132211059111136  Train loss: 1.3269663232785684
# 27 Test accuracy: 0.6237  Test loss: 1.0386454
# 28 1248 Train accuracy: 0.516709962785244  Train loss: 1.3184374178307396
# 28 Test accuracy: 0.6642  Test loss: 0.94570744
# 29 1248 Train accuracy: 0.5200836006115223  Train loss: 1.309740846979207
# 29 Test accuracy: 0.5942  Test loss: 1.1386588
# 30 1248 Train accuracy: 0.5235555615822474  Train loss: 1.3018750321070354
# 30 Test accuracy: 0.6634  Test loss: 0.94481486
# 31 1248 Train accuracy: 0.5261583637037585  Train loss: 1.2945293173482342
# 31 Test accuracy: 0.6515  Test loss: 0.9798588
# 32 1248 Train accuracy: 0.5295643999427557  Train loss: 1.2871387734636663
# 32 Test accuracy: 0.6448  Test loss: 0.99056816
# 33 1248 Train accuracy: 0.5322865072344288  Train loss: 1.2797328189647559
# 33 Test accuracy: 0.6688  Test loss: 0.9302868
# 34 1248 Train accuracy: 0.5353297740396331  Train loss: 1.272899439930916
# 34 Test accuracy: 0.6702  Test loss: 0.9225863
# 35 1248 Train accuracy: 0.5383030359745026  Train loss: 1.2653155840805599
# 35 Test accuracy: 0.6716  Test loss: 0.92751056
# 36 1248 Train accuracy: 0.5414814870887332  Train loss: 1.257294571068552
# 36 Test accuracy: 0.6397  Test loss: 1.0051634
# 37 1248 Train accuracy: 0.5445208901166916  Train loss: 1.2506652013031212
# 37 Test accuracy: 0.6735  Test loss: 0.9051123
# 38 1248 Train accuracy: 0.5471132432316479  Train loss: 1.2446993092800442
# 38 Test accuracy: 0.6747  Test loss: 0.9212631
# 39 1248 Train accuracy: 0.5494327950324768  Train loss: 1.237816381790699
# 39 Test accuracy: 0.6594  Test loss: 0.9542088
# 40 1248 Train accuracy: 0.5515606115907431  Train loss: 1.2325914417803288
# 40 Test accuracy: 0.6877  Test loss: 0.8824388
# 41 1248 Train accuracy: 0.5543976404317995  Train loss: 1.2259237730503083
# 41 Test accuracy: 0.682  Test loss: 0.89739805
# 42 1248 Train accuracy: 0.5567676822344462  Train loss: 1.220241623520851
# 42 Test accuracy: 0.6632  Test loss: 0.9446963
# 43 1248 Train accuracy: 0.5591120562026667  Train loss: 1.2143223141514978
# 43 Test accuracy: 0.6928  Test loss: 0.8614805
# 44 1248 Train accuracy: 0.5616391238976609  Train loss: 1.2084780598499558
# 44 Test accuracy: 0.688  Test loss: 0.88855696
# 45 1248 Train accuracy: 0.5638383892907036  Train loss: 1.2032433321475984
# 45 Test accuracy: 0.7044  Test loss: 0.83995557
# 46 1248 Train accuracy: 0.5661791885806167  Train loss: 1.1980516955645188
# 46 Test accuracy: 0.6756  Test loss: 0.9140443
# 47 1248 Train accuracy: 0.5683172201983472  Train loss: 1.1929299906974142
# 47 Test accuracy: 0.68  Test loss: 0.8980127
# 48 1248 Train accuracy: 0.5700757631038627  Train loss: 1.188122555365165
# 48 Test accuracy: 0.6972  Test loss: 0.8553785
# 49 1248 Train accuracy: 0.572047006183741  Train loss: 1.1836433035743479
# 49 Test accuracy: 0.6988  Test loss: 0.8588086
# 50 1248 Train accuracy: 0.5736484904050827  Train loss: 1.1793280334711074
# Early stopping, best loss:  0.83995557
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.30969697892665865  Train loss: 1.875121192932129
# 1 Test accuracy: 0.3665  Test loss: 1.6879723
# 2 1248 Train accuracy: 0.3618181905150413  Train loss: 1.751077845096588
# 2 Test accuracy: 0.4143  Test loss: 1.5751473
# 3 1248 Train accuracy: 0.3864646550019582  Train loss: 1.6827896769841513
# 3 Test accuracy: 0.3742  Test loss: 1.7353182
# 4 1248 Train accuracy: 0.3984848573803902  Train loss: 1.65053020298481
# 4 Test accuracy: 0.4156  Test loss: 1.6369746
# 5 1248 Train accuracy: 0.41139394783973693  Train loss: 1.6142640171051026
# 5 Test accuracy: 0.4552  Test loss: 1.4820347
# 6 1248 Train accuracy: 0.423232331375281  Train loss: 1.5849477656682331
# 6 Test accuracy: 0.483  Test loss: 1.38905
# 7 1248 Train accuracy: 0.43082251855305265  Train loss: 1.5589905970437186
# 7 Test accuracy: 0.4995  Test loss: 1.4061085
# 8 1248 Train accuracy: 0.438560613617301  Train loss: 1.538977856040001
# 8 Test accuracy: 0.4199  Test loss: 1.6438105
# 9 1248 Train accuracy: 0.44276095019446476  Train loss: 1.5228818832503426
# 9 Test accuracy: 0.5481  Test loss: 1.2688293
# 10 1248 Train accuracy: 0.45006061375141143  Train loss: 1.5060909210443496
# 10 Test accuracy: 0.495  Test loss: 1.3936324
# 11 1248 Train accuracy: 0.4561983545259996  Train loss: 1.489103568792343
# 11 Test accuracy: 0.4635  Test loss: 1.4886011
# 12 1248 Train accuracy: 0.4621717243889968  Train loss: 1.4743322397271792
# 12 Test accuracy: 0.574  Test loss: 1.2135979
# 13 1248 Train accuracy: 0.4669930140330241  Train loss: 1.4597750957195574
# 13 Test accuracy: 0.5214  Test loss: 1.3472055
# 14 1248 Train accuracy: 0.4733766304169382  Train loss: 1.4448540948118482
# 14 Test accuracy: 0.5826  Test loss: 1.1770672
# 15 1248 Train accuracy: 0.4778989967107773  Train loss: 1.4335557746887206
# 15 Test accuracy: 0.5736  Test loss: 1.1593863
# 16 1248 Train accuracy: 0.4832575821131468  Train loss: 1.4206497009098529
# 16 Test accuracy: 0.5722  Test loss: 1.170981
# 17 1248 Train accuracy: 0.4886274573031594  Train loss: 1.4063056560123668
# 17 Test accuracy: 0.6084  Test loss: 1.0867478
# 18 1248 Train accuracy: 0.4922895685831706  Train loss: 1.3954982817173005
# 18 Test accuracy: 0.5782  Test loss: 1.1887895
# 19 1248 Train accuracy: 0.4955661944025441  Train loss: 1.3856662617859088
# 19 Test accuracy: 0.5997  Test loss: 1.1265546
# 20 1248 Train accuracy: 0.49924243056774137  Train loss: 1.3762826335430145
# 20 Test accuracy: 0.6096  Test loss: 1.0770812
# 21 1248 Train accuracy: 0.5030014491081238  Train loss: 1.3667654161226181
# 21 Test accuracy: 0.6049  Test loss: 1.0993367
# 22 1248 Train accuracy: 0.507355377972126  Train loss: 1.356040060249242
# 22 Test accuracy: 0.6386  Test loss: 1.0341573
# 23 1248 Train accuracy: 0.5093807701701704  Train loss: 1.3487581442750018
# 23 Test accuracy: 0.6177  Test loss: 1.0951871
# 24 1248 Train accuracy: 0.5135858644048373  Train loss: 1.339619077593088
# 24 Test accuracy: 0.6208  Test loss: 1.0655175
# 25 1248 Train accuracy: 0.51701818754673  Train loss: 1.3304243043899535
# 25 Test accuracy: 0.6333  Test loss: 1.0322272
# 26 1248 Train accuracy: 0.5204895162582397  Train loss: 1.3206768623223673
# 26 Test accuracy: 0.6013  Test loss: 1.1363242
# 27 1248 Train accuracy: 0.5235241360355306  Train loss: 1.313011898111414
# 27 Test accuracy: 0.6348  Test loss: 1.0279537
# 28 1248 Train accuracy: 0.5273376681123461  Train loss: 1.3036179914644785
# 28 Test accuracy: 0.6643  Test loss: 0.95207715
# 29 1248 Train accuracy: 0.5301776441212358  Train loss: 1.2963372516221014
# 29 Test accuracy: 0.5647  Test loss: 1.2655314
# 30 1248 Train accuracy: 0.53296970252196  Train loss: 1.2882417043844858
# 30 Test accuracy: 0.5902  Test loss: 1.1679792
# 31 1248 Train accuracy: 0.5359921853965328  Train loss: 1.2809753926338687
# 31 Test accuracy: 0.6621  Test loss: 0.9529053
# 32 1248 Train accuracy: 0.5388257629983128  Train loss: 1.273500589877367
# 32 Test accuracy: 0.6054  Test loss: 1.1363637
# 33 1248 Train accuracy: 0.5413039539799546  Train loss: 1.2660801261844057
# 33 Test accuracy: 0.6618  Test loss: 0.9464787
# 34 1248 Train accuracy: 0.5438324475113083  Train loss: 1.259673243585755
# 34 Test accuracy: 0.6701  Test loss: 0.91573644
# 35 1248 Train accuracy: 0.5465281439338412  Train loss: 1.2529435671397617
# 35 Test accuracy: 0.6743  Test loss: 0.9148154
# 36 1248 Train accuracy: 0.5484680187371042  Train loss: 1.2470080366068417
# 36 Test accuracy: 0.6783  Test loss: 0.90651506
# 37 1248 Train accuracy: 0.5507944360133764  Train loss: 1.2404768437308233
# 37 Test accuracy: 0.6714  Test loss: 0.92936873
# 38 1248 Train accuracy: 0.5528867675913007  Train loss: 1.2355151328915044
# 38 Test accuracy: 0.6516  Test loss: 0.9929913
# 39 1248 Train accuracy: 0.5552136803131837  Train loss: 1.2297330710826775
# 39 Test accuracy: 0.6865  Test loss: 0.89296687
# 40 1248 Train accuracy: 0.5569090959727764  Train loss: 1.2249619633853435
# 40 Test accuracy: 0.6812  Test loss: 0.909973
# 41 1248 Train accuracy: 0.5592461247996586  Train loss: 1.2192808514978828
# 41 Test accuracy: 0.6452  Test loss: 0.9830581
# 42 1248 Train accuracy: 0.5617748967664582  Train loss: 1.2136067226103373
# 42 Test accuracy: 0.6957  Test loss: 0.8737654
# 43 1248 Train accuracy: 0.5637068407895953  Train loss: 1.2083934429079988
# 43 Test accuracy: 0.6705  Test loss: 0.93763614
# 44 1248 Train accuracy: 0.5658677735789256  Train loss: 1.2034091302210634
# 44 Test accuracy: 0.6815  Test loss: 0.90293074
# 45 1248 Train accuracy: 0.5681212171713511  Train loss: 1.1978026519616445
# 45 Test accuracy: 0.7017  Test loss: 0.8478438
# 46 1248 Train accuracy: 0.5699473041814307  Train loss: 1.1931778533691946
# 46 Test accuracy: 0.7038  Test loss: 0.85113955
# 47 1248 Train accuracy: 0.5721470070392527  Train loss: 1.187476536403311
# 47 Test accuracy: 0.7013  Test loss: 0.84606797
# 48 1248 Train accuracy: 0.5742298031225801  Train loss: 1.1818627515311042
# 48 Test accuracy: 0.6782  Test loss: 0.91476125
# 49 1248 Train accuracy: 0.5760544268817318  Train loss: 1.1771727047039537
# 49 Test accuracy: 0.6885  Test loss: 0.87939817
# 50 1248 Train accuracy: 0.5778181869268417  Train loss: 1.1729450389266014
# 50 Test accuracy: 0.6432  Test loss: 1.0184898
# 51 1248 Train accuracy: 0.5792751090433084  Train loss: 1.1696525793566424
# 51 Test accuracy: 0.7049  Test loss: 0.8403664
# 52 1248 Train accuracy: 0.5812354363615696  Train loss: 1.1643987219494123
# 52 Test accuracy: 0.6966  Test loss: 0.8633545
# 53 1248 Train accuracy: 0.5823785071103078  Train loss: 1.1607089614080932
# 53 Test accuracy: 0.703  Test loss: 0.8410172
# 54 1248 Train accuracy: 0.5836924854252074  Train loss: 1.1566732284426688
# 54 Test accuracy: 0.7041  Test loss: 0.836283
# 55 1248 Train accuracy: 0.5852341647906737  Train loss: 1.1532272589748556
# 55 Test accuracy: 0.7081  Test loss: 0.82681847
# 56 1248 Train accuracy: 0.5869372344123466  Train loss: 1.1489848614271199
# 56 Test accuracy: 0.682  Test loss: 0.9097675
# 57 1248 Train accuracy: 0.5883253638054196  Train loss: 1.1449264067411422
# 57 Test accuracy: 0.7043  Test loss: 0.843722
# 58 1248 Train accuracy: 0.5897596706501369  Train loss: 1.1407234900162138
# 58 Test accuracy: 0.7083  Test loss: 0.81810623
# 59 1248 Train accuracy: 0.5910426347033452  Train loss: 1.137138480978497
# 59 Test accuracy: 0.7003  Test loss: 0.8624177
# 60 1248 Train accuracy: 0.5925353585481644  Train loss: 1.1335098717212677
# 60 Test accuracy: 0.7162  Test loss: 0.80537945
# 61 1248 Train accuracy: 0.5935916592254014  Train loss: 1.1307874691877209
# 61 Test accuracy: 0.7177  Test loss: 0.80369836
# 62 1248 Train accuracy: 0.5948582649807777  Train loss: 1.1275410591402362
# 62 Test accuracy: 0.7147  Test loss: 0.80944437
# 63 1248 Train accuracy: 0.5963828814029694  Train loss: 1.1236280991728345
# 63 Test accuracy: 0.7085  Test loss: 0.82782733
# 64 1248 Train accuracy: 0.5978409141860902  Train loss: 1.1202345594391228
# 64 Test accuracy: 0.7087  Test loss: 0.82585627
# 65 1248 Train accuracy: 0.5989090959383891  Train loss: 1.117163376899866
# 65 Test accuracy: 0.7081  Test loss: 0.8314955
# 66 1248 Train accuracy: 0.6001377460541147  Train loss: 1.114032928799138
# 66 Test accuracy: 0.7247  Test loss: 0.7906922
# 67 1248 Train accuracy: 0.6011216694116592  Train loss: 1.1116590406467666
# 67 Test accuracy: 0.7166  Test loss: 0.8040188
# 68 1248 Train accuracy: 0.6024331600964069  Train loss: 1.1080338671803474
# 68 Test accuracy: 0.719  Test loss: 0.7971454
# 69 1248 Train accuracy: 0.6036188016853471  Train loss: 1.1044966013880744
# 69 Test accuracy: 0.7105  Test loss: 0.82796174
# 70 1248 Train accuracy: 0.6046320396236011  Train loss: 1.1013905469179153
# 70 Test accuracy: 0.7189  Test loss: 0.79760075
# 71 1248 Train accuracy: 0.6058813536922697  Train loss: 1.098169390366111
# Early stopping, best loss:  0.7906922
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3539394038915634  Train loss: 1.7915072822570801
# 1 Test accuracy: 0.3611  Test loss: 1.8892688
# 2 1248 Train accuracy: 0.39242425203323367  Train loss: 1.6565899634361267
# 2 Test accuracy: 0.4666  Test loss: 1.5738101
# 3 1248 Train accuracy: 0.4262626341978709  Train loss: 1.5701492396990457
# 3 Test accuracy: 0.4985  Test loss: 1.4292234
# 4 1248 Train accuracy: 0.4548484916985035  Train loss: 1.5087588065862656
# 4 Test accuracy: 0.6034  Test loss: 1.1180332
# 5 1248 Train accuracy: 0.4686060663461685  Train loss: 1.4666438603401184
# 5 Test accuracy: 0.5833  Test loss: 1.206391
# 6 1248 Train accuracy: 0.48252525766690574  Train loss: 1.4284717398881912
# 6 Test accuracy: 0.6143  Test loss: 1.081327
# 7 1248 Train accuracy: 0.49463203975132536  Train loss: 1.3961412589890616
# 7 Test accuracy: 0.5106  Test loss: 1.39528
# 8 1248 Train accuracy: 0.5050757624953985  Train loss: 1.3674711459875106
# 8 Test accuracy: 0.5869  Test loss: 1.1883466
# 9 1248 Train accuracy: 0.5159596009386911  Train loss: 1.338061858812968
# 9 Test accuracy: 0.6338  Test loss: 1.0329052
# 10 1248 Train accuracy: 0.5249697014689445  Train loss: 1.3173140089511872
# 10 Test accuracy: 0.6516  Test loss: 0.99058133
# 11 1248 Train accuracy: 0.5314049631899054  Train loss: 1.29972506349737
# 11 Test accuracy: 0.6626  Test loss: 0.95526
# 12 1248 Train accuracy: 0.5391414187351863  Train loss: 1.2781695420543353
# 12 Test accuracy: 0.673  Test loss: 0.9136046
# 13 1248 Train accuracy: 0.5449417297656719  Train loss: 1.2633729216685663
# 13 Test accuracy: 0.5889  Test loss: 1.1855099
# 14 1248 Train accuracy: 0.550735935653959  Train loss: 1.2468209270068578
# 14 Test accuracy: 0.6503  Test loss: 0.9903329
# 15 1248 Train accuracy: 0.5566464696327845  Train loss: 1.2352422348658243
# 15 Test accuracy: 0.6356  Test loss: 1.0433576
# 16 1248 Train accuracy: 0.5606060657277703  Train loss: 1.2263729537278414
# 16 Test accuracy: 0.609  Test loss: 1.1436706
# 17 1248 Train accuracy: 0.5630303080993541  Train loss: 1.2171107446446139
# 17 Test accuracy: 0.687  Test loss: 0.89390224
# 18 1248 Train accuracy: 0.5660942809118165  Train loss: 1.2067822380198372
# 18 Test accuracy: 0.6688  Test loss: 0.93238974
# 19 1248 Train accuracy: 0.5689314243981712  Train loss: 1.198093866611782
# 19 Test accuracy: 0.6509  Test loss: 0.9916192
# 20 1248 Train accuracy: 0.5719090957939624  Train loss: 1.190928145110607
# 20 Test accuracy: 0.6963  Test loss: 0.88079005
# 21 1248 Train accuracy: 0.5756132804495948  Train loss: 1.1822107992285773
# 21 Test accuracy: 0.6841  Test loss: 0.90893847
# 22 1248 Train accuracy: 0.5789807211539962  Train loss: 1.1746225752613761
# 22 Test accuracy: 0.6318  Test loss: 1.0672772
# 23 1248 Train accuracy: 0.5813965793537057  Train loss: 1.1678818558091704
# 23 Test accuracy: 0.6796  Test loss: 0.90082246
# 24 1248 Train accuracy: 0.5845707119752963  Train loss: 1.160183708667755
# 24 Test accuracy: 0.6936  Test loss: 0.86725056
# 25 1248 Train accuracy: 0.5866909138917923  Train loss: 1.1543913086891173
# 25 Test accuracy: 0.6635  Test loss: 0.96614474
# 26 1248 Train accuracy: 0.5887878833596523  Train loss: 1.1498885815418685
# 26 Test accuracy: 0.6974  Test loss: 0.8568546
# 27 1248 Train accuracy: 0.5904826084110472  Train loss: 1.1451915479147876
# 27 Test accuracy: 0.6983  Test loss: 0.87057024
# 28 1248 Train accuracy: 0.5926190522100244  Train loss: 1.1391991469689777
# 28 Test accuracy: 0.6976  Test loss: 0.85355985
# 29 1248 Train accuracy: 0.5942110808347834  Train loss: 1.1334368346888444
# 29 Test accuracy: 0.6402  Test loss: 1.0595624
# 30 1248 Train accuracy: 0.5959393985470136  Train loss: 1.1289821594953537
# 30 Test accuracy: 0.6879  Test loss: 0.8920041
# 31 1248 Train accuracy: 0.597966768953108  Train loss: 1.1240723802197363
# 31 Test accuracy: 0.6846  Test loss: 0.9102231
# 32 1248 Train accuracy: 0.5993371257185935  Train loss: 1.1199135215952993
# 32 Test accuracy: 0.693  Test loss: 0.8748414
# 33 1248 Train accuracy: 0.6009917400822495  Train loss: 1.1162062176610483
# Early stopping, best loss:  0.85355985
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3478787958621979  Train loss: 1.7516540598869323
# 1 Test accuracy: 0.4311  Test loss: 1.5550694
# 2 1248 Train accuracy: 0.4000000092387199  Train loss: 1.6314276272058488
# 2 Test accuracy: 0.4734  Test loss: 1.4246402
# 3 1248 Train accuracy: 0.4327272812525431  Train loss: 1.5556971474488577
# 3 Test accuracy: 0.54  Test loss: 1.2771453
# 4 1248 Train accuracy: 0.45257576525211335  Train loss: 1.4990414622426034
# 4 Test accuracy: 0.4743  Test loss: 1.4639139
# 5 1248 Train accuracy: 0.47248485624790193  Train loss: 1.4490121037960053
# 5 Test accuracy: 0.5662  Test loss: 1.1920493
# 6 1248 Train accuracy: 0.4857575833797455  Train loss: 1.4120177648464838
# 6 Test accuracy: 0.5944  Test loss: 1.1371179
# 7 1248 Train accuracy: 0.4991342066015516  Train loss: 1.3776514499528068
# 7 Test accuracy: 0.6198  Test loss: 1.0726725
# 8 1248 Train accuracy: 0.5090151581168175  Train loss: 1.3544699671864509
# 8 Test accuracy: 0.5656  Test loss: 1.2198058
# 9 1248 Train accuracy: 0.5200000063578287  Train loss: 1.3302507519721984
# 9 Test accuracy: 0.6276  Test loss: 1.0317662
# 10 1248 Train accuracy: 0.528363642513752  Train loss: 1.3096008422374725
# 10 Test accuracy: 0.6453  Test loss: 0.9845621
# 11 1248 Train accuracy: 0.5366391245343468  Train loss: 1.289843173677271
# 11 Test accuracy: 0.6575  Test loss: 0.9763644
# 12 1248 Train accuracy: 0.5418181875348091  Train loss: 1.2772943663597107
# 12 Test accuracy: 0.6096  Test loss: 1.0988302
# 13 1248 Train accuracy: 0.5470862527994009  Train loss: 1.2617004862198462
# 13 Test accuracy: 0.6618  Test loss: 0.9457959
# 14 1248 Train accuracy: 0.5517748971070562  Train loss: 1.2479968440532685
# 14 Test accuracy: 0.6529  Test loss: 0.97223514
# 15 1248 Train accuracy: 0.5560000053644181  Train loss: 1.23943275030454
# 15 Test accuracy: 0.6552  Test loss: 0.97517246
# 16 1248 Train accuracy: 0.5596212174370885  Train loss: 1.2287709647417069
# 16 Test accuracy: 0.6746  Test loss: 0.91213465
# 17 1248 Train accuracy: 0.5633868145592072  Train loss: 1.2196187503197613
# 17 Test accuracy: 0.6578  Test loss: 0.9700299
# 18 1248 Train accuracy: 0.5675084227654669  Train loss: 1.2088479276498159
# 18 Test accuracy: 0.6634  Test loss: 0.96924895
# 19 1248 Train accuracy: 0.570653912707379  Train loss: 1.1997259768373087
# 19 Test accuracy: 0.6788  Test loss: 0.8898441
# 20 1248 Train accuracy: 0.5738484899699688  Train loss: 1.19194682893157
# 20 Test accuracy: 0.6521  Test loss: 0.9639805
# 21 1248 Train accuracy: 0.5769985619896935  Train loss: 1.1833905332145236
# 21 Test accuracy: 0.6849  Test loss: 0.8809793
# 22 1248 Train accuracy: 0.5797520709037781  Train loss: 1.1756766297600485
# 22 Test accuracy: 0.6546  Test loss: 0.97794783
# 23 1248 Train accuracy: 0.5831357095552527  Train loss: 1.1675541652803836
# 23 Test accuracy: 0.6973  Test loss: 0.8581592
# 24 1248 Train accuracy: 0.5850000047435363  Train loss: 1.1620119882623354
# 24 Test accuracy: 0.7054  Test loss: 0.83374035
# 25 1248 Train accuracy: 0.5870787925958634  Train loss: 1.1569260030269624
# 25 Test accuracy: 0.6872  Test loss: 0.88595784
# 26 1248 Train accuracy: 0.5893473240274649  Train loss: 1.1503557817294048
# 26 Test accuracy: 0.6303  Test loss: 1.0933424
# 27 1248 Train accuracy: 0.5915151560085791  Train loss: 1.143954867301164
# 27 Test accuracy: 0.6639  Test loss: 0.9366248
# 28 1248 Train accuracy: 0.5942424287753446  Train loss: 1.138488153219223
# 28 Test accuracy: 0.6907  Test loss: 0.84895116
# 29 1248 Train accuracy: 0.5968234109673006  Train loss: 1.1319631192190893
# Early stopping, best loss:  0.83374035
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3058461610972881  Train loss: 1.853124680519104
# 1 Test accuracy: 0.4555  Test loss: 1.5177428
# 2 623 Train accuracy: 0.36215385399758815  Train loss: 1.720281798839569
# 2 Test accuracy: 0.465  Test loss: 1.4217076
# 3 623 Train accuracy: 0.3911794950067997  Train loss: 1.6577262846628824
# 3 Test accuracy: 0.5027  Test loss: 1.3456506
# 4 623 Train accuracy: 0.40692308466881516  Train loss: 1.6152293145656587
# 4 Test accuracy: 0.4816  Test loss: 1.4467455
# 5 623 Train accuracy: 0.4194461620748043  Train loss: 1.5846048421859742
# 5 Test accuracy: 0.479  Test loss: 1.5359466
# 6 623 Train accuracy: 0.4294359068820874  Train loss: 1.5557974235216776
# 6 Test accuracy: 0.5288  Test loss: 1.2899384
# 7 623 Train accuracy: 0.44000001011150225  Train loss: 1.5319601263318743
# 7 Test accuracy: 0.5167  Test loss: 1.3427006
# 8 623 Train accuracy: 0.4478461649082601  Train loss: 1.513670760989189
# 8 Test accuracy: 0.5563  Test loss: 1.2351971
# 9 623 Train accuracy: 0.4530598402520021  Train loss: 1.497480042775472
# 9 Test accuracy: 0.4823  Test loss: 1.5243742
# 10 623 Train accuracy: 0.4568000117987394  Train loss: 1.4835222997665405
# 10 Test accuracy: 0.5641  Test loss: 1.2064949
# 11 623 Train accuracy: 0.4619300817765973  Train loss: 1.4703826735236427
# 11 Test accuracy: 0.5041  Test loss: 1.4971046
# 12 623 Train accuracy: 0.4668718073144555  Train loss: 1.4570768241087595
# 12 Test accuracy: 0.45  Test loss: 1.529761
# 13 623 Train accuracy: 0.47105326738495096  Train loss: 1.4478669537030733
# 13 Test accuracy: 0.5823  Test loss: 1.2034208
# 14 623 Train accuracy: 0.47595605751233444  Train loss: 1.4365570194380624
# 14 Test accuracy: 0.4891  Test loss: 1.5862615
# 15 623 Train accuracy: 0.47995898861686387  Train loss: 1.4289833056132
# 15 Test accuracy: 0.5783  Test loss: 1.1701175
# 16 623 Train accuracy: 0.4830384757649153  Train loss: 1.420386829674244
# 16 Test accuracy: 0.5542  Test loss: 1.2335987
# 17 623 Train accuracy: 0.4864434534924872  Train loss: 1.412819895323585
# 17 Test accuracy: 0.5567  Test loss: 1.2996633
# 18 623 Train accuracy: 0.48933334816661145  Train loss: 1.4081214339203305
# 18 Test accuracy: 0.5624  Test loss: 1.2405993
# 19 623 Train accuracy: 0.4919190433386125  Train loss: 1.4003705575591638
# 19 Test accuracy: 0.5326  Test loss: 1.3497918
# 20 623 Train accuracy: 0.495261553786695  Train loss: 1.3921598204374313
# Early stopping, best loss:  1.1701175
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3489230862259865  Train loss: 1.7940584754943847
# 1 Test accuracy: 0.392  Test loss: 1.751381
# 2 623 Train accuracy: 0.41292308881878853  Train loss: 1.6229062163829804
# 2 Test accuracy: 0.4048  Test loss: 1.7829287
# 3 623 Train accuracy: 0.44205129593610765  Train loss: 1.5360637227694194
# 3 Test accuracy: 0.5173  Test loss: 1.378692
# 4 623 Train accuracy: 0.4613846299797297  Train loss: 1.4819027423858642
# 4 Test accuracy: 0.4394  Test loss: 1.668327
# 5 623 Train accuracy: 0.4804923236966133  Train loss: 1.427791841506958
# 5 Test accuracy: 0.5776  Test loss: 1.1659203
# 6 623 Train accuracy: 0.4950769401093324  Train loss: 1.3916037730375925
# 6 Test accuracy: 0.6062  Test loss: 1.1370453
# 7 623 Train accuracy: 0.5060219960979053  Train loss: 1.3597403386660984
# 7 Test accuracy: 0.5874  Test loss: 1.1839932
# 8 623 Train accuracy: 0.5197692492976784  Train loss: 1.327425557076931
# 8 Test accuracy: 0.6199  Test loss: 1.0628314
# 9 623 Train accuracy: 0.5296410444378853  Train loss: 1.3020478661855062
# 9 Test accuracy: 0.64  Test loss: 1.0189451
# 10 623 Train accuracy: 0.5361230961382389  Train loss: 1.282364164829254
# 10 Test accuracy: 0.563  Test loss: 1.2380873
# 11 623 Train accuracy: 0.54293708240444  Train loss: 1.2646073098616166
# 11 Test accuracy: 0.6273  Test loss: 1.0542357
# 12 623 Train accuracy: 0.5501025837908189  Train loss: 1.2457859402894973
# 12 Test accuracy: 0.6482  Test loss: 0.98000175
# 13 623 Train accuracy: 0.5568757593860993  Train loss: 1.229066043633681
# 13 Test accuracy: 0.6737  Test loss: 0.93662024
# 14 623 Train accuracy: 0.5619780418063913  Train loss: 1.216834147998265
# 14 Test accuracy: 0.591  Test loss: 1.2336643
# 15 623 Train accuracy: 0.5669743788441022  Train loss: 1.2031962585449218
# 15 Test accuracy: 0.6689  Test loss: 0.9564374
# 16 623 Train accuracy: 0.5722307891584932  Train loss: 1.1889188657701015
# 16 Test accuracy: 0.6657  Test loss: 0.94846445
# 17 623 Train accuracy: 0.5775565810238614  Train loss: 1.17508357370601
# 17 Test accuracy: 0.6554  Test loss: 0.98762697
# 18 623 Train accuracy: 0.5808205328550604  Train loss: 1.1664072771867116
# Early stopping, best loss:  0.93662024
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 32, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.3866666758060455  Train loss: 1.6597350668907165
# 1 Test accuracy: 0.3889  Test loss: 1.7184012
# 2 1248 Train accuracy: 0.4203030383586884  Train loss: 1.571398434638977
# 2 Test accuracy: 0.4824  Test loss: 1.4351879
# 3 1248 Train accuracy: 0.44444445192813875  Train loss: 1.5150525482495625
# 3 Test accuracy: 0.4671  Test loss: 1.4831328
# 4 1248 Train accuracy: 0.4610606138408184  Train loss: 1.464994751214981
# 4 Test accuracy: 0.4825  Test loss: 1.5014391
# 5 1248 Train accuracy: 0.4740606138706207  Train loss: 1.4315196146965028
# 5 Test accuracy: 0.519  Test loss: 1.3508025
# 6 1248 Train accuracy: 0.4845454616347949  Train loss: 1.4092062671979269
# 6 Test accuracy: 0.588  Test loss: 1.1442113
# 7 1248 Train accuracy: 0.49627706255231585  Train loss: 1.380156190906252
# 7 Test accuracy: 0.5514  Test loss: 1.2924826
# 8 1248 Train accuracy: 0.5034848545491696  Train loss: 1.366283225119114
# 8 Test accuracy: 0.556  Test loss: 1.3338752
# 9 1248 Train accuracy: 0.5129292989439435  Train loss: 1.3445528631740147
# 9 Test accuracy: 0.5897  Test loss: 1.1245838
# 10 1248 Train accuracy: 0.5187272781729698  Train loss: 1.329967738866806
# 10 Test accuracy: 0.5767  Test loss: 1.2425454
# 11 1248 Train accuracy: 0.5237465619499033  Train loss: 1.3209896919944069
# 11 Test accuracy: 0.6134  Test loss: 1.0911349
# 12 1248 Train accuracy: 0.5296464700500171  Train loss: 1.305951362848282
# 12 Test accuracy: 0.5924  Test loss: 1.1904457
# 13 1248 Train accuracy: 0.5341258792693798  Train loss: 1.2980717420578003
# 13 Test accuracy: 0.5986  Test loss: 1.2068077
# 14 1248 Train accuracy: 0.5380086632711547  Train loss: 1.2879985709701265
# 14 Test accuracy: 0.6256  Test loss: 1.0629723
# 15 1248 Train accuracy: 0.540767682115237  Train loss: 1.2814705364704133
# 15 Test accuracy: 0.606  Test loss: 1.1166551
# 16 1248 Train accuracy: 0.5441287930309773  Train loss: 1.2744893234223127
# 16 Test accuracy: 0.5952  Test loss: 1.203229
# 17 1248 Train accuracy: 0.5498039266993018  Train loss: 1.2636161200439229
# 17 Test accuracy: 0.6655  Test loss: 0.96099454
# 18 1248 Train accuracy: 0.5535016884406407  Train loss: 1.2554993343353271
# 18 Test accuracy: 0.6558  Test loss: 0.99856484
# 19 1248 Train accuracy: 0.5560127639770508  Train loss: 1.2490098602520792
# 19 Test accuracy: 0.6384  Test loss: 1.0286127
# 20 1248 Train accuracy: 0.5584545503854752  Train loss: 1.2440384082198144
# 20 Test accuracy: 0.6225  Test loss: 1.1184965
# 21 1248 Train accuracy: 0.5606349255641302  Train loss: 1.2384922506128038
# 21 Test accuracy: 0.6388  Test loss: 1.0604467
# 22 1248 Train accuracy: 0.5630027597329833  Train loss: 1.2328616722605445
# Early stopping, best loss:  0.96099454
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3323077005147934  Train loss: 1.785011692047119
# 1 Test accuracy: 0.4258  Test loss: 1.587282
# 2 623 Train accuracy: 0.3910769298672676  Train loss: 1.6528001427650452
# 2 Test accuracy: 0.4863  Test loss: 1.4074391
# 3 623 Train accuracy: 0.41538462340831755  Train loss: 1.5851624536514282
# 3 Test accuracy: 0.3627  Test loss: 1.9148504
# 4 623 Train accuracy: 0.4367692403495312  Train loss: 1.5351579880714417
# 4 Test accuracy: 0.5209  Test loss: 1.3163567
# 5 623 Train accuracy: 0.44923077976703646  Train loss: 1.5094471044540405
# 5 Test accuracy: 0.5604  Test loss: 1.2213969
# 6 623 Train accuracy: 0.461846166352431  Train loss: 1.473538053035736
# 6 Test accuracy: 0.5307  Test loss: 1.3201274
# 7 623 Train accuracy: 0.4734945192507335  Train loss: 1.4392637654713223
# 7 Test accuracy: 0.5723  Test loss: 1.1856416
# 8 623 Train accuracy: 0.4841538605839014  Train loss: 1.4143832165002823
# 8 Test accuracy: 0.5948  Test loss: 1.1352955
# 9 623 Train accuracy: 0.4966837760474947  Train loss: 1.3874546888139512
# 9 Test accuracy: 0.6048  Test loss: 1.1027845
# 10 623 Train accuracy: 0.5028923240303993  Train loss: 1.3710197777748108
# 10 Test accuracy: 0.605  Test loss: 1.1160768
# 11 623 Train accuracy: 0.5099860308928923  Train loss: 1.3521971360119907
# 11 Test accuracy: 0.6007  Test loss: 1.0969143
# 12 623 Train accuracy: 0.5155384789407254  Train loss: 1.3345410760243734
# 12 Test accuracy: 0.6125  Test loss: 1.0792067
# 13 623 Train accuracy: 0.5197633311840204  Train loss: 1.3234916696181664
# 13 Test accuracy: 0.6312  Test loss: 1.0438033
# 14 623 Train accuracy: 0.5254505673902375  Train loss: 1.3093175906794412
# 14 Test accuracy: 0.6071  Test loss: 1.104077
# 15 623 Train accuracy: 0.53037950527668  Train loss: 1.2995265714327495
# 15 Test accuracy: 0.6171  Test loss: 1.0648106
# 16 623 Train accuracy: 0.5351923261210323  Train loss: 1.2849635472893715
# 16 Test accuracy: 0.6477  Test loss: 1.0032989
# 17 623 Train accuracy: 0.538895946355427  Train loss: 1.2744413014019236
# 17 Test accuracy: 0.6237  Test loss: 1.0753697
# 18 623 Train accuracy: 0.5411624121997092  Train loss: 1.2681093808015187
# 18 Test accuracy: 0.6542  Test loss: 0.98264337
# 19 623 Train accuracy: 0.5438380759327035  Train loss: 1.2617811066225955
# 19 Test accuracy: 0.6648  Test loss: 0.9681545
# 20 623 Train accuracy: 0.5462461731731891  Train loss: 1.2541207889318466
# 20 Test accuracy: 0.6661  Test loss: 0.95407224
# 21 623 Train accuracy: 0.5491282245942525  Train loss: 1.247223937511444
# 21 Test accuracy: 0.6046  Test loss: 1.0899205
# 22 623 Train accuracy: 0.5521398797631264  Train loss: 1.2387006941708651
# 22 Test accuracy: 0.629  Test loss: 1.058408
# 23 623 Train accuracy: 0.5543277789976286  Train loss: 1.2326736299887948
# 23 Test accuracy: 0.6711  Test loss: 0.9344957
# 24 623 Train accuracy: 0.5565128403653701  Train loss: 1.226083558301131
# 24 Test accuracy: 0.6276  Test loss: 1.059465
# 25 623 Train accuracy: 0.5594338660955429  Train loss: 1.2180737183570862
# 25 Test accuracy: 0.6575  Test loss: 0.9762371
# 26 623 Train accuracy: 0.5613728011342195  Train loss: 1.2141205939879784
# 26 Test accuracy: 0.6561  Test loss: 0.9694874
# 27 623 Train accuracy: 0.563327655505251  Train loss: 1.2086656186315747
# 27 Test accuracy: 0.6575  Test loss: 0.9649146
# 28 623 Train accuracy: 0.5647692510272775  Train loss: 1.2061405495234898
# 28 Test accuracy: 0.6836  Test loss: 0.9051916
# 29 623 Train accuracy: 0.566153866525354  Train loss: 1.2027892745774367
# 29 Test accuracy: 0.6574  Test loss: 0.9568422
# 30 623 Train accuracy: 0.5678769435286521  Train loss: 1.1983982428709665
# 30 Test accuracy: 0.6836  Test loss: 0.90739715
# 31 623 Train accuracy: 0.5699454298903865  Train loss: 1.1940794107221788
# 31 Test accuracy: 0.6176  Test loss: 1.1123207
# 32 623 Train accuracy: 0.5716538666374982  Train loss: 1.1901081015914678
# 32 Test accuracy: 0.6732  Test loss: 0.9420411
# 33 623 Train accuracy: 0.5732214656562516  Train loss: 1.1861307481563452
# Early stopping, best loss:  0.9051916
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3243077012896538  Train loss: 1.9521616983413697
# 1 Test accuracy: 0.3915  Test loss: 1.6065425
# 2 623 Train accuracy: 0.3596923170983791  Train loss: 1.801398434638977
# 2 Test accuracy: 0.4546  Test loss: 1.5350693
# 3 623 Train accuracy: 0.3909743681550026  Train loss: 1.7111614974339804
# 3 Test accuracy: 0.4389  Test loss: 1.534633
# 4 623 Train accuracy: 0.40553847037255764  Train loss: 1.6558725666999816
# 4 Test accuracy: 0.4467  Test loss: 1.4997916
# 5 623 Train accuracy: 0.4156307787299156  Train loss: 1.628468306541443
# 5 Test accuracy: 0.4217  Test loss: 1.7816594
# 6 623 Train accuracy: 0.4241025739411513  Train loss: 1.605096313158671
# 6 Test accuracy: 0.3708  Test loss: 2.2615743
# 7 623 Train accuracy: 0.4373626475249018  Train loss: 1.5713452642304557
# 7 Test accuracy: 0.5235  Test loss: 1.3854082
# 8 623 Train accuracy: 0.4436923184618354  Train loss: 1.5504568299651147
# 8 Test accuracy: 0.4704  Test loss: 1.597939
# 9 623 Train accuracy: 0.45032479759719635  Train loss: 1.5370582996474371
# 9 Test accuracy: 0.5113  Test loss: 1.4890922
# 10 623 Train accuracy: 0.45772308894991875  Train loss: 1.5180762078762053
# 10 Test accuracy: 0.5533  Test loss: 1.2556914
# 11 623 Train accuracy: 0.4622657466747544  Train loss: 1.506868883262981
# 11 Test accuracy: 0.5708  Test loss: 1.2402738
# 12 623 Train accuracy: 0.4660512947787841  Train loss: 1.4979741781949998
# 12 Test accuracy: 0.5568  Test loss: 1.2725418
# 13 623 Train accuracy: 0.4692071137749232  Train loss: 1.4890764744465168
# 13 Test accuracy: 0.5298  Test loss: 1.4200822
# 14 623 Train accuracy: 0.47353847484503475  Train loss: 1.4815159589903695
# 14 Test accuracy: 0.5625  Test loss: 1.2424445
# 15 623 Train accuracy: 0.4770461674332619  Train loss: 1.474208443959554
# 15 Test accuracy: 0.5527  Test loss: 1.2719454
# 16 623 Train accuracy: 0.4798077063076198  Train loss: 1.4693950548768044
# 16 Test accuracy: 0.5903  Test loss: 1.1908277
# 17 623 Train accuracy: 0.4830407382986125  Train loss: 1.4618300266826854
# 17 Test accuracy: 0.5555  Test loss: 1.3450958
# 18 623 Train accuracy: 0.48536753586596915  Train loss: 1.456338090631697
# 18 Test accuracy: 0.6034  Test loss: 1.1441635
# 19 623 Train accuracy: 0.488194346663199  Train loss: 1.4499091470868963
# 19 Test accuracy: 0.4441  Test loss: 1.7331871
# 20 623 Train accuracy: 0.49138463024795054  Train loss: 1.4431235588788986
# 20 Test accuracy: 0.4411  Test loss: 1.8186605
# 21 623 Train accuracy: 0.4935384765551204  Train loss: 1.4377362449963889
# 21 Test accuracy: 0.5182  Test loss: 1.4104191
# 22 623 Train accuracy: 0.4961958194185387  Train loss: 1.43183197053996
# 22 Test accuracy: 0.5515  Test loss: 1.4325744
# 23 623 Train accuracy: 0.49814048351153084  Train loss: 1.425954584868058
# Early stopping, best loss:  1.1441635
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.2450805019873839  Train loss: 2.0849236891819882
# 1 Test accuracy: 0.267  Test loss: 1.9130765
# 2 310 Train accuracy: 0.2912939769717363  Train loss: 1.9075353604096632
# 2 Test accuracy: 0.398  Test loss: 1.637969
# 3 310 Train accuracy: 0.3233949515299919  Train loss: 1.8164290495407887
# 3 Test accuracy: 0.4023  Test loss: 1.5920455
# 4 310 Train accuracy: 0.3446630895710908  Train loss: 1.7529882467710054
# 4 Test accuracy: 0.4185  Test loss: 1.6096417
# 5 310 Train accuracy: 0.3638640433549881  Train loss: 1.7124584839894221
# 5 Test accuracy: 0.4444  Test loss: 1.5007471
# 6 310 Train accuracy: 0.376068376768858  Train loss: 1.679319665982173
# 6 Test accuracy: 0.4833  Test loss: 1.4267333
# 7 310 Train accuracy: 0.387085782793852  Train loss: 1.6508551220317462
# 7 Test accuracy: 0.4714  Test loss: 1.4300336
# 8 310 Train accuracy: 0.39333631485127485  Train loss: 1.6341835948137136
# 8 Test accuracy: 0.464  Test loss: 1.5135098
# 9 310 Train accuracy: 0.40237196120950913  Train loss: 1.6115968217197647
# 9 Test accuracy: 0.4893  Test loss: 1.3868951
# 10 310 Train accuracy: 0.4113893865392758  Train loss: 1.5916592341202955
# 10 Test accuracy: 0.5264  Test loss: 1.3247597
# 11 310 Train accuracy: 0.41833360534864705  Train loss: 1.5750460883120556
# 11 Test accuracy: 0.442  Test loss: 1.5426612
# 12 310 Train accuracy: 0.4251142928424554  Train loss: 1.5576065702316089
# 12 Test accuracy: 0.4559  Test loss: 1.5310749
# 13 310 Train accuracy: 0.4308976669459653  Train loss: 1.5432702373470781
# 13 Test accuracy: 0.4684  Test loss: 1.4829991
# 14 310 Train accuracy: 0.4373881948681978  Train loss: 1.5257057305220718
# 14 Test accuracy: 0.4955  Test loss: 1.3811754
# 15 310 Train accuracy: 0.442615783902315  Train loss: 1.5095270694830478
# 15 Test accuracy: 0.5553  Test loss: 1.2348876
# 16 310 Train accuracy: 0.4474508069598904  Train loss: 1.495059212239889
# 16 Test accuracy: 0.4179  Test loss: 1.6313657
# 17 310 Train accuracy: 0.4530499158806391  Train loss: 1.4827899657762968
# 17 Test accuracy: 0.4167  Test loss: 1.6705514
# 18 310 Train accuracy: 0.4575962381612541  Train loss: 1.470536145899031
# 18 Test accuracy: 0.5701  Test loss: 1.1884745
# 19 310 Train accuracy: 0.4627624533557699  Train loss: 1.4582196478901603
# 19 Test accuracy: 0.5871  Test loss: 1.142356
# 20 310 Train accuracy: 0.467084080267411  Train loss: 1.4478980756722963
# 20 Test accuracy: 0.5677  Test loss: 1.1927179
# 21 310 Train accuracy: 0.47170400843297167  Train loss: 1.4368328572192908
# 21 Test accuracy: 0.5991  Test loss: 1.1125299
# 22 310 Train accuracy: 0.47709654849934413  Train loss: 1.4242181256934479
# 22 Test accuracy: 0.4834  Test loss: 1.4870195
# 23 310 Train accuracy: 0.4815275743354523  Train loss: 1.4134328301535004
# 23 Test accuracy: 0.5571  Test loss: 1.220325
# 24 310 Train accuracy: 0.4849185071025903  Train loss: 1.403679764805696
# 24 Test accuracy: 0.6182  Test loss: 1.0718964
# 25 310 Train accuracy: 0.48889684131512273  Train loss: 1.3936815624970655
# 25 Test accuracy: 0.5398  Test loss: 1.2939285
# 26 310 Train accuracy: 0.49293610546186833  Train loss: 1.3833037442004188
# 26 Test accuracy: 0.6038  Test loss: 1.0928999
# 27 310 Train accuracy: 0.49603569138253856  Train loss: 1.375813041317497
# 27 Test accuracy: 0.638  Test loss: 1.0254738
# 28 310 Train accuracy: 0.4987860990503987  Train loss: 1.3683810446943556
# 28 Test accuracy: 0.5826  Test loss: 1.1654168
# 29 310 Train accuracy: 0.5015318827303398  Train loss: 1.361132209750006
# 29 Test accuracy: 0.5776  Test loss: 1.1727664
# 30 310 Train accuracy: 0.5040151073764532  Train loss: 1.3541806444143638
# 30 Test accuracy: 0.6006  Test loss: 1.1175088
# 31 310 Train accuracy: 0.5070113690925887  Train loss: 1.347131233653123
# 31 Test accuracy: 0.5286  Test loss: 1.3404226
# 32 310 Train accuracy: 0.5098949022089633  Train loss: 1.339467713322777
# 32 Test accuracy: 0.6386  Test loss: 1.0245768
# 33 310 Train accuracy: 0.5119712330869861  Train loss: 1.3338356552979884
# 33 Test accuracy: 0.6424  Test loss: 1.0007282
# 34 310 Train accuracy: 0.5144866535364233  Train loss: 1.3269163960784809
# 34 Test accuracy: 0.5526  Test loss: 1.2702618
# 35 310 Train accuracy: 0.5175568618944713  Train loss: 1.3187546728731512
# 35 Test accuracy: 0.6004  Test loss: 1.1143553
# 36 310 Train accuracy: 0.5194957927824595  Train loss: 1.3131716081984022
# 36 Test accuracy: 0.6346  Test loss: 1.0122278
# 37 310 Train accuracy: 0.5220712662796468  Train loss: 1.3068184690267282
# 37 Test accuracy: 0.6153  Test loss: 1.055599
# 38 310 Train accuracy: 0.5248093400225948  Train loss: 1.299842091707083
# Early stopping, best loss:  1.0007282
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3273846223950386  Train loss: 1.8287934732437134
# 1 Test accuracy: 0.3749  Test loss: 1.7334166
# 2 623 Train accuracy: 0.3716923137009144  Train loss: 1.700404827594757
# 2 Test accuracy: 0.428  Test loss: 1.566682
# 3 623 Train accuracy: 0.3860512885451317  Train loss: 1.6452885993321738
# 3 Test accuracy: 0.4674  Test loss: 1.467781
# 4 623 Train accuracy: 0.40369231559336183  Train loss: 1.6039037322998047
# 4 Test accuracy: 0.471  Test loss: 1.4758155
# 5 623 Train accuracy: 0.4210461626648903  Train loss: 1.565576379776001
# 5 Test accuracy: 0.4978  Test loss: 1.3878988
# 6 623 Train accuracy: 0.43251283014814057  Train loss: 1.5370719679196676
# 6 Test accuracy: 0.4552  Test loss: 1.5323992
# 7 623 Train accuracy: 0.43973627367189955  Train loss: 1.516571888242449
# 7 Test accuracy: 0.4919  Test loss: 1.4305643
# 8 623 Train accuracy: 0.4503077033534646  Train loss: 1.4975661194324494
# 8 Test accuracy: 0.521  Test loss: 1.3504183
# 9 623 Train accuracy: 0.4585299265715811  Train loss: 1.4775954124662611
# 9 Test accuracy: 0.488  Test loss: 1.4045624
# 10 623 Train accuracy: 0.46664616659283636  Train loss: 1.461015516757965
# 10 Test accuracy: 0.4432  Test loss: 1.5724822
# 11 623 Train accuracy: 0.47194406934759836  Train loss: 1.4458073247562755
# 11 Test accuracy: 0.554  Test loss: 1.2260543
# 12 623 Train accuracy: 0.4754359110444784  Train loss: 1.4369897262255351
# 12 Test accuracy: 0.5007  Test loss: 1.3688381
# 13 623 Train accuracy: 0.4810887717512938  Train loss: 1.4219567687694843
# 13 Test accuracy: 0.4124  Test loss: 1.7246207
# 14 623 Train accuracy: 0.48672528975776264  Train loss: 1.4096375240598407
# 14 Test accuracy: 0.4926  Test loss: 1.4484484
# 15 623 Train accuracy: 0.49349745132525763  Train loss: 1.3954199644724528
# 15 Test accuracy: 0.5456  Test loss: 1.3299444
# 16 623 Train accuracy: 0.4972692467458546  Train loss: 1.3860961411893369
# 16 Test accuracy: 0.5699  Test loss: 1.1952193
# 17 623 Train accuracy: 0.5010678895256099  Train loss: 1.3765947371370653
# 17 Test accuracy: 0.5135  Test loss: 1.3881345
# 18 623 Train accuracy: 0.5035213839511077  Train loss: 1.3687527166472542
# 18 Test accuracy: 0.538  Test loss: 1.3789527
# 19 623 Train accuracy: 0.5066234983425392  Train loss: 1.3608166534022281
# 19 Test accuracy: 0.5543  Test loss: 1.2546129
# 20 623 Train accuracy: 0.5100615552812815  Train loss: 1.351422510623932
# 20 Test accuracy: 0.5607  Test loss: 1.2571917
# 21 623 Train accuracy: 0.5124395774801572  Train loss: 1.3454197305724733
# 21 Test accuracy: 0.5807  Test loss: 1.1792408
# 22 623 Train accuracy: 0.5143496675518426  Train loss: 1.3400971227342433
# 22 Test accuracy: 0.5852  Test loss: 1.1633435
# 23 623 Train accuracy: 0.5165485124613928  Train loss: 1.333695279618968
# 23 Test accuracy: 0.5517  Test loss: 1.2741048
# 24 623 Train accuracy: 0.5183333509787917  Train loss: 1.328676575620969
# 24 Test accuracy: 0.466  Test loss: 1.5497199
# 25 623 Train accuracy: 0.5213292485833168  Train loss: 1.322215835571289
# 25 Test accuracy: 0.4309  Test loss: 1.6109791
# 26 623 Train accuracy: 0.5224852249370171  Train loss: 1.3185428303938647
# 26 Test accuracy: 0.5546  Test loss: 1.2989044
# 27 623 Train accuracy: 0.5242621263420141  Train loss: 1.314902991718716
# Early stopping, best loss:  1.1633435
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.371692313849926  Train loss: 1.7397375202178955
# 1 Test accuracy: 0.4672  Test loss: 1.4301134
# 2 623 Train accuracy: 0.4169230864942074  Train loss: 1.6046320796012878
# 2 Test accuracy: 0.5306  Test loss: 1.2853299
# 3 623 Train accuracy: 0.45005129486322404  Train loss: 1.5299018096923829
# 3 Test accuracy: 0.5476  Test loss: 1.2595849
# 4 623 Train accuracy: 0.4712307836860418  Train loss: 1.4812992405891419
# 4 Test accuracy: 0.5277  Test loss: 1.3116086
# 5 623 Train accuracy: 0.4866461693644524  Train loss: 1.4345443844795227
# 5 Test accuracy: 0.5566  Test loss: 1.2286276
# 6 623 Train accuracy: 0.49733334973454474  Train loss: 1.4114288938045503
# 6 Test accuracy: 0.5966  Test loss: 1.1303809
# 7 623 Train accuracy: 0.505406610752855  Train loss: 1.3884958515848431
# 7 Test accuracy: 0.6022  Test loss: 1.1188896
# 8 623 Train accuracy: 0.5123846332356333  Train loss: 1.3637033116817474
# 8 Test accuracy: 0.6045  Test loss: 1.1346145
# 9 623 Train accuracy: 0.5193162576026387  Train loss: 1.3418201751179166
# 9 Test accuracy: 0.5393  Test loss: 1.3418334
# 10 623 Train accuracy: 0.5257230957448482  Train loss: 1.3218113403320313
# 10 Test accuracy: 0.5955  Test loss: 1.1344935
# 11 623 Train accuracy: 0.5324755436452953  Train loss: 1.3042998938126997
# 11 Test accuracy: 0.5907  Test loss: 1.1826345
# 12 623 Train accuracy: 0.5384615578005711  Train loss: 1.2905879877010982
# 12 Test accuracy: 0.6068  Test loss: 1.0833018
# 13 623 Train accuracy: 0.5413017945793959  Train loss: 1.2781169132085948
# 13 Test accuracy: 0.5301  Test loss: 1.3766015
# 14 623 Train accuracy: 0.5461099097345556  Train loss: 1.268781077010291
# 14 Test accuracy: 0.6431  Test loss: 0.9856928
# 15 623 Train accuracy: 0.5506051478981971  Train loss: 1.2569113578796387
# 15 Test accuracy: 0.6126  Test loss: 1.1145824
# 16 623 Train accuracy: 0.555000019799918  Train loss: 1.2464549085497856
# 16 Test accuracy: 0.6436  Test loss: 1.0175984
# 17 623 Train accuracy: 0.5579728705567472  Train loss: 1.2379148232235628
# 17 Test accuracy: 0.658  Test loss: 0.9522093
# 18 623 Train accuracy: 0.5608547209203243  Train loss: 1.228106062412262
# 18 Test accuracy: 0.6664  Test loss: 0.9327383
# 19 623 Train accuracy: 0.5625587246135662  Train loss: 1.2219533217580696
# 19 Test accuracy: 0.6275  Test loss: 1.0437646
# 20 623 Train accuracy: 0.5656615586727858  Train loss: 1.2125004242658615
# 20 Test accuracy: 0.6686  Test loss: 0.9343037
# 21 623 Train accuracy: 0.56770698006664  Train loss: 1.2062185600825719
# 21 Test accuracy: 0.6402  Test loss: 1.0344652
# 22 623 Train accuracy: 0.569454565955834  Train loss: 1.199596353335814
# 22 Test accuracy: 0.6656  Test loss: 0.9580944
# 23 623 Train accuracy: 0.5724682479708091  Train loss: 1.1926483773148577
# Early stopping, best loss:  0.9327383
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.17173524143604132  Train loss: 2.2737206862523007
# 1 Test accuracy: 0.2274  Test loss: 2.0262358
# 2 310 Train accuracy: 0.23017292727644628  Train loss: 2.103675223313845
# 2 Test accuracy: 0.256  Test loss: 1.9087572
# ...
# 16 310 Train accuracy: 0.4659361969679594  Train loss: 1.467450393507114
# 16 Test accuracy: 0.548  Test loss: 1.2397621
# 17 310 Train accuracy: 0.4688694812863121  Train loss: 1.4589966762119828
# 17 Test accuracy: 0.564  Test loss: 1.2095852
# 18 310 Train accuracy: 0.4725369388221676  Train loss: 1.4501972835288088
# 18 Test accuracy: 0.5611  Test loss: 1.2177553
# 19 310 Train accuracy: 0.4742177460599042  Train loss: 1.443955877531878
# 19 Test accuracy: 0.5011  Test loss: 1.3835025
# 20 310 Train accuracy: 0.4768932630236332  Train loss: 1.4395957414920513
# 20 Test accuracy: 0.4861  Test loss: 1.3986183
# 21 310 Train accuracy: 0.48047817921463826  Train loss: 1.4333687924640082
# 21 Test accuracy: 0.5268  Test loss: 1.3314205
# 22 310 Train accuracy: 0.48216512299084163  Train loss: 1.4276421015912837
# Early stopping, best loss:  1.2095852
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.33571854348366076  Train loss: 1.9113291135201087
# 1 Test accuracy: 0.3618  Test loss: 1.805523
# 2 310 Train accuracy: 0.3890876557964545  Train loss: 1.7101974441454961
# 2 Test accuracy: 0.4607  Test loss: 1.4893082
# 3 310 Train accuracy: 0.42377260900460756  Train loss: 1.6136851066198103
# 3 Test accuracy: 0.4389  Test loss: 1.8708977
# 4 310 Train accuracy: 0.44961240228552085  Train loss: 1.5388685120986059
# 4 Test accuracy: 0.404  Test loss: 1.9277488
# 5 310 Train accuracy: 0.4671437109892185  Train loss: 1.490605114056514
# 5 Test accuracy: 0.4479  Test loss: 1.7588099
# 6 310 Train accuracy: 0.4826078340411186  Train loss: 1.443079344737224
# 6 Test accuracy: 0.5353  Test loss: 1.3339659
# 7 310 Train accuracy: 0.4967203371144913  Train loss: 1.4070577582160195
# 7 Test accuracy: 0.5238  Test loss: 1.4335904
# 8 310 Train accuracy: 0.5076774024906067  Train loss: 1.3775003781685462
# 8 Test accuracy: 0.532  Test loss: 1.4094352
# 9 310 Train accuracy: 0.5168621233131132  Train loss: 1.3519082135624356
# 9 Test accuracy: 0.6132  Test loss: 1.0966234
# 10 310 Train accuracy: 0.5240906393298737  Train loss: 1.331939255274259
# 10 Test accuracy: 0.6099  Test loss: 1.0943953
# 11 310 Train accuracy: 0.5322816729337185  Train loss: 1.3127913595913174
# 11 Test accuracy: 0.6225  Test loss: 1.0543308
# 12 310 Train accuracy: 0.5379149282398896  Train loss: 1.2973896436966383
# 12 Test accuracy: 0.6084  Test loss: 1.0909383
# 13 310 Train accuracy: 0.5452043487299123  Train loss: 1.2801338952673962
# 13 Test accuracy: 0.6228  Test loss: 1.0659679
# 14 310 Train accuracy: 0.5503875969366713  Train loss: 1.2658725888519498
# 14 Test accuracy: 0.6698  Test loss: 0.9113409
# 15 310 Train accuracy: 0.5554760482830879  Train loss: 1.2519345751175515
# 15 Test accuracy: 0.6182  Test loss: 1.1422002
# 16 310 Train accuracy: 0.5595930232308232  Train loss: 1.24203867236009
# 16 Test accuracy: 0.6539  Test loss: 0.9996482
# 17 310 Train accuracy: 0.5634010309412468  Train loss: 1.2293188704085027
# 17 Test accuracy: 0.6608  Test loss: 0.9527133
# 18 310 Train accuracy: 0.5674816135030526  Train loss: 1.217755844959846
# 18 Test accuracy: 0.4886  Test loss: 1.708057
# 19 310 Train accuracy: 0.570756048989682  Train loss: 1.2091447380390243
# Early stopping, best loss:  0.9113409
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.33154442791755384  Train loss: 1.8517783330037043
# 1 Test accuracy: 0.3497  Test loss: 1.8411758
# 2 310 Train accuracy: 0.3878950528227366  Train loss: 1.6766633620628943
# 2 Test accuracy: 0.483  Test loss: 1.3906204
# 3 310 Train accuracy: 0.4195984911460143  Train loss: 1.5812642941108117
# 3 Test accuracy: 0.5284  Test loss: 1.3071078
# 4 310 Train accuracy: 0.44379845118293393  Train loss: 1.5198547679644365
# 4 Test accuracy: 0.5223  Test loss: 1.3293642
# 5 310 Train accuracy: 0.46273107001414665  Train loss: 1.4737119894761306
# 5 Test accuracy: 0.5812  Test loss: 1.1536884
# 6 310 Train accuracy: 0.4791293994356424  Train loss: 1.4303117425013812
# 6 Test accuracy: 0.5394  Test loss: 1.2625346
# 7 310 Train accuracy: 0.4928869600151921  Train loss: 1.3925571402350625
# 7 Test accuracy: 0.6327  Test loss: 1.0341519
# 8 310 Train accuracy: 0.5058139552577183  Train loss: 1.35589614797097
# 8 Test accuracy: 0.6119  Test loss: 1.1075109
# 9 310 Train accuracy: 0.5184522644322143  Train loss: 1.3233476418715258
# 9 Test accuracy: 0.5405  Test loss: 1.3600086
# 10 310 Train accuracy: 0.5268336329322595  Train loss: 1.2988312987180857
# 10 Test accuracy: 0.6372  Test loss: 1.027707
# 11 310 Train accuracy: 0.5354258156531341  Train loss: 1.2782644658655553
# 11 Test accuracy: 0.643  Test loss: 1.0291919
# 12 310 Train accuracy: 0.5443748767750386  Train loss: 1.2578362986827507
# 12 Test accuracy: 0.6615  Test loss: 0.9537416
# 13 310 Train accuracy: 0.5518095508305985  Train loss: 1.2381379011820053
# 13 Test accuracy: 0.6328  Test loss: 1.0374067
# 14 310 Train accuracy: 0.5591191764880012  Train loss: 1.2172550899641854
# 14 Test accuracy: 0.6963  Test loss: 0.85989493
# 15 310 Train accuracy: 0.5652951712027574  Train loss: 1.199581430814205
# 15 Test accuracy: 0.6325  Test loss: 1.0155413
# 16 310 Train accuracy: 0.5704010149750572  Train loss: 1.1859043541436012
# 16 Test accuracy: 0.6571  Test loss: 0.96954024
# 17 310 Train accuracy: 0.5763092362637973  Train loss: 1.1709938993281368
# 17 Test accuracy: 0.6791  Test loss: 0.91039765
# 18 310 Train accuracy: 0.5807659188524271  Train loss: 1.1583064175569093
# 18 Test accuracy: 0.6799  Test loss: 0.9059817
# 19 310 Train accuracy: 0.5846279391996291  Train loss: 1.1475912882731512
# Early stopping, best loss:  0.85989493
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.3208109713517703  Train loss: 1.8616100549697876
# 1 Test accuracy: 0.3882  Test loss: 1.6491578
# 2 310 Train accuracy: 0.36911150698478407  Train loss: 1.718551048865685
# 2 Test accuracy: 0.4149  Test loss: 1.6048052
# 3 310 Train accuracy: 0.4021069369254968  Train loss: 1.6410447328518598
# 3 Test accuracy: 0.4962  Test loss: 1.3692642
# 4 310 Train accuracy: 0.42725104322800267  Train loss: 1.5836605315025036
# 4 Test accuracy: 0.5206  Test loss: 1.3443524
# 5 310 Train accuracy: 0.43780560676868147  Train loss: 1.5511896041723399
# 5 Test accuracy: 0.521  Test loss: 1.3200026
# 6 310 Train accuracy: 0.4509043953357599  Train loss: 1.5131096518956697
# 6 Test accuracy: 0.5278  Test loss: 1.2932011
# 7 310 Train accuracy: 0.4617088374855754  Train loss: 1.4847131299448537
# 7 Test accuracy: 0.5409  Test loss: 1.2684662
# 8 310 Train accuracy: 0.47160107671068263  Train loss: 1.4578488721297338
# 8 Test accuracy: 0.5487  Test loss: 1.2732228
# 9 310 Train accuracy: 0.47790366742346024  Train loss: 1.443797858352335
# 9 Test accuracy: 0.5199  Test loss: 1.3471369
# 10 310 Train accuracy: 0.48473464800761296  Train loss: 1.4209480469043438
# 10 Test accuracy: 0.4894  Test loss: 1.5239019
# 11 310 Train accuracy: 0.493413565875767  Train loss: 1.3995533156228233
# 11 Test accuracy: 0.4752  Test loss: 1.5292776
# 12 310 Train accuracy: 0.5007453805361038  Train loss: 1.3834255154316242
# 12 Test accuracy: 0.5734  Test loss: 1.2051123
# 13 310 Train accuracy: 0.5059400959127753  Train loss: 1.3701523796341124
# 13 Test accuracy: 0.5946  Test loss: 1.1271162
# 14 310 Train accuracy: 0.5128631072712468  Train loss: 1.3508508372437822
# 14 Test accuracy: 0.6225  Test loss: 1.0495926
# 15 310 Train accuracy: 0.5183462547950256  Train loss: 1.3378046283355125
# 15 Test accuracy: 0.5833  Test loss: 1.1920646
# 16 310 Train accuracy: 0.5225849743359364  Train loss: 1.3274557220821197
# 16 Test accuracy: 0.4525  Test loss: 1.7016387
# 17 310 Train accuracy: 0.5264653276264398  Train loss: 1.3149588086486401
# 17 Test accuracy: 0.6195  Test loss: 1.0667211
# 18 310 Train accuracy: 0.5302789383209668  Train loss: 1.306295805507236
# 18 Test accuracy: 0.6242  Test loss: 1.0563662
# 19 310 Train accuracy: 0.5344129565515017  Train loss: 1.2944354323240428
# Early stopping, best loss:  1.0495926
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.29107693016529085  Train loss: 1.90025963306427
# 1 Test accuracy: 0.3746  Test loss: 1.6414168
# 2 623 Train accuracy: 0.3363077008724213  Train loss: 1.758640673160553
# 2 Test accuracy: 0.3909  Test loss: 1.6174589
# 3 623 Train accuracy: 0.3616410338878632  Train loss: 1.6962528689702352
# 3 Test accuracy: 0.4034  Test loss: 1.6230044
# 4 623 Train accuracy: 0.3780000075697899  Train loss: 1.6649211645126343
# 4 Test accuracy: 0.4597  Test loss: 1.4802691
# 5 623 Train accuracy: 0.38929231524467467  Train loss: 1.6327763185501099
# 5 Test accuracy: 0.487  Test loss: 1.3960536
# 6 623 Train accuracy: 0.39558975100517274  Train loss: 1.6214645449320475
# 6 Test accuracy: 0.4499  Test loss: 1.4464583
# 7 623 Train accuracy: 0.4018461615698678  Train loss: 1.6031403296334403
# 7 Test accuracy: 0.4277  Test loss: 1.5583773
# 8 623 Train accuracy: 0.4073846232891083  Train loss: 1.590100061893463
# 8 Test accuracy: 0.3352  Test loss: 2.049848
# 9 623 Train accuracy: 0.41258120470576815  Train loss: 1.5738551383548314
# 9 Test accuracy: 0.4484  Test loss: 1.4094877
# 10 623 Train accuracy: 0.4178461617231369  Train loss: 1.560160029888153
# Early stopping, best loss:  1.3960536
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.002, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 1248 Train accuracy: 0.373333340883255  Train loss: 1.6958237528800963
# 1 Test accuracy: 0.4593  Test loss: 1.4676225
# 2 1248 Train accuracy: 0.4200000083446503  Train loss: 1.5848886227607728
# 2 Test accuracy: 0.4887  Test loss: 1.4314368
# 3 1248 Train accuracy: 0.4452525333563487  Train loss: 1.5217040344079336
# 3 Test accuracy: 0.4756  Test loss: 1.4826328
# 4 1248 Train accuracy: 0.467121219933033  Train loss: 1.4727544531226158
# 4 Test accuracy: 0.5543  Test loss: 1.2303703
# 5 1248 Train accuracy: 0.48290909838676455  Train loss: 1.4379173393249511
# 5 Test accuracy: 0.5665  Test loss: 1.2023084
# 6 1248 Train accuracy: 0.49181818922360737  Train loss: 1.4113584691286087
# 6 Test accuracy: 0.5819  Test loss: 1.184266
# 7 1248 Train accuracy: 0.5045021717037473  Train loss: 1.3791584668840682
# 7 Test accuracy: 0.5895  Test loss: 1.1664482
# 8 1248 Train accuracy: 0.5125000070780515  Train loss: 1.356588092148304
# 8 Test accuracy: 0.5604  Test loss: 1.2374951
# 9 1248 Train accuracy: 0.5199326667520735  Train loss: 1.336035394668579
# 9 Test accuracy: 0.5736  Test loss: 1.2189221
# 10 1248 Train accuracy: 0.523636370241642  Train loss: 1.3220740574598313
# 10 Test accuracy: 0.6035  Test loss: 1.1412665
# 11 1248 Train accuracy: 0.5281542765010487  Train loss: 1.3096356816725296
# 11 Test accuracy: 0.5907  Test loss: 1.1649885
# 12 1248 Train accuracy: 0.5331818243364493  Train loss: 1.295215714176496
# 12 Test accuracy: 0.6342  Test loss: 1.0207047
# 13 1248 Train accuracy: 0.5384149245115427  Train loss: 1.2821488745395955
# 13 Test accuracy: 0.6402  Test loss: 1.0286028
# 14 1248 Train accuracy: 0.5433333393505642  Train loss: 1.2708544247491018
# 14 Test accuracy: 0.6321  Test loss: 1.0311986
# 15 1248 Train accuracy: 0.548484854221344  Train loss: 1.25919100856781
# 15 Test accuracy: 0.6337  Test loss: 1.0100311
# 16 1248 Train accuracy: 0.5525000058487057  Train loss: 1.2490699665993452
# 16 Test accuracy: 0.6533  Test loss: 0.96275145
# 17 1248 Train accuracy: 0.5560427866262548  Train loss: 1.2397895125781788
# 17 Test accuracy: 0.6603  Test loss: 0.98423594
# 18 1248 Train accuracy: 0.5594612851407793  Train loss: 1.2313850388924281
# 18 Test accuracy: 0.6746  Test loss: 0.9243244
# 19 1248 Train accuracy: 0.5622966564015338  Train loss: 1.2252450674458555
# 19 Test accuracy: 0.6306  Test loss: 1.0280775
# 20 1248 Train accuracy: 0.5647575813233853  Train loss: 1.2190603588223456
# 20 Test accuracy: 0.664  Test loss: 0.9505537
# 21 1248 Train accuracy: 0.5674747528632482  Train loss: 1.2114484487828754
# 21 Test accuracy: 0.6728  Test loss: 0.9320996
# 22 1248 Train accuracy: 0.570000005310232  Train loss: 1.2040035235339945
# 22 Test accuracy: 0.623  Test loss: 1.0902319
# 23 1248 Train accuracy: 0.5725164742314297  Train loss: 1.197696831278179
# 23 Test accuracy: 0.6817  Test loss: 0.89352775
# 24 1248 Train accuracy: 0.5750000051409007  Train loss: 1.1907368159790834
# 24 Test accuracy: 0.6417  Test loss: 0.9966697
# 25 1248 Train accuracy: 0.5773575808763504  Train loss: 1.1855357893943788
# 25 Test accuracy: 0.6855  Test loss: 0.91940117
# 26 1248 Train accuracy: 0.578624713558417  Train loss: 1.1826027340613878
# 26 Test accuracy: 0.6638  Test loss: 0.9350309
# 27 1248 Train accuracy: 0.5805611721012327  Train loss: 1.1780768257158774
# 27 Test accuracy: 0.6867  Test loss: 0.8922582
# 28 1248 Train accuracy: 0.5833333382223334  Train loss: 1.1719567016618593
# 28 Test accuracy: 0.6577  Test loss: 0.9730326
# 29 1248 Train accuracy: 0.5848693884446703  Train loss: 1.1685899443461978
# 29 Test accuracy: 0.6788  Test loss: 0.9190022
# 30 1248 Train accuracy: 0.5860404090086619  Train loss: 1.1645812391837438
# 30 Test accuracy: 0.6757  Test loss: 0.9172628
# 31 1248 Train accuracy: 0.588015645338643  Train loss: 1.1588853661091096
# 31 Test accuracy: 0.6779  Test loss: 0.9280917
# 32 1248 Train accuracy: 0.5892613686434924  Train loss: 1.1557951738871635
# Early stopping, best loss:  0.8922582
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.3261776967690541  Train loss: 1.8781624757326567
# 1 Test accuracy: 0.3142  Test loss: 2.2275422
# 2 310 Train accuracy: 0.39087656426888245  Train loss: 1.6790307530990014
# 2 Test accuracy: 0.4457  Test loss: 1.6699351
# 3 310 Train accuracy: 0.43251838630590683  Train loss: 1.5697963176629481
# 3 Test accuracy: 0.5426  Test loss: 1.3068424
# 4 310 Train accuracy: 0.4598986297272719  Train loss: 1.496690878501305
# 4 Test accuracy: 0.4826  Test loss: 1.5021298
# 5 310 Train accuracy: 0.4815742389513896  Train loss: 1.4391426654962394
# 5 Test accuracy: 0.5244  Test loss: 1.315792
# 6 310 Train accuracy: 0.4981117063225844  Train loss: 1.3964715363123479
# 6 Test accuracy: 0.5843  Test loss: 1.2318488
# 7 310 Train accuracy: 0.508390833224569  Train loss: 1.3698395222097963
# 7 Test accuracy: 0.6189  Test loss: 1.0946928
# 8 310 Train accuracy: 0.5169200947364936  Train loss: 1.3453455550166278
# 8 Test accuracy: 0.5967  Test loss: 1.1346183
# 9 310 Train accuracy: 0.5287881797959662  Train loss: 1.3146119229813926
# 9 Test accuracy: 0.5648  Test loss: 1.2462913
# 10 310 Train accuracy: 0.537984495323438  Train loss: 1.2889260342487923
# 10 Test accuracy: 0.5706  Test loss: 1.293026
# 11 310 Train accuracy: 0.5455629636982938  Train loss: 1.2718601335178723
# 11 Test accuracy: 0.6143  Test loss: 1.1049246
# 12 310 Train accuracy: 0.5517789697608887  Train loss: 1.2548257830815437
# Early stopping, best loss:  1.0946928
# time: 5h 14min 42s
