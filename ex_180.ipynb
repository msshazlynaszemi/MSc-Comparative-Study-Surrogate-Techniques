# %% [markdown]
# # **To use Tensorflow Version 1**

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %% [markdown]
# # **Mount the Google Drive**

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
#define your folder or create one in your google drive
root_path = '/content/drive/My Drive/ex_180/'
os.chdir(root_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Record the time execution per code section**

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=eb22918f834cc3561d975271b75d8acec86a1e51c3a393ba70987c15e732d8e0
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %% [markdown]
# #**Ngrok : Running tensorboard inside Google Colab**

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip

# %%
import os
LOG_DIR = '/content/drive/My Drive/ex_20/log'
#LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)
get_ipython().system_raw(
    'tensorboard --logdir {} --host 0.0.0.0 --port 6006 &'
    .format(LOG_DIR))

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
get_ipython().system_raw('./ngrok http 6006 &')

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %% [markdown]
# # **Data Preparation**

# %%
# Downloading cifar-10-python files
# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -xvzf cifar-10-python.tar.gz
# Out:
# --2020-04-23 13:58:37--  https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 170498071 (163M) [application/x-gzip]
# Saving to: ‘cifar-10-python.tar.gz’
#
# cifar-10-python.tar 100%[===================>] 162.60M  43.1MB/s    in 4.2s
#
# 2020-04-23 13:58:41 (38.8 MB/s) - ‘cifar-10-python.tar.gz’ saved [170498071/170498071]
#
# cifar-10-batches-py/
# cifar-10-batches-py/data_batch_4
# cifar-10-batches-py/readme.html
# cifar-10-batches-py/test_batch
# cifar-10-batches-py/data_batch_3
# cifar-10-batches-py/batches.meta
# cifar-10-batches-py/data_batch_2
# cifar-10-batches-py/data_batch_5
# cifar-10-batches-py/data_batch_1
# time: 10.7 s

# %%
# Provided on https://www.cs.toronto.edu/~kriz/cifar.html 
# Given a "pickled" file, returns a dictionary containing the image data
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
# Out:
# time: 2.94 ms

# %% [markdown]
# The training data is stored in four files, which are read and merged.

# %%
import numpy as np

for file_no in range(4):
    # Obtain data dictionary from each file
    filename = "cifar-10-batches-py/data_batch_" + str(file_no + 1)
    image_batch = unpickle(filename)
    # First file, create numpy arrays containing data & labels
    if file_no == 0:
        # Reshape to 32x32 image with 3 channels (RGB), which is made to be the last axes
        image_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_labels = image_batch[b'labels']
    else: # Concatenate to one file
        new_data = image_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
        image_data = np.concatenate([image_data, new_data])
        image_labels = np.concatenate([image_labels, image_batch[b'labels']])

print("Training data shape: ",image_data.shape)

# Create numpy array containing test data
test_batch = unpickle("cifar-10-batches-py/test_batch")
test_data = test_batch[b'data'].reshape((-1,3,32,32)).transpose((0,2,3,1))
test_labels = test_batch[b'labels']

# Obtain label names from the meta data
label_names = unpickle("cifar-10-batches-py/batches.meta")[b'label_names']
label_names = [l.decode('UTF-8') for l in label_names]
# Out:
# Training data shape:  (40000, 32, 32, 3)
# time: 474 ms

# %% [markdown]
# ### **Image samples**

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(10,9,figsize=(7,9))
plt.subplots_adjust(wspace=0.01, hspace=0.01)

for image_type in range(10):
    # Obtain indices of images in each group
    group = np.argwhere(image_labels == image_type)
    # Display 1st 5 images from each group
    for col in range(8):
        n = group[col][0]
        img_rgb = image_data[n]
        axes[image_type,col].imshow(img_rgb)
        axes[image_type,col].axis('off')
    # Display image labels    
    axes[image_type,8].axis('off')    
    axes[image_type,8].text(0.1,0.5,label_names[image_type], fontsize=12)

plt.show()
# Out:
# time: 2.8 s

# %% [markdown]
# ## Model Building
# ### Hyperparameters

# %%
import tensorflow as tf
# Fixed hyperparameters
height = 32
width = 32
channels = 3
outputs = 10

n_epochs = 500
# number of epochs to try to get a lower loss before stopping
early_stop_rounds = 4

# number of iterations, within epoch, to do an accuracy check
acc_check = 25

# Variable Hyperparameters
hyperparam_range = {'filter1':[16, 32, 64, 96],
                    'kernelsize_1':[3, 4, 5],
                    'filter2':[48, 64, 96, 128],
                    'kernelsize_2':[3, 4, 5],
                    'filter3':[64, 96, 128],
                    'kernelsize_3':[3, 4, 5],
                    'hidden_1':[60, 100, 125],
                    'hidden_2':[80, 100, 125],
                    'activation':['relu', 'lrelu', 'elu'],
                    'learning_rate':[0.001, 0.0015, 0.002, 0.003],
                    'batch_size':[32, 64, 128],
                    'momentum':[0.9, 0.95, 0.99],
                    'p_reduct':[0],
                    'optimizer':['adam', 'rmsprop', 'nesterov']
                   }

# Calculate the number of hyperparamter grid points
first_item = True
for key,values in hyperparam_range.items():
    count = len(values)
    if first_item:
        display = str(count)
        total = count
        first_item = False
    else:
        display = display + ' X ' + str(count)
        total *= count

print('The total number of possible hyperparameter combinations is ' + display + ' = ' + "{:,}".format(total))
# Out:
# The total number of possible hyperparameter combinations is 4 X 3 X 4 X 3 X 3 X 3 X 3 X 3 X 3 X 4 X 3 X 3 X 1 X 3 = 3,779,136
# time: 27.8 ms

# %% [markdown]
# ### Convolutional Layer

# %%
def conv_layer(tensor_input, layer_no, filters, ksize, kstride, activation_unit, momentum, phase_train):
    # convolutional layer with batch normalisation and max pooling
    with tf.name_scope("conv_layer" + str(layer_no)):
        conv = tf.layers.conv2d(
            tensor_input,
            filters=filters,
            kernel_size=ksize,
            strides=[kstride,kstride],
            padding="SAME",
            activation=None
        )

        conv_bn = tf.layers.batch_normalization(
            inputs=conv,
            axis=-1,
            momentum=0.9,
            epsilon=0.001,
            center=True,
            scale=True,
            trainable=True,
            training = phase_train
        )

        #apply activation unit
        conv_bn_relu =  activation_unit(conv_bn)

        max_pool = tf.nn.max_pool(
            conv_bn_relu,
            ksize=[1,2,2,1],
            strides=[1,2,2,1],
            padding="VALID"
        )
            
        dropout = tf.layers.dropout(
            max_pool,
            training = phase_train
        )
            
        return dropout
# Out:
# time: 11.4 ms

# %% [markdown]
# ### Graph defintion

# %%
def build_graph(hyperparam):
    # Retrieve hyperparamaters from dictionary   
    filter1 = hyperparam['filter1']
    kernelsize_1 = hyperparam['kernelsize_1']
    filter2 = hyperparam['filter2']
    kernelsize_2 = hyperparam['kernelsize_2']
    filter3 = hyperparam['filter3']
    kernelsize_3 = hyperparam['kernelsize_3']
    hidden_1 = hyperparam['hidden_1']
    hidden_2 = hyperparam['hidden_2']
    activation = hyperparam['activation']
    learning_rate = hyperparam['learning_rate']
    momentum = hyperparam['momentum']
    p_reduct =  hyperparam['p_reduct']
    optimizer_method = hyperparam['optimizer']
    
    patch_height = height - 2 * p_reduct
    patch_width = width - 2 * p_reduct
    
    if activation == 'elu':
        activation_unit = tf.nn.elu
    elif activation == 'lrelu':
        activation_unit = tf.nn.leaky_relu
    else:    
        activation_unit = tf.nn.relu
        
    graph = tf.Graph()
    with graph.as_default():
        X = tf.placeholder(shape=(None, patch_height, patch_width, channels), dtype=tf.float32)
        y = tf.placeholder(shape=(None), dtype=tf.int32)
        phase_train = tf.placeholder(tf.bool, name='phase_train')

        # 1st convolutional layer
        conv1 = conv_layer(X, 1, filter1, kernelsize_1, 2, activation_unit, momentum, phase_train)
        
        # 2nd convolutional layer
        conv2 = conv_layer(conv1, 2, filter2, kernelsize_2, 1, activation_unit, momentum, phase_train)
        
        # 3rd cnn
        conv3 = conv_layer(conv2, 3, filter3, kernelsize_3, 1, activation_unit, momentum, phase_train)
        
        # 1st fully connected (dense) layer
        fully_conn1 = tf.layers.dense(conv3, hidden_1, name="fully_conn1", activation=activation_unit)
        flat = tf.contrib.layers.flatten(fully_conn1)
        
        # 2nd fully connected layer
        fully_conn2 = tf.layers.dense(flat, hidden_2, name="fully_conn2", activation=activation_unit)
        
        # Output layer (no activation function, as this is built into cross-entropy)
        logits = tf.layers.dense(fully_conn2, outputs, name="logits")

        # Cross Entropy Loss
        with tf.name_scope("loss"):
            xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
            loss = tf.reduce_mean(xentropy, name="loss")

        # Training    
        with tf.name_scope("train"):
            if optimizer_method == 'rmsprop':
                    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate, momentum=0.9)
            elif optimizer_method == 'nesterov':
                    optimizer = tf.train.MomentumOptimizer(learning_rate=learning_rate, momentum=0.9, use_nesterov = True)
            else:    
                optimizer = tf.train.AdamOptimizer(learning_rate)
            training_op = optimizer.minimize(loss)
    
        # Initialization & Saver
        init = tf.global_variables_initializer()
        saver = tf.train.Saver() 
        
        return graph, X, y, phase_train, logits, loss, training_op, init, saver
# Out:
# time: 71.7 ms

# %% [markdown]
# ### Model Training

# %%
# Function to train model, returns minimised loss
def train_model(batch_size = 128):
    training_size = image_data.shape[0]
    no_batches = training_size // batch_size
    
    with graph.as_default():
        # Ensure batch normalisation gets updated
        extra_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)    
        # Add Evaluation metrics
        with tf.name_scope("evaluation"):
            correct = tf.nn.in_top_k(logits, y, 1)
            accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
            acc_summary = tf.summary.scalar('Accuracy', accuracy)
            loss_summary = tf.summary.scalar('Loss', loss)
            
    # Initialise best loss for early stopping
    best_loss = 1e9
    best_acc = 1e9
    early_stopping = False
    
    # Run training
    with tf.Session(graph=graph) as sess:                     
        init.run()
        epoch = 0
        early_stop_count = 0
        # Initialise training accuracy sum
        sum_acc_train = 0.0
        sum_loss_train = 0.0
        count_train = 0
        while (epoch < n_epochs) and (not early_stopping):
            epoch += 1
            # Shuffle training data
            p = np.random.permutation(training_size)
            image_data_shuffle = image_data_patch[p]
            image_labels_shuffle = image_labels[p]
            for iteration in range(no_batches-1):
                # Train on mini-batch
                X_batch = image_data_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                y_batch = image_labels_shuffle[iteration * batch_size:(iteration + 1) * batch_size + 1]
                sess.run([training_op, extra_update_ops], feed_dict={X: X_batch, y: y_batch, phase_train: True})
                # Evaluate model on current mini-batch
                if (iteration % acc_check == 0):
                    acc_train, loss_train = sess.run([accuracy, loss], feed_dict={X: X_batch,
                                                                                   y: y_batch,
                                                                                   phase_train: True})
                    # Update training average for current epoch
                    sum_acc_train += acc_train
                    sum_loss_train += loss_train
                    count_train += 1
                    mean_acc_train = sum_acc_train / count_train
                    mean_loss_train = sum_loss_train / count_train
                    print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train, end='\r')
                     
            # Print mean Train accuracy        
            print(epoch, iteration, "Train accuracy:", mean_acc_train, " Train loss:", mean_loss_train)
            train_summary = tf.Summary()
            train_summary.value.add(tag='eval/Accuracy', simple_value=mean_acc_train)
            train_summary.value.add(tag='eval/Loss', simple_value=mean_loss_train)
            file_writer_train.add_summary(train_summary, epoch)
            
            # Evaluate model on test data every epoch
            acc_test, loss_test, summary_str_acc_test, summary_str_loss_test = sess.run([accuracy, loss,
                                                                                         acc_summary,
                                                                                         loss_summary],
                                                                                        feed_dict={X: test_data_patch,
                                                                                                   y: test_labels,
                                                                                                   phase_train: False})
            # Check for mininimum loss
            if loss_test < best_loss:
                # Reset early stopping best loss and count
                best_loss = loss_test
                best_acc = acc_test
                best_train_acc = mean_acc_train
                best_train_loss = mean_loss_train
                early_stop_count = 0
                # Save model
                save_path = saver.save(sess, ckptfile)
            else:
                # Increment early stopping count
                early_stop_count += 1
            # Check if sufficient rounds (epochs) have passed without improvement
            if early_stop_count  > early_stop_rounds:
                # Flag early stopping, so training loop will stop
                early_stopping = True
                print("Early stopping, best loss: ", best_loss)
            else:    
                # Record and display test loss and accuracy
                file_writer_test.add_summary(summary_str_acc_test, epoch)
                file_writer_test.add_summary(summary_str_loss_test, epoch)
                print(epoch, "Test accuracy:", acc_test, " Test loss:", loss_test)
            
        # Return Best Loss obtaned and number of epochs
        return best_loss, best_acc, best_train_acc, best_train_loss, epoch
# Out:
# time: 87.9 ms

# %% [markdown]
# ### Random Hyperparameter Selection and Evaluation

# %%
import pandas as pd

import random
random.seed(261001)

import os.path
if not os.path.exists('./log'):
    os.makedirs('./log')
if not os.path.exists('./graphs'):
    os.makedirs('./graphs')
    
if(os.path.isfile('./log/model_hyperparam.csv')):
    hyperparam_df = pd.read_csv('./log/model_hyperparam.csv')
    new_results_file = False
else:
    new_results_file = True

# Random Model search
for n in range(180):
    # Create log directory using current timestamp
    from datetime import datetime
    now = datetime.now().strftime("%Y%m%dT%H%M%S")
    root_logdir = "./log"
    root_graphdir = "./graphs"
    logdir = "{}/run-{}/".format(root_logdir, now)
    graphdir = "{}/run-{}/".format(root_graphdir, now)
    #root_modeldir = "./model"
    graphfile = graphdir
    ckptfile = graphdir + "checkpoint.ckpt"

    # Note that the graph is not written using same filewriter as the logging data.
    # This allows the logs to be viewed during training before the filewriter is closed
    file_writer_train = tf.summary.FileWriter(logdir + '/train')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    file_writer_test = tf.summary.FileWriter(logdir + '/test')
    
    # tensorboard --logdir e:\Programming\TensorFlow\CIFAR-10\log
    # The command must be executed from same drive (E:) as the logdir

    tf.reset_default_graph()

    hyperparam_dict = {key:random.choice(values) for (key,values) in hyperparam_range.items()}
    print("Training Model with following hyperparameters:")
    print(hyperparam_dict)

    # Obtain graph and nodes required for training
    graph, X, y, phase_train, logits, loss, training_op, init, saver = build_graph(hyperparam = hyperparam_dict)
    
    # Write graph to file and close to avoid TensorBoard conflict
    file_writer_graph = tf.summary.FileWriter(graphfile, graph)
    file_writer_graph.close()

    # Extract image patches
    p_reduct =  hyperparam_dict['p_reduct']
    if p_reduct == 0:
        image_data_patch = image_data
        test_data_patch = test_data
    else:
        image_data_patch = image_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
        test_data_patch = test_data[:,p_reduct:-p_reduct,p_reduct:-p_reduct,:]
    
    # Train the model
    best_loss, best_acc, best_train_acc, best_train_loss, no_epochs = train_model(batch_size = hyperparam_dict['batch_size'])
    
    # Add results to dictionary
    hyperparam_dict['best_loss'] = best_loss
    hyperparam_dict['best_acc'] = best_acc
    hyperparam_dict['best_train_acc'] = best_train_acc
    hyperparam_dict['best_train_loss'] = best_train_loss
    hyperparam_dict['no_epochs'] = no_epochs
    hyperparam_dict['logdir'] = logdir
    
    # Add results to dataframe
    if new_results_file:
        hyperparam_df = pd.DataFrame(hyperparam_dict, index=[0])
        new_results_file = False
    else:
        hyperparam_df = hyperparam_df.append(hyperparam_dict, ignore_index=True)
        
    # Write results file (don't wait until end, as next model may be interrupted)
    hyperparam_df.to_csv('./log/modelhyperparameter_180.csv', index=False)

    # Close filewriters
    file_writer_train.close()
    file_writer_test.close()
    
    # NOTE - From this point onwards there are only training logs.
    # Results and Conclusion are in a seperate notebook
# Out:
# Streaming output truncated to the last 5000 lines.
# 11 310 Train accuracy: 0.3993061210413079  Train loss: 1.6324071867482646
# 11 Test accuracy: 0.4946  Test loss: 1.3792346
# 12 310 Train accuracy: 0.4039455387168206  Train loss: 1.6175723442664514
# 12 Test accuracy: 0.4786  Test loss: 1.4802395
# 13 310 Train accuracy: 0.40924728344354405  Train loss: 1.6045323046001456
# 13 Test accuracy: 0.4414  Test loss: 1.5877204
# 14 310 Train accuracy: 0.41413238059197155  Train loss: 1.5917715692258143
# 14 Test accuracy: 0.4999  Test loss: 1.3930091
# 15 310 Train accuracy: 0.4196779980491369  Train loss: 1.5797899087270102
# 15 Test accuracy: 0.4938  Test loss: 1.4037793
# 16 310 Train accuracy: 0.42531306085248405  Train loss: 1.5657559925547013
# Early stopping, best loss:  1.3792346
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'relu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 1248 Train accuracy: 0.22606061279773712  Train loss: 2.0134078454971314
# 1 Test accuracy: 0.2774  Test loss: 1.9354254
# 2 1248 Train accuracy: 0.27393940210342405  Train loss: 1.8903003191947938
# 2 Test accuracy: 0.3767  Test loss: 1.7020996
# 3 1248 Train accuracy: 0.3026262710491816  Train loss: 1.8195974739392597
# 3 Test accuracy: 0.4226  Test loss: 1.5906771
# 4 1248 Train accuracy: 0.32757576629519464  Train loss: 1.769900642633438
# 4 Test accuracy: 0.3784  Test loss: 1.7522722
# 5 1248 Train accuracy: 0.34666667544841767  Train loss: 1.7329932384490967
# 5 Test accuracy: 0.4305  Test loss: 1.5482329
# 6 1248 Train accuracy: 0.3601010192433993  Train loss: 1.698631360133489
# 6 Test accuracy: 0.4453  Test loss: 1.5353669
# 7 1248 Train accuracy: 0.3745454630681447  Train loss: 1.6691951663153513
# 7 Test accuracy: 0.4868  Test loss: 1.4148568
# 8 1248 Train accuracy: 0.38242425069212915  Train loss: 1.646757365167141
# 8 Test accuracy: 0.4686  Test loss: 1.4376945
# 9 1248 Train accuracy: 0.39111111952198874  Train loss: 1.6232107384999592
# 9 Test accuracy: 0.4703  Test loss: 1.4163513
# 10 1248 Train accuracy: 0.39606061452627184  Train loss: 1.606090919494629
# 10 Test accuracy: 0.4859  Test loss: 1.421992
# 11 1248 Train accuracy: 0.4037465648759495  Train loss: 1.5895336866378784
# 11 Test accuracy: 0.4716  Test loss: 1.4694517
# 12 1248 Train accuracy: 0.40848485683401425  Train loss: 1.579447410106659
# Early stopping, best loss:  1.4148568
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.3600000089406967  Train loss: 1.775299129486084
# 1 Test accuracy: 0.4056  Test loss: 1.5905952
# 2 1248 Train accuracy: 0.38727273643016813  Train loss: 1.6974584686756133
# 2 Test accuracy: 0.3963  Test loss: 1.7070258
# 3 1248 Train accuracy: 0.4064646553993225  Train loss: 1.6359657541910808
# 3 Test accuracy: 0.4905  Test loss: 1.3833729
# 4 1248 Train accuracy: 0.41545455396175385  Train loss: 1.6061896914243698
# 4 Test accuracy: 0.4432  Test loss: 1.5500684
# 5 1248 Train accuracy: 0.42230303871631625  Train loss: 1.5848859214782716
# 5 Test accuracy: 0.4641  Test loss: 1.4999249
# 6 1248 Train accuracy: 0.42646465480327606  Train loss: 1.5671396028995515
# 6 Test accuracy: 0.4299  Test loss: 1.6914803
# 7 1248 Train accuracy: 0.43593074440956114  Train loss: 1.5431732528550284
# 7 Test accuracy: 0.5297  Test loss: 1.3138542
# 8 1248 Train accuracy: 0.44136364474892614  Train loss: 1.5319487142562866
# 8 Test accuracy: 0.4683  Test loss: 1.4938625
# 9 1248 Train accuracy: 0.4459932740529378  Train loss: 1.5219197512997522
# 9 Test accuracy: 0.5302  Test loss: 1.3020629
# 10 1248 Train accuracy: 0.4506666747331619  Train loss: 1.5096624909639358
# 10 Test accuracy: 0.4691  Test loss: 1.514641
# 11 1248 Train accuracy: 0.45421488404273985  Train loss: 1.5021256450089542
# 11 Test accuracy: 0.5117  Test loss: 1.3772545
# 12 1248 Train accuracy: 0.4573737452427546  Train loss: 1.4919553686181704
# 12 Test accuracy: 0.4936  Test loss: 1.3280368
# 13 1248 Train accuracy: 0.46167832929354446  Train loss: 1.4853489016569579
# 13 Test accuracy: 0.5462  Test loss: 1.2664652
# 14 1248 Train accuracy: 0.4636796610695975  Train loss: 1.4811644096885408
# 14 Test accuracy: 0.5879  Test loss: 1.1733674
# 15 1248 Train accuracy: 0.46618182547887166  Train loss: 1.476572997967402
# 15 Test accuracy: 0.5604  Test loss: 1.2570021
# 16 1248 Train accuracy: 0.4687878858670592  Train loss: 1.4704833578318357
# 16 Test accuracy: 0.5678  Test loss: 1.2320542
# 17 1248 Train accuracy: 0.4705525917516035  Train loss: 1.4655697196371416
# 17 Test accuracy: 0.5455  Test loss: 1.2213701
# 18 1248 Train accuracy: 0.4731313202778498  Train loss: 1.458636788725853
# 18 Test accuracy: 0.5421  Test loss: 1.2731432
# 19 1248 Train accuracy: 0.47422648247919585  Train loss: 1.455308148735448
# Early stopping, best loss:  1.1733674
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 32, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.34787879765033725  Train loss: 1.8290903067588806
# 1 Test accuracy: 0.2586  Test loss: 2.3064008
# 2 1248 Train accuracy: 0.3936363738775253  Train loss: 1.7100084018707276
# 2 Test accuracy: 0.3354  Test loss: 2.131927
# 3 1248 Train accuracy: 0.4210101115703583  Train loss: 1.6272983304659525
# 3 Test accuracy: 0.5402  Test loss: 1.3056581
# 4 1248 Train accuracy: 0.4313636460900307  Train loss: 1.5984246480464934
# 4 Test accuracy: 0.353  Test loss: 2.2957587
# 5 1248 Train accuracy: 0.4467878878116608  Train loss: 1.5714080443382263
# 5 Test accuracy: 0.5262  Test loss: 1.3384765
# 6 1248 Train accuracy: 0.45949495792388917  Train loss: 1.5426468694210052
# 6 Test accuracy: 0.5439  Test loss: 1.3739511
# 7 1248 Train accuracy: 0.46891775710242134  Train loss: 1.5175606395517076
# 7 Test accuracy: 0.6053  Test loss: 1.1677054
# 8 1248 Train accuracy: 0.47931818917393687  Train loss: 1.4908007107675076
# 8 Test accuracy: 0.5273  Test loss: 1.3582504
# 9 1248 Train accuracy: 0.48686869429217444  Train loss: 1.4756656817595164
# 9 Test accuracy: 0.6055  Test loss: 1.1335181
# 10 1248 Train accuracy: 0.49406061339378354  Train loss: 1.4600784205198287
# 10 Test accuracy: 0.5915  Test loss: 1.1836476
# 11 1248 Train accuracy: 0.5004958749359304  Train loss: 1.4447895041379062
# 11 Test accuracy: 0.5415  Test loss: 1.2957354
# 12 1248 Train accuracy: 0.5040404111146927  Train loss: 1.436149672071139
# 12 Test accuracy: 0.5915  Test loss: 1.207332
# 13 1248 Train accuracy: 0.5092773960645383  Train loss: 1.4256422395889576
# 13 Test accuracy: 0.4659  Test loss: 1.7635043
# 14 1248 Train accuracy: 0.5141991407530648  Train loss: 1.4141536725418908
# Early stopping, best loss:  1.1335181
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 32, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 1248 Train accuracy: 0.3309090983867645  Train loss: 1.8250403094291687
# 1 Test accuracy: 0.3978  Test loss: 1.6202487
# 2 1248 Train accuracy: 0.3681818273663521  Train loss: 1.7102383410930633
# 2 Test accuracy: 0.4351  Test loss: 1.509084
# 3 1248 Train accuracy: 0.39191920061906177  Train loss: 1.6592827439308167
# 3 Test accuracy: 0.5295  Test loss: 1.285156
# 4 1248 Train accuracy: 0.4095454628765583  Train loss: 1.6162194555997849
# 4 Test accuracy: 0.4482  Test loss: 1.5117193
# 5 1248 Train accuracy: 0.42666667461395263  Train loss: 1.572076722383499
# 5 Test accuracy: 0.5095  Test loss: 1.3115168
# 6 1248 Train accuracy: 0.4390909168124199  Train loss: 1.5471470441420874
# 6 Test accuracy: 0.5441  Test loss: 1.302907
# 7 1248 Train accuracy: 0.45030303827353885  Train loss: 1.521858139889581
# 7 Test accuracy: 0.5178  Test loss: 1.4038223
# 8 1248 Train accuracy: 0.46250000715255735  Train loss: 1.4985526384413241
# 8 Test accuracy: 0.5918  Test loss: 1.1833858
# 9 1248 Train accuracy: 0.4693602766593297  Train loss: 1.4772572416729397
# 9 Test accuracy: 0.4825  Test loss: 1.5693662
# 10 1248 Train accuracy: 0.4773333404660225  Train loss: 1.4550989578962326
# 10 Test accuracy: 0.4955  Test loss: 1.405954
# 11 1248 Train accuracy: 0.4847382990880446  Train loss: 1.43791951992295
# 11 Test accuracy: 0.5629  Test loss: 1.2063631
# 12 1248 Train accuracy: 0.4896464718878269  Train loss: 1.4251534699400266
# 12 Test accuracy: 0.5351  Test loss: 1.2556487
# 13 1248 Train accuracy: 0.4965501235081599  Train loss: 1.4091857483753791
# Early stopping, best loss:  1.1833858
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.2787692385911942  Train loss: 1.957512617111206
# 1 Test accuracy: 0.289  Test loss: 1.8805397
# 2 623 Train accuracy: 0.3196923154592514  Train loss: 1.8269658827781676
# 2 Test accuracy: 0.3492  Test loss: 1.7202127
# 3 623 Train accuracy: 0.3452307766675949  Train loss: 1.761650325457255
# 3 Test accuracy: 0.3995  Test loss: 1.6305162
# 4 623 Train accuracy: 0.36323077633976936  Train loss: 1.7119749855995179
# 4 Test accuracy: 0.3932  Test loss: 1.6912347
# 5 623 Train accuracy: 0.37858462274074556  Train loss: 1.6718500003814698
# 5 Test accuracy: 0.4778  Test loss: 1.4307902
# 6 623 Train accuracy: 0.3918974436322848  Train loss: 1.641387596130371
# 6 Test accuracy: 0.4333  Test loss: 1.6434308
# 7 623 Train accuracy: 0.4028131947347096  Train loss: 1.6152350350788662
# 7 Test accuracy: 0.5075  Test loss: 1.3713658
# 8 623 Train accuracy: 0.4136153931170702  Train loss: 1.5880644541978837
# 8 Test accuracy: 0.4807  Test loss: 1.4049867
# 9 623 Train accuracy: 0.42099146174059976  Train loss: 1.5673585960600112
# 9 Test accuracy: 0.4189  Test loss: 1.6608229
# 10 623 Train accuracy: 0.428430778324604  Train loss: 1.5477692799568177
# 10 Test accuracy: 0.5367  Test loss: 1.2816732
# 11 623 Train accuracy: 0.435020988908681  Train loss: 1.5293473997983065
# 11 Test accuracy: 0.5358  Test loss: 1.297992
# 12 623 Train accuracy: 0.43943590755263967  Train loss: 1.5173921966552735
# 12 Test accuracy: 0.5256  Test loss: 1.3253092
# 13 623 Train accuracy: 0.4458224959098376  Train loss: 1.504803241949815
# 13 Test accuracy: 0.5367  Test loss: 1.316412
# 14 623 Train accuracy: 0.4503736373782158  Train loss: 1.4940043125833784
# 14 Test accuracy: 0.5121  Test loss: 1.3587731
# 15 623 Train accuracy: 0.45710770404338835  Train loss: 1.4776614011128744
# Early stopping, best loss:  1.2816732
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.21288014489870805  Train loss: 2.148111049945538
# 1 Test accuracy: 0.2678  Test loss: 1.9508665
# 2 310 Train accuracy: 0.25819916736621124  Train loss: 2.0014824179502635
# 2 Test accuracy: 0.3174  Test loss: 1.7719448
# 3 310 Train accuracy: 0.2888093854372318  Train loss: 1.9136555408820128
# 3 Test accuracy: 0.3685  Test loss: 1.6796273
# 4 310 Train accuracy: 0.30396541809806454  Train loss: 1.8626579779845018
# 4 Test accuracy: 0.3798  Test loss: 1.6971766
# 5 310 Train accuracy: 0.3200954109430313  Train loss: 1.8171462957675641
# 5 Test accuracy: 0.4104  Test loss: 1.5903348
# 6 310 Train accuracy: 0.3345259414651455  Train loss: 1.782266685595879
# 6 Test accuracy: 0.3896  Test loss: 1.653305
# 7 310 Train accuracy: 0.34687793041978565  Train loss: 1.7573789069940755
# 7 Test accuracy: 0.3569  Test loss: 1.8638598
# 8 310 Train accuracy: 0.35606738394842696  Train loss: 1.7347675160719798
# 8 Test accuracy: 0.3782  Test loss: 1.6849222
# 9 310 Train accuracy: 0.36705757804915434  Train loss: 1.7096071630461602
# 9 Test accuracy: 0.4614  Test loss: 1.469032
# 10 310 Train accuracy: 0.3735241515132097  Train loss: 1.693548020032736
# 10 Test accuracy: 0.4586  Test loss: 1.5047383
# 11 310 Train accuracy: 0.37941128734525265  Train loss: 1.6781073591925881
# 11 Test accuracy: 0.4635  Test loss: 1.4834924
# 12 310 Train accuracy: 0.38640429452061653  Train loss: 1.659129431614509
# 12 Test accuracy: 0.4546  Test loss: 1.5014454
# 13 310 Train accuracy: 0.39278014868321504  Train loss: 1.6441516382454415
# 13 Test accuracy: 0.3697  Test loss: 1.743892
# 14 310 Train accuracy: 0.39879887665693575  Train loss: 1.6293053338815877
# Early stopping, best loss:  1.469032
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 3, 'filter2': 96, 'kernelsize_2': 4, 'filter3': 96, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.3446630881382869  Train loss: 1.8111722285930927
# 1 Test accuracy: 0.4238  Test loss: 1.5630125
# 2 310 Train accuracy: 0.41204532178548664  Train loss: 1.615673078940465
# 2 Test accuracy: 0.3985  Test loss: 1.7603894
# 3 310 Train accuracy: 0.4420592356950809  Train loss: 1.5216535452084663
# 3 Test accuracy: 0.4439  Test loss: 1.5333395
# 4 310 Train accuracy: 0.46645796298980713  Train loss: 1.4562810086286986
# 4 Test accuracy: 0.5353  Test loss: 1.3078672
# 5 310 Train accuracy: 0.4850327968597412  Train loss: 1.4111991185408372
# 5 Test accuracy: 0.6172  Test loss: 1.0675652
# 6 310 Train accuracy: 0.5003975358528968  Train loss: 1.3683311969805987
# 6 Test accuracy: 0.6029  Test loss: 1.0868137
# 7 310 Train accuracy: 0.5130760705733037  Train loss: 1.335627053465162
# 7 Test accuracy: 0.6324  Test loss: 1.0183808
# 8 310 Train accuracy: 0.5241502675299461  Train loss: 1.3029605774925306
# 8 Test accuracy: 0.5591  Test loss: 1.3485953
# 9 310 Train accuracy: 0.5339561382420043  Train loss: 1.2778551074174733
# 9 Test accuracy: 0.5912  Test loss: 1.1954545
# 10 310 Train accuracy: 0.5465712586274514  Train loss: 1.2478517591953278
# 10 Test accuracy: 0.6296  Test loss: 1.0414081
# 11 310 Train accuracy: 0.5548869744464234  Train loss: 1.226684517793722
# 11 Test accuracy: 0.6548  Test loss: 0.9617389
# 12 310 Train accuracy: 0.5639534892562108  Train loss: 1.206404386422573
# 12 Test accuracy: 0.6853  Test loss: 0.88399553
# 13 310 Train accuracy: 0.5696986389936075  Train loss: 1.189229937700125
# 13 Test accuracy: 0.6164  Test loss: 1.0797887
# 14 310 Train accuracy: 0.5756026927258943  Train loss: 1.1730044412088918
# 14 Test accuracy: 0.6984  Test loss: 0.8519085
# 15 310 Train accuracy: 0.5808785540935321  Train loss: 1.161196297254318
# 15 Test accuracy: 0.7046  Test loss: 0.8493346
# 16 310 Train accuracy: 0.5878056059949673  Train loss: 1.1439804658293724
# 16 Test accuracy: 0.6832  Test loss: 0.9103244
# 17 310 Train accuracy: 0.5928303352578194  Train loss: 1.1299938888571381
# 17 Test accuracy: 0.6491  Test loss: 1.0410221
# 18 310 Train accuracy: 0.5975617846617332  Train loss: 1.117462135023541
# 18 Test accuracy: 0.7179  Test loss: 0.80588984
# 19 310 Train accuracy: 0.6019834927943072  Train loss: 1.1060174206490458
# 19 Test accuracy: 0.7195  Test loss: 0.81237096
# 20 310 Train accuracy: 0.6061419210754908  Train loss: 1.094504012969824
# 20 Test accuracy: 0.6975  Test loss: 0.85519725
# 21 310 Train accuracy: 0.6101030763033982  Train loss: 1.083832500181792
# 21 Test accuracy: 0.7244  Test loss: 0.7961872
# 22 310 Train accuracy: 0.6129180904660192  Train loss: 1.0740380608118498
# 22 Test accuracy: 0.7249  Test loss: 0.7697339
# 23 310 Train accuracy: 0.6166290745487979  Train loss: 1.0644924820067492
# 23 Test accuracy: 0.7137  Test loss: 0.8053659
# 24 310 Train accuracy: 0.6199314257082267  Train loss: 1.0554408178879664
# 24 Test accuracy: 0.7108  Test loss: 0.8121664
# 25 310 Train accuracy: 0.6225163990717668  Train loss: 1.0472228185947126
# 25 Test accuracy: 0.7332  Test loss: 0.7860318
# 26 310 Train accuracy: 0.6256364392634679  Train loss: 1.0391527215051932
# 26 Test accuracy: 0.6629  Test loss: 1.0058506
# 27 310 Train accuracy: 0.628149915539641  Train loss: 1.032709653560932
# Early stopping, best loss:  0.7697339
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.344615394026041  Train loss: 1.8194108295440674
# 1 Test accuracy: 0.2751  Test loss: 2.2807567
# 2 623 Train accuracy: 0.3800000087171793  Train loss: 1.6960406351089476
# 2 Test accuracy: 0.358  Test loss: 1.7990242
# 3 623 Train accuracy: 0.40861539348959924  Train loss: 1.6139318704605103
# 3 Test accuracy: 0.4268  Test loss: 1.5516516
# 4 623 Train accuracy: 0.42784616369754075  Train loss: 1.578162717819214
# 4 Test accuracy: 0.4878  Test loss: 1.4094253
# 5 623 Train accuracy: 0.4388923183977604  Train loss: 1.5467650594711304
# 5 Test accuracy: 0.4404  Test loss: 1.4621341
# 6 623 Train accuracy: 0.44748719048996766  Train loss: 1.5207562255859375
# 6 Test accuracy: 0.4437  Test loss: 1.8122711
# 7 623 Train accuracy: 0.4551208904172693  Train loss: 1.5034512615203857
# 7 Test accuracy: 0.5222  Test loss: 1.2978323
# 8 623 Train accuracy: 0.4604615502990782  Train loss: 1.4905871045589447
# 8 Test accuracy: 0.566  Test loss: 1.2183865
# 9 623 Train accuracy: 0.46584616616368296  Train loss: 1.473227625687917
# 9 Test accuracy: 0.4929  Test loss: 1.3990352
# 10 623 Train accuracy: 0.47310770554840564  Train loss: 1.4563755009174346
# 10 Test accuracy: 0.5147  Test loss: 1.3635927
# 11 623 Train accuracy: 0.47960840567946433  Train loss: 1.4440199680761858
# 11 Test accuracy: 0.572  Test loss: 1.2193563
# 12 623 Train accuracy: 0.48425642476727565  Train loss: 1.4372642797231674
# 12 Test accuracy: 0.5443  Test loss: 1.2752488
# 13 623 Train accuracy: 0.4890887725009368  Train loss: 1.424734241962433
# 13 Test accuracy: 0.5564  Test loss: 1.20722
# 14 623 Train accuracy: 0.4940219936732735  Train loss: 1.4153052822181156
# 14 Test accuracy: 0.5652  Test loss: 1.2544786
# 15 623 Train accuracy: 0.4964923234482606  Train loss: 1.4093575795491537
# 15 Test accuracy: 0.6207  Test loss: 1.0851151
# 16 623 Train accuracy: 0.49923078511841595  Train loss: 1.4012697741389275
# 16 Test accuracy: 0.5069  Test loss: 1.3949462
# 17 623 Train accuracy: 0.5023348577320575  Train loss: 1.3932541164229897
# 17 Test accuracy: 0.61  Test loss: 1.1106868
# 18 623 Train accuracy: 0.5056752300676373  Train loss: 1.3849808098210228
# 18 Test accuracy: 0.6295  Test loss: 1.0699749
# 19 623 Train accuracy: 0.5078866561855141  Train loss: 1.3767860770225524
# 19 Test accuracy: 0.5998  Test loss: 1.1396533
# 20 623 Train accuracy: 0.5107692475691438  Train loss: 1.3698342863321304
# 20 Test accuracy: 0.5861  Test loss: 1.1628059
# 21 623 Train accuracy: 0.5130842661077067  Train loss: 1.362423251129332
# 21 Test accuracy: 0.4373  Test loss: 1.6316743
# 22 623 Train accuracy: 0.5148531640998342  Train loss: 1.356662608493458
# 22 Test accuracy: 0.5584  Test loss: 1.1962683
# 23 623 Train accuracy: 0.5177525258906509  Train loss: 1.351559644471044
# Early stopping, best loss:  1.0699749
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.0015, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3236923161149025  Train loss: 1.8864160919189452
# 1 Test accuracy: 0.3713  Test loss: 1.781216
# 2 623 Train accuracy: 0.3769230856001377  Train loss: 1.7322607445716858
# 2 Test accuracy: 0.4688  Test loss: 1.4569163
# 3 623 Train accuracy: 0.4047179584701856  Train loss: 1.6648134692509968
# 3 Test accuracy: 0.4396  Test loss: 1.683633
# 4 623 Train accuracy: 0.42123077876865866  Train loss: 1.6234481394290925
# 4 Test accuracy: 0.5307  Test loss: 1.3748556
# 5 623 Train accuracy: 0.43864616471529005  Train loss: 1.5812468557357788
# 5 Test accuracy: 0.5609  Test loss: 1.2484695
# 6 623 Train accuracy: 0.4526153966287772  Train loss: 1.5487908470630645
# 6 Test accuracy: 0.5351  Test loss: 1.3942912
# 7 623 Train accuracy: 0.45986814435039247  Train loss: 1.5324717102731977
# 7 Test accuracy: 0.5172  Test loss: 1.3353703
# 8 623 Train accuracy: 0.47000001300126315  Train loss: 1.510126186311245
# 8 Test accuracy: 0.565  Test loss: 1.3751897
# 9 623 Train accuracy: 0.4778803555501832  Train loss: 1.4876957964897155
# 9 Test accuracy: 0.5725  Test loss: 1.3032912
# 10 623 Train accuracy: 0.48338462963700296  Train loss: 1.474106467962265
# Early stopping, best loss:  1.2484695
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3446153926849365  Train loss: 1.7815996980667115
# 1 Test accuracy: 0.3956  Test loss: 1.6056713
# 2 623 Train accuracy: 0.3892307770252228  Train loss: 1.6439203596115113
# 2 Test accuracy: 0.4348  Test loss: 1.4965342
# 3 623 Train accuracy: 0.4192820600668589  Train loss: 1.5677416912714641
# 3 Test accuracy: 0.4906  Test loss: 1.420049
# 4 623 Train accuracy: 0.43400000900030133  Train loss: 1.5272860527038574
# 4 Test accuracy: 0.5002  Test loss: 1.3698889
# 5 623 Train accuracy: 0.44984616446495057  Train loss: 1.4889396209716796
# 5 Test accuracy: 0.5768  Test loss: 1.198
# 6 623 Train accuracy: 0.46051283200581866  Train loss: 1.459268290201823
# 6 Test accuracy: 0.561  Test loss: 1.2023602
# 7 623 Train accuracy: 0.47120880365371703  Train loss: 1.432194890294756
# 7 Test accuracy: 0.447  Test loss: 1.5872815
# 8 623 Train accuracy: 0.48338462904095647  Train loss: 1.4038302892446517
# 8 Test accuracy: 0.5594  Test loss: 1.2524484
# 9 623 Train accuracy: 0.49018804828325907  Train loss: 1.3844813476668463
# 9 Test accuracy: 0.617  Test loss: 1.0921301
# 10 623 Train accuracy: 0.4980923224687576  Train loss: 1.3622858471870423
# 10 Test accuracy: 0.5793  Test loss: 1.1617239
# 11 623 Train accuracy: 0.5082517636906017  Train loss: 1.3381458919698541
# 11 Test accuracy: 0.5599  Test loss: 1.2378883
# 12 623 Train accuracy: 0.5135897596677145  Train loss: 1.3245526645580927
# 12 Test accuracy: 0.6306  Test loss: 1.0499108
# 13 623 Train accuracy: 0.520568063901021  Train loss: 1.309721614397489
# 13 Test accuracy: 0.6359  Test loss: 1.0232375
# 14 623 Train accuracy: 0.524879137958799  Train loss: 1.299896046774728
# 14 Test accuracy: 0.5927  Test loss: 1.1174818
# 15 623 Train accuracy: 0.5303795044422149  Train loss: 1.2885929284095765
# 15 Test accuracy: 0.6391  Test loss: 1.0127476
# 16 623 Train accuracy: 0.5346538636833429  Train loss: 1.2788920411467553
# 16 Test accuracy: 0.6146  Test loss: 1.0731168
# 17 623 Train accuracy: 0.5406335019364077  Train loss: 1.2661386554381426
# 17 Test accuracy: 0.6339  Test loss: 1.0381024
# 18 623 Train accuracy: 0.5432478812005784  Train loss: 1.2593874420060052
# 18 Test accuracy: 0.6386  Test loss: 1.01368
# 19 623 Train accuracy: 0.5465263339092857  Train loss: 1.250250823748739
# 19 Test accuracy: 0.647  Test loss: 0.9978742
# 20 623 Train accuracy: 0.5496615567803382  Train loss: 1.2441533421278
# 20 Test accuracy: 0.5942  Test loss: 1.1412054
# 21 623 Train accuracy: 0.5524395788283575  Train loss: 1.2361817038626899
# 21 Test accuracy: 0.6402  Test loss: 1.0202003
# 22 623 Train accuracy: 0.555804214314981  Train loss: 1.2276421281424437
# 22 Test accuracy: 0.6565  Test loss: 0.9475613
# 23 623 Train accuracy: 0.5588227611521016  Train loss: 1.2202269739690035
# 23 Test accuracy: 0.6501  Test loss: 0.9939793
# 24 623 Train accuracy: 0.5616666854421297  Train loss: 1.2134808638691903
# 24 Test accuracy: 0.6568  Test loss: 0.9632825
# 25 623 Train accuracy: 0.564996941947937  Train loss: 1.2063468708992005
# 25 Test accuracy: 0.6506  Test loss: 0.96130645
# 26 623 Train accuracy: 0.5675029775729546  Train loss: 1.2009063982963561
# 26 Test accuracy: 0.6498  Test loss: 0.9826304
# 27 623 Train accuracy: 0.5697777968865854  Train loss: 1.1950353838779308
# Early stopping, best loss:  0.9475613
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 5, 'hidden_1': 100, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.31961836551244444  Train loss: 1.832057265134958
# 1 Test accuracy: 0.4597  Test loss: 1.4835663
# 2 310 Train accuracy: 0.39057841467169613  Train loss: 1.6772638330092797
# 2 Test accuracy: 0.501  Test loss: 1.3900499
# 3 310 Train accuracy: 0.42735042652258504  Train loss: 1.5746639783565815
# 3 Test accuracy: 0.5483  Test loss: 1.2435814
# 4 310 Train accuracy: 0.45706618992755044  Train loss: 1.5030051171779633
# 4 Test accuracy: 0.486  Test loss: 1.4340228
# 5 310 Train accuracy: 0.4769230779546958  Train loss: 1.447334335400508
# 5 Test accuracy: 0.5312  Test loss: 1.3384546
# 6 310 Train accuracy: 0.49185052905709314  Train loss: 1.4118330012529323
# 6 Test accuracy: 0.5172  Test loss: 1.3660727
# 7 310 Train accuracy: 0.504557459645874  Train loss: 1.38191316481475
# 7 Test accuracy: 0.5967  Test loss: 1.1355804
# 8 310 Train accuracy: 0.5117769826633426  Train loss: 1.3599702744529798
# 8 Test accuracy: 0.5697  Test loss: 1.2003452
# 9 310 Train accuracy: 0.5235539649923643  Train loss: 1.332295616977235
# 9 Test accuracy: 0.6316  Test loss: 1.0643725
# 10 310 Train accuracy: 0.5281454976361531  Train loss: 1.3147065442342025
# 10 Test accuracy: 0.6336  Test loss: 1.0481924
# 11 310 Train accuracy: 0.5349379290754979  Train loss: 1.296128896149722
# 11 Test accuracy: 0.571  Test loss: 1.1784455
# 12 310 Train accuracy: 0.5411449006448189  Train loss: 1.2803476479573128
# 12 Test accuracy: 0.6263  Test loss: 1.054385
# 13 310 Train accuracy: 0.5463052145563639  Train loss: 1.2660421983024779
# 13 Test accuracy: 0.5758  Test loss: 1.1524811
# 14 310 Train accuracy: 0.5529431802640249  Train loss: 1.249356976904712
# 14 Test accuracy: 0.6482  Test loss: 0.99010956
# 15 310 Train accuracy: 0.55766249165321  Train loss: 1.2351174574631911
# 15 Test accuracy: 0.6382  Test loss: 1.0055292
# 16 310 Train accuracy: 0.5624999991761377  Train loss: 1.222155143148624
# 16 Test accuracy: 0.6479  Test loss: 1.0282704
# 17 310 Train accuracy: 0.5651548629230504  Train loss: 1.2144886581606456
# 17 Test accuracy: 0.6305  Test loss: 1.0441751
# 18 310 Train accuracy: 0.5682104286284019  Train loss: 1.2056847708856957
# 18 Test accuracy: 0.613  Test loss: 1.0943708
# 19 310 Train accuracy: 0.5705363589078791  Train loss: 1.1995916870924144
# 19 Test accuracy: 0.6546  Test loss: 0.9711131
# 20 310 Train accuracy: 0.5748360173346905  Train loss: 1.1882178063576039
# 20 Test accuracy: 0.6918  Test loss: 0.877306
# 21 310 Train accuracy: 0.5781866718397473  Train loss: 1.17755754504885
# 21 Test accuracy: 0.6328  Test loss: 1.0450916
# 22 310 Train accuracy: 0.5824253269686148  Train loss: 1.1674039736911133
# 22 Test accuracy: 0.6646  Test loss: 0.9448365
# 23 310 Train accuracy: 0.5860361413263956  Train loss: 1.1596936884532405
# 23 Test accuracy: 0.6645  Test loss: 0.9575764
# 24 310 Train accuracy: 0.5881534490304497  Train loss: 1.1537596583366394
# 24 Test accuracy: 0.6883  Test loss: 0.89841056
# 25 310 Train accuracy: 0.5911270130826877  Train loss: 1.145834649342757
# 25 Test accuracy: 0.698  Test loss: 0.85721135
# 26 310 Train accuracy: 0.5935278201817408  Train loss: 1.1384231118408181
# 26 Test accuracy: 0.6893  Test loss: 0.8850793
# 27 310 Train accuracy: 0.5949336339817767  Train loss: 1.1349662771591773
# 27 Test accuracy: 0.6014  Test loss: 1.1684427
# 28 310 Train accuracy: 0.5969418181045042  Train loss: 1.1295976357145623
# 28 Test accuracy: 0.6753  Test loss: 0.92090076
# 29 310 Train accuracy: 0.5987498203900196  Train loss: 1.1257354517514258
# 29 Test accuracy: 0.664  Test loss: 0.9680242
# 30 310 Train accuracy: 0.6004174124162931  Train loss: 1.120815293605511
# 30 Test accuracy: 0.6963  Test loss: 0.85398436
# 31 310 Train accuracy: 0.6024775428341577  Train loss: 1.1155780401478335
# 31 Test accuracy: 0.6904  Test loss: 0.87746423
# 32 310 Train accuracy: 0.6035330950533255  Train loss: 1.1124380129174545
# 32 Test accuracy: 0.7155  Test loss: 0.8272659
# 33 310 Train accuracy: 0.6054462336333759  Train loss: 1.1084832792237644
# 33 Test accuracy: 0.6869  Test loss: 0.89432305
# 34 310 Train accuracy: 0.6072117582604086  Train loss: 1.1033837096723496
# 34 Test accuracy: 0.7034  Test loss: 0.85786945
# 35 310 Train accuracy: 0.6091319540208513  Train loss: 1.0984956043107168
# 35 Test accuracy: 0.7047  Test loss: 0.84368134
# 36 310 Train accuracy: 0.6108129605428021  Train loss: 1.0940945575125196
# 36 Test accuracy: 0.7101  Test loss: 0.8327118
# 37 310 Train accuracy: 0.6125481484492702  Train loss: 1.090011982313065
# Early stopping, best loss:  0.8272659
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 60, 'hidden_2': 80, 'activation': 'elu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.26177698431106716  Train loss: 2.058527322915884
# 1 Test accuracy: 0.3274  Test loss: 1.8319019
# 2 310 Train accuracy: 0.3136553377486192  Train loss: 1.8875694870948792
# 2 Test accuracy: 0.3642  Test loss: 1.7438233
# 3 310 Train accuracy: 0.3390975947945546  Train loss: 1.8054955066778722
# 3 Test accuracy: 0.395  Test loss: 1.6539693
# 4 310 Train accuracy: 0.35480023820239764  Train loss: 1.7518858909606934
# 4 Test accuracy: 0.3877  Test loss: 1.7169844
# 5 310 Train accuracy: 0.37268932702449653  Train loss: 1.7049926592753484
# 5 Test accuracy: 0.4521  Test loss: 1.5108116
# 6 310 Train accuracy: 0.3840190818867622  Train loss: 1.6707142729025621
# 6 Test accuracy: 0.3917  Test loss: 1.8035957
# 7 310 Train accuracy: 0.39534883749681515  Train loss: 1.6430883643391367
# 7 Test accuracy: 0.4204  Test loss: 1.6935662
# 8 310 Train accuracy: 0.4036970784027989  Train loss: 1.6184721084741445
# 8 Test accuracy: 0.4545  Test loss: 1.5661186
# 9 310 Train accuracy: 0.41091896994755817  Train loss: 1.6001609176652045
# 9 Test accuracy: 0.4935  Test loss: 1.422111
# 10 310 Train accuracy: 0.41747167689295916  Train loss: 1.5798917018450223
# 10 Test accuracy: 0.3949  Test loss: 1.8240738
# 11 310 Train accuracy: 0.4251639853928473  Train loss: 1.5589678020744058
# 11 Test accuracy: 0.4702  Test loss: 1.4987352
# 12 310 Train accuracy: 0.43311469127925545  Train loss: 1.5388093613661253
# 12 Test accuracy: 0.4887  Test loss: 1.4422021
# 13 310 Train accuracy: 0.44053025292397957  Train loss: 1.5225463364956646
# 13 Test accuracy: 0.4774  Test loss: 1.5095979
# 14 310 Train accuracy: 0.44548087710371387  Train loss: 1.5093538459840712
# 14 Test accuracy: 0.541  Test loss: 1.261306
# 15 310 Train accuracy: 0.4517193412551513  Train loss: 1.494814896583557
# 15 Test accuracy: 0.489  Test loss: 1.4575645
# 16 310 Train accuracy: 0.45643261923956185  Train loss: 1.4822867529896588
# 16 Test accuracy: 0.5329  Test loss: 1.3335059
# 17 310 Train accuracy: 0.46122277312284143  Train loss: 1.470239638742818
# 17 Test accuracy: 0.5721  Test loss: 1.1825151
# 18 310 Train accuracy: 0.4658782234112931  Train loss: 1.4577755571430564
# 18 Test accuracy: 0.5789  Test loss: 1.1927341
# 19 310 Train accuracy: 0.47020054795602073  Train loss: 1.4442021677851193
# 19 Test accuracy: 0.5628  Test loss: 1.2403512
# 20 310 Train accuracy: 0.4738819340387216  Train loss: 1.4345818368288188
# 20 Test accuracy: 0.5871  Test loss: 1.1544137
# 21 310 Train accuracy: 0.47709913025081374  Train loss: 1.4259246941451187
# 21 Test accuracy: 0.5657  Test loss: 1.2344056
# 22 310 Train accuracy: 0.4820838091517245  Train loss: 1.4148934708608614
# 22 Test accuracy: 0.504  Test loss: 1.4354252
# 23 310 Train accuracy: 0.4848979820425694  Train loss: 1.4073614555856455
# 23 Test accuracy: 0.5895  Test loss: 1.1372613
# 24 310 Train accuracy: 0.48904293558249873  Train loss: 1.3971722229168966
# 24 Test accuracy: 0.6115  Test loss: 1.1030623
# 25 310 Train accuracy: 0.49223613750476103  Train loss: 1.38935696381789
# 25 Test accuracy: 0.606  Test loss: 1.116821
# 26 310 Train accuracy: 0.49532131729482193  Train loss: 1.380707865283334
# 26 Test accuracy: 0.5808  Test loss: 1.1546504
# 27 310 Train accuracy: 0.4984650735204716  Train loss: 1.3724329064035008
# 27 Test accuracy: 0.5879  Test loss: 1.1746013
# 28 310 Train accuracy: 0.5024278060133968  Train loss: 1.3632636535298692
# 28 Test accuracy: 0.5874  Test loss: 1.1775329
# 29 310 Train accuracy: 0.5057060033359642  Train loss: 1.3559960839919134
# Early stopping, best loss:  1.1030623
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 4, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 310 Train accuracy: 0.17829457441201577  Train loss: 2.2952340932992787
# 1 Test accuracy: 0.1993  Test loss: 2.093391
# 2 310 Train accuracy: 0.2116875364803351  Train loss: 2.16557331268604
# 2 Test accuracy: 0.2524  Test loss: 1.9814361
# 3 310 Train accuracy: 0.24289405670685646  Train loss: 2.066402236620585
# 3 Test accuracy: 0.2806  Test loss: 1.892505
# 4 310 Train accuracy: 0.25894454307854176  Train loss: 2.010998485180048
# 4 Test accuracy: 0.3198  Test loss: 1.8069729
# 5 310 Train accuracy: 0.27215265322190063  Train loss: 1.9717925548553468
# 5 Test accuracy: 0.327  Test loss: 1.7822868
# 6 310 Train accuracy: 0.28483402853210765  Train loss: 1.9317771991093953
# 6 Test accuracy: 0.2895  Test loss: 1.9105787
# 7 310 Train accuracy: 0.2944032704600921  Train loss: 1.9067653050789466
# 7 Test accuracy: 0.3378  Test loss: 1.7758106
# 8 310 Train accuracy: 0.30128205030296856  Train loss: 1.885402874304698
# 8 Test accuracy: 0.3124  Test loss: 1.8381128
# 9 310 Train accuracy: 0.3101437747096404  Train loss: 1.863630971337995
# 9 Test accuracy: 0.3731  Test loss: 1.6667726
# 10 310 Train accuracy: 0.316935002631866  Train loss: 1.844573254768665
# 10 Test accuracy: 0.304  Test loss: 1.929879
# 11 310 Train accuracy: 0.32119043749737575  Train loss: 1.8305828863090567
# 11 Test accuracy: 0.4003  Test loss: 1.6072975
# 12 310 Train accuracy: 0.3266746174926177  Train loss: 1.8146151724534156
# 12 Test accuracy: 0.3342  Test loss: 1.8515203
# 13 310 Train accuracy: 0.3314526857444521  Train loss: 1.7985000356414613
# 13 Test accuracy: 0.3175  Test loss: 1.8970027
# 14 310 Train accuracy: 0.33669818565249443  Train loss: 1.785638819029043
# 14 Test accuracy: 0.3474  Test loss: 1.7899616
# 15 310 Train accuracy: 0.34052872233665904  Train loss: 1.7727653411718516
# 15 Test accuracy: 0.3519  Test loss: 1.7777075
# 16 310 Train accuracy: 0.34540846761172783  Train loss: 1.7615055619524076
# Early stopping, best loss:  1.6072975
# Training Model with following hyperparameters:
# {'filter1': 32, 'kernelsize_1': 5, 'filter2': 48, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 5, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'nesterov'}
# 1 623 Train accuracy: 0.2504615454375744  Train loss: 2.0459736299514772
# 1 Test accuracy: 0.2825  Test loss: 1.857226
# 2 623 Train accuracy: 0.26984616182744503  Train loss: 1.9247170734405517
# 2 Test accuracy: 0.3131  Test loss: 1.8576822
# 3 623 Train accuracy: 0.30420513585209846  Train loss: 1.8554106187820434
# 3 Test accuracy: 0.3691  Test loss: 1.6916534
# 4 623 Train accuracy: 0.32184616159647705  Train loss: 1.81272518157959
# 4 Test accuracy: 0.383  Test loss: 1.6604141
# 5 623 Train accuracy: 0.33575385412573816  Train loss: 1.775718713760376
# 5 Test accuracy: 0.4203  Test loss: 1.5579661
# 6 623 Train accuracy: 0.34871795671681566  Train loss: 1.7445950237909953
# 6 Test accuracy: 0.4145  Test loss: 1.6163446
# 7 623 Train accuracy: 0.3594725358273302  Train loss: 1.7174598857334682
# 7 Test accuracy: 0.4402  Test loss: 1.5321043
# 8 623 Train accuracy: 0.3697692394070327  Train loss: 1.6910587739944458
# 8 Test accuracy: 0.4218  Test loss: 1.598072
# 9 623 Train accuracy: 0.37736752985252275  Train loss: 1.6715009281370374
# 9 Test accuracy: 0.4107  Test loss: 1.5969932
# 10 623 Train accuracy: 0.3833846239894628  Train loss: 1.657289783477783
# 10 Test accuracy: 0.41  Test loss: 1.6559805
# 11 623 Train accuracy: 0.3918881208110939  Train loss: 1.6385919813676313
# 11 Test accuracy: 0.4771  Test loss: 1.4062643
# 12 623 Train accuracy: 0.39815385539084674  Train loss: 1.6241674462954203
# 12 Test accuracy: 0.4803  Test loss: 1.411435
# 13 623 Train accuracy: 0.4050177610722872  Train loss: 1.6096320779506976
# 13 Test accuracy: 0.4692  Test loss: 1.4374413
# 14 623 Train accuracy: 0.4081318778544664  Train loss: 1.598792553629194
# 14 Test accuracy: 0.5145  Test loss: 1.3363346
# 15 623 Train accuracy: 0.4120615481436253  Train loss: 1.5888000367482504
# 15 Test accuracy: 0.467  Test loss: 1.4451057
# 16 623 Train accuracy: 0.4159230867680162  Train loss: 1.5802389711141587
# 16 Test accuracy: 0.4969  Test loss: 1.3849797
# 17 623 Train accuracy: 0.41922172938199603  Train loss: 1.5714445711584653
# 17 Test accuracy: 0.4838  Test loss: 1.4138867
# 18 623 Train accuracy: 0.42205129192107255  Train loss: 1.5631094929907057
# 18 Test accuracy: 0.4276  Test loss: 1.5905927
# 19 623 Train accuracy: 0.4261052732640191  Train loss: 1.555907708720157
# Early stopping, best loss:  1.3363346
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.0015, 'batch_size': 128, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 310 Train accuracy: 0.2999403723157369  Train loss: 1.9359776698626006
# 1 Test accuracy: 0.3712  Test loss: 1.6549063
# 2 310 Train accuracy: 0.36314847922095883  Train loss: 1.7698234273837163
# 2 Test accuracy: 0.404  Test loss: 1.6864595
# 3 310 Train accuracy: 0.39395746187521863  Train loss: 1.6825843285291622
# 3 Test accuracy: 0.4987  Test loss: 1.348097
# 4 310 Train accuracy: 0.40906380331860137  Train loss: 1.626526117324829
# 4 Test accuracy: 0.4323  Test loss: 1.6200083
# 5 310 Train accuracy: 0.42098986082352124  Train loss: 1.591360040811392
# 5 Test accuracy: 0.3503  Test loss: 2.1088607
# 6 310 Train accuracy: 0.4309282447092044  Train loss: 1.558543793666057
# 6 Test accuracy: 0.5275  Test loss: 1.3302085
# 7 310 Train accuracy: 0.44058267354637715  Train loss: 1.530021071434021
# 7 Test accuracy: 0.5268  Test loss: 1.3490611
# 8 310 Train accuracy: 0.4517740033423671  Train loss: 1.5078490009674659
# 8 Test accuracy: 0.5055  Test loss: 1.3870994
# 9 310 Train accuracy: 0.4572318315378621  Train loss: 1.493705349090772
# 9 Test accuracy: 0.4671  Test loss: 1.4750755
# 10 310 Train accuracy: 0.4626714387192176  Train loss: 1.4768224285199092
# 10 Test accuracy: 0.5124  Test loss: 1.3925655
# 11 310 Train accuracy: 0.4678809581832452  Train loss: 1.4644266408640187
# Early stopping, best loss:  1.3302085
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 128, 'kernelsize_2': 5, 'filter3': 64, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.002, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.3714967215290436  Train loss: 1.7123363935030425
# 1 Test accuracy: 0.4748  Test loss: 1.4481157
# 2 310 Train accuracy: 0.4165175926799958  Train loss: 1.5885952390157259
# 2 Test accuracy: 0.5348  Test loss: 1.2881364
# 3 310 Train accuracy: 0.4468296577151005  Train loss: 1.5097572742364345
# 3 Test accuracy: 0.4442  Test loss: 1.5668812
# 4 310 Train accuracy: 0.4743589766037006  Train loss: 1.4513983130455017
# 4 Test accuracy: 0.5766  Test loss: 1.175344
# 5 310 Train accuracy: 0.49421586314072974  Train loss: 1.3998070331720205
# 5 Test accuracy: 0.5413  Test loss: 1.2755957
# 6 310 Train accuracy: 0.5106340689727893  Train loss: 1.3575904483978565
# 6 Test accuracy: 0.6089  Test loss: 1.0930235
# 7 310 Train accuracy: 0.5271317831926293  Train loss: 1.3173878441800129
# 7 Test accuracy: 0.6425  Test loss: 1.0108657
# 8 310 Train accuracy: 0.5379397735142937  Train loss: 1.2867026495245786
# 8 Test accuracy: 0.6311  Test loss: 1.038218
# 9 310 Train accuracy: 0.5485324317700843  Train loss: 1.261015734101972
# 9 Test accuracy: 0.6456  Test loss: 1.0258949
# 10 310 Train accuracy: 0.5580799041459193  Train loss: 1.2377832467739398
# 10 Test accuracy: 0.663  Test loss: 0.97718924
# 11 310 Train accuracy: 0.5651867508992449  Train loss: 1.2181461782722207
# 11 Test accuracy: 0.6611  Test loss: 0.95531535
# 12 310 Train accuracy: 0.5738918699610692  Train loss: 1.1970682312280705
# 12 Test accuracy: 0.6821  Test loss: 0.8969499
# 13 310 Train accuracy: 0.5802944823217815  Train loss: 1.177070927690472
# 13 Test accuracy: 0.6902  Test loss: 0.8846221
# 14 310 Train accuracy: 0.5859953998946227  Train loss: 1.1600139003533583
# 14 Test accuracy: 0.6881  Test loss: 0.89558303
# 15 310 Train accuracy: 0.5920890476841193  Train loss: 1.1429343174665403
# 15 Test accuracy: 0.692  Test loss: 0.88411164
# 16 310 Train accuracy: 0.5976818718660909  Train loss: 1.1294068338779302
# 16 Test accuracy: 0.7149  Test loss: 0.81477433
# 17 310 Train accuracy: 0.6024413339759969  Train loss: 1.1164091631298152
# 17 Test accuracy: 0.693  Test loss: 0.87720937
# 18 310 Train accuracy: 0.6061419194134382  Train loss: 1.105609503057268
# 18 Test accuracy: 0.7122  Test loss: 0.82048184
# 19 310 Train accuracy: 0.6115557222291526  Train loss: 1.091620702975192
# 19 Test accuracy: 0.6604  Test loss: 0.98909914
# 20 310 Train accuracy: 0.6157125811450757  Train loss: 1.0799092847567338
# 20 Test accuracy: 0.6471  Test loss: 1.0422666
# 21 310 Train accuracy: 0.6199278743330375  Train loss: 1.0695262915922172
# Early stopping, best loss:  0.81477433
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.001, 'batch_size': 128, 'momentum': 0.9, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.2617769848841887  Train loss: 1.9758491699512188
# 1 Test accuracy: 0.3234  Test loss: 1.8362125
# 2 310 Train accuracy: 0.3261777007809052  Train loss: 1.8111799771969135
# 2 Test accuracy: 0.4105  Test loss: 1.5894926
# 3 310 Train accuracy: 0.35321009961458355  Train loss: 1.7474117890382423
# 3 Test accuracy: 0.3982  Test loss: 1.6536531
# 4 310 Train accuracy: 0.3746273136482789  Train loss: 1.6839113648121173
# 4 Test accuracy: 0.4525  Test loss: 1.4677318
# 5 310 Train accuracy: 0.39797257162057437  Train loss: 1.6364468354445236
# 5 Test accuracy: 0.4181  Test loss: 1.6562562
# 6 310 Train accuracy: 0.41224408856569195  Train loss: 1.6021996705960004
# 6 Test accuracy: 0.5014  Test loss: 1.3577392
# 7 310 Train accuracy: 0.42328989063645456  Train loss: 1.5726556948253088
# 7 Test accuracy: 0.5133  Test loss: 1.3280268
# 8 310 Train accuracy: 0.43209600692185074  Train loss: 1.5504253735909095
# 8 Test accuracy: 0.4982  Test loss: 1.401165
# 9 310 Train accuracy: 0.4411979094784484  Train loss: 1.5276472853799152
# 9 Test accuracy: 0.5195  Test loss: 1.3352195
# 10 310 Train accuracy: 0.44782349707988595  Train loss: 1.5094313383102418
# 10 Test accuracy: 0.4847  Test loss: 1.4277145
# 11 310 Train accuracy: 0.45465387570691274  Train loss: 1.4920027556119266
# 11 Test accuracy: 0.5584  Test loss: 1.2480322
# 12 310 Train accuracy: 0.4602961657712093  Train loss: 1.474638663805448
# 12 Test accuracy: 0.5279  Test loss: 1.3152329
# 13 310 Train accuracy: 0.4660795393603793  Train loss: 1.4592418310910287
# 13 Test accuracy: 0.4837  Test loss: 1.4353988
# 14 310 Train accuracy: 0.47248488132442745  Train loss: 1.4442518045614055
# 14 Test accuracy: 0.5991  Test loss: 1.1240062
# 15 310 Train accuracy: 0.47692307868064976  Train loss: 1.4331564573141244
# 15 Test accuracy: 0.605  Test loss: 1.1143441
# 16 310 Train accuracy: 0.48103011535623896  Train loss: 1.4226105115734613
# 16 Test accuracy: 0.5622  Test loss: 1.2174956
# 17 310 Train accuracy: 0.4853555038908488  Train loss: 1.4096634743979615
# 17 Test accuracy: 0.5739  Test loss: 1.1842837
# 18 310 Train accuracy: 0.4902272598228903  Train loss: 1.3971663881570866
# 18 Test accuracy: 0.5583  Test loss: 1.2284799
# 19 310 Train accuracy: 0.49442927768597233  Train loss: 1.3864028960587043
# 19 Test accuracy: 0.5648  Test loss: 1.2045391
# 20 310 Train accuracy: 0.49788312677007457  Train loss: 1.3777211134250347
# Early stopping, best loss:  1.1143441
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 5, 'filter2': 128, 'kernelsize_2': 3, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 60, 'hidden_2': 125, 'activation': 'lrelu', 'learning_rate': 0.003, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.3680000078678131  Train loss: 1.7203376626968383
# 1 Test accuracy: 0.4422  Test loss: 1.5210583
# 2 623 Train accuracy: 0.42030770182609556  Train loss: 1.5895115733146667
# 2 Test accuracy: 0.4917  Test loss: 1.4074771
# 3 623 Train accuracy: 0.45497437119483947  Train loss: 1.4963227748870849
# 3 Test accuracy: 0.4768  Test loss: 1.5382767
# 4 623 Train accuracy: 0.4815384757518768  Train loss: 1.4279003077745438
# 4 Test accuracy: 0.5462  Test loss: 1.3212217
# 5 623 Train accuracy: 0.49673847699165347  Train loss: 1.3786867480278016
# 5 Test accuracy: 0.5005  Test loss: 1.4617869
# 6 623 Train accuracy: 0.5169230935970942  Train loss: 1.3301505442460377
# 6 Test accuracy: 0.5469  Test loss: 1.3656176
# 7 623 Train accuracy: 0.5331868306228092  Train loss: 1.292903001989637
# 7 Test accuracy: 0.5865  Test loss: 1.2042823
# 8 623 Train accuracy: 0.5440769411623478  Train loss: 1.2660507771372795
# 8 Test accuracy: 0.6676  Test loss: 0.94229627
# 9 623 Train accuracy: 0.553982924355401  Train loss: 1.2408884790208605
# 9 Test accuracy: 0.5878  Test loss: 1.2061994
# 10 623 Train accuracy: 0.5623384802341461  Train loss: 1.2180881447792054
# 10 Test accuracy: 0.6623  Test loss: 0.9667146
# 11 623 Train accuracy: 0.5700699489766902  Train loss: 1.1985806625539606
# 11 Test accuracy: 0.6852  Test loss: 0.900183
# 12 623 Train accuracy: 0.5777436087528864  Train loss: 1.1777820177872975
# 12 Test accuracy: 0.5853  Test loss: 1.1836816
# 13 623 Train accuracy: 0.5831006108797514  Train loss: 1.1616878460003779
# 13 Test accuracy: 0.6965  Test loss: 0.85675335
# 14 623 Train accuracy: 0.5883077115671975  Train loss: 1.1485658727373396
# 14 Test accuracy: 0.6742  Test loss: 0.9245618
# 15 623 Train accuracy: 0.59355899365743  Train loss: 1.1356724592844645
# 15 Test accuracy: 0.6927  Test loss: 0.85841924
# 16 623 Train accuracy: 0.5981538654863834  Train loss: 1.1232959240674973
# 16 Test accuracy: 0.7086  Test loss: 0.8291588
# 17 623 Train accuracy: 0.6025339559947743  Train loss: 1.1133782438670887
# 17 Test accuracy: 0.6694  Test loss: 0.9434346
# 18 623 Train accuracy: 0.6063931817478604  Train loss: 1.103404581281874
# 18 Test accuracy: 0.6924  Test loss: 0.8795369
# 19 623 Train accuracy: 0.6111093310305947  Train loss: 1.0926813584879824
# 19 Test accuracy: 0.7023  Test loss: 0.8376466
# 20 623 Train accuracy: 0.6150769423246384  Train loss: 1.0822364100217818
# 20 Test accuracy: 0.7125  Test loss: 0.8193124
# 21 623 Train accuracy: 0.6184615576834905  Train loss: 1.0736117006483532
# 21 Test accuracy: 0.7206  Test loss: 0.78981584
# 22 623 Train accuracy: 0.6224615576050498  Train loss: 1.0630658921328457
# ...
# 15 1248 Train accuracy: 0.4149495033025742  Train loss: 1.572154710451762
# 15 Test accuracy: 0.5029  Test loss: 1.3523588
# 16 1248 Train accuracy: 0.4197348567470908  Train loss: 1.5612405449151994
# 16 Test accuracy: 0.5005  Test loss: 1.3400693
# 17 1248 Train accuracy: 0.4246702398622737  Train loss: 1.5487316811084748
# 17 Test accuracy: 0.4255  Test loss: 1.584368
# 18 1248 Train accuracy: 0.42942761735783685  Train loss: 1.5384529327683978
# 18 Test accuracy: 0.4658  Test loss: 1.438066
# 19 1248 Train accuracy: 0.432950566034568  Train loss: 1.5278498054178138
# 19 Test accuracy: 0.5556  Test loss: 1.2219718
# 20 1248 Train accuracy: 0.43724243211746217  Train loss: 1.5177575241327286
# 20 Test accuracy: 0.5372  Test loss: 1.3062938
# 21 1248 Train accuracy: 0.4405194883119492  Train loss: 1.5093583772295998
# 21 Test accuracy: 0.5671  Test loss: 1.1964638
# 22 1248 Train accuracy: 0.444517914083871  Train loss: 1.5009238374233247
# 22 Test accuracy: 0.5465  Test loss: 1.2447608
# 23 1248 Train accuracy: 0.4481950011201527  Train loss: 1.4934066302879996
# 23 Test accuracy: 0.5599  Test loss: 1.2180865
# 24 1248 Train accuracy: 0.45194445210198564  Train loss: 1.484430680225293
# 24 Test accuracy: 0.5421  Test loss: 1.2637045
# 25 1248 Train accuracy: 0.4551272802591324  Train loss: 1.4760449315071107
# 25 Test accuracy: 0.5599  Test loss: 1.1945767
# 26 1248 Train accuracy: 0.4590442965351618  Train loss: 1.4668359560691393
# 26 Test accuracy: 0.5906  Test loss: 1.1442299
# 27 1248 Train accuracy: 0.461189681953854  Train loss: 1.4610314215112616
# 27 Test accuracy: 0.5859  Test loss: 1.1636785
# 28 1248 Train accuracy: 0.4643723018467426  Train loss: 1.4534531269328934
# 28 Test accuracy: 0.6132  Test loss: 1.0782862
# 29 1248 Train accuracy: 0.4672727346625821  Train loss: 1.4458466836090746
# 29 Test accuracy: 0.5916  Test loss: 1.1281554
# 30 1248 Train accuracy: 0.47044445166985194  Train loss: 1.4382916222016016
# 30 Test accuracy: 0.5702  Test loss: 1.1591418
# 31 1248 Train accuracy: 0.4737243473529816  Train loss: 1.4313294465695658
# 31 Test accuracy: 0.6165  Test loss: 1.0564439
# 32 1248 Train accuracy: 0.4761742495186627  Train loss: 1.424293475598097
# 32 Test accuracy: 0.6061  Test loss: 1.087373
# 33 1248 Train accuracy: 0.4793939463839386  Train loss: 1.416246188806765
# 33 Test accuracy: 0.6208  Test loss: 1.0531213
# 34 1248 Train accuracy: 0.48256685181575665  Train loss: 1.408232123080422
# 34 Test accuracy: 0.6087  Test loss: 1.0829589
# 35 1248 Train accuracy: 0.48445022334371296  Train loss: 1.4023145227091653
# 35 Test accuracy: 0.6133  Test loss: 1.0809892
# 36 1248 Train accuracy: 0.4874915892051326  Train loss: 1.3940228141347568
# 36 Test accuracy: 0.6436  Test loss: 1.0095769
# 37 1248 Train accuracy: 0.49013923674016385  Train loss: 1.3879003399449426
# 37 Test accuracy: 0.6403  Test loss: 1.0103447
# 38 1248 Train accuracy: 0.49183413737698606  Train loss: 1.3843631449498628
# 38 Test accuracy: 0.6267  Test loss: 1.042445
# 39 1248 Train accuracy: 0.49400156050156324  Train loss: 1.3782898590503594
# 39 Test accuracy: 0.6224  Test loss: 1.0529177
# 40 1248 Train accuracy: 0.4965606125295162  Train loss: 1.371900081962347
# 40 Test accuracy: 0.6328  Test loss: 1.0323926
# 41 1248 Train accuracy: 0.49832964436310095  Train loss: 1.366704133341952
# Early stopping, best loss:  1.0095769
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 3, 'filter2': 64, 'kernelsize_2': 5, 'filter3': 128, 'kernelsize_3': 4, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'relu', 'learning_rate': 0.003, 'batch_size': 128, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 310 Train accuracy: 0.3172331555531575  Train loss: 1.917103125498845
# 1 Test accuracy: 0.4131  Test loss: 1.5836393
# 2 310 Train accuracy: 0.36135957275445646  Train loss: 1.755793910760146
# 2 Test accuracy: 0.3855  Test loss: 1.683374
# 3 310 Train accuracy: 0.39157225497258014  Train loss: 1.665160860770788
# 3 Test accuracy: 0.4724  Test loss: 1.4399947
# 4 310 Train accuracy: 0.4127907005067055  Train loss: 1.6061445841422448
# 4 Test accuracy: 0.485  Test loss: 1.4066
# 5 310 Train accuracy: 0.4282647616588152  Train loss: 1.567474757708036
# 5 Test accuracy: 0.5208  Test loss: 1.3383945
# 6 310 Train accuracy: 0.4420592358861214  Train loss: 1.533937578017895
# 6 Test accuracy: 0.5067  Test loss: 1.3600374
# 7 310 Train accuracy: 0.453616154226628  Train loss: 1.503056709582989
# 7 Test accuracy: 0.4993  Test loss: 1.3854082
# 8 310 Train accuracy: 0.46213476804013437  Train loss: 1.484491004393651
# 8 Test accuracy: 0.5073  Test loss: 1.3798201
# 9 310 Train accuracy: 0.4675677496398616  Train loss: 1.4694152071944668
# 9 Test accuracy: 0.4662  Test loss: 1.484837
# 10 310 Train accuracy: 0.4728085894997303  Train loss: 1.4544194689163794
# Early stopping, best loss:  1.3383945
# Training Model with following hyperparameters:
# {'filter1': 64, 'kernelsize_1': 4, 'filter2': 96, 'kernelsize_2': 3, 'filter3': 128, 'kernelsize_3': 3, 'hidden_1': 100, 'hidden_2': 100, 'activation': 'lrelu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.99, 'p_reduct': 0, 'optimizer': 'rmsprop'}
# 1 623 Train accuracy: 0.3403076981008053  Train loss: 1.8164913177490234
# 1 Test accuracy: 0.4695  Test loss: 1.4415994
# 2 623 Train accuracy: 0.4012307768315077  Train loss: 1.6293664026260375
# 2 Test accuracy: 0.4422  Test loss: 1.5836216
# 3 623 Train accuracy: 0.43138462498784064  Train loss: 1.5570810079574584
# 3 Test accuracy: 0.5529  Test loss: 1.2712373
# 4 623 Train accuracy: 0.4569230892881751  Train loss: 1.4932868784666062
# 4 Test accuracy: 0.5397  Test loss: 1.262877
# 5 623 Train accuracy: 0.4695384750068188  Train loss: 1.4574136576652528
# 5 Test accuracy: 0.4847  Test loss: 1.4388654
# 6 623 Train accuracy: 0.48041027086476484  Train loss: 1.4318206290404
# 6 Test accuracy: 0.5704  Test loss: 1.2035127
# 7 623 Train accuracy: 0.4903736415718283  Train loss: 1.4076781868934631
# 7 Test accuracy: 0.5722  Test loss: 1.1598368
# 8 623 Train accuracy: 0.5016923239640891  Train loss: 1.3797707024216652
# 8 Test accuracy: 0.5424  Test loss: 1.2754884
# 9 623 Train accuracy: 0.5099487349556552  Train loss: 1.3617579566107856
# 9 Test accuracy: 0.6005  Test loss: 1.0766313
# 10 623 Train accuracy: 0.5146461711972952  Train loss: 1.3480160298347472
# 10 Test accuracy: 0.5099  Test loss: 1.4614532
# 11 623 Train accuracy: 0.5212867309694941  Train loss: 1.3357808091423728
# 11 Test accuracy: 0.5582  Test loss: 1.2963184
# 12 623 Train accuracy: 0.5273846332107981  Train loss: 1.3225559242566427
# 12 Test accuracy: 0.5753  Test loss: 1.1569377
# 13 623 Train accuracy: 0.5303668819826383  Train loss: 1.3145556556261502
# 13 Test accuracy: 0.635  Test loss: 1.0190833
# 14 623 Train accuracy: 0.5355165019099202  Train loss: 1.3015350343499865
# 14 Test accuracy: 0.6023  Test loss: 1.1211921
# 15 623 Train accuracy: 0.5396102751791477  Train loss: 1.2913046627044678
# 15 Test accuracy: 0.6181  Test loss: 1.0732917
# 16 623 Train accuracy: 0.5429230959620327  Train loss: 1.2819969050586224
# 16 Test accuracy: 0.6566  Test loss: 1.0002494
# 17 623 Train accuracy: 0.5463529604235117  Train loss: 1.2731136603916393
# 17 Test accuracy: 0.585  Test loss: 1.1993004
# 18 623 Train accuracy: 0.5491966005745861  Train loss: 1.2658178859286837
# 18 Test accuracy: 0.6257  Test loss: 1.0980102
# 19 623 Train accuracy: 0.5521943513892199  Train loss: 1.2581330891659386
# 19 Test accuracy: 0.6328  Test loss: 1.035829
# 20 623 Train accuracy: 0.5550154040977359  Train loss: 1.2515127041339875
# 20 Test accuracy: 0.6128  Test loss: 1.0916598
# 21 623 Train accuracy: 0.557655697259165  Train loss: 1.243613443601699
# 21 Test accuracy: 0.6554  Test loss: 0.9905466
# 22 623 Train accuracy: 0.559356663111936  Train loss: 1.2384782801974903
# 22 Test accuracy: 0.667  Test loss: 0.9455918
# 23 623 Train accuracy: 0.5614448359155136  Train loss: 1.2332226409082827
# 23 Test accuracy: 0.6312  Test loss: 1.0586896
# 24 623 Train accuracy: 0.5641025840677321  Train loss: 1.225864175260067
# 24 Test accuracy: 0.6419  Test loss: 1.0150012
# 25 623 Train accuracy: 0.5650707893311977  Train loss: 1.2232306364059449
# 25 Test accuracy: 0.6162  Test loss: 1.1369272
# 26 623 Train accuracy: 0.5674793100758241  Train loss: 1.2174846275953146
# 26 Test accuracy: 0.6619  Test loss: 0.9537453
# 27 623 Train accuracy: 0.5685698208047284  Train loss: 1.2135500678309687
# Early stopping, best loss:  0.9455918
# Training Model with following hyperparameters:
# {'filter1': 96, 'kernelsize_1': 4, 'filter2': 48, 'kernelsize_2': 5, 'filter3': 96, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 80, 'activation': 'relu', 'learning_rate': 0.002, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.33353846818208693  Train loss: 1.7681150436401367
# 1 Test accuracy: 0.4005  Test loss: 1.6492862
# 2 623 Train accuracy: 0.39600000753998754  Train loss: 1.6323567247390747
# 2 Test accuracy: 0.4883  Test loss: 1.3886232
# 3 623 Train accuracy: 0.4287179586291313  Train loss: 1.5481612253189088
# 3 Test accuracy: 0.5174  Test loss: 1.3245124
# 4 623 Train accuracy: 0.44430770315229895  Train loss: 1.5057492804527284
# 4 Test accuracy: 0.516  Test loss: 1.3114048
# 5 623 Train accuracy: 0.46055385905504226  Train loss: 1.4728785152435302
# 5 Test accuracy: 0.5729  Test loss: 1.1954318
# 6 623 Train accuracy: 0.4725128345191479  Train loss: 1.4400432558854421
# 6 Test accuracy: 0.5759  Test loss: 1.1560231
# 7 623 Train accuracy: 0.4833406746813229  Train loss: 1.4093319954190935
# 7 Test accuracy: 0.4758  Test loss: 1.4997054
# 8 623 Train accuracy: 0.49576924700289965  Train loss: 1.3766215664148331
# 8 Test accuracy: 0.6  Test loss: 1.1287639
# 9 623 Train accuracy: 0.5051624102393786  Train loss: 1.3540151127179463
# 9 Test accuracy: 0.5876  Test loss: 1.1414036
# 10 623 Train accuracy: 0.5140307869017124  Train loss: 1.331491960287094
# 10 Test accuracy: 0.6338  Test loss: 1.0366734
# 11 623 Train accuracy: 0.5220140040191737  Train loss: 1.3127041834050959
# 11 Test accuracy: 0.642  Test loss: 1.0113912
# 12 623 Train accuracy: 0.5315897616992394  Train loss: 1.2906616961956023
# 12 Test accuracy: 0.6397  Test loss: 1.0142379
# 13 623 Train accuracy: 0.538177533172644  Train loss: 1.2743089373295124
# 13 Test accuracy: 0.6111  Test loss: 1.1305418
# 14 623 Train accuracy: 0.5432967220246792  Train loss: 1.2598807103293284
# 14 Test accuracy: 0.6731  Test loss: 0.9250768
# 15 623 Train accuracy: 0.5488820702433587  Train loss: 1.2453677015304565
# 15 Test accuracy: 0.6426  Test loss: 1.0190622
# 16 623 Train accuracy: 0.5540000191517174  Train loss: 1.234112036526203
# 16 Test accuracy: 0.6524  Test loss: 0.9853277
# 17 623 Train accuracy: 0.5595294310240184  Train loss: 1.2195674702700448
# 17 Test accuracy: 0.6686  Test loss: 0.9490647
# 18 623 Train accuracy: 0.5635213868651126  Train loss: 1.209061860508389
# 18 Test accuracy: 0.647  Test loss: 0.9904557
# 19 623 Train accuracy: 0.56897167928909  Train loss: 1.196387921007056
# 19 Test accuracy: 0.6774  Test loss: 0.921084
# 20 623 Train accuracy: 0.5716615579277277  Train loss: 1.1878564915657044
# 20 Test accuracy: 0.6609  Test loss: 0.9619083
# 21 623 Train accuracy: 0.5747985543665431  Train loss: 1.180607422647022
# 21 Test accuracy: 0.6763  Test loss: 0.9182627
# 22 623 Train accuracy: 0.5787412783368068  Train loss: 1.171458575075323
# 22 Test accuracy: 0.6875  Test loss: 0.88817674
# 23 623 Train accuracy: 0.5808963407770447  Train loss: 1.16619928214861
# 23 Test accuracy: 0.6778  Test loss: 0.92664295
# 24 623 Train accuracy: 0.5840769428138931  Train loss: 1.1594107821583748
# 24 Test accuracy: 0.6819  Test loss: 0.8989189
# 25 623 Train accuracy: 0.5866092505574226  Train loss: 1.1530700002670289
# 25 Test accuracy: 0.6875  Test loss: 0.87770236
# 26 623 Train accuracy: 0.5893964695128111  Train loss: 1.145817804153149
# 26 Test accuracy: 0.6901  Test loss: 0.8707877
# 27 623 Train accuracy: 0.5919316437619704  Train loss: 1.1397995984112774
# 27 Test accuracy: 0.711  Test loss: 0.83412385
# 28 623 Train accuracy: 0.5940659539295094  Train loss: 1.1344769441229956
# 28 Test accuracy: 0.6954  Test loss: 0.86700135
# 29 623 Train accuracy: 0.5956923275672156  Train loss: 1.1297762876543505
# 29 Test accuracy: 0.7063  Test loss: 0.8380367
# 30 623 Train accuracy: 0.5975589942634105  Train loss: 1.1259233677387237
# 30 Test accuracy: 0.7081  Test loss: 0.83089757
# 31 623 Train accuracy: 0.6003771910840465  Train loss: 1.1188292606415287
# 31 Test accuracy: 0.7168  Test loss: 0.81908804
# 32 623 Train accuracy: 0.6020961737353354  Train loss: 1.114996612817049
# 32 Test accuracy: 0.6887  Test loss: 0.8843585
# 33 623 Train accuracy: 0.6040279919180003  Train loss: 1.1107816531441428
# 33 Test accuracy: 0.6964  Test loss: 0.8735488
# 34 623 Train accuracy: 0.6063167619442239  Train loss: 1.1047170538762037
# 34 Test accuracy: 0.7103  Test loss: 0.81644636
# 35 623 Train accuracy: 0.608017602281911  Train loss: 1.1001610736846923
# 35 Test accuracy: 0.7229  Test loss: 0.80314094
# 36 623 Train accuracy: 0.6093162592003742  Train loss: 1.096501002046797
# 36 Test accuracy: 0.6889  Test loss: 0.8818922
# 37 623 Train accuracy: 0.6108939907760234  Train loss: 1.0924602103877712
# 37 Test accuracy: 0.6933  Test loss: 0.8669694
# 38 623 Train accuracy: 0.611919048248153  Train loss: 1.0890357519450942
# 38 Test accuracy: 0.6993  Test loss: 0.85408837
# 39 623 Train accuracy: 0.6130966668633314  Train loss: 1.086096881658603
# 39 Test accuracy: 0.6927  Test loss: 0.882669
# 40 623 Train accuracy: 0.6145230968371034  Train loss: 1.0823097403645516
# Early stopping, best loss:  0.80314094
# Training Model with following hyperparameters:
# {'filter1': 16, 'kernelsize_1': 5, 'filter2': 64, 'kernelsize_2': 3, 'filter3': 64, 'kernelsize_3': 3, 'hidden_1': 125, 'hidden_2': 100, 'activation': 'elu', 'learning_rate': 0.001, 'batch_size': 64, 'momentum': 0.95, 'p_reduct': 0, 'optimizer': 'adam'}
# 1 623 Train accuracy: 0.32553846925497054  Train loss: 1.8641126823425294
# 1 Test accuracy: 0.3816  Test loss: 1.6900733
# 2 623 Train accuracy: 0.35569231525063516  Train loss: 1.7596992826461793
# 2 Test accuracy: 0.4384  Test loss: 1.538225
# 3 623 Train accuracy: 0.3755897511045138  Train loss: 1.6859981870651246
# 3 Test accuracy: 0.4665  Test loss: 1.4960328
# 4 623 Train accuracy: 0.398307701125741  Train loss: 1.6224416160583497
# 4 Test accuracy: 0.4824  Test loss: 1.4258357
# 5 623 Train accuracy: 0.4151384719014168  Train loss: 1.5889252681732178
# 5 Test accuracy: 0.5249  Test loss: 1.3162882
# 6 623 Train accuracy: 0.4304615496098995  Train loss: 1.5512975676854452
# 6 Test accuracy: 0.5098  Test loss: 1.4231879
# 7 623 Train accuracy: 0.4431648474505969  Train loss: 1.5184417384011404
# 7 Test accuracy: 0.4914  Test loss: 1.4736017
# 8 623 Train accuracy: 0.45515385959297416  Train loss: 1.4896052223443985
# 8 Test accuracy: 0.523  Test loss: 1.327868
# 9 623 Train accuracy: 0.4618803559740384  Train loss: 1.4713787900076971
# 9 Test accuracy: 0.5335  Test loss: 1.3000264
# 10 623 Train accuracy: 0.469846168667078  Train loss: 1.451045916557312
# 10 Test accuracy: 0.5874  Test loss: 1.1521404
# 11 623 Train accuracy: 0.4763077076185833  Train loss: 1.4328409771485762
# 11 Test accuracy: 0.5858  Test loss: 1.1575612
# 12 623 Train accuracy: 0.4853846312810977  Train loss: 1.4097156385580698
# 12 Test accuracy: 0.5473  Test loss: 1.2668778
# 13 623 Train accuracy: 0.49188167317555503  Train loss: 1.3952282885404734
# 13 Test accuracy: 0.4829  Test loss: 1.5114648
# 14 623 Train accuracy: 0.4960439725645951  Train loss: 1.383565845489502
# 14 Test accuracy: 0.5952  Test loss: 1.1300515
# 15 623 Train accuracy: 0.5008000168204307  Train loss: 1.370892956415812
# 15 Test accuracy: 0.6018  Test loss: 1.1358094
# 16 623 Train accuracy: 0.5053846324421465  Train loss: 1.358996345102787
# 16 Test accuracy: 0.5148  Test loss: 1.4285125
# 17 623 Train accuracy: 0.5089592934531324  Train loss: 1.3487354466494392
# 17 Test accuracy: 0.6041  Test loss: 1.1358229
# 18 623 Train accuracy: 0.5127179664538967  Train loss: 1.3391266216172113
# 18 Test accuracy: 0.5745  Test loss: 1.1915158
# 19 623 Train accuracy: 0.5170202608641825  Train loss: 1.3283489627587168
# Early stopping, best loss:  1.1300515
# time: 5h 53min 49s
